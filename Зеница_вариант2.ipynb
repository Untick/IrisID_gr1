# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/Ischenko-Ekaterina-folder/%D0%97%D0%B5%D0%BD%D0%B8%D1%86%D0%B0_%D0%B2%D0%B0%D1%80%D0%B8%D0%B0%D0%BD%D1%822.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# АЛГОРИТМ
# 1.   Загрузка данных
# 2.   Формирование датасета
# 3.   Аугментация, создание выборок
# 4.   Построение модели
# 5.   Обучение
# 6.   Подбор параметров для получения точности 97%
# 7.   Визуализация

# %% [markdown]
# ## Загрузка данных

# %%
# Сеть прямого распространения
from tensorflow.keras.models import Sequential 

# Базовые слои для свёрточных сетей
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Работа с изображениями
from tensorflow.keras.preprocessing.image import ImageDataGenerator 

# Оптимизаторы
from tensorflow.keras.optimizers import Adam     

# Используем для to_categoricall
from tensorflow.keras import utils               

# Для отрисовки изображений
from tensorflow.keras.preprocessing import image 

# Библиотека работы с массивами
import numpy as np

# Для отрисовки графиков
import matplotlib.pyplot as plt                  

# Для отрисовки изображений
from PIL import Image                            

# Для генерации случайных чисел 
import random                                    

# Для округления
import math                                      

# Для работы с файлами 
import os    
import shutil

# Для работы с файлами
import gc

# импортируем модуль для загрузки данных
import gdown 

# для разделения выборок
from sklearn.model_selection import train_test_split

# импорт tensorflow
import tensorflow as tf

# модуль для отсчета времени
import time

# %%
# Подключение гугл диска 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Задание переменных

# %%
# задание переменных
ZIP_FILE = '/content/drive/MyDrive/ZENICA/iris49_56.zip' # исходный zip-файл
TRAIN_PATH = '/content/drive/MyDrive/ZENICA/iris_base' # путь к тренировочной базе в Google Drive
TEST_PATH = '/content/drive/MyDrive/ZENICA/iris_test' # путь к тестовой базе в Google Drive

# %%
TEST_SPLIT = 0.2
VAL_SPLIT = 0.2

# %%
IMG_WIDTH           = 192 # 768                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144 #576                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %% [markdown]
# ## Формирование датасета

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_PATH} {TEST_PATH}

# Архив разархивируем в путь TRAIN_PATH
# !unzip -q {ZIP_FILE} -d {TRAIN_PATH} # Указываем путь к базе в Google Drive

# Проверяем, что в базе?
print('Проверяем, что в папке TRAIN_PATH:',os.listdir(TRAIN_PATH))

# Создаем сортированный список из базы
train_list = sorted(os.listdir(TRAIN_PATH))
print('Отсортированный список train_list:', train_list)

len_list = len(train_list)  # Длина списка

# Проверка результата
print(f'Количество файлов: {len_list}')
# Out:
# Проверяем, что в папке TRAIN_PATH: ['056R_1.png', '049L_2.png', '049L_3.png', '049R_1.png', '049R_2.png', '049R_3.png', '050L_1.png', '050L_2.png', '050L_3.png', '050R_1.png', '050R_2.png', '050R_3.png', '051L_1.png', '051L_2.png', '051L_3.png', '051R_1.png', '051R_2.png', '051R_3.png', '052L_1.png', '052L_2.png', '052L_3.png', '052R_1.png', '052R_2.png', '052R_3.png', '053L_1.png', '053L_2.png', '053L_3.png', '053R_1.png', '053R_2.png', '053R_3.png', '054L_1.png', '054L_2.png', '054L_3.png', '054R_1.png', '054R_2.png', '054R_3.png', '055L_1.png', '055L_2.png', '055L_3.png', '055R_1.png', '055R_2.png', '055R_3.png', '056L_1.png', '056L_2.png', '056L_3.png', '049L_1.png', '056R_2.png', '056R_3.png']
# Отсортированный список train_list: ['049L_1.png', '049L_2.png', '049L_3.png', '049R_1.png', '049R_2.png', '049R_3.png', '050L_1.png', '050L_2.png', '050L_3.png', '050R_1.png', '050R_2.png', '050R_3.png', '051L_1.png', '051L_2.png', '051L_3.png', '051R_1.png', '051R_2.png', '051R_3.png', '052L_1.png', '052L_2.png', '052L_3.png', '052R_1.png', '052R_2.png', '052R_3.png', '053L_1.png', '053L_2.png', '053L_3.png', '053R_1.png', '053R_2.png', '053R_3.png', '054L_1.png', '054L_2.png', '054L_3.png', '054R_1.png', '054R_2.png', '054R_3.png', '055L_1.png', '055L_2.png', '055L_3.png', '055R_1.png', '055R_2.png', '055R_3.png', '056L_1.png', '056L_2.png', '056L_3.png', '056R_1.png', '056R_2.png', '056R_3.png']
# Количество файлов: 48

# %%
# Создаем папки для каждого класса и перемещаем файлы С ГЛАЗАМИ в соответствующую папку ИХ КЛАССА
CLASS_LIST = []           # Список папок - пока пуст
for i in range(len_list):           # перебираем файлы с глазами в списке train_list
        file_name=train_list[i]      # берем название файла с глазом
        class_name = file_name[:3]  # создаем название папки из первых трех символов
        class_full_path = os.path.join(TRAIN_PATH,class_name)  # создаем полный путь к папке
        if not os.path.exists(class_full_path):                # если такой папки нет, то создаем папку
               os.makedirs(class_full_path)
               CLASS_LIST.append(class_name)
        shutil.move(os.path.join(TRAIN_PATH,file_name), class_full_path) #переносим файл с глазом в папку правильного класса
CLASS_COUNT = len(CLASS_LIST)        # получилось такое количество классов CLASS_COUNT
print(f'Создано (CLASS_COUNT):{CLASS_COUNT} папок. Названия папок классов = список CLASS_LIST: {CLASS_LIST}')
# Out:
# Создано (CLASS_COUNT):8 папок. Названия папок классов = список CLASS_LIST: ['049', '050', '051', '052', '053', '054', '055', '056']

# %%
# создание итоговых списков "путь изображения + метка класса" для обучения

# Создание директории тестовых данных
os.mkdir(TEST_PATH)                                        
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path_f = f'{TRAIN_PATH}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path_f = f'{TEST_PATH}/{class_name}'           # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path_f)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path_f)                               # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path_f}/{f}', f'{test_path_f}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 48, выделено для обучения: 40, для теста: 8

# %% [markdown]
# ## Аугментация

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 8                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.15                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.15                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.15                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.7, 1.3)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение запрещено

BATCH_SIZE          = 8                     # Размер батча
EPOCHS              = 200                   # Эпох обучения
OPTIMIZER           = Adam(0.0001)           # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную 

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, 
    subset='training'
)
# Out:
# Found 32 images belonging to 8 classes.

# %%
# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 8 images belonging to 8 classes.
# Found 8 images belonging to 8 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 144, 192, 3), (8, 8), батчей: 4
# Формы данных   проверочной выборки: (8, 144, 192, 3), (8, 8), батчей: 1
# Формы данных      тестовой выборки: (8, 144, 192, 3), (8, 8), батчей: 1
#
# Метки классов тренировочной выборки: {'049': 0, '050': 1, '051': 2, '052': 3, '053': 4, '054': 5, '055': 6, '056': 7}
# Метки классов   проверочной выборки: {'049': 0, '050': 1, '051': 2, '052': 3, '053': 4, '054': 5, '055': 6, '056': 7}
# Метки классов      тестовой выборки: {'049': 0, '050': 1, '051': 2, '052': 3, '053': 4, '054': 5, '055': 6, '056': 7}

# %%
# Проверка одного изображения из выборки
#Аугментация работает "на лету".
#Индексы для примера выбраны такие: [1][0][2], что означает:
#1: номер батча в выборке. Сам батч - это кортеж (x_train, y_train) с примерами и метками классов;
#0: первый элемент в кортеже, то есть сами изображения. Под индексом 1 будут метки классов в формате one hot encoding для изображений;
#2: номер картинки в батче.

plt.imshow(train_generator[1][0][2])
plt.show()

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25,8),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])  
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
#show_batch(train_generator[0])
show_batch(train_generator[1], range(8), columns = 4)

# %%
show_batch(validation_generator[0], range(8), columns = 4)

# %%
show_batch(test_generator[0], range(8), columns = 4)

# %% [markdown]
# ## Создание и обучение модели нейронной сети

# %% [markdown]
# ### Сервисные функции

# %%
# Функция компиляции и обучения модели нейронной сети
# По окончанию выводит графики обучения

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    # Вывод сводки
    model.summary()

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция вывода результатов оценки модели на заданных данных

def eval_model(model, 
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(10, 10)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    plt.show()    

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Формируется сообщение о верности или неверности предсказания
        msg = 'ВЕРНО :-)' if cls_pred == cls else 'НЕВЕРНО :-('
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model, 
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1], 
               class_labels=class_labels, 
               title=title,
               figsize=cm_size)

# %% [markdown]
# ### Архитектура модели нейронной сети

# %%
# Создание последовательной модели
model_conv = Sequential()

# Первый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model_conv.add(BatchNormalization())

# Второй сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())
model_conv.add(Dropout(0.2))

# Четвертый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Пятый сверточный слой
model_conv.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())

# Шестой сверточный слой
model_conv.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Слой преобразования многомерных данных в одномерные 
model_conv.add(Flatten())

# Промежуточный полносвязный слой
model_conv.add(Dense(2048, activation='relu'))

# Промежуточный полносвязный слой
model_conv.add(Dense(4096, activation='relu'))

# Выходной полносвязный слой с количеством нейронов по количеству классов
model_conv.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model_conv,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         title='Сверточный классификатор')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 144, 192, 256)     7168
#
#  batch_normalization (BatchN  (None, 144, 192, 256)    1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 144, 192, 256)     590080
#
#  max_pooling2d (MaxPooling2D  (None, 48, 64, 256)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 48, 64, 256)       590080
#
#  batch_normalization_1 (Batc  (None, 48, 64, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 48, 64, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 48, 64, 256)       590080
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 21, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 21, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 16, 21, 512)       1180160
#
#  batch_normalization_2 (Batc  (None, 16, 21, 512)      2048
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 16, 21, 1024)      4719616
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 7, 1024)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 5, 7, 1024)        0
#
#  flatten (Flatten)           (None, 35840)             0
#
#  dense (Dense)               (None, 2048)              73402368
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  dense_2 (Dense)             (None, 8)                 32776
#
# =================================================================
# Total params: 89,509,128
# Trainable params: 89,507,080
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/200
# 4/4 [==============================] - 21s 489ms/step - loss: 13.8030 - accuracy: 0.0625 - val_loss: 2.0803 - val_accuracy: 0.1250
# Epoch 2/200
# 4/4 [==============================] - 2s 387ms/step - loss: 10.1912 - accuracy: 0.0625 - val_loss: 2.0809 - val_accuracy: 0.1250
# Epoch 3/200
# 4/4 [==============================] - 2s 476ms/step - loss: 5.0949 - accuracy: 0.0625 - val_loss: 2.0836 - val_accuracy: 0.2500
# Epoch 4/200
# 4/4 [==============================] - 2s 431ms/step - loss: 4.2685 - accuracy: 0.1875 - val_loss: 2.0934 - val_accuracy: 0.1250
# Epoch 5/200
# 4/4 [==============================] - 1s 343ms/step - loss: 3.6555 - accuracy: 0.2500 - val_loss: 2.0805 - val_accuracy: 0.1250
# Epoch 6/200
# 4/4 [==============================] - 1s 342ms/step - loss: 2.3781 - accuracy: 0.2188 - val_loss: 2.0793 - val_accuracy: 0.1250
# Epoch 7/200
# 4/4 [==============================] - 1s 342ms/step - loss: 2.6912 - accuracy: 0.1562 - val_loss: 2.0778 - val_accuracy: 0.1250
# Epoch 8/200
# 4/4 [==============================] - 1s 346ms/step - loss: 2.0116 - accuracy: 0.2812 - val_loss: 2.0841 - val_accuracy: 0.1250
# Epoch 9/200
# 4/4 [==============================] - 1s 344ms/step - loss: 1.9886 - accuracy: 0.2500 - val_loss: 2.0680 - val_accuracy: 0.1250
# Epoch 10/200
# 4/4 [==============================] - 1s 361ms/step - loss: 1.8510 - accuracy: 0.3750 - val_loss: 2.0678 - val_accuracy: 0.1250
# Epoch 11/200
# 4/4 [==============================] - 2s 573ms/step - loss: 1.9637 - accuracy: 0.3125 - val_loss: 2.1059 - val_accuracy: 0.1250
# Epoch 12/200
# 4/4 [==============================] - 1s 340ms/step - loss: 1.6604 - accuracy: 0.4375 - val_loss: 2.1349 - val_accuracy: 0.1250
# Epoch 13/200
# 4/4 [==============================] - 1s 345ms/step - loss: 2.0033 - accuracy: 0.4062 - val_loss: 2.1289 - val_accuracy: 0.1250
# Epoch 14/200
# 4/4 [==============================] - 1s 340ms/step - loss: 1.8917 - accuracy: 0.2500 - val_loss: 2.1962 - val_accuracy: 0.1250
# Epoch 15/200
# 4/4 [==============================] - 1s 357ms/step - loss: 1.2592 - accuracy: 0.5312 - val_loss: 2.3333 - val_accuracy: 0.1250
# Epoch 16/200
# 4/4 [==============================] - 1s 346ms/step - loss: 1.3819 - accuracy: 0.5000 - val_loss: 2.3048 - val_accuracy: 0.1250
# Epoch 17/200
# 4/4 [==============================] - 2s 462ms/step - loss: 1.1907 - accuracy: 0.5312 - val_loss: 2.2648 - val_accuracy: 0.1250
# Epoch 18/200
# 4/4 [==============================] - 2s 449ms/step - loss: 1.1471 - accuracy: 0.5000 - val_loss: 2.3717 - val_accuracy: 0.1250
# Epoch 19/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.9211 - accuracy: 0.6250 - val_loss: 2.5168 - val_accuracy: 0.1250
# Epoch 20/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.9279 - accuracy: 0.6562 - val_loss: 2.5808 - val_accuracy: 0.1250
# Epoch 21/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.9280 - accuracy: 0.6875 - val_loss: 2.5664 - val_accuracy: 0.1250
# Epoch 22/200
# 4/4 [==============================] - 1s 336ms/step - loss: 0.9247 - accuracy: 0.5938 - val_loss: 2.6661 - val_accuracy: 0.1250
# Epoch 23/200
# 4/4 [==============================] - 3s 752ms/step - loss: 0.7198 - accuracy: 0.7500 - val_loss: 2.6579 - val_accuracy: 0.1250
# Epoch 24/200
# 4/4 [==============================] - 3s 656ms/step - loss: 0.6165 - accuracy: 0.6875 - val_loss: 3.0762 - val_accuracy: 0.1250
# Epoch 25/200
# 4/4 [==============================] - 2s 360ms/step - loss: 0.5845 - accuracy: 0.7812 - val_loss: 3.2532 - val_accuracy: 0.1250
# Epoch 26/200
# 4/4 [==============================] - 2s 356ms/step - loss: 0.5019 - accuracy: 0.7812 - val_loss: 3.2152 - val_accuracy: 0.1250
# Epoch 27/200
# 4/4 [==============================] - 1s 358ms/step - loss: 0.5222 - accuracy: 0.7500 - val_loss: 3.5632 - val_accuracy: 0.1250
# Epoch 28/200
# 4/4 [==============================] - 1s 357ms/step - loss: 0.7582 - accuracy: 0.6875 - val_loss: 3.1852 - val_accuracy: 0.1250
# Epoch 29/200
# 4/4 [==============================] - 1s 352ms/step - loss: 0.6285 - accuracy: 0.8125 - val_loss: 2.9255 - val_accuracy: 0.1250
# Epoch 30/200
# 4/4 [==============================] - 2s 539ms/step - loss: 1.0744 - accuracy: 0.7812 - val_loss: 3.3509 - val_accuracy: 0.1250
# Epoch 31/200
# 4/4 [==============================] - 2s 499ms/step - loss: 0.5584 - accuracy: 0.8750 - val_loss: 3.2787 - val_accuracy: 0.1250
# Epoch 32/200
# 4/4 [==============================] - 2s 360ms/step - loss: 0.5265 - accuracy: 0.8438 - val_loss: 3.2493 - val_accuracy: 0.1250
# Epoch 33/200
# 4/4 [==============================] - 2s 355ms/step - loss: 0.6526 - accuracy: 0.7500 - val_loss: 3.7331 - val_accuracy: 0.1250
# Epoch 34/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.5189 - accuracy: 0.8125 - val_loss: 3.5138 - val_accuracy: 0.1250
# Epoch 35/200
# 4/4 [==============================] - 1s 341ms/step - loss: 0.4962 - accuracy: 0.8438 - val_loss: 3.3181 - val_accuracy: 0.1250
# Epoch 36/200
# 4/4 [==============================] - 2s 480ms/step - loss: 0.6749 - accuracy: 0.8438 - val_loss: 3.7251 - val_accuracy: 0.1250
# Epoch 37/200
# 4/4 [==============================] - 1s 356ms/step - loss: 0.4093 - accuracy: 0.9062 - val_loss: 3.3719 - val_accuracy: 0.1250
# Epoch 38/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.5830 - accuracy: 0.8125 - val_loss: 3.5134 - val_accuracy: 0.2500
# Epoch 39/200
# 4/4 [==============================] - 1s 338ms/step - loss: 1.1036 - accuracy: 0.7188 - val_loss: 4.5608 - val_accuracy: 0.1250
# Epoch 40/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.5637 - accuracy: 0.7500 - val_loss: 5.2288 - val_accuracy: 0.1250
# Epoch 41/200
# 4/4 [==============================] - 1s 343ms/step - loss: 1.3368 - accuracy: 0.6562 - val_loss: 5.3704 - val_accuracy: 0.1250
# Epoch 42/200
# 4/4 [==============================] - 1s 360ms/step - loss: 0.5255 - accuracy: 0.8438 - val_loss: 2.9477 - val_accuracy: 0.1250
# Epoch 43/200
# 4/4 [==============================] - 2s 481ms/step - loss: 0.2806 - accuracy: 0.9375 - val_loss: 3.4970 - val_accuracy: 0.1250
# Epoch 44/200
# 4/4 [==============================] - 2s 484ms/step - loss: 0.6487 - accuracy: 0.8125 - val_loss: 3.9141 - val_accuracy: 0.2500
# Epoch 45/200
# 4/4 [==============================] - 1s 352ms/step - loss: 0.4755 - accuracy: 0.7812 - val_loss: 3.6825 - val_accuracy: 0.1250
# Epoch 46/200
# 4/4 [==============================] - 1s 355ms/step - loss: 0.3153 - accuracy: 0.8750 - val_loss: 3.5814 - val_accuracy: 0.1250
# Epoch 47/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.5196 - accuracy: 0.8438 - val_loss: 4.5762 - val_accuracy: 0.1250
# Epoch 48/200
# 4/4 [==============================] - 1s 353ms/step - loss: 0.7043 - accuracy: 0.7812 - val_loss: 4.5418 - val_accuracy: 0.1250
# Epoch 49/200
# 4/4 [==============================] - 2s 361ms/step - loss: 0.2918 - accuracy: 0.9062 - val_loss: 4.6139 - val_accuracy: 0.1250
# Epoch 50/200
# 4/4 [==============================] - 2s 561ms/step - loss: 0.4663 - accuracy: 0.8750 - val_loss: 5.3772 - val_accuracy: 0.1250
# Epoch 51/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.5181 - accuracy: 0.9062 - val_loss: 6.8950 - val_accuracy: 0.1250
# Epoch 52/200
# 4/4 [==============================] - 1s 349ms/step - loss: 0.3193 - accuracy: 0.8750 - val_loss: 8.2638 - val_accuracy: 0.1250
# Epoch 53/200
# 4/4 [==============================] - 1s 352ms/step - loss: 0.1095 - accuracy: 0.9688 - val_loss: 7.2622 - val_accuracy: 0.1250
# Epoch 54/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.6970 - accuracy: 0.8125 - val_loss: 7.5605 - val_accuracy: 0.1250
# Epoch 55/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.4163 - accuracy: 0.9062 - val_loss: 8.1479 - val_accuracy: 0.1250
# Epoch 56/200
# 4/4 [==============================] - 2s 450ms/step - loss: 0.2048 - accuracy: 0.9062 - val_loss: 7.8164 - val_accuracy: 0.1250
# Epoch 57/200
# 4/4 [==============================] - 2s 463ms/step - loss: 0.4128 - accuracy: 0.8750 - val_loss: 8.3300 - val_accuracy: 0.1250
# Epoch 58/200
# 4/4 [==============================] - 2s 378ms/step - loss: 0.1966 - accuracy: 0.9375 - val_loss: 7.5601 - val_accuracy: 0.1250
# Epoch 59/200
# 4/4 [==============================] - 1s 358ms/step - loss: 0.3213 - accuracy: 0.8750 - val_loss: 5.7969 - val_accuracy: 0.1250
# Epoch 60/200
# 4/4 [==============================] - 1s 337ms/step - loss: 0.2626 - accuracy: 0.9062 - val_loss: 5.0627 - val_accuracy: 0.1250
# Epoch 61/200
# 4/4 [==============================] - 1s 339ms/step - loss: 0.1270 - accuracy: 0.9375 - val_loss: 5.2449 - val_accuracy: 0.1250
# Epoch 62/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.3260 - accuracy: 0.8438 - val_loss: 5.6870 - val_accuracy: 0.1250
# Epoch 63/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.8053 - accuracy: 0.8438 - val_loss: 6.5726 - val_accuracy: 0.1250
# Epoch 64/200
# 4/4 [==============================] - 2s 401ms/step - loss: 0.6064 - accuracy: 0.8125 - val_loss: 5.7349 - val_accuracy: 0.1250
# Epoch 65/200
# 4/4 [==============================] - 2s 459ms/step - loss: 0.8695 - accuracy: 0.8438 - val_loss: 5.3236 - val_accuracy: 0.1250
# Epoch 66/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.1173 - accuracy: 0.9375 - val_loss: 5.9403 - val_accuracy: 0.1250
# Epoch 67/200
# 4/4 [==============================] - 2s 362ms/step - loss: 0.6763 - accuracy: 0.7500 - val_loss: 7.2407 - val_accuracy: 0.1250
# Epoch 68/200
# 4/4 [==============================] - 1s 350ms/step - loss: 0.3047 - accuracy: 0.8438 - val_loss: 6.7789 - val_accuracy: 0.1250
# Epoch 69/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.3338 - accuracy: 0.8750 - val_loss: 5.1334 - val_accuracy: 0.2500
# Epoch 70/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.2213 - accuracy: 0.9375 - val_loss: 4.9704 - val_accuracy: 0.1250
# Epoch 71/200
# 4/4 [==============================] - 2s 436ms/step - loss: 0.3660 - accuracy: 0.9062 - val_loss: 5.2354 - val_accuracy: 0.1250
# Epoch 72/200
# 4/4 [==============================] - 2s 547ms/step - loss: 0.4677 - accuracy: 0.8750 - val_loss: 6.3914 - val_accuracy: 0.1250
# Epoch 73/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.2254 - accuracy: 0.8750 - val_loss: 7.8370 - val_accuracy: 0.1250
# Epoch 74/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.4964 - accuracy: 0.8125 - val_loss: 4.9550 - val_accuracy: 0.1250
# Epoch 75/200
# 4/4 [==============================] - 1s 348ms/step - loss: 0.1329 - accuracy: 0.9375 - val_loss: 4.2628 - val_accuracy: 0.2500
# Epoch 76/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.4356 - accuracy: 0.9375 - val_loss: 4.6440 - val_accuracy: 0.2500
# Epoch 77/200
# 4/4 [==============================] - 1s 335ms/step - loss: 0.1594 - accuracy: 0.9375 - val_loss: 6.2263 - val_accuracy: 0.1250
# Epoch 78/200
# 4/4 [==============================] - 2s 567ms/step - loss: 0.1378 - accuracy: 0.9688 - val_loss: 7.4531 - val_accuracy: 0.1250
# Epoch 79/200
# 4/4 [==============================] - 1s 343ms/step - loss: 0.1018 - accuracy: 0.9375 - val_loss: 6.4614 - val_accuracy: 0.1250
# Epoch 80/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.1477 - accuracy: 0.9375 - val_loss: 5.8145 - val_accuracy: 0.1250
# Epoch 81/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.3452 - accuracy: 0.8438 - val_loss: 6.5565 - val_accuracy: 0.2500
# Epoch 82/200
# 4/4 [==============================] - 1s 351ms/step - loss: 0.2836 - accuracy: 0.9062 - val_loss: 7.7913 - val_accuracy: 0.1250
# Epoch 83/200
# 4/4 [==============================] - 1s 359ms/step - loss: 0.0705 - accuracy: 0.9688 - val_loss: 8.2954 - val_accuracy: 0.1250
# Epoch 84/200
# 4/4 [==============================] - 2s 542ms/step - loss: 0.1352 - accuracy: 0.8750 - val_loss: 8.7500 - val_accuracy: 0.1250
# Epoch 85/200
# 4/4 [==============================] - 2s 422ms/step - loss: 0.0358 - accuracy: 1.0000 - val_loss: 8.5276 - val_accuracy: 0.1250
# Epoch 86/200
# 4/4 [==============================] - 1s 337ms/step - loss: 0.1391 - accuracy: 0.9062 - val_loss: 8.6126 - val_accuracy: 0.1250
# Epoch 87/200
# 4/4 [==============================] - 1s 339ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 10.1800 - val_accuracy: 0.1250
# Epoch 88/200
# 4/4 [==============================] - 1s 338ms/step - loss: 0.2965 - accuracy: 0.9062 - val_loss: 10.2132 - val_accuracy: 0.1250
# Epoch 89/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.1223 - accuracy: 0.9062 - val_loss: 7.6432 - val_accuracy: 0.1250
# Epoch 90/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.2417 - accuracy: 0.9375 - val_loss: 6.8395 - val_accuracy: 0.1250
# Epoch 91/200
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 7.6122 - val_accuracy: 0.1250
# Epoch 92/200
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0909 - accuracy: 0.9688 - val_loss: 8.9988 - val_accuracy: 0.1250
# Epoch 93/200
# 4/4 [==============================] - 1s 344ms/step - loss: 0.1380 - accuracy: 0.9375 - val_loss: 11.1940 - val_accuracy: 0.1250
# Epoch 94/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0994 - accuracy: 1.0000 - val_loss: 10.9583 - val_accuracy: 0.1250
# Epoch 95/200
# 4/4 [==============================] - 1s 350ms/step - loss: 0.2384 - accuracy: 0.9375 - val_loss: 10.1076 - val_accuracy: 0.1250
# Epoch 96/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 9.7195 - val_accuracy: 0.1250
# Epoch 97/200
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0379 - accuracy: 0.9688 - val_loss: 9.6346 - val_accuracy: 0.1250
# Epoch 98/200
# 4/4 [==============================] - 2s 579ms/step - loss: 0.1382 - accuracy: 0.9062 - val_loss: 10.4832 - val_accuracy: 0.1250
# Epoch 99/200
# 4/4 [==============================] - 2s 442ms/step - loss: 0.3140 - accuracy: 0.9375 - val_loss: 10.1170 - val_accuracy: 0.1250
# Epoch 100/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 9.2157 - val_accuracy: 0.1250
# Epoch 101/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.3250 - accuracy: 0.8750 - val_loss: 10.7984 - val_accuracy: 0.1250
# Epoch 102/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.1583 - accuracy: 0.9375 - val_loss: 13.9404 - val_accuracy: 0.1250
# Epoch 103/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.7107 - accuracy: 0.7812 - val_loss: 13.4793 - val_accuracy: 0.1250
# Epoch 104/200
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 11.3408 - val_accuracy: 0.1250
# Epoch 105/200
# 4/4 [==============================] - 2s 565ms/step - loss: 0.1514 - accuracy: 0.9062 - val_loss: 8.1270 - val_accuracy: 0.1250
# Epoch 106/200
# 4/4 [==============================] - 2s 606ms/step - loss: 0.3909 - accuracy: 0.8750 - val_loss: 5.9645 - val_accuracy: 0.2500
# Epoch 107/200
# 4/4 [==============================] - 2s 575ms/step - loss: 0.5589 - accuracy: 0.8438 - val_loss: 7.1838 - val_accuracy: 0.2500
# Epoch 108/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.3470 - accuracy: 0.8750 - val_loss: 8.9268 - val_accuracy: 0.2500
# Epoch 109/200
# 4/4 [==============================] - 1s 357ms/step - loss: 0.2302 - accuracy: 0.9062 - val_loss: 8.1888 - val_accuracy: 0.2500
# Epoch 110/200
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0675 - accuracy: 0.9688 - val_loss: 7.0786 - val_accuracy: 0.2500
# Epoch 111/200
# 4/4 [==============================] - 1s 351ms/step - loss: 0.2489 - accuracy: 0.9062 - val_loss: 6.4035 - val_accuracy: 0.2500
# Epoch 112/200
# 4/4 [==============================] - 2s 472ms/step - loss: 0.0589 - accuracy: 1.0000 - val_loss: 6.4261 - val_accuracy: 0.2500
# Epoch 113/200
# 4/4 [==============================] - 2s 438ms/step - loss: 0.2019 - accuracy: 0.9062 - val_loss: 6.3724 - val_accuracy: 0.2500
# Epoch 114/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.1712 - accuracy: 0.9375 - val_loss: 6.2927 - val_accuracy: 0.2500
# Epoch 115/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.0930 - accuracy: 0.9375 - val_loss: 5.3084 - val_accuracy: 0.2500
# Epoch 116/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.4406 - accuracy: 0.9375 - val_loss: 3.9860 - val_accuracy: 0.2500
# Epoch 117/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.2771 - accuracy: 0.9062 - val_loss: 5.8513 - val_accuracy: 0.2500
# Epoch 118/200
# 4/4 [==============================] - 1s 351ms/step - loss: 0.1065 - accuracy: 0.9375 - val_loss: 6.0038 - val_accuracy: 0.2500
# Epoch 119/200
# 4/4 [==============================] - 2s 560ms/step - loss: 0.0692 - accuracy: 0.9688 - val_loss: 6.4593 - val_accuracy: 0.2500
# Epoch 120/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.3238 - accuracy: 0.9062 - val_loss: 5.5382 - val_accuracy: 0.1250
# Epoch 121/200
# 4/4 [==============================] - 1s 351ms/step - loss: 0.0579 - accuracy: 0.9688 - val_loss: 6.1502 - val_accuracy: 0.1250
# Epoch 122/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.2735 - accuracy: 0.8750 - val_loss: 5.8490 - val_accuracy: 0.2500
# Epoch 123/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.2168 - accuracy: 0.9688 - val_loss: 8.1040 - val_accuracy: 0.2500
# Epoch 124/200
# 4/4 [==============================] - 1s 341ms/step - loss: 0.4012 - accuracy: 0.9062 - val_loss: 6.8994 - val_accuracy: 0.2500
# Epoch 125/200
# 4/4 [==============================] - 2s 447ms/step - loss: 0.2272 - accuracy: 0.9062 - val_loss: 5.2443 - val_accuracy: 0.3750
# Epoch 126/200
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1354 - accuracy: 0.9062 - val_loss: 4.5137 - val_accuracy: 0.3750
# Epoch 127/200
# 4/4 [==============================] - 1s 355ms/step - loss: 0.2220 - accuracy: 0.9375 - val_loss: 5.9432 - val_accuracy: 0.3750
# Epoch 128/200
# 4/4 [==============================] - 1s 355ms/step - loss: 0.3253 - accuracy: 0.9062 - val_loss: 8.3087 - val_accuracy: 0.1250
# Epoch 129/200
# 4/4 [==============================] - 1s 351ms/step - loss: 0.1331 - accuracy: 0.9688 - val_loss: 9.0825 - val_accuracy: 0.1250
# Epoch 130/200
# 4/4 [==============================] - 1s 341ms/step - loss: 0.1577 - accuracy: 0.9375 - val_loss: 8.6955 - val_accuracy: 0.1250
# Epoch 131/200
# 4/4 [==============================] - 1s 339ms/step - loss: 0.5627 - accuracy: 0.9062 - val_loss: 10.3497 - val_accuracy: 0.1250
# Epoch 132/200
# 4/4 [==============================] - 2s 500ms/step - loss: 0.1838 - accuracy: 0.9375 - val_loss: 4.6374 - val_accuracy: 0.2500
# Epoch 133/200
# 4/4 [==============================] - 2s 560ms/step - loss: 0.2845 - accuracy: 0.9062 - val_loss: 4.9258 - val_accuracy: 0.2500
# Epoch 134/200
# 4/4 [==============================] - 2s 339ms/step - loss: 0.2916 - accuracy: 0.9375 - val_loss: 3.5271 - val_accuracy: 0.5000
# Epoch 135/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.4656 - accuracy: 0.9375 - val_loss: 3.5879 - val_accuracy: 0.6250
# Epoch 136/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0825 - accuracy: 0.9688 - val_loss: 3.5766 - val_accuracy: 0.6250
# Epoch 137/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.3325 - accuracy: 0.9062 - val_loss: 4.0582 - val_accuracy: 0.3750
# Epoch 138/200
# 4/4 [==============================] - 1s 353ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 5.3117 - val_accuracy: 0.2500
# Epoch 139/200
# 4/4 [==============================] - 2s 401ms/step - loss: 0.9700 - accuracy: 0.8750 - val_loss: 2.2338 - val_accuracy: 0.2500
# Epoch 140/200
# 4/4 [==============================] - 2s 467ms/step - loss: 0.1039 - accuracy: 0.9688 - val_loss: 1.7406 - val_accuracy: 0.6250
# Epoch 141/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.8333 - accuracy: 0.8750 - val_loss: 1.5217 - val_accuracy: 0.5000
# Epoch 142/200
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0718 - accuracy: 0.9688 - val_loss: 4.4619 - val_accuracy: 0.2500
# Epoch 143/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0897 - accuracy: 0.9688 - val_loss: 5.8146 - val_accuracy: 0.3750
# Epoch 144/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.5338 - accuracy: 0.9688 - val_loss: 4.8820 - val_accuracy: 0.3750
# Epoch 145/200
# 4/4 [==============================] - 1s 357ms/step - loss: 0.3454 - accuracy: 0.9062 - val_loss: 3.4320 - val_accuracy: 0.5000
# Epoch 146/200
# 4/4 [==============================] - 2s 562ms/step - loss: 0.0837 - accuracy: 0.9688 - val_loss: 3.9276 - val_accuracy: 0.5000
# Epoch 147/200
# 4/4 [==============================] - 2s 426ms/step - loss: 0.2974 - accuracy: 0.9062 - val_loss: 4.2479 - val_accuracy: 0.3750
# Epoch 148/200
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0843 - accuracy: 1.0000 - val_loss: 5.0939 - val_accuracy: 0.2500
# Epoch 149/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.1159 - accuracy: 0.9688 - val_loss: 2.7277 - val_accuracy: 0.5000
# Epoch 150/200
# 4/4 [==============================] - 1s 338ms/step - loss: 0.0596 - accuracy: 0.9688 - val_loss: 1.9406 - val_accuracy: 0.7500
# Epoch 151/200
# 4/4 [==============================] - 1s 348ms/step - loss: 0.2065 - accuracy: 0.9688 - val_loss: 0.6420 - val_accuracy: 0.6250
# Epoch 152/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.2182 - accuracy: 0.9375 - val_loss: 0.8847 - val_accuracy: 0.7500
# Epoch 153/200
# 4/4 [==============================] - 2s 362ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.7268 - val_accuracy: 0.6250
# Epoch 154/200
# 4/4 [==============================] - 2s 567ms/step - loss: 0.2879 - accuracy: 0.9375 - val_loss: 2.3880 - val_accuracy: 0.5000
# Epoch 155/200
# 4/4 [==============================] - 2s 418ms/step - loss: 0.1068 - accuracy: 0.9688 - val_loss: 3.0465 - val_accuracy: 0.5000
# Epoch 156/200
# 4/4 [==============================] - 1s 350ms/step - loss: 0.1740 - accuracy: 0.9375 - val_loss: 2.6080 - val_accuracy: 0.3750
# Epoch 157/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 1.4080 - val_accuracy: 0.6250
# Epoch 158/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.3017 - val_accuracy: 0.6250
# Epoch 159/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.2762 - val_accuracy: 0.6250
# Epoch 160/200
# 4/4 [==============================] - 2s 363ms/step - loss: 0.1183 - accuracy: 0.9688 - val_loss: 1.5431 - val_accuracy: 0.6250
# Epoch 161/200
# 4/4 [==============================] - 2s 577ms/step - loss: 0.1463 - accuracy: 0.9375 - val_loss: 2.2652 - val_accuracy: 0.6250
# Epoch 162/200
# 4/4 [==============================] - 2s 413ms/step - loss: 0.2351 - accuracy: 0.9688 - val_loss: 1.0463 - val_accuracy: 0.7500
# Epoch 163/200
# 4/4 [==============================] - 1s 354ms/step - loss: 0.3251 - accuracy: 0.9062 - val_loss: 0.6508 - val_accuracy: 0.6250
# Epoch 164/200
# 4/4 [==============================] - 1s 340ms/step - loss: 0.1463 - accuracy: 0.9375 - val_loss: 3.2712 - val_accuracy: 0.7500
# Epoch 165/200
# 4/4 [==============================] - 1s 348ms/step - loss: 0.2489 - accuracy: 0.9062 - val_loss: 1.7700 - val_accuracy: 0.6250
# Epoch 166/200
# 4/4 [==============================] - 1s 341ms/step - loss: 0.1684 - accuracy: 0.9375 - val_loss: 0.7240 - val_accuracy: 0.7500
# Epoch 167/200
# 4/4 [==============================] - 2s 366ms/step - loss: 0.2207 - accuracy: 0.9688 - val_loss: 4.4021 - val_accuracy: 0.3750
# Epoch 168/200
# 4/4 [==============================] - 2s 554ms/step - loss: 0.2446 - accuracy: 0.9062 - val_loss: 4.5718 - val_accuracy: 0.2500
# Epoch 169/200
# 4/4 [==============================] - 2s 411ms/step - loss: 0.4967 - accuracy: 0.9062 - val_loss: 6.0950 - val_accuracy: 0.5000
# Epoch 170/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0743 - accuracy: 0.9688 - val_loss: 5.3453 - val_accuracy: 0.3750
# Epoch 171/200
# 4/4 [==============================] - 1s 353ms/step - loss: 0.2685 - accuracy: 0.9062 - val_loss: 3.8302 - val_accuracy: 0.3750
# Epoch 172/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0889 - accuracy: 0.9375 - val_loss: 2.7538 - val_accuracy: 0.5000
# Epoch 173/200
# 4/4 [==============================] - 1s 352ms/step - loss: 0.1940 - accuracy: 0.9375 - val_loss: 2.6935 - val_accuracy: 0.7500
# Epoch 174/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.0685 - accuracy: 0.9688 - val_loss: 2.3685 - val_accuracy: 0.6250
# Epoch 175/200
# 4/4 [==============================] - 2s 394ms/step - loss: 0.2378 - accuracy: 0.9375 - val_loss: 2.2532 - val_accuracy: 0.5000
# Epoch 176/200
# 4/4 [==============================] - 2s 457ms/step - loss: 0.1206 - accuracy: 0.9375 - val_loss: 2.3519 - val_accuracy: 0.6250
# Epoch 177/200
# 4/4 [==============================] - 1s 342ms/step - loss: 0.1988 - accuracy: 0.9375 - val_loss: 0.5675 - val_accuracy: 0.7500
# Epoch 178/200
# 4/4 [==============================] - 1s 343ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 1.9043 - val_accuracy: 0.7500
# Epoch 179/200
# 4/4 [==============================] - 1s 344ms/step - loss: 0.1225 - accuracy: 0.9375 - val_loss: 2.2800 - val_accuracy: 0.6250
# Epoch 180/200
# 4/4 [==============================] - 1s 348ms/step - loss: 0.3118 - accuracy: 0.8750 - val_loss: 3.6962 - val_accuracy: 0.7500
# Epoch 181/200
# 4/4 [==============================] - 2s 502ms/step - loss: 0.0910 - accuracy: 0.9375 - val_loss: 1.9062 - val_accuracy: 0.6250
# Epoch 182/200
# 4/4 [==============================] - 2s 465ms/step - loss: 0.2467 - accuracy: 0.9375 - val_loss: 1.6979 - val_accuracy: 0.6250
# Epoch 183/200
# 4/4 [==============================] - 1s 350ms/step - loss: 0.1743 - accuracy: 0.9688 - val_loss: 1.2058 - val_accuracy: 0.7500
# Epoch 184/200
# 4/4 [==============================] - 1s 339ms/step - loss: 0.2351 - accuracy: 0.9375 - val_loss: 1.9162 - val_accuracy: 0.5000
# Epoch 185/200
# 4/4 [==============================] - 1s 341ms/step - loss: 0.2600 - accuracy: 0.9375 - val_loss: 2.4957 - val_accuracy: 0.3750
# Epoch 186/200
# 4/4 [==============================] - 1s 341ms/step - loss: 0.2673 - accuracy: 0.9062 - val_loss: 1.0937 - val_accuracy: 0.8750
# Epoch 187/200
# 4/4 [==============================] - 1s 349ms/step - loss: 0.3023 - accuracy: 0.8750 - val_loss: 3.7634 - val_accuracy: 0.6250
# Epoch 188/200
# 4/4 [==============================] - 2s 401ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 6.8137 - val_accuracy: 0.6250
# Epoch 189/200
# 4/4 [==============================] - 2s 478ms/step - loss: 0.0886 - accuracy: 0.9688 - val_loss: 8.1726 - val_accuracy: 0.6250
# Epoch 190/200
# 4/4 [==============================] - 1s 350ms/step - loss: 0.2397 - accuracy: 0.9062 - val_loss: 1.0131 - val_accuracy: 0.8750
# Epoch 191/200
# 4/4 [==============================] - 2s 363ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.7500
# Epoch 192/200
# 4/4 [==============================] - 1s 349ms/step - loss: 0.3846 - accuracy: 0.9375 - val_loss: 0.5330 - val_accuracy: 0.8750
# Epoch 193/200
# 4/4 [==============================] - 1s 344ms/step - loss: 0.2895 - accuracy: 0.9375 - val_loss: 0.3862 - val_accuracy: 0.8750
# Epoch 194/200
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0639 - accuracy: 0.9375 - val_loss: 1.4564 - val_accuracy: 0.7500
# Epoch 195/200
# 4/4 [==============================] - 1s 346ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.2076 - val_accuracy: 0.6250
# Epoch 196/200
# 4/4 [==============================] - 2s 544ms/step - loss: 0.1223 - accuracy: 0.9062 - val_loss: 2.8610 - val_accuracy: 0.6250
# Epoch 197/200
# 4/4 [==============================] - 2s 481ms/step - loss: 0.1245 - accuracy: 0.9375 - val_loss: 1.0411 - val_accuracy: 0.8750
# Epoch 198/200
# 4/4 [==============================] - 2s 348ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 3.5202 - val_accuracy: 0.6250
# Epoch 199/200
# 4/4 [==============================] - 1s 345ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.3105 - val_accuracy: 0.7500
# Epoch 200/200
# 4/4 [==============================] - 1s 343ms/step - loss: 0.2206 - accuracy: 0.9375 - val_loss: 3.0460 - val_accuracy: 0.6250
# 1/1 [==============================] - 0s 163ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-125707e6ab88> in <cell line: 2>()
#       1 # Обучение модели и вывод оценки ее работы на тестовых данных
# ----> 2 compile_train_eval_model(model_conv,
#       3                          train_generator,
#       4                          validation_generator,
#       5                          test_generator,
#
# <ipython-input-23-a438d784290f> in compile_train_eval_model(model, train_data, val_data, test_data, class_labels, title, optimizer, epochs, batch_size, graph_size, cm_size)
#      25
#      26     # Вывод результатов оценки работы модели на тестовых данных
# ---> 27     eval_model(model, test_data[0][0], test_data[0][1],
#      28                class_labels=class_labels,
#      29                title=title,
#
# <ipython-input-22-3fe6bd911758> in eval_model(model, x, y_true, class_labels, cm_round, title, figsize)
#      12     y_pred = model.predict(x)
#      13     # Построение матрицы ошибок
# ---> 14     cm = confusion_matrix(np.argmax(y_true, axis=1),
#      15                           np.argmax(y_pred, axis=1),
#      16                           normalize='true')
#
# NameError: name 'confusion_matrix' is not defined
