# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/Ischenko-Ekaterina-folder/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B5%D0%BD%D0%B8%D1%86%D0%B0_64_%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D0%B0_97pr_2023_07_02_%D0%B1%D0%BE%D0%BB%D1%8C%D1%88%D0%B5_%D1%84%D0%B8%D0%BB%D1%8C%D1%82%D1%80%D0%BE%D0%B2_%D0%B8_%D0%B4%D0%B2%D0%B0_%D1%82%D0%B5%D1%81%D1%82%D0%B0%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# АЛГОРИТМ
# 1.   Загрузка данных
# 2.   Формирование датасета
# 3.   Аугментация, создание выборок
# 4.   Построение модели
# 5.   Обучение
# 6.   Подбор параметров для получения точности 97%
# 7.   Визуализация

# %% [markdown]
# ## Загрузка данных

# %%
# Сеть прямого распространения
from tensorflow.keras.models import Sequential

# Базовые слои для свёрточных сетей
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Работа с изображениями
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Оптимизаторы
from tensorflow.keras.optimizers import Adam

# Используем для to_categoricall
from tensorflow.keras import utils

# Для отрисовки изображений
from tensorflow.keras.preprocessing import image

# Библиотека работы с массивами
import numpy as np

# Для отрисовки графиков
import matplotlib.pyplot as plt

# Для отрисовки изображений
from PIL import Image

# Для генерации случайных чисел
import random

# Для округления
import math

# Для работы с файлами
import os
import shutil

# Для работы с файлами
import gc

# импортируем модуль для загрузки данных
import gdown

# для разделения выборок
from sklearn.model_selection import train_test_split

# импорт tensorflow
import tensorflow as tf

# модуль для отсчета времени
import time

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Подключение гугл диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Задание переменных

# %%
# задание переменных
ZIP_FILE = '/content/drive/MyDrive/ZENICA/iris.zip' # исходный zip-файл
TRAIN_PATH = '/content/drive/MyDrive/ZENICA/iris_base' # путь к тренировочной базе в Google Drive
TEST_PATH = '/content/drive/MyDrive/ZENICA/iris_test' # путь к тестовой базе в Google Drive

# %%
TEST_SPLIT = 0.2
VAL_SPLIT = 0.2

# %%
IMG_WIDTH           = 192 # 768                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144 #576                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %% [markdown]
# ## Формирование датасета

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_PATH} {TEST_PATH}

# Архив разархивируем в путь TRAIN_PATH
# !unzip -q {ZIP_FILE} -d {TRAIN_PATH} # Указываем путь к базе в Google Drive

# Проверяем, что в базе?
print('Проверяем, что в папке TRAIN_PATH:',os.listdir(TRAIN_PATH))

# Создаем сортированный список из базы
train_list = sorted(os.listdir(TRAIN_PATH))
print('Отсортированный список train_list:', train_list)

len_list = len(train_list)  # Длина списка

# Проверка результата
print(f'Количество файлов: {len_list}')
# Out:
# Проверяем, что в папке TRAIN_PATH: ['001L_1.png', '001L_2.png', '001L_3.png', '001R_1.png', '001R_2.png', '001R_3.png', '002L_1.png', '002L_2.png', '002L_3.png', '002R_1.png', '002R_2.png', '002R_3.png', '003L_1.png', '003L_2.png', '003L_3.png', '003R_1.png', '003R_2.png', '003R_3.png', '004L_1.png', '004L_2.png', '004L_3.png', '004R_1.png', '004R_2.png', '004R_3.png', '005L_1.png', '005L_2.png', '005L_3.png', '005R_1.png', '005R_2.png', '005R_3.png', '006L_1.png', '006L_2.png', '006L_3.png', '006R_1.png', '006R_2.png', '006R_3.png',
'023L_1.png', '023L_2.png', '023L_3.png', '023R_1.png', '023R_2.png', '023R_3.png', '024L_1.png', '024L_2.png', '024L_3.png', '024R_1.png', '024R_2.png', '024R_3.png', '025L_1.png', '025L_2.png', '025L_3.png', '025R_1.png', '025R_2.png', '025R_3.png', '026L_1.png', '026L_2.png', '026L_3.png', '026R_1.png', '026R_2.png', '026R_3.png', '027L_1.png', '027L_2.png', '027L_3.png', '027R_1.png', '027R_2.png', '027R_3.png', '028L_1.png', '028L_2.png', '028L_3.png', '028R_1.png', '028R_2.png', '028R_3.png', '029L_1.png', '029L_2.png', '029L_3.png', '029R_1.png', '029R_2.png', '029R_3.png', '030L_1.png', '030L_2.png', '030L_3.png', '030R_1.png', '030R_2.png', '030R_3.png', '031L_1.png', '031L_2.png', '031L_3.png', '031R_1.png', '031R_2.png', '031R_3.png', '032L_1.png', '032L_2.png', '032L_3.png', '032R_1.png', '032R_2.png', '032R_3.png', '033L_1.png', '033L_2.png', '033L_3.png', '033R_1.png', '033R_2.png', '033R_3.png', '034L_1.png', '034L_2.png', '034L_3.png', '034R_1.png', '034R_2.png', '034R_3.png', '035L_1.png', '035L_2.png', '035L_3.png', '035R_1.png', '035R_2.png', '035R_3.png', '036L_1.png', '036L_2.png', '036L_3.png', '036R_1.png', '036R_2.png', '036R_3.png', '037L_1.png', '037L_2.png', '037L_3.png', '037R_1.png', '037R_2.png', '037R_3.png', '038L_1.png', '038L_2.png', '038L_3.png', '038R_1.png', '038R_2.png', '038R_3.png', '039L_1.png', '039L_2.png', '039L_3.png', '039R_1.png', '039R_2.png', '039R_3.png', '040L_1.png', '040L_2.png', '040L_3.png', '040R_1.png', '040R_2.png', '040R_3.png', '041L_1.png', '041L_2.png', '041L_3.png', '041R_1.png', '041R_2.png', '041R_3.png', '042L_1.png', '042L_2.png', '042L_3.png', '042R_1.png', '042R_2.png', '042R_3.png', '043L_1.png', '043L_2.png', '043L_3.png', '043R_1.png', '043R_2.png', '043R_3.png', '044L_1.png', '044L_2.png', '044L_3.png', '044R_1.png', '044R_2.png', '044R_3.png', '045L_1.png', '045L_2.png', '045L_3.png', '045R_1.png', '045R_2.png', '045R_3.png', '046L_1.png', '046L_2.png', '046L_3.png', '046R_1.png', '046R_2.png', '046R_3.png', '047L_1.png', '047L_2.png', '047L_3.png', '047R_1.png', '047R_2.png', '047R_3.png', '048L_1.png', '0 ...
# Количество файлов: 384

# %%
# Создаем папки для каждого класса и перемещаем файлы С ГЛАЗАМИ в соответствующую папку ИХ КЛАССА
CLASS_LIST = []           # Список папок - пока пуст
for i in range(len_list):           # перебираем файлы с глазами в списке train_list
        file_name=train_list[i]      # берем название файла с глазом
        class_name = file_name[:3]  # создаем название папки из первых трех символов
        class_full_path = os.path.join(TRAIN_PATH,class_name)  # создаем полный путь к папке
        if not os.path.exists(class_full_path):                # если такой папки нет, то создаем папку
               os.makedirs(class_full_path)
               CLASS_LIST.append(class_name)
        shutil.move(os.path.join(TRAIN_PATH,file_name), class_full_path) #переносим файл с глазом в папку правильного класса
CLASS_COUNT = len(CLASS_LIST)        # получилось такое количество классов CLASS_COUNT
print(f'Создано (CLASS_COUNT):{CLASS_COUNT} папок. Названия папок классов = список CLASS_LIST: {CLASS_LIST}')
# Out:
# Создано (CLASS_COUNT):64 папок. Названия папок классов = список CLASS_LIST: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# создание итоговых списков "путь изображения + метка класса" для обучения

# Создание директории тестовых данных
os.mkdir(TEST_PATH)
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path_f = f'{TRAIN_PATH}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path_f = f'{TEST_PATH}/{class_name}'           # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path_f)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path_f)                               # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path_f}/{f}', f'{test_path_f}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# ## Аугментация

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 4                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.05                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.05                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.05                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.9, 1.1)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение запрещено

BATCH_SIZE          = 8                     # Размер батча
EPOCHS              = 300                   # Эпох обучения
OPTIMIZER           = Adam(0.0001)           # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='training'
)
# Out:
# Found 256 images belonging to 64 classes.

# %%
# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 144, 192, 3), (8, 64), батчей: 32
# Формы данных   проверочной выборки: (8, 144, 192, 3), (8, 64), батчей: 8
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %%
# Проверка одного изображения из выборки
#Аугментация работает "на лету".
#Индексы для примера выбраны такие: [1][0][2], что означает:
#1: номер батча в выборке. Сам батч - это кортеж (x_train, y_train) с примерами и метками классов;
#0: первый элемент в кортеже, то есть сами изображения. Под индексом 1 будут метки классов в формате one hot encoding для изображений;
#2: номер картинки в батче.

plt.imshow(train_generator[1][0][2])
plt.show()

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25,8),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
#show_batch(train_generator[0])
show_batch(train_generator[1], range(8), columns = 4)

# %%
show_batch(validation_generator[0], range(8), columns = 4)

# %%
show_batch(test_generator[0], range(8), columns = 4)

# %% [markdown]
# ## Создание и обучение модели нейронной сети

# %% [markdown]
# ### Сервисные функции

# %%
# Функции для работы с сохраненной моделью
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.models import load_model

#Сохранение лучшей модели
#from tensorflow.keras.callbacks import Callback

class SaveModelOnAccuracy(Callback):
    def __init__(self, filepath, monitor='val_loss', mode='min', save_best_only=True, verbose=1, min_accuracy=0.0):
        super(SaveModelOnAccuracy, self).__init__()
        self.filepath = filepath
        self.monitor = monitor
        self.mode = mode
        self.save_best_only = save_best_only
        self.verbose = verbose
        self.min_accuracy = min_accuracy
        self.best_accuracy = 0.0

    def on_epoch_end(self, epoch, logs=None):
        current_accuracy = logs.get('val_accuracy')
        if current_accuracy >= self.min_accuracy and current_accuracy > self.best_accuracy:
            self.model.save(self.filepath)
            self.best_accuracy = current_accuracy
            if self.verbose == 1:
                print(f" Модель сохранена с точностью {self.best_accuracy * 100:.2f} %")

# %%
# Функция компиляции и обучения модели нейронной сети

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5),        # размер полотна для графиков
                        min_accuracy=0.8,       # минимальное значение accuracy для сохранения модели
                        checkpoint_path='/content/Best_model/best_model.h5'):

    # Компиляция модели
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Создание обратного вызова для сохранения модели с заданным значением accuracy
    checkpoint = SaveModelOnAccuracy(filepath=checkpoint_path,
                                     monitor='val_loss',
                                     mode='min',
                                     save_best_only=True,
                                     verbose=1,
                                     min_accuracy=min_accuracy)

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data,
                        callbacks=[checkpoint])  # Передача обратного вызова в качестве списка)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'],
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

    return history

# %%
# Функция вывода результатов оценки модели на заданных данных

def eval_model(model,
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(10, 10)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    plt.show()

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Формируется сообщение о верности или неверности предсказания
        msg = 'ВЕРНО :-)' if cls_pred == cls else 'НЕВЕРНО :-('
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model,
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1],
               class_labels=class_labels,
               title=title,
               figsize=cm_size)

# %%
# Сохранение лучшей модели
def save_model_to_drive(model, save_path):

    from google.colab import drive
    import shutil

    # Подключение к Google Диску
    drive.mount('/content/drive')

    # Сохранение модели в указанную папку на Google Диск
    shutil.copyfile(model, '/content/drive/MyDrive/' + save_path)

# %%
# Загрузка лучшей модели
def load_best_model(model_path):
    # Загрузка модели из указанного файла
    best_model = load_model(model_path)

    return best_model

# %% [markdown]
# ### Архитектура модели нейронной сети

# %%
# Создание последовательной модели
model = Sequential()

# Первый сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model.add(BatchNormalization())

# Второй сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.1))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Четвертый сверточный слой
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.2))

# Пятый сверточный слой
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

# Слой преобразования многомерных данных в одномерные
model.add(Flatten())

# Промежуточный полносвязный слой
model.add(Dense(128, activation='relu'))

# Промежуточный полносвязный слой
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))

# Выходной полносвязный слой с количеством нейронов по количесту классов
model.add(Dense(CLASS_COUNT, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 144, 192, 32)      896
#
#  batch_normalization (BatchN  (None, 144, 192, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 144, 192, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 48, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 48, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 64, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 48, 64, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 48, 64, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 64, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 21, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 21, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 16, 21, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 16, 21, 128)      512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 16, 21, 128)       0
#
#  flatten (Flatten)           (None, 43008)             0
#
#  dense (Dense)               (None, 128)               5505152
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
# =================================================================
# Total params: 5,805,600
# Trainable params: 5,805,152
# Non-trainable params: 448
# _________________________________________________________________

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         )
# Out:
# Epoch 1/300
# 32/32 [==============================] - 22s 245ms/step - loss: 4.4717 - accuracy: 0.0117 - val_loss: 4.1610 - val_accuracy: 0.0156
# Epoch 2/300
# 32/32 [==============================] - 6s 198ms/step - loss: 4.1939 - accuracy: 0.0078 - val_loss: 4.1648 - val_accuracy: 0.0156
# Epoch 3/300
# 32/32 [==============================] - 8s 237ms/step - loss: 4.1526 - accuracy: 0.0117 - val_loss: 4.1660 - val_accuracy: 0.0156
# Epoch 4/300
# 32/32 [==============================] - 6s 198ms/step - loss: 4.1383 - accuracy: 0.0312 - val_loss: 4.1726 - val_accuracy: 0.0156
# Epoch 5/300
# 32/32 [==============================] - 6s 197ms/step - loss: 4.1164 - accuracy: 0.0117 - val_loss: 4.2128 - val_accuracy: 0.0156
# Epoch 6/300
# 32/32 [==============================] - 8s 238ms/step - loss: 4.0959 - accuracy: 0.0430 - val_loss: 4.1851 - val_accuracy: 0.0156
# Epoch 7/300
# 32/32 [==============================] - 8s 243ms/step - loss: 4.0235 - accuracy: 0.0391 - val_loss: 4.2398 - val_accuracy: 0.0156
# Epoch 8/300
# 32/32 [==============================] - 6s 198ms/step - loss: 3.8956 - accuracy: 0.0508 - val_loss: 4.3960 - val_accuracy: 0.0156
# Epoch 9/300
# 32/32 [==============================] - 8s 237ms/step - loss: 3.8232 - accuracy: 0.0664 - val_loss: 4.3160 - val_accuracy: 0.0156
# Epoch 10/300
300
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0485 - accuracy: 0.9922 - val_loss: 0.8448 - val_accuracy: 0.8750
# Epoch 192/300
# 32/32 [==============================] - 7s 235ms/step - loss: 0.0328 - accuracy: 0.9844 - val_loss: 0.6786 - val_accuracy: 0.8750
# Epoch 193/300
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0221 - accuracy: 0.9883 - val_loss: 0.5189 - val_accuracy: 0.8594
# Epoch 194/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0193 - accuracy: 0.9961 - val_loss: 0.5406 - val_accuracy: 0.8906
# Epoch 195/300
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0666 - accuracy: 0.9805 - val_loss: 1.4545 - val_accuracy: 0.7812
# Epoch 196/300
# 32/32 [==============================] - 8s 238ms/step - loss: 0.0782 - accuracy: 0.9688 - val_loss: 0.6194 - val_accuracy: 0.8906
# Epoch 197/300
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0821 - accuracy: 0.9844 - val_loss: 0.5406 - val_accuracy: 0.8906
# Epoch 198/300
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0309 - accuracy: 0.9922 - val_loss: 0.9918 - val_accuracy: 0.8125
# Epoch 199/300
# 32/32 [==============================] - 8s 236ms/step - loss: 0.0450 - accuracy: 0.9922 - val_loss: 0.9263 - val_accuracy: 0.7812
# Epoch 200/300
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0284 - accuracy: 0.9883 - val_loss: 0.5236 - val_accuracy: 0.8906
# Epoch 201/300
# 32/32 [==============================] - 8s 238ms/step - loss: 0.0376 - accuracy: 0.9883 - val_loss: 1.0301 - val_accuracy: 0.8281
# Epoch 202/300
# 32/32 [==============================] - 8s 246ms/step - loss: 0.0212 - accuracy: 0.9922 - val_loss: 0.7558 - val_accuracy: 0.8438
# Epoch 203/300
# 32/32 [==============================] - 7s 206ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.6269 - val_accuracy: 0.8438
# Epoch 204/300
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0567 - accuracy: 0.9883 - val_loss: 0.4616 - val_accuracy: 0.8750
# Epoch 205/300
# 32/32 [==============================] - 6s 204ms/step - loss: 0.0341 - accuracy: 0.9844 - val_loss: 0.5321 - val_accuracy: 0.8750
# Epoch 206/300
# 32/32 [==============================] - 8s 238ms/step - loss: 0.0161 - accuracy: 0.9922 - val_loss: 0.4711 - val_accuracy: 0.8750
# Epoch 207/300
# 32/32 [==============================] - 6s 202ms/step - loss: 0.0272 - accuracy: 0.9883 - val_loss: 0.4549 - val_accuracy: 0.9062
# Epoch 208/300
# 32/32 [==============================] - 8s 236ms/step - loss: 0.0360 - accuracy: 0.9844 - val_loss: 0.6413 - val_accuracy: 0.8594
# Epoch 209/300
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0285 - accuracy: 0.9883 - val_loss: 0.4184 - val_accuracy: 0.9062
# Epoch 210/300
# 32/32 [==============================] - 8s 237ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.4976 - val_accuracy: 0.9219
# Epoch 211/300
# 32/32 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000 Модель сохранена с точностью 93.75 %
# 32/32 [==============================] - 7s 216ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.4464 - val_accuracy: 0.9375
# Epoch 212/300
# 32/32 [==============================] - 6s 202ms/step - loss: 0.0419 - accuracy: 0.9922 - val_loss: 0.3864 - val_accuracy: 0.9062
# Epoch 213/300
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.9062
# Epoch 214/300
# 32/32 [==============================] - 8s 236ms/step - loss: 0.0308 - accuracy: 0.9883 - val_loss: 0.8069 - val_accuracy: 0.8281
# Epoch 215/300
# 32/32 [==============================] - 6s 202ms/step - loss: 0.0512 - accuracy: 0.9805 - val_loss: 0.7236 - val_accuracy: 0.8438
# Epoch 216/300
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0575 - accuracy: 0.9805 - val_loss: 1.0793 - val_accuracy: 0.7812
# Epoch 217/300
# 32/32 [==============================] - 6s 202ms/step - loss: 0.0302 - accuracy: 0.9922 - val_loss: 0.4539 - val_accuracy: 0.9062
# Epoch 218/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0469 - accuracy: 0.9883 - val_loss: 0.5062 - val_accuracy: 0.8750
# Epoch 219/300
# 32/32 [==============================] - 6s 201ms/step - loss: 0.
300
# 32/32 [==============================] - 8s 242ms/step - loss: 0.0317 - accuracy: 0.9961 - val_loss: 0.8556 - val_accuracy: 0.8438
# Epoch 246/300
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0581 - accuracy: 0.9844 - val_loss: 1.5743 - val_accuracy: 0.7969
# Epoch 247/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.1352 - accuracy: 0.9727 - val_loss: 1.7956 - val_accuracy: 0.7812
# Epoch 248/300
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0487 - accuracy: 0.9883 - val_loss: 1.8827 - val_accuracy: 0.7969
# Epoch 249/300
# 32/32 [==============================] - 8s 238ms/step - loss: 0.0517 - accuracy: 0.9922 - val_loss: 1.1514 - val_accuracy: 0.8438
# Epoch 250/300
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0125 - accuracy: 0.9922 - val_loss: 1.0284 - val_accuracy: 0.8438
# Epoch 251/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0373 - accuracy: 0.9922 - val_loss: 0.5429 - val_accuracy: 0.9062
# Epoch 252/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0539 - accuracy: 0.9805 - val_loss: 1.3524 - val_accuracy: 0.8750
# Epoch 253/300
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1444 - accuracy: 0.9766 - val_loss: 1.1882 - val_accuracy: 0.8281
# Epoch 254/300
# 32/32 [==============================] - 8s 240ms/step - loss: 0.0330 - accuracy: 0.9844 - val_loss: 1.4980 - val_accuracy: 0.7500
# Epoch 255/300
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0336 - accuracy: 0.9883 - val_loss: 1.8812 - val_accuracy: 0.7656
# Epoch 256/300
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0411 - accuracy: 0.9922 - val_loss: 1.1301 - val_accuracy: 0.8125
# Epoch 257/300
# 32/32 [==============================] - 6s 196ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.9703 - val_accuracy: 0.8594
# Epoch 258/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 1.7717 - val_accuracy: 0.7500
# Epoch 259/300
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0264 - accuracy: 0.9922 - val_loss: 1.1956 - val_accuracy: 0.8438
# Epoch 260/300
# 32/32 [==============================] - 7s 205ms/step - loss: 0.0210 - accuracy: 0.9961 - val_loss: 1.0137 - val_accuracy: 0.8438
# Epoch 261/300
# 32/32 [==============================] - 7s 211ms/step - loss: 0.0202 - accuracy: 0.9883 - val_loss: 0.8534 - val_accuracy: 0.8125
# Epoch 262/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 1.3287 - val_accuracy: 0.8281
# Epoch 263/300
# 32/32 [==============================] - 8s 243ms/step - loss: 0.0459 - accuracy: 0.9844 - val_loss: 0.9476 - val_accuracy: 0.8125
# Epoch 264/300
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0120 - accuracy: 0.9922 - val_loss: 0.8595 - val_accuracy: 0.7969
# Epoch 265/300
# 32/32 [==============================] - 8s 237ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.6429 - val_accuracy: 0.9062
# Epoch 266/300
# 32/32 [==============================] - 6s 202ms/step - loss: 0.0227 - accuracy: 0.9922 - val_loss: 0.3415 - val_accuracy: 0.9375
# Epoch 267/300
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0142 - accuracy: 0.9922 - val_loss: 1.2278 - val_accuracy: 0.7812
# Epoch 268/300
# 32/32 [==============================] - 8s 242ms/step - loss: 0.0175 - accuracy: 0.9961 - val_loss: 0.6755 - val_accuracy: 0.8750
# Epoch 269/300
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.5398 - val_accuracy: 0.9219
# Epoch 270/300
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.7515 - val_accuracy: 0.8906
# Epoch 271/300
# 32/32 [==============================] - 7s 204ms/step - loss: 0.0138 - accuracy: 0.9922 - val_loss: 0.3342 - val_accuracy: 0.9375
# Epoch 272/300
# 32/32 [==============================] - 8s 240ms/step - loss: 0.0130 - accuracy: 0.9922 - val_loss: 0.6568 - val_accuracy: 0.8438
# Epoch 273/300
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0139 - accuracy: 0.9922 - val_loss: 1.1154 - val_accuracy: 0.8281
# Epoch 274/300
# 32/32 [==============================] - 8s 242ms/step - loss: 0.0452 - accuracy: 0.9961 - val_loss: 1.3697 - val_accuracy: 0.7344
# Epoch 275/300
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0133 - accuracy: 0.9922 - val_loss: 0.4743 - val_accuracy: 0.8750
# Epoch 276/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0296 - accuracy: 0.9883 - val_loss: 0.9762 - val_accuracy: 0.8594
# Epoch 277/300
# 32/32 [==============================] - 8s 246ms/step - loss: 0.1051 - accuracy: 0.9961 - val_loss: 0.7526 - val_accuracy: 0.8906
# Epoch 278/300
# 32/32 [==============================] - 6s 202ms/step - loss: 0.0191 - accuracy: 0.9883 - val_loss: 1.0120 - val_accuracy: 0.8906
# Epoch 279/300
# 32/32 [==============================] - 8s 239ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.9279 - val_accuracy: 0.8750
# Epoch 280/300
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.7442 - val_accuracy: 0.8750
# Epoch 281/300
# 32/32 [==============================] - 8s 238ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.8138 - val_accuracy: 0.8594
# Epoch 282/300
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.6671 - val_accuracy: 0.8906
# Epoch 283/300
# 32/32 [==============================] - 8s 239ms/step - loss: 5.9476e-04 - accuracy: 1.0000 - val_loss: 0.7646 - val_accuracy: 0.8750
# Epoch 284/300
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0053 - accuracy: 0.9961 - val_loss: 0.3549 - val_accuracy: 0.9062
# Epoch 285/300
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0054 - accuracy: 0.9961 - val_loss: 0.6116 - val_accuracy: 0.8438
# Epoch 286/300
# 32/32 [==============================] - 8s 242ms/step - loss: 0.0066 - accuracy: 0.9961 - val_loss: 0.7873 - val_accuracy: 0.8750
# Epoch 287/300
# 32/32 [==============================] - 7s 204ms/step - loss: 0.0299 - accuracy: 0.9922 - val_loss: 1.5072 - val_accuracy: 0.7812
# Epoch 288/300
# 32/32 [==============================] - 7s 204ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.8981 - val_accuracy: 0.8125
# Epoch 289/300
# 32/32 [==============================] - 8s 242ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5400 - val_accuracy: 0.8906
# Epoch 290/300
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0063 - accuracy: 0.9961 - val_loss: 0.7451 - val_accuracy: 0.8750
# Epoch 291/300
# 32/32 [==============================] - 8s 234ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5653 - val_accuracy: 0.8438
# Epoch 292/300
# 32/32 [==============================] - 7s 217ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5967 - val_accuracy: 0.8906
# Epoch 293/300
# 32/32 [==============================] - 7s 205ms/step - loss: 0.0085 - accuracy: 0.9961 - val_loss: 0.8730 - val_accuracy: 0.8906
# Epoch 294/300
# 32/32 [==============================] - 8s 240ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8490 - val_accuracy: 0.8750
# Epoch 295/300
# 32/32 [==============================] - 7s 223ms/step - loss: 0.0430 - accuracy: 0.9922 - val_loss: 0.9090 - val_accuracy: 0.8906
# Epoch 296/300
# 32/32 [==============================] - 7s 204ms/step - loss: 0.0568 - accuracy: 0.9922 - val_loss: 1.8299 - val_accuracy: 0.7344
# Epoch 297/300
# 32/32 [==============================] - 8s 244ms/step - loss: 0.0684 - accuracy: 0.9883 - val_loss: 0.8485 - val_accuracy: 0.8594
# Epoch 298/300
# 32/32 [==============================] - 7s 204ms/step - loss: 0.0351 - accuracy: 0.9805 - val_loss: 0.3855 - val_accuracy: 0.9062
# Epoch 299/300
# 32/32 [==============================] - 6s 203ms/step - loss: 0.0475 - accuracy: 0.9883 - val_loss: 0.2903 - val_accuracy: 0.9062
# Epoch 300/300
# 32/32 [==============================] - 8s 240ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0