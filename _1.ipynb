# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiaAntimonova/IrisID_gr1/blob/AnastasiaAntimonova-folder/_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Инструменты для построения графиков
import matplotlib.pyplot as plt 

# Инструменты для работы с изображениями
from tensorflow.keras.preprocessing import image 

from tensorflow.keras.models import Sequential #Сеть прямого распространения

#Базовые слои для свёрточных сетей
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator # работа с изображениями
from tensorflow.keras.optimizers import Adam, Adadelta # оптимизаторы
from tensorflow.keras import utils #Используем для to_categoricall
from tensorflow.keras.preprocessing import image #Для отрисовки изображений

# Инструменты для работы с массивами
import numpy as np 

# Системные инструменты
import time, random, gdown, os

# Дополнительные инструменты для работы с изображениями
from PIL import Image 

# Дополнительные инструменты визуализации
import seaborn as sns
sns.set_style('darkgrid')


# Отрисовка графиков
import matplotlib.pyplot as plt

# Рисование графиков в ячейках Colab
# %matplotlib inline

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=1OBAS7s-FnQao0jMp9VHBzZdjGk3RGcVV', None, quiet=True)
# Out:
# 'iris_5.zip'

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_DIR} {TEST_DIR}

# Разархивация датасета
# !unzip -qo "iris_5.zip" -d {TRAIN_DIR}

# %%
# Глобальные параметры

TRAIN_DIR          = '/content/iris_5/iris_5'           # Папка для обучающего набора данных
TEST_DIR           = '/content/iris_test'  # Папка для тестового набора данных

TEST_SPLIT          = 0.2                   # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.2                   # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 256                   # Ширина изображения для нейросети
IMG_HEIGHT          = 192                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %%
#просмотр списка папок
os.listdir(TRAIN_DIR)
# Out:
# ['003', '001', '009', '007', '002', '005', '010', '008', '004', '006']

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_DIR))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 10, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    class_path = f'{TRAIN_DIR}/{CLASS_LIST[i]}' 
    # Выбор случайного фото из i-го класса
    img_path = class_path +'/'+random.choice(os.listdir(class_path)) 
    # Отображение фотографии (подробнее будет объяснено далее)
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))  
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
# Создание директории тестовых данных
os.mkdir(TEST_DIR)                                        
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_DIR}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_DIR}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 60, выделено для обучения: 50, для теста: 10

# %% [markdown]
# Аугментация данных

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 6                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.1                   # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.1                   # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.1                   # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.7, 1.3)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение разрешено

BATCH_SIZE          = 8                     # Размер батча
EPOCHS              = 150                   # Эпох обучения
OPTIMIZER           = Adam(0.001)           # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную 

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, 
    subset='training'
)

# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 40 images belonging to 10 classes.
# Found 10 images belonging to 10 classes.
# Found 10 images belonging to 10 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 192, 256, 3), (8, 10), батчей: 5
# Формы данных   проверочной выборки: (8, 192, 256, 3), (8, 10), батчей: 2
# Формы данных      тестовой выборки: (10, 192, 256, 3), (10, 10), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 6),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])  
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(6), columns = 3)

# %%
# Функция компиляции и обучения модели нейронной сети

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    # Вывод сводки
    model.summary()

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model, 
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

# %%
# Создание последовательной модели
model = Sequential()

# Первый сверточный слой
model.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model.add(BatchNormalization())

# Второй сверточный слой
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Четвертый сверточный слой
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.2))

# Пятый сверточный слой
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

# Слой преобразования многомерных данных в одномерные 
model.add(Flatten())

# Промежуточный полносвязный слой
model.add(Dense(2048, activation='relu'))


# Выходной полносвязный слой с количеством нейронов по количесту классов
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 192, 256, 256)     7168
#
#  batch_normalization (BatchN  (None, 192, 256, 256)    1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 192, 256, 256)     590080
#
#  max_pooling2d (MaxPooling2D  (None, 64, 85, 256)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 85, 256)       590080
#
#  batch_normalization_1 (Batc  (None, 64, 85, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 64, 85, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 64, 85, 256)       590080
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 28, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 21, 28, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 21, 28, 512)       1180160
#
#  batch_normalization_2 (Batc  (None, 21, 28, 512)      2048
#  hNormalization)
#
#  flatten (Flatten)           (None, 301056)            0
#
#  dense (Dense)               (None, 2048)              616564736
#
#  dense_1 (Dense)             (None, 10)                20490
#
# =================================================================
# Total params: 619,546,890
# Trainable params: 619,544,842
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/150
# 5/5 [==============================] - 5s 801ms/step - loss: 1.6563 - accuracy: 0.8000 - val_loss: 7.7203 - val_accuracy: 0.9000
# Epoch 2/150
# 5/5 [==============================] - 5s 952ms/step - loss: 3.9398 - accuracy: 0.7500 - val_loss: 7.9738 - val_accuracy: 0.7000
# Epoch 3/150
# 5/5 [==============================] - 3s 567ms/step - loss: 1.3581 - accuracy: 0.8750 - val_loss: 16.6410 - val_accuracy: 0.5000
# Epoch 4/150
# 5/5 [==============================] - 3s 551ms/step - loss: 2.9974 - accuracy: 0.8000 - val_loss: 4.1333 - val_accuracy: 0.7000
# Epoch 5/150
# 5/5 [==============================] - 3s 634ms/step - loss: 1.4130 - accuracy: 0.8250 - val_loss: 3.9098 - val_accuracy: 0.6000
# Epoch 6/150
# 5/5 [==============================] - 3s 560ms/step - loss: 1.4158 - accuracy: 0.8500 - val_loss: 9.1220 - val_accuracy: 0.5000
# Epoch 7/150
# 5/5 [==============================] - 3s 633ms/step - loss: 0.9624 - accuracy: 0.9000 - val_loss: 10.5012 - val_accuracy: 0.5000
# Epoch 8/150
# 5/5 [==============================] - 3s 556ms/step - loss: 0.8205 - accuracy: 0.8750 - val_loss: 3.5164 - val_accuracy: 0.6000
# Epoch 9/150
# 5/5 [==============================] - 3s 585ms/step - loss: 0.3575 - accuracy: 0.9250 - val_loss: 3.9180 - val_accuracy: 0.5000
# Epoch 10/150
# 5/5 [==============================] - 3s 555ms/step - loss: 1.9188 - accuracy: 0.8500 - val_loss: 6.2889 - val_accuracy: 0.5000
# Epoch 11/150
# 5/5 [==============================] - 3s 558ms/step - loss: 0.7595 - accuracy: 0.9000 - val_loss: 24.9376 - val_accuracy: 0.4000
# Epoch 12/150
# 5/5 [==============================] - 3s 633ms/step - loss: 0.1745 - accuracy: 0.9500 - val_loss: 0.8115 - val_accuracy: 0.8000
# Epoch 13/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.4466 - accuracy: 0.9250 - val_loss: 2.0243 - val_accuracy: 0.9000
# Epoch 14/150
# 5/5 [==============================] - 3s 549ms/step - loss: 0.0767 - accuracy: 0.9750 - val_loss: 0.0649 - val_accuracy: 1.0000
# Epoch 15/150
# 5/5 [==============================] - 3s 632ms/step - loss: 0.0306 - accuracy: 0.9750 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 16/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 2.6230 - val_accuracy: 0.9000
# Epoch 17/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.0275 - accuracy: 0.9750 - val_loss: 8.8855e-04 - val_accuracy: 1.0000
# Epoch 18/150
# 5/5 [==============================] - 3s 627ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.4762 - val_accuracy: 0.9000
# Epoch 19/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 7.1523e-06 - val_accuracy: 1.0000
# Epoch 20/150
# 5/5 [==============================] - 3s 547ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 21/150
# 5/5 [==============================] - 3s 586ms/step - loss: 0.3105 - accuracy: 0.9500 - val_loss: 2.7940 - val_accuracy: 0.8000
# Epoch 22/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.9029 - accuracy: 0.9500 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 23/150
# 5/5 [==============================] - 3s 631ms/step - loss: 0.1559 - accuracy: 0.9750 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 24/150
# 5/5 [==============================] - 3s 557ms/step - loss: 0.2777 - accuracy: 0.9500 - val_loss: 3.0804 - val_accuracy: 0.8000
# Epoch 25/150
# 5/5 [==============================] - 3s 640ms/step - loss: 0.3426 - accuracy: 0.9750 - val_loss: 2.6216 - val_accuracy: 0.8000
# Epoch 26/150
# 5/5 [==============================] - 3s 558ms/step - loss: 0.6799 - accuracy: 0.9500 - val_loss: 6.2480 - val_accuracy: 0.9000
# Epoch 27/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.1841 - accuracy: 0.9750 - val_loss: 3.7307 - val_accuracy: 0.9000
# Epoch 28/150
# 5/5 [==============================] - 3s 581ms/step - loss: 0.2892 - accuracy: 0.9750 - val_loss: 0.2772 - val_accuracy: 0.9000
# Epoch 29/150
# 5/5 [==============================] - 3s 573ms/step - loss: 0.3378 - accuracy: 0.9500 - val_loss: 2.5154 - val_accuracy: 0.9000
# Epoch 30/150
# 5/5 [==============================] - 3s 557ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.3571 - val_accuracy: 0.9000
# Epoch 31/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.5775 - accuracy: 0.9250 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 32/150
# 5/5 [==============================] - 3s 554ms/step - loss: 0.3332 - accuracy: 0.9000 - val_loss: 0.8610 - val_accuracy: 0.8000
# Epoch 33/150
# 5/5 [==============================] - 3s 634ms/step - loss: 0.6901 - accuracy: 0.9500 - val_loss: 57.0430 - val_accuracy: 0.5000
# Epoch 34/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.3183 - accuracy: 0.9250 - val_loss: 90.9946 - val_accuracy: 0.2000
# Epoch 35/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.3902 - accuracy: 0.9500 - val_loss: 82.2063 - val_accuracy: 0.2000
# Epoch 36/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.1272 - accuracy: 0.9750 - val_loss: 60.3636 - val_accuracy: 0.4000
# Epoch 37/150
# 5/5 [==============================] - 3s 548ms/step - loss: 1.2230 - accuracy: 0.8750 - val_loss: 17.2969 - val_accuracy: 0.4000
# Epoch 38/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.5922 - accuracy: 0.9500 - val_loss: 27.6914 - val_accuracy: 0.2000
# Epoch 39/150
# 5/5 [==============================] - 3s 573ms/step - loss: 0.6800 - accuracy: 0.9250 - val_loss: 1.2633 - val_accuracy: 0.9000
# Epoch 40/150
# 5/5 [==============================] - 3s 546ms/step - loss: 0.3801 - accuracy: 0.9250 - val_loss: 1.8615 - val_accuracy: 0.9000
# Epoch 41/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.9724 - accuracy: 0.9250 - val_loss: 7.4013 - val_accuracy: 0.7000
# Epoch 42/150
# 5/5 [==============================] - 3s 582ms/step - loss: 0.1889 - accuracy: 0.9500 - val_loss: 0.1531 - val_accuracy: 0.9000
# Epoch 43/150
# 5/5 [==============================] - 3s 550ms/step - loss: 1.2339 - accuracy: 0.9000 - val_loss: 3.0045 - val_accuracy: 0.8000
# Epoch 44/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.0310 - accuracy: 0.9750 - val_loss: 2.2356 - val_accuracy: 0.8000
# Epoch 45/150
# 5/5 [==============================] - 3s 554ms/step - loss: 0.4730 - accuracy: 0.8750 - val_loss: 2.4702 - val_accuracy: 0.6000
# Epoch 46/150
# 5/5 [==============================] - 3s 585ms/step - loss: 0.1545 - accuracy: 0.9750 - val_loss: 6.5881 - val_accuracy: 0.6000
# Epoch 47/150
# 5/5 [==============================] - 3s 556ms/step - loss: 1.1643 - accuracy: 0.8500 - val_loss: 15.7386 - val_accuracy: 0.6000
# Epoch 48/150
# 5/5 [==============================] - 3s 557ms/step - loss: 0.0937 - accuracy: 0.9500 - val_loss: 17.8836 - val_accuracy: 0.5000
# Epoch 49/150
# 5/5 [==============================] - 3s 556ms/step - loss: 0.6971 - accuracy: 0.9000 - val_loss: 5.4910 - val_accuracy: 0.6000
# Epoch 50/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.1213 - accuracy: 0.9750 - val_loss: 14.3339 - val_accuracy: 0.5000
# Epoch 51/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.6888 - accuracy: 0.8500 - val_loss: 8.0897 - val_accuracy: 0.6000
# Epoch 52/150
# 5/5 [==============================] - 3s 632ms/step - loss: 0.2872 - accuracy: 0.9500 - val_loss: 6.3189 - val_accuracy: 0.7000
# Epoch 53/150
# 5/5 [==============================] - 3s 556ms/step - loss: 1.0260 - accuracy: 0.9250 - val_loss: 2.3284 - val_accuracy: 0.9000
# Epoch 54/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.2021 - accuracy: 0.9500 - val_loss: 0.4339 - val_accuracy: 0.9000
# Epoch 55/150
# 5/5 [==============================] - 3s 578ms/step - loss: 4.4053e-05 - accuracy: 1.0000 - val_loss: 4.1298 - val_accuracy: 0.7000
# Epoch 56/150
# 5/5 [==============================] - 3s 545ms/step - loss: 0.1539 - accuracy: 0.9250 - val_loss: 3.6846 - val_accuracy: 0.9000
# Epoch 57/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.0470 - accuracy: 0.9750 - val_loss: 0.0760 - val_accuracy: 1.0000
# Epoch 58/150
# 5/5 [==============================] - 3s 553ms/step - loss: 1.9938e-04 - accuracy: 1.0000 - val_loss: 10.8590 - val_accuracy: 0.7000
# Epoch 59/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.6540 - accuracy: 0.9250 - val_loss: 1.0787 - val_accuracy: 0.9000
# Epoch 60/150
# 5/5 [==============================] - 3s 557ms/step - loss: 0.0180 - accuracy: 0.9750 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 61/150
# 5/5 [==============================] - 3s 636ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 5.7816 - val_accuracy: 0.8000
# Epoch 62/150
# 5/5 [==============================] - 3s 564ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 1.4444 - val_accuracy: 0.9000
# Epoch 63/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.5298 - accuracy: 0.9500 - val_loss: 2.6996e-04 - val_accuracy: 1.0000
# Epoch 64/150
# 5/5 [==============================] - 3s 557ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 65/150
# 5/5 [==============================] - 3s 595ms/step - loss: 0.1413 - accuracy: 0.9750 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 66/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.2765 - accuracy: 0.9500 - val_loss: 2.0332 - val_accuracy: 0.8000
# Epoch 67/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.6820 - val_accuracy: 0.9000
# Epoch 68/150
# 5/5 [==============================] - 3s 589ms/step - loss: 1.8067 - accuracy: 0.7750 - val_loss: 5.5037e-05 - val_accuracy: 1.0000
# Epoch 69/150
# 5/5 [==============================] - 3s 552ms/step - loss: 1.0850 - accuracy: 0.9500 - val_loss: 45.8471 - val_accuracy: 0.5000
# Epoch 70/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.1774 - accuracy: 0.9250 - val_loss: 67.9486 - val_accuracy: 0.3000
# Epoch 71/150
# 5/5 [==============================] - 3s 631ms/step - loss: 1.4105 - accuracy: 0.9250 - val_loss: 53.9978 - val_accuracy: 0.3000
# Epoch 72/150
# 5/5 [==============================] - 3s 548ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 62.8303 - val_accuracy: 0.4000
# Epoch 73/150
# 5/5 [==============================] - 3s 547ms/step - loss: 0.0424 - accuracy: 0.9750 - val_loss: 97.4734 - val_accuracy: 0.4000
# Epoch 74/150
# 5/5 [==============================] - 3s 575ms/step - loss: 1.3524 - accuracy: 0.9000 - val_loss: 24.7328 - val_accuracy: 0.5000
# Epoch 75/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.3441 - accuracy: 0.9250 - val_loss: 51.5674 - val_accuracy: 0.3000
# Epoch 76/150
# 5/5 [==============================] - 3s 555ms/step - loss: 2.0292 - accuracy: 0.9250 - val_loss: 118.7999 - val_accuracy: 0.3000
# Epoch 77/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.4654 - accuracy: 0.9500 - val_loss: 48.3517 - val_accuracy: 0.2000
# Epoch 78/150
# 5/5 [==============================] - 3s 549ms/step - loss: 0.8188 - accuracy: 0.8500 - val_loss: 81.8556 - val_accuracy: 0.5000
# Epoch 79/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.0228 - accuracy: 0.9750 - val_loss: 170.0464 - val_accuracy: 0.2000
# Epoch 80/150
# 5/5 [==============================] - 3s 552ms/step - loss: 0.4382 - accuracy: 0.9750 - val_loss: 18.6434 - val_accuracy: 0.6000
# Epoch 81/150
# 5/5 [==============================] - 3s 554ms/step - loss: 0.4461 - accuracy: 0.9000 - val_loss: 13.2224 - val_accuracy: 0.7000
# Epoch 82/150
# 5/5 [==============================] - 3s 591ms/step - loss: 0.2695 - accuracy: 0.9500 - val_loss: 1.4885 - val_accuracy: 0.8000
# Epoch 83/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.3614 - accuracy: 0.9750 - val_loss: 0.7658 - val_accuracy: 0.9000
# Epoch 84/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.6839 - accuracy: 0.9250 - val_loss: 4.1775 - val_accuracy: 0.6000
# Epoch 85/150
# 5/5 [==============================] - 3s 556ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 43.2137 - val_accuracy: 0.4000
# Epoch 86/150
# 5/5 [==============================] - 3s 552ms/step - loss: 0.6188 - accuracy: 0.9250 - val_loss: 9.0246 - val_accuracy: 0.5000
# Epoch 87/150
# 5/5 [==============================] - 3s 553ms/step - loss: 1.5420 - accuracy: 0.9000 - val_loss: 23.9967 - val_accuracy: 0.6000
# Epoch 88/150
# 5/5 [==============================] - 3s 631ms/step - loss: 0.7683 - accuracy: 0.9250 - val_loss: 75.0679 - val_accuracy: 0.5000
# Epoch 89/150
# 5/5 [==============================] - 3s 558ms/step - loss: 1.6743 - accuracy: 0.9750 - val_loss: 26.5795 - val_accuracy: 0.4000
# Epoch 90/150
# 5/5 [==============================] - 3s 558ms/step - loss: 0.6268 - accuracy: 0.9000 - val_loss: 17.7944 - val_accuracy: 0.5000
# Epoch 91/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.4929 - accuracy: 0.9250 - val_loss: 12.5251 - val_accuracy: 0.5000
# Epoch 92/150
# 5/5 [==============================] - 3s 552ms/step - loss: 2.8750e-05 - accuracy: 1.0000 - val_loss: 6.5632 - val_accuracy: 0.6000
# Epoch 93/150
# 5/5 [==============================] - 3s 639ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 12.5496 - val_accuracy: 0.3000
# Epoch 94/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.1677 - accuracy: 0.9500 - val_loss: 2.2769 - val_accuracy: 0.9000
# Epoch 95/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.4305 - accuracy: 0.9000 - val_loss: 1.7778 - val_accuracy: 0.8000
# Epoch 96/150
# 5/5 [==============================] - 3s 575ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 28.9688 - val_accuracy: 0.4000
# Epoch 97/150
# 5/5 [==============================] - 3s 548ms/step - loss: 0.1082 - accuracy: 0.9500 - val_loss: 25.8278 - val_accuracy: 0.4000
# Epoch 98/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.4452 - accuracy: 0.9750 - val_loss: 21.5080 - val_accuracy: 0.6000
# Epoch 99/150
# 5/5 [==============================] - 3s 633ms/step - loss: 1.0119 - accuracy: 0.9750 - val_loss: 6.9427 - val_accuracy: 0.7000
# Epoch 100/150
# 5/5 [==============================] - 3s 554ms/step - loss: 0.6503 - accuracy: 0.9500 - val_loss: 0.4837 - val_accuracy: 0.8000
# Epoch 101/150
# 5/5 [==============================] - 3s 550ms/step - loss: 0.3792 - accuracy: 0.9750 - val_loss: 0.0615 - val_accuracy: 1.0000
# Epoch 102/150
# 5/5 [==============================] - 3s 636ms/step - loss: 0.9081 - accuracy: 0.9000 - val_loss: 0.8705 - val_accuracy: 0.9000
# Epoch 103/150
# 5/5 [==============================] - 3s 556ms/step - loss: 0.8409 - accuracy: 0.9500 - val_loss: 5.9344 - val_accuracy: 0.8000
# Epoch 104/150
# 5/5 [==============================] - 3s 556ms/step - loss: 0.8875 - accuracy: 0.9500 - val_loss: 0.3777 - val_accuracy: 0.8000
# Epoch 105/150
# 5/5 [==============================] - 3s 632ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 12.9409 - val_accuracy: 0.6000
# Epoch 106/150
# 5/5 [==============================] - 3s 582ms/step - loss: 0.2300 - accuracy: 0.9750 - val_loss: 37.3409 - val_accuracy: 0.2000
# Epoch 107/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 29.4090 - val_accuracy: 0.2000
# Epoch 108/150
# 5/5 [==============================] - 3s 560ms/step - loss: 0.8925 - accuracy: 0.8750 - val_loss: 13.6226 - val_accuracy: 0.6000
# Epoch 109/150
# 5/5 [==============================] - 3s 582ms/step - loss: 0.2227 - accuracy: 0.9750 - val_loss: 2.7914 - val_accuracy: 0.9000
# Epoch 110/150
# 5/5 [==============================] - 3s 549ms/step - loss: 0.9189 - accuracy: 0.9500 - val_loss: 19.0307 - val_accuracy: 0.7000
# Epoch 111/150
# 5/5 [==============================] - 3s 554ms/step - loss: 0.5299 - accuracy: 0.9500 - val_loss: 2.8958 - val_accuracy: 0.9000
# Epoch 112/150
# 5/5 [==============================] - 3s 552ms/step - loss: 0.6093 - accuracy: 0.9000 - val_loss: 14.7828 - val_accuracy: 0.6000
# Epoch 113/150
# 5/5 [==============================] - 3s 588ms/step - loss: 0.6439 - accuracy: 0.9250 - val_loss: 1.3921 - val_accuracy: 0.9000
# Epoch 114/150
# 5/5 [==============================] - 3s 550ms/step - loss: 7.6051 - accuracy: 0.9000 - val_loss: 0.0654 - val_accuracy: 1.0000
# Epoch 115/150
# 5/5 [==============================] - 3s 549ms/step - loss: 3.8961 - accuracy: 0.9250 - val_loss: 83.6035 - val_accuracy: 0.3000
# Epoch 116/150
# 5/5 [==============================] - 3s 634ms/step - loss: 3.2331 - accuracy: 0.8500 - val_loss: 9.9127 - val_accuracy: 0.6000
# Epoch 117/150
# 5/5 [==============================] - 3s 549ms/step - loss: 3.8681 - accuracy: 0.8000 - val_loss: 2.3629 - val_accuracy: 0.8000
# Epoch 118/150
# 5/5 [==============================] - 3s 553ms/step - loss: 0.7418 - accuracy: 0.8750 - val_loss: 13.2675 - val_accuracy: 0.6000
# Epoch 119/150
# 5/5 [==============================] - 3s 550ms/step - loss: 6.7350 - accuracy: 0.7500 - val_loss: 13.4402 - val_accuracy: 0.4000
# Epoch 120/150
# 5/5 [==============================] - 3s 641ms/step - loss: 1.9727 - accuracy: 0.8750 - val_loss: 4.5689 - val_accuracy: 0.8000
# Epoch 121/150
# 5/5 [==============================] - 3s 554ms/step - loss: 8.7430 - accuracy: 0.9000 - val_loss: 5.5006 - val_accuracy: 0.5000
# Epoch 122/150
# 5/5 [==============================] - 3s 553ms/step - loss: 1.9005 - accuracy: 0.8000 - val_loss: 31.7839 - val_accuracy: 0.4000
# Epoch 123/150
# 5/5 [==============================] - 3s 632ms/step - loss: 3.7195 - accuracy: 0.7500 - val_loss: 20.0723 - val_accuracy: 0.4000
# Epoch 124/150
# 5/5 [==============================] - 3s 561ms/step - loss: 3.1116 - accuracy: 0.8000 - val_loss: 31.9840 - val_accuracy: 0.4000
# Epoch 125/150
# 5/5 [==============================] - 3s 552ms/step - loss: 4.9712 - accuracy: 0.8250 - val_loss: 35.0832 - val_accuracy: 0.4000
# Epoch 126/150
# 5/5 [==============================] - 3s 553ms/step - loss: 1.2731 - accuracy: 0.8250 - val_loss: 175.5483 - val_accuracy: 0.5000
# Epoch 127/150
# 5/5 [==============================] - 3s 558ms/step - loss: 3.8867 - accuracy: 0.8250 - val_loss: 28.4037 - val_accuracy: 0.6000
# Epoch 128/150
# 5/5 [==============================] - 3s 547ms/step - loss: 4.7279 - accuracy: 0.8250 - val_loss: 25.3887 - val_accuracy: 0.6000
# Epoch 129/150
# 5/5 [==============================] - 3s 553ms/step - loss: 2.2824 - accuracy: 0.9000 - val_loss: 49.0638 - val_accuracy: 0.4000
# Epoch 130/150
# 5/5 [==============================] - 3s 635ms/step - loss: 3.9118 - accuracy: 0.8000 - val_loss: 97.4944 - val_accuracy: 0.3000
# Epoch 131/150
# 5/5 [==============================] - 3s 556ms/step - loss: 6.1016 - accuracy: 0.8250 - val_loss: 2.5374 - val_accuracy: 0.9000
# Epoch 132/150
# 5/5 [==============================] - 3s 553ms/step - loss: 3.5859 - accuracy: 0.8250 - val_loss: 6.6221 - val_accuracy: 0.8000
# Epoch 133/150
# 5/5 [==============================] - 3s 555ms/step - loss: 0.7491 - accuracy: 0.9750 - val_loss: 81.1343 - val_accuracy: 0.5000
# Epoch 134/150
# 5/5 [==============================] - 3s 555ms/step - loss: 5.6077 - accuracy: 0.8000 - val_loss: 17.9099 - val_accuracy: 0.7000
# Epoch 135/150
# 5/5 [==============================] - 3s 552ms/step - loss: 3.9127 - accuracy: 0.8750 - val_loss: 3.5417 - val_accuracy: 0.9000
# Epoch 136/150
# 5/5 [==============================] - 3s 552ms/step - loss: 1.8538 - accuracy: 0.8750 - val_loss: 8.8260 - val_accuracy: 0.8000
# Epoch 137/150
# 5/5 [==============================] - 3s 555ms/step - loss: 5.7404 - accuracy: 0.8500 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 138/150
# 5/5 [==============================] - 3s 635ms/step - loss: 2.8720 - accuracy: 0.8750 - val_loss: 6.2596 - val_accuracy: 0.8000
# Epoch 139/150
# 5/5 [==============================] - 3s 554ms/step - loss: 4.3748 - accuracy: 0.7750 - val_loss: 3.7751 - val_accuracy: 0.7000
# Epoch 140/150
# 5/5 [==============================] - 3s 552ms/step - loss: 4.7147 - accuracy: 0.7250 - val_loss: 25.2779 - val_accuracy: 0.7000
# Epoch 141/150
# 5/5 [==============================] - 3s 554ms/step - loss: 2.6894 - accuracy: 0.9000 - val_loss: 141.9812 - val_accuracy: 0.2000
# Epoch 142/150
# 5/5 [==============================] - 3s 556ms/step - loss: 2.5375 - accuracy: 0.8500 - val_loss: 173.5583 - val_accuracy: 0.2000
# Epoch 143/150
# 5/5 [==============================] - 3s 580ms/step - loss: 8.8689 - accuracy: 0.7000 - val_loss: 59.5473 - val_accuracy: 0.6000
# Epoch 144/150
# 5/5 [==============================] - 3s 553ms/step - loss: 7.1284 - accuracy: 0.7750 - val_loss: 407.4309 - val_accuracy: 0.2000
# Epoch 145/150
# 5/5 [==============================] - 3s 553ms/step - loss: 2.1707 - accuracy: 0.9000 - val_loss: 346.5106 - val_accuracy: 0.2000
# Epoch 146/150
# 5/5 [==============================] - 3s 551ms/step - loss: 1.2784 - accuracy: 0.9250 - val_loss: 290.6852 - val_accuracy: 0.3000
# Epoch 147/150
# 5/5 [==============================] - 3s 627ms/step - loss: 1.7197 - accuracy: 0.7250 - val_loss: 328.6873 - val_accuracy: 0.2000
# Epoch 148/150
# 5/5 [==============================] - 3s 549ms/step - loss: 2.1078 - accuracy: 0.8000 - val_loss: 136.5647 - val_accuracy: 0.1000
# Epoch 149/150
# 5/5 [==============================] - 3s 552ms/step - loss: 2.0458 - accuracy: 0.8000 - val_loss: 94.7360 - val_accuracy: 0.5000
# Epoch 150/150
# 5/5 [==============================] - 3s 551ms/step - loss: 0.7759 - accuracy: 0.9000 - val_loss: 56.2519 - val_accuracy: 0.6000
