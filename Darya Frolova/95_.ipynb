# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/Darya-Frolova-folder/Darya%20Frolova/95_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ЗАГРУЗКА НЕОБХОДИМЫХ БИБЛИОТЕК

# %%
# Работа с массивами
import numpy as np

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Основа для создания последовательной модели
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Оптимизатор
from tensorflow.keras.optimizers import Adam

from tensorflow.data import Dataset

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Подключение модуля для загрузки данных
import gdown

# Инструменты для работы с файлами
import os

# Отрисовка графиков
import matplotlib.pyplot as plt

# Сегментация картинок
import cv2

# Рисование графиков в ячейках Colab
# %matplotlib inline

import random
from PIL import Image
import math
from PIL import Image, ImageEnhance
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.layers import Dropout, BatchNormalization

# %% [markdown]
# #Задание гиперпараметров модели

# %%
#Задание гиперпараметров

TRAINING_DATA       = '/content/iris_train'    # Папка для обучающего набора данных
TEST_DATA           = '/content/iris_test'     # Папка для тестового набора данных

TEST_SPLIT          = 0.2                      # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.2                      # Доля проверочной выборки в обучающем наборе
IMG_WIDTH           = 192                      # Ширина изображения для нейросети
IMG_HEIGHT          = 144                      # Высота изображения для нейросети
IMG_CHANNELS        = 3                        # Количество каналов (для RGB равно 3, для Grey равно 1)

# Параметры аугментации
ROTATION_RANGE      = 2                        # Пределы поворота
WIDTH_SHIFT_RANGE   = 5                        # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 5                        # Пределы сдвига по вертикали
HORIZONTAL_FLIP     = True                     # Горизонтальное отражение разрешено


EPOCHS              = 200                      # Число эпох обучения
BATCH_SIZE          = 10                       # Размер батча для обучения модели
OPTIMIZER           = Adam(0.00001)            # Оптимизатор

# %% [markdown]
# #ЗАГРУЗКА ДАТАСЕТА И ПОДГОТОВКА ДАННЫХ

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=1RbG7rr_M0DFKEelNVLZyY1tvF4hIWxLM', None, quiet=True)
# Out:
# 'DATASET_1.zip'

# %%
# Очистка данных от прошлого запуска
# !rm -rf {TRAINING_DATA} {TEST_PATH}
# !rm -rf `find -type d -name .ipynb_checkpoints`
# Разархивация датасета в директорию данных
# !unzip -qo "DATASET_1.zip" -d {TRAINING_DATA}

# %% [markdown]
# **Определяем список классов и их число:**

# %%
#Задаем список классов из списка папок
CLASS_LIST = sorted(os.listdir(TRAINING_DATA)) # Определение списка имен классов
CLASS_COUNT = len(CLASS_LIST)  # Определение количества классов
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}') # Проверка результата
# Out:
# Количество классов: 64, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    class_path = f'{TRAINING_DATA}/{CLASS_LIST[i]}'
    # Выбор случайного фото из i-го класса
    img_path = class_path +'/'+random.choice(os.listdir(class_path))
    # Отображение фотографии
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))
    axs[i].axis('off')

# %%
# Перенос файлов для теста в отдельное дерево папок, расчет размеров наборов данных
#os.mkdir(TEST_DATA)
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAINING_DATA}/{class_name}'           # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_DATA}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    #os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# #Аугментация и формирование выборок

# %%
# Генераторы изображений
# Изображения для обучающего набора нормализуются и аугментируются согласно заданным гиперпараметрам
# Далее набор будет разделен на обучающую и проверочную выборку в соотношении VAL_SPLIT

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Изображения для тестовой выборки остаются в прежнем виде, только проводим нормализацию:
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки из папки обучающего набора
train_generator = train_datagen.flow_from_directory(
    TRAINING_DATA,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='training'
)

# Создание проверочной выборки из папки обучающего набора
validation_generator = train_datagen.flow_from_directory(
    TRAINING_DATA,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_DATA,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 256 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (10, 144, 192, 3), (10, 64), батчей: 26
# Формы данных   проверочной выборки: (10, 144, 192, 3), (10, 64), батчей: 7
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %% [markdown]
# #ПРОВЕРКА РАБОТЫ ГЕНЕРАТОРОВ ВЫБОРОК

# %%
# Проверка одного изображения из выборки
plt.imshow(train_generator[1][0][2])
plt.show()

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 6),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(8), columns = 4)

# %%
# Вывод примеров из 0-го батча validation_generator
show_batch(validation_generator[0])

# %% [markdown]
# #Создание и обучение модели нейронной сети

# %% [markdown]
# #СОЗДАНИЕ СЕРВИСНЫХ ФУНКЦИЙ

# %%
# Функция компиляции и обучения модели нейронной сети
# По окончанию выводит графики обучения
def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                       epochs=epochs,
                       batch_size=batch_size,
                       validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'],
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция вывода результатов оценки модели на заданных данных
def eval_model(model,
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(10, 10)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    plt.show()

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Формируется сообщение о верности или неверности предсказания
        msg = 'ВЕРНО :-)' if cls_pred == cls else 'НЕВЕРНО :-('
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети
def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model,
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1],
               class_labels=class_labels,
               title=title,
               figsize=cm_size)

# %% [markdown]
# #Архитектура модели нейронной сети

# %%
# Создание последовательной модели
model = Sequential()

# Первый сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model.add(BatchNormalization())

# Второй сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Четвертый сверточный слой
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.2))

# Пятый сверточный слой
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

# Слой преобразования многомерных данных в одномерные
model.add(Flatten())

# Промежуточный полносвязный слой
model.add(Dense(512, activation='relu'))


# Промежуточный полносвязный слой
model.add(Dense(1024, activation='relu'))


# Выходной полносвязный слой с количеством нейронов по количесту классов
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         )
# Out:
# Epoch 1/200
# 26/26 [==============================] - 15s 298ms/step - loss: 4.4596 - accuracy: 0.0078 - val_loss: 4.1601 - val_accuracy: 0.0156
# Epoch 2/200
# 26/26 [==============================] - 6s 221ms/step - loss: 4.1500 - accuracy: 0.0234 - val_loss: 4.1640 - val_accuracy: 0.0156
# Epoch 3/200
# 26/26 [==============================] - 7s 262ms/step - loss: 4.0134 - accuracy: 0.0430 - val_loss: 4.1733 - val_accuracy: 0.0156
# Epoch 4/200
# 26/26 [==============================] - 6s 218ms/step - loss: 3.8624 - accuracy: 0.0664 - val_loss: 4.1924 - val_accuracy: 0.0156
# Epoch 5/200
# 26/26 [==============================] - 7s 256ms/step - loss: 3.6980 - accuracy: 0.1055 - val_loss: 4.2195 - val_accuracy: 0.0156
# Epoch 6/200
# 26/26 [==============================] - 6s 226ms/step - loss: 3.5125 - accuracy: 0.1289 - val_loss: 4.2703 - val_accuracy: 0.0156
# Epoch 7/200
# 26/26 [==============================] - 7s 253ms/step - loss: 3.3208 - accuracy: 0.1836 - val_loss: 4.3331 - val_accuracy: 0.0156
# Epoch 8/200
# 26/26 [==============================] - 6s 222ms/step - loss: 3.1527 - accuracy: 0.2148 - val_loss: 4.4379 - val_accuracy: 0.0156
# Epoch 9/200
# 26/26 [==============================] - 8s 296ms/step - loss: 2.8946 - accuracy: 0.2500 - val_loss: 4.5287 - val_accuracy: 0.0156
# Epoch 10/200
# 26/26 [==============================] - 6s 228ms/step - loss: 2.6917 - accuracy: 0.3086 - val_loss: 4.6314 - val_accuracy: 0.0156
200
# 26/26 [==============================] - 6s 218ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.3325 - val_accuracy: 0.8438
# Epoch 92/200
# 26/26 [==============================] - 7s 257ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.3435 - val_accuracy: 0.8594
# Epoch 93/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.3144 - val_accuracy: 0.8906
# Epoch 94/200
# 26/26 [==============================] - 7s 255ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.3219 - val_accuracy: 0.9219
# Epoch 95/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.2811 - val_accuracy: 0.9219
# Epoch 96/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.9375
# Epoch 97/200
# 26/26 [==============================] - 6s 231ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.8594
# Epoch 98/200
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.3373 - val_accuracy: 0.8906
# Epoch 99/200
# 26/26 [==============================] - 6s 221ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.3024 - val_accuracy: 0.8750
# Epoch 100/200
# 26/26 [==============================] - 7s 256ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.3432 - val_accuracy: 0.8750
# Epoch 101/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.3729 - val_accuracy: 0.8594
# Epoch 102/200
# 26/26 [==============================] - 7s 254ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.8750
# Epoch 103/200
# 26/26 [==============================] - 6s 219ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.3495 - val_accuracy: 0.8906
# Epoch 104/200
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0172 - accuracy: 0.9961 - val_loss: 0.3111 - val_accuracy: 0.8750
# Epoch 105/200
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.2395 - val_accuracy: 0.9219
# Epoch 106/200
# 26/26 [==============================] - 7s 264ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.2358 - val_accuracy: 0.8906
# Epoch 107/200
# 26/26 [==============================] - 6s 222ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.2991 - val_accuracy: 0.8750
# Epoch 108/200
# 26/26 [==============================] - 6s 222ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.4251 - val_accuracy: 0.8750
# Epoch 109/200
# 26/26 [==============================] - 7s 253ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.3082 - val_accuracy: 0.9062
# Epoch 110/200
# 26/26 [==============================] - 6s 226ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.9219
# Epoch 111/200
# 26/26 [==============================] - 7s 253ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.3792 - val_accuracy: 0.8594
# Epoch 112/200
# 26/26 [==============================] - 6s 221ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.3147 - val_accuracy: 0.8906
# Epoch 113/200
# 26/26 [==============================] - 7s 253ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.3006 - val_accuracy: 0.9062
# Epoch 114/200
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0216 - accuracy: 0.9961 - val_loss: 0.3296 - val_accuracy: 0.8750
# Epoch 115/200
# 26/26 [==============================] - 7s 253ms/step - loss: 0.0213 - accuracy: 0.9961 - val_loss: 0.3553 - val_accuracy: 0.8750
# Epoch 116/200
# 26/26 [==============================] - 6s 229ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.3240 - val_accuracy: 0.8906
# Epoch 117/200
# 26/26 [==============================] - 8s 296ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.3849 - val_accuracy: 0.8594
# Epoch 118/200
# 26/26 [==============================] - 6s 226ms/step - loss: 0.0144 - accuracy: 0.9961 - val_loss: 0.2901 - val_accuracy: 0.8906
# Epoch 119/200
# 26/26 [==============================] - 7s 252ms/step - loss: 0.0217 - accuracy: 0.9922 - val_loss: 0.3220 - val_accuracy: 0.8750
# Epoch 120/200
# 26/26 [==============================] - 7s 277ms/step - loss: 0.0241 - accuracy: 0.9922 - val_loss: 0.2333 - val_accuracy: 0.9062
# Epoch 121/200
# 26/26 [==============================] - 6s 219ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9062
# Epoch 122/200
# 26/26 [==============================] - 7s 254ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2726 - val_accuracy: 0.8906
# Epoch 123/200
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.3540 - val_accuracy: 0.8750
# Epoch 124/200
# 26/26 [==============================] - 7s 258ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2741 - val_accuracy: 0.9219
# Epoch 125/200
# 26/26 [==============================] - 6s 218ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2939 - val_accuracy: 0.9062
# Epoch 126/200
# 26/26 [==============================] - 7s 289ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.9062
# Epoch 127/200
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.3592 - val_accuracy: 0.8750
# Epoch 128/200
# 26/26 [==============================] - 7s 253ms/step - loss: 0.0233 - accuracy: 0.9961 - val_loss: 0.3447 - val_accuracy: 0.8594
# Epoch 129/200
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0324 - accuracy: 0.9961 - val_loss: 0.2441 - val_accuracy: 0.9062
# Epoch 130/200
# 26/26 [==============================] - 7s 255ms/step - loss: 0.0190 - accuracy: 0.9922 - val_loss: 0.2529 - val_accuracy: 0.9219
# Epoch 131/200
# 26/26 [==============================] - 6s 218ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.3291 - val_accuracy: 0.8906
# Epoch 132/200
# 26/26 [==============================] - 7s 260ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.3408 - val_accuracy: 0.8906
# Epoch 133/200
# 26/26 [==============================] - 6s 225ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.8594
# Epoch 134/200
# 26/26 [==============================] - 7s 262ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2396 - val_accuracy: 0.9219
# Epoch 135/200
# 26/26 [==============================] - 6s 222ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.2999 - val_accuracy: 0.8594
# Epoch 136/200
# 26/26 [==============================] - 7s 255ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2692 - val_accuracy: 0.9062
# Epoch 137/200
# 26/26 [==============================] - 6s 219ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9062
# Epoch 138/200
# 26/26 [==============================] - 7s 257ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.3073 - val_accuracy: 0.8750
# Epoch 139/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2841 - val_accuracy: 0.8438
# Epoch 140/200
# 26/26 [==============================] - 7s 253ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.8750
# Epoch 141/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.8906
# Epoch 142/200
# 26/26 [==============================] - 8s 301ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2899 - val_accuracy: 0.8906
# Epoch 143/200
# 26/26 [==============================] - 6s 218ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9219
# Epoch 144/200
# 26/26 [==============================] - 7s 252ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9219
# Epoch 145/200
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2975 - val_accuracy: 0.9062
# Epoch 146/200
# 26/26 [==============================] - 7s 254ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2717 - val_accuracy: 0.8906
# Epoch 147/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9375
# Epoch 148/200
# 26/26 [==============================] - 7s 263ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9062
# Epoch 149/200
# 26/26 [==============================] - 6s 216ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.3430 - val_accuracy: 0.8750
# Epoch 150/200
# 26/26 [==============================] - 7s 261ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.8906
# Epoch 151/200
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9375
# Epoch 152/200
# 26/26 [==============================] - 6s 222ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9062
# Epoch 153/200
# 26/26 [==============================] - 7s 254ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.8906
# Epoch 154/200
# 26/26 [==============================] - 6s 219ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2811 - val_accuracy: 0.9062
# Epoch 155/200
# 26/26 [==============================] - 6s 244ms/step - loss: 0.0082 - accuracy: 0.9961 - val_loss: 0.3971 - val_accuracy: 0.8750
# Epoch 156/200
# 26/26 [==============================] - 6s 226ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9531
# Epoch 157/200
# 26/26 [==============================] - 6s 244ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2421 - val_accuracy: 0.8906
# Epoch 158/200
# 26/26 [==============================] - 6s 226ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.3816 - val_accuracy: 0.8750
# Epoch 159/200
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3358 - val_accuracy: 0.8594
# Epoch 160/200
# 26/26 [==============================] - 6s 228ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9219
# Epoch 161/200
# 26/26 [==============================] - 7s 265ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9062
# Epoch 162/200
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2763 - val_accuracy: 0.8906
# Epoch 163/200
# 26/26 [==============================] - 7s 258ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2475 - val_accuracy: 0.9219
# Epoch 164/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9062
# Epoch 165/200
# 26/26 [==============================] - 6s 249ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2383 - val_accuracy: 0.9062
# Epoch 166/200
# 26/26 [==============================] - 6s 217ms/step - loss: 0.0321 - accuracy: 0.9844 - val_loss: 0.1745 - val_accuracy: 0.9219
# Epoch 167/200
# 26/26 [==============================] - 6s 219ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1811 - val_accuracy: 0.9531
# Epoch 168/200
# 26/26 [==============================] - 6s 249ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9062
# Epoch 169/200
# 26/26 [==============================] - 6s 221ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9062
# Epoch 170/200
# 26/26 [==============================] - 6s 220ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1794 - val_accuracy: 0.9531
# Epoch 171/200
# 26/26 [==============================] - 6s 240ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2632 - val_accuracy: 0.9219
# Epoch 172/200
# 26/26 [==============================] - 6s 218ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2541 - val_accuracy: 0.9062
# Epoch 173/200
# 26/26 [==============================] - 6s 240ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3285 - val_accuracy: 0.8750
# Epoch 174/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2437 - val_accuracy: 0.8906
# Epoch 175/200
# 26/26 [==============================] - 6s 225ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9062
# Epoch 176/200
# 26/26 [==============================] - 6s 239ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9219
# Epoch 177/200
# 26/26 [==============================] - 6s 229ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9375
# Epoch 178/200
# 26/26 [==============================] - 6s 230ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.8906
# Epoch 179/200
# 26/26 [==============================] - 6s 235ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9219
# Epoch 180/200
# 26/26 [==============================] - 6s 229ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.3278 - val_accuracy: 0.8594
# Epoch 181/200
# 26/26 [==============================] - 6s 240ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0