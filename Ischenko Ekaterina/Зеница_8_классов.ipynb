# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/main/Ischenko%20Ekaterina/%D0%97%D0%B5%D0%BD%D0%B8%D1%86%D0%B0_8_%D0%BA%D0%BB%D0%B0%D1%81%D1%81%D0%BE%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# АЛГОРИТМ
# 1.   Загрузка данных
# 2.   Формирование датасета
# 3.   Аугментация, создание выборок
# 4.   Построение модели
# 5.   Обучение
# 6.   Подбор параметров для получения точности 97%
# 7.   Визуализация

# %% [markdown]
# ## Загрузка данных

# %%
# Сеть прямого распространения
from tensorflow.keras.models import Sequential

# Базовые слои для свёрточных сетей
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Работа с изображениями
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Оптимизаторы
from tensorflow.keras.optimizers import Adam

# Используем для to_categoricall
from tensorflow.keras import utils

# Для отрисовки изображений
from tensorflow.keras.preprocessing import image

# Библиотека работы с массивами
import numpy as np

# Для отрисовки графиков
import matplotlib.pyplot as plt

# Для отрисовки изображений
from PIL import Image

# Для генерации случайных чисел
import random

# Для округления
import math

# Для работы с файлами
import os
import shutil

# Для работы с файлами
import gc

# импортируем модуль для загрузки данных
import gdown

# для разделения выборок
from sklearn.model_selection import train_test_split

# импорт tensorflow
import tensorflow as tf

# модуль для отсчета времени
import time

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Подключение гугл диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Задание переменных

# %%
# задание переменных
ZIP_FILE = '/content/drive/MyDrive/ZENICA/iris49_56.zip' # исходный zip-файл
TRAIN_PATH = '/content/drive/MyDrive/ZENICA/iris_base' # путь к тренировочной базе в Google Drive
TEST_PATH = '/content/drive/MyDrive/ZENICA/iris_test' # путь к тестовой базе в Google Drive

# %%
TEST_SPLIT = 0.2
VAL_SPLIT = 0.2

# %%
IMG_WIDTH           = 192 # 768                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144 #576                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %% [markdown]
# ## Формирование датасета

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_PATH} {TEST_PATH}

# Архив разархивируем в путь TRAIN_PATH
# !unzip -q {ZIP_FILE} -d {TRAIN_PATH} # Указываем путь к базе в Google Drive

# Проверяем, что в базе?
print('Проверяем, что в папке TRAIN_PATH:',os.listdir(TRAIN_PATH))

# Создаем сортированный список из базы
train_list = sorted(os.listdir(TRAIN_PATH))
print('Отсортированный список train_list:', train_list)

len_list = len(train_list)  # Длина списка

# Проверка результата
print(f'Количество файлов: {len_list}')
# Out:
# Проверяем, что в папке TRAIN_PATH: ['056R_1.png', '049L_2.png', '049L_3.png', '049R_1.png', '049R_2.png', '049R_3.png', '050L_1.png', '050L_2.png', '050L_3.png', '050R_1.png', '050R_2.png', '050R_3.png', '051L_1.png', '051L_2.png', '051L_3.png', '051R_1.png', '051R_2.png', '051R_3.png', '052L_1.png', '052L_2.png', '052L_3.png', '052R_1.png', '052R_2.png', '052R_3.png', '053L_1.png', '053L_2.png', '053L_3.png', '053R_1.png', '053R_2.png', '053R_3.png', '054L_1.png', '054L_2.png', '054L_3.png', '054R_1.png', '054R_2.png', '054R_3.png', '055L_1.png', '055L_2.png', '055L_3.png', '055R_1.png', '055R_2.png', '055R_3.png', '056L_1.png', '056L_2.png', '056L_3.png', '049L_1.png', '056R_2.png', '056R_3.png']
# Отсортированный список train_list: ['049L_1.png', '049L_2.png', '049L_3.png', '049R_1.png', '049R_2.png', '049R_3.png', '050L_1.png', '050L_2.png', '050L_3.png', '050R_1.png', '050R_2.png', '050R_3.png', '051L_1.png', '051L_2.png', '051L_3.png', '051R_1.png', '051R_2.png', '051R_3.png', '052L_1.png', '052L_2.png', '052L_3.png', '052R_1.png', '052R_2.png', '052R_3.png', '053L_1.png', '053L_2.png', '053L_3.png', '053R_1.png', '053R_2.png', '053R_3.png', '054L_1.png', '054L_2.png', '054L_3.png', '054R_1.png', '054R_2.png', '054R_3.png', '055L_1.png', '055L_2.png', '055L_3.png', '055R_1.png', '055R_2.png', '055R_3.png', '056L_1.png', '056L_2.png', '056L_3.png', '056R_1.png', '056R_2.png', '056R_3.png']
# Количество файлов: 48

# %%
# Создаем папки для каждого класса и перемещаем файлы С ГЛАЗАМИ в соответствующую папку ИХ КЛАССА
CLASS_LIST = []           # Список папок - пока пуст
for i in range(len_list):           # перебираем файлы с глазами в списке train_list
        file_name=train_list[i]      # берем название файла с глазом
        class_name = file_name[:3]  # создаем название папки из первых трех символов
        class_full_path = os.path.join(TRAIN_PATH,class_name)  # создаем полный путь к папке
        if not os.path.exists(class_full_path):                # если такой папки нет, то создаем папку
               os.makedirs(class_full_path)
               CLASS_LIST.append(class_name)
        shutil.move(os.path.join(TRAIN_PATH,file_name), class_full_path) #переносим файл с глазом в папку правильного класса
CLASS_COUNT = len(CLASS_LIST)        # получилось такое количество классов CLASS_COUNT
print(f'Создано (CLASS_COUNT):{CLASS_COUNT} папок. Названия папок классов = список CLASS_LIST: {CLASS_LIST}')
# Out:
# Создано (CLASS_COUNT):8 папок. Названия папок классов = список CLASS_LIST: ['049', '050', '051', '052', '053', '054', '055', '056']

# %%
# создание итоговых списков "путь изображения + метка класса" для обучения

# Создание директории тестовых данных
os.mkdir(TEST_PATH)
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path_f = f'{TRAIN_PATH}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path_f = f'{TEST_PATH}/{class_name}'           # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path_f)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path_f)                               # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path_f}/{f}', f'{test_path_f}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 48, выделено для обучения: 40, для теста: 8

# %% [markdown]
# ## Аугментация

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 4                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.08                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.08                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.08                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.85, 1.15)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение запрещено

BATCH_SIZE          = 8                     # Размер батча
EPOCHS              = 250                   # Эпох обучения
OPTIMIZER           = Adam(0.0001)           # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='training'
)
# Out:
# Found 32 images belonging to 8 classes.

# %%
# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 8 images belonging to 8 classes.
# Found 8 images belonging to 8 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 144, 192, 3), (8, 8), батчей: 4
# Формы данных   проверочной выборки: (8, 144, 192, 3), (8, 8), батчей: 1
# Формы данных      тестовой выборки: (8, 144, 192, 3), (8, 8), батчей: 1
#
# Метки классов тренировочной выборки: {'049': 0, '050': 1, '051': 2, '052': 3, '053': 4, '054': 5, '055': 6, '056': 7}
# Метки классов   проверочной выборки: {'049': 0, '050': 1, '051': 2, '052': 3, '053': 4, '054': 5, '055': 6, '056': 7}
# Метки классов      тестовой выборки: {'049': 0, '050': 1, '051': 2, '052': 3, '053': 4, '054': 5, '055': 6, '056': 7}

# %%
# Проверка одного изображения из выборки
#Аугментация работает "на лету".
#Индексы для примера выбраны такие: [1][0][2], что означает:
#1: номер батча в выборке. Сам батч - это кортеж (x_train, y_train) с примерами и метками классов;
#0: первый элемент в кортеже, то есть сами изображения. Под индексом 1 будут метки классов в формате one hot encoding для изображений;
#2: номер картинки в батче.

plt.imshow(train_generator[1][0][2])
plt.show()

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25,8),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
#show_batch(train_generator[0])
show_batch(train_generator[1], range(8), columns = 4)

# %%
show_batch(validation_generator[0], range(8), columns = 4)

# %%
show_batch(test_generator[0], range(8), columns = 4)

# %% [markdown]
# ## Создание и обучение модели нейронной сети

# %% [markdown]
# ### Сервисные функции

# %%
# Функция компиляции и обучения модели нейронной сети
# По окончанию выводит графики обучения

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Вывод сводки
    model.summary()

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'],
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция вывода результатов оценки модели на заданных данных

def eval_model(model,
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(10, 10)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    plt.show()

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Формируется сообщение о верности или неверности предсказания
        msg = 'ВЕРНО :-)' if cls_pred == cls else 'НЕВЕРНО :-('
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model,
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1],
               class_labels=class_labels,
               title=title,
               figsize=cm_size)

# %% [markdown]
# ### Архитектура модели нейронной сети

# %%
# Создание последовательной модели
model_conv = Sequential()

# Первый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model_conv.add(BatchNormalization())

# Второй сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())
model_conv.add(Dropout(0.2))

# Четвертый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Пятый сверточный слой
model_conv.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())

# Шестой сверточный слой
model_conv.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Слой преобразования многомерных данных в одномерные
model_conv.add(Flatten())

# Промежуточный полносвязный слой
model_conv.add(Dense(2048, activation='relu'))

# Промежуточный полносвязный слой
model_conv.add(Dense(4096, activation='relu'))

# Выходной полносвязный слой с количеством нейронов по количеству классов
model_conv.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model_conv,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         title='Сверточный классификатор')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 144, 192, 256)     7168
#
#  batch_normalization (BatchN  (None, 144, 192, 256)    1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 144, 192, 256)     590080
#
#  max_pooling2d (MaxPooling2D  (None, 48, 64, 256)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 48, 64, 256)       590080
#
#  batch_normalization_1 (Batc  (None, 48, 64, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 48, 64, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 48, 64, 256)       590080
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 21, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 21, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 16, 21, 512)       1180160
#
#  batch_normalization_2 (Batc  (None, 16, 21, 512)      2048
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 16, 21, 1024)      4719616
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 7, 1024)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 5, 7, 1024)        0
#
#  flatten (Flatten)           (None, 35840)             0
#
#  dense (Dense)               (None, 2048)              73402368
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  dense_2 (Dense)             (None, 8)                 32776
#
# =================================================================
# Total params: 89,509,128
# Trainable params: 89,507,080
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/250
# 4/4 [==============================] - 21s 430ms/step - loss: 13.5487 - accuracy: 0.1250 - val_loss: 2.0895 - val_accuracy: 0.1250
# Epoch 2/250
# 4/4 [==============================] - 1s 319ms/step - loss: 16.1843 - accuracy: 0.1562 - val_loss: 2.0896 - val_accuracy: 0.1250
# Epoch 3/250
# 4/4 [==============================] - 1s 342ms/step - loss: 6.7020 - accuracy: 0.1250 - val_loss: 2.0845 - val_accuracy: 0.1250
# Epoch 4/250
# 4/4 [==============================] - 1s 309ms/step - loss: 3.8381 - accuracy: 0.2188 - val_loss: 2.0765 - val_accuracy: 0.1250
# Epoch 5/250
# 4/4 [==============================] - 2s 537ms/step - loss: 3.4117 - accuracy: 0.1250 - val_loss: 2.0851 - val_accuracy: 0.1250
# Epoch 6/250
# 4/4 [==============================] - 2s 400ms/step - loss: 2.4545 - accuracy: 0.3750 - val_loss: 2.0911 - val_accuracy: 0.1250
# Epoch 7/250
# 4/4 [==============================] - 1s 301ms/step - loss: 1.9282 - accuracy: 0.3125 - val_loss: 2.0883 - val_accuracy: 0.1250
# Epoch 8/250
# 4/4 [==============================] - 1s 314ms/step - loss: 1.6386 - accuracy: 0.2500 - val_loss: 2.1064 - val_accuracy: 0.2500
# Epoch 9/250
# 4/4 [==============================] - 1s 317ms/step - loss: 1.4419 - accuracy: 0.5000 - val_loss: 2.1111 - val_accuracy: 0.1250
# Epoch 10/250
# 4/4 [==============================] - 1s 312ms/step - loss: 1.1660 - accuracy: 0.6250 - val_loss: 2.1463 - val_accuracy: 0.1250
# Epoch 11/250
# 4/4 [==============================] - 1s 309ms/step - loss: 1.0355 - accuracy: 0.6250 - val_loss: 2.2190 - val_accuracy: 0.1250
# Epoch 12/250
# 4/4 [==============================] - 2s 433ms/step - loss: 0.9149 - accuracy: 0.6562 - val_loss: 2.2406 - val_accuracy: 0.1250
# Epoch 13/250
# 4/4 [==============================] - 2s 370ms/step - loss: 0.7671 - accuracy: 0.6875 - val_loss: 2.3016 - val_accuracy: 0.1250
# Epoch 14/250
# 4/4 [==============================] - 1s 305ms/step - loss: 0.7820 - accuracy: 0.7188 - val_loss: 2.2993 - val_accuracy: 0.1250
# Epoch 15/250
# 4/4 [==============================] - 1s 306ms/step - loss: 0.5815 - accuracy: 0.8125 - val_loss: 2.3928 - val_accuracy: 0.1250
# Epoch 16/250
# 4/4 [==============================] - 1s 304ms/step - loss: 0.4225 - accuracy: 0.8750 - val_loss: 2.4145 - val_accuracy: 0.1250
# Epoch 17/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.5893 - accuracy: 0.8125 - val_loss: 2.5390 - val_accuracy: 0.1250
# Epoch 18/250
# 4/4 [==============================] - 1s 318ms/step - loss: 0.6899 - accuracy: 0.7812 - val_loss: 2.4607 - val_accuracy: 0.1250
# Epoch 19/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.6052 - accuracy: 0.7188 - val_loss: 2.3814 - val_accuracy: 0.1250
# Epoch 20/250
# 4/4 [==============================] - 2s 412ms/step - loss: 0.4386 - accuracy: 0.7812 - val_loss: 2.5774 - val_accuracy: 0.1250
# Epoch 21/250
# 4/4 [==============================] - 2s 383ms/step - loss: 0.4308 - accuracy: 0.8125 - val_loss: 2.5328 - val_accuracy: 0.1250
# Epoch 22/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.2722 - accuracy: 0.9062 - val_loss: 2.6137 - val_accuracy: 0.1250
# Epoch 23/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.4201 - accuracy: 0.7812 - val_loss: 2.8334 - val_accuracy: 0.1250
# Epoch 24/250
# 4/4 [==============================] - 1s 318ms/step - loss: 0.4927 - accuracy: 0.8125 - val_loss: 2.6397 - val_accuracy: 0.1250
# Epoch 25/250
# 4/4 [==============================] - 1s 314ms/step - loss: 0.5132 - accuracy: 0.8438 - val_loss: 2.7632 - val_accuracy: 0.2500
# Epoch 26/250
# 4/4 [==============================] - 1s 343ms/step - loss: 0.4313 - accuracy: 0.8125 - val_loss: 2.9170 - val_accuracy: 0.1250
# Epoch 27/250
# 4/4 [==============================] - 2s 438ms/step - loss: 0.3453 - accuracy: 0.9062 - val_loss: 3.0856 - val_accuracy: 0.1250
# Epoch 28/250
# 4/4 [==============================] - 1s 306ms/step - loss: 0.4327 - accuracy: 0.7812 - val_loss: 3.3671 - val_accuracy: 0.1250
# Epoch 29/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.3361 - accuracy: 0.8750 - val_loss: 3.2965 - val_accuracy: 0.1250
# Epoch 30/250
# 4/4 [==============================] - 1s 307ms/step - loss: 0.1955 - accuracy: 0.9375 - val_loss: 3.0411 - val_accuracy: 0.2500
# Epoch 31/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.2618 - accuracy: 0.9062 - val_loss: 3.3134 - val_accuracy: 0.2500
# Epoch 32/250
# 4/4 [==============================] - 1s 308ms/step - loss: 0.1208 - accuracy: 0.9688 - val_loss: 3.7089 - val_accuracy: 0.1250
# Epoch 33/250
# 4/4 [==============================] - 1s 319ms/step - loss: 0.5605 - accuracy: 0.7812 - val_loss: 4.0779 - val_accuracy: 0.2500
# Epoch 34/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.1417 - accuracy: 0.9375 - val_loss: 3.6071 - val_accuracy: 0.2500
# Epoch 35/250
# 4/4 [==============================] - 2s 425ms/step - loss: 0.4180 - accuracy: 0.8750 - val_loss: 3.9469 - val_accuracy: 0.1250
# Epoch 36/250
# 4/4 [==============================] - 2s 432ms/step - loss: 0.5641 - accuracy: 0.9062 - val_loss: 4.0772 - val_accuracy: 0.1250
# Epoch 37/250
# 4/4 [==============================] - 1s 319ms/step - loss: 0.1900 - accuracy: 0.9062 - val_loss: 3.2473 - val_accuracy: 0.2500
# Epoch 38/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.5003 - accuracy: 0.8438 - val_loss: 3.2762 - val_accuracy: 0.1250
# Epoch 39/250
# 4/4 [==============================] - 1s 305ms/step - loss: 0.0703 - accuracy: 1.0000 - val_loss: 3.2834 - val_accuracy: 0.1250
# Epoch 40/250
# 4/4 [==============================] - 1s 317ms/step - loss: 0.2278 - accuracy: 0.9062 - val_loss: 3.7256 - val_accuracy: 0.1250
# Epoch 41/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0852 - accuracy: 1.0000 - val_loss: 3.5147 - val_accuracy: 0.2500
# Epoch 42/250
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1448 - accuracy: 0.9375 - val_loss: 3.6619 - val_accuracy: 0.2500
# Epoch 43/250
# 4/4 [==============================] - 2s 406ms/step - loss: 0.1284 - accuracy: 0.9688 - val_loss: 4.1633 - val_accuracy: 0.1250
# Epoch 44/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.0638 - accuracy: 0.9688 - val_loss: 4.9799 - val_accuracy: 0.1250
# Epoch 45/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0496 - accuracy: 0.9688 - val_loss: 5.5366 - val_accuracy: 0.1250
# Epoch 46/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.2039 - accuracy: 0.9375 - val_loss: 5.8702 - val_accuracy: 0.1250
# Epoch 47/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0667 - accuracy: 0.9688 - val_loss: 5.7183 - val_accuracy: 0.1250
# Epoch 48/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.3171 - accuracy: 0.9062 - val_loss: 6.7935 - val_accuracy: 0.1250
# Epoch 49/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.3421 - accuracy: 0.9375 - val_loss: 6.3037 - val_accuracy: 0.1250
# Epoch 50/250
# 4/4 [==============================] - 2s 405ms/step - loss: 0.2376 - accuracy: 0.9688 - val_loss: 4.2551 - val_accuracy: 0.1250
# Epoch 51/250
# 4/4 [==============================] - 2s 458ms/step - loss: 0.1198 - accuracy: 0.9688 - val_loss: 4.2481 - val_accuracy: 0.1250
# Epoch 52/250
# 4/4 [==============================] - 1s 343ms/step - loss: 0.4066 - accuracy: 0.9375 - val_loss: 5.0329 - val_accuracy: 0.1250
# Epoch 53/250
# 4/4 [==============================] - 1s 319ms/step - loss: 0.6655 - accuracy: 0.8438 - val_loss: 5.3335 - val_accuracy: 0.1250
# Epoch 54/250
# 4/4 [==============================] - 1s 325ms/step - loss: 0.3146 - accuracy: 0.9375 - val_loss: 6.0166 - val_accuracy: 0.1250
# Epoch 55/250
# 4/4 [==============================] - 1s 319ms/step - loss: 0.1948 - accuracy: 0.9375 - val_loss: 6.8121 - val_accuracy: 0.1250
# Epoch 56/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 7.3102 - val_accuracy: 0.1250
# Epoch 57/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.0464 - accuracy: 0.9688 - val_loss: 7.4065 - val_accuracy: 0.1250
# Epoch 58/250
# 4/4 [==============================] - 2s 557ms/step - loss: 0.1488 - accuracy: 0.9688 - val_loss: 6.7534 - val_accuracy: 0.1250
# Epoch 59/250
# 4/4 [==============================] - 2s 426ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 5.0534 - val_accuracy: 0.1250
# Epoch 60/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.2586 - accuracy: 0.8750 - val_loss: 5.1929 - val_accuracy: 0.1250
# Epoch 61/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 6.1831 - val_accuracy: 0.1250
# Epoch 62/250
# 4/4 [==============================] - 1s 330ms/step - loss: 0.2867 - accuracy: 0.9375 - val_loss: 6.9531 - val_accuracy: 0.1250
# Epoch 63/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.2687 - accuracy: 0.9688 - val_loss: 6.9290 - val_accuracy: 0.1250
# Epoch 64/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0728 - accuracy: 0.9375 - val_loss: 5.5538 - val_accuracy: 0.1250
# Epoch 65/250
# 4/4 [==============================] - 2s 560ms/step - loss: 0.1043 - accuracy: 0.9688 - val_loss: 4.7465 - val_accuracy: 0.1250
# Epoch 66/250
# 4/4 [==============================] - 2s 353ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 4.3173 - val_accuracy: 0.1250
# Epoch 67/250
# 4/4 [==============================] - 1s 322ms/step - loss: 0.1611 - accuracy: 0.9062 - val_loss: 4.6273 - val_accuracy: 0.1250
# Epoch 68/250
# 4/4 [==============================] - 1s 334ms/step - loss: 0.3508 - accuracy: 0.9062 - val_loss: 4.4868 - val_accuracy: 0.1250
# Epoch 69/250
# 4/4 [==============================] - 1s 329ms/step - loss: 0.2567 - accuracy: 0.9062 - val_loss: 6.0172 - val_accuracy: 0.1250
# Epoch 70/250
# 4/4 [==============================] - 1s 336ms/step - loss: 0.0856 - accuracy: 0.9688 - val_loss: 8.6269 - val_accuracy: 0.1250
# Epoch 71/250
# 4/4 [==============================] - 2s 560ms/step - loss: 0.0442 - accuracy: 0.9688 - val_loss: 10.1507 - val_accuracy: 0.1250
# Epoch 72/250
# 4/4 [==============================] - 2s 624ms/step - loss: 0.1964 - accuracy: 0.9375 - val_loss: 10.8072 - val_accuracy: 0.1250
# Epoch 73/250
# 4/4 [==============================] - 2s 588ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 10.6009 - val_accuracy: 0.1250
# Epoch 74/250
# 4/4 [==============================] - 1s 323ms/step - loss: 0.0822 - accuracy: 0.9375 - val_loss: 8.4091 - val_accuracy: 0.1250
# Epoch 75/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.1615 - accuracy: 0.9062 - val_loss: 6.7333 - val_accuracy: 0.1250
# Epoch 76/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 5.9910 - val_accuracy: 0.1250
# Epoch 77/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.1185 - accuracy: 0.9375 - val_loss: 5.2748 - val_accuracy: 0.1250
# Epoch 78/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 4.6828 - val_accuracy: 0.2500
# Epoch 79/250
# 4/4 [==============================] - 1s 359ms/step - loss: 0.2202 - accuracy: 0.9062 - val_loss: 5.1426 - val_accuracy: 0.1250
# Epoch 80/250
# 4/4 [==============================] - 2s 420ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 6.8033 - val_accuracy: 0.1250
# Epoch 81/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 8.1753 - val_accuracy: 0.1250
# Epoch 82/250
# 4/4 [==============================] - 1s 309ms/step - loss: 0.0676 - accuracy: 0.9688 - val_loss: 8.6997 - val_accuracy: 0.1250
# Epoch 83/250
# 4/4 [==============================] - 1s 307ms/step - loss: 0.1008 - accuracy: 0.9688 - val_loss: 7.1262 - val_accuracy: 0.1250
# Epoch 84/250
# 4/4 [==============================] - 1s 309ms/step - loss: 0.2803 - accuracy: 0.9375 - val_loss: 7.0893 - val_accuracy: 0.1250
# Epoch 85/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.1377 - accuracy: 0.9375 - val_loss: 6.6278 - val_accuracy: 0.1250
# Epoch 86/250
# 4/4 [==============================] - 1s 349ms/step - loss: 0.0600 - accuracy: 0.9688 - val_loss: 6.1206 - val_accuracy: 0.1250
# Epoch 87/250
# 4/4 [==============================] - 2s 388ms/step - loss: 0.1426 - accuracy: 0.9375 - val_loss: 5.1338 - val_accuracy: 0.1250
# Epoch 88/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0802 - accuracy: 0.9688 - val_loss: 5.2105 - val_accuracy: 0.1250
# Epoch 89/250
# 4/4 [==============================] - 1s 322ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 5.2330 - val_accuracy: 0.1250
# Epoch 90/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 5.2710 - val_accuracy: 0.1250
# Epoch 91/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 5.1929 - val_accuracy: 0.1250
# Epoch 92/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 4.7717 - val_accuracy: 0.1250
# Epoch 93/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 4.6595 - val_accuracy: 0.1250
# Epoch 94/250
# 4/4 [==============================] - 2s 439ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 4.5617 - val_accuracy: 0.1250
# Epoch 95/250
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0368 - accuracy: 0.9688 - val_loss: 4.7939 - val_accuracy: 0.1250
# Epoch 96/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 4.5795 - val_accuracy: 0.1250
# Epoch 97/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 4.5421 - val_accuracy: 0.1250
# Epoch 98/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 4.6447 - val_accuracy: 0.1250
# Epoch 99/250
# 4/4 [==============================] - 1s 314ms/step - loss: 7.7919e-04 - accuracy: 1.0000 - val_loss: 4.6887 - val_accuracy: 0.1250
# Epoch 100/250
# 4/4 [==============================] - 1s 314ms/step - loss: 9.2463e-04 - accuracy: 1.0000 - val_loss: 4.5049 - val_accuracy: 0.1250
# Epoch 101/250
# 4/4 [==============================] - 1s 306ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 4.3427 - val_accuracy: 0.1250
# Epoch 102/250
# 4/4 [==============================] - 2s 398ms/step - loss: 4.0665e-04 - accuracy: 1.0000 - val_loss: 4.3989 - val_accuracy: 0.1250
# Epoch 103/250
# 4/4 [==============================] - 2s 430ms/step - loss: 6.3998e-04 - accuracy: 1.0000 - val_loss: 3.8393 - val_accuracy: 0.1250
# Epoch 104/250
# 4/4 [==============================] - 2s 353ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.9009 - val_accuracy: 0.2500
# Epoch 105/250
# 4/4 [==============================] - 1s 315ms/step - loss: 2.6168e-04 - accuracy: 1.0000 - val_loss: 4.0874 - val_accuracy: 0.1250
# Epoch 106/250
# 4/4 [==============================] - 1s 314ms/step - loss: 0.2025 - accuracy: 0.9688 - val_loss: 4.6558 - val_accuracy: 0.1250
# Epoch 107/250
# 4/4 [==============================] - 1s 326ms/step - loss: 0.4976 - accuracy: 0.9062 - val_loss: 4.3055 - val_accuracy: 0.1250
# Epoch 108/250
# 4/4 [==============================] - 1s 317ms/step - loss: 0.3164 - accuracy: 0.8438 - val_loss: 4.0445 - val_accuracy: 0.1250
# Epoch 109/250
# 4/4 [==============================] - 1s 308ms/step - loss: 0.1312 - accuracy: 0.9375 - val_loss: 4.1625 - val_accuracy: 0.2500
# Epoch 110/250
# 4/4 [==============================] - 2s 415ms/step - loss: 0.4078 - accuracy: 0.9688 - val_loss: 4.2435 - val_accuracy: 0.1250
# Epoch 111/250
# 4/4 [==============================] - 2s 427ms/step - loss: 0.4360 - accuracy: 0.9062 - val_loss: 2.9302 - val_accuracy: 0.1250
# Epoch 112/250
# 4/4 [==============================] - 1s 331ms/step - loss: 0.0712 - accuracy: 0.9375 - val_loss: 2.9799 - val_accuracy: 0.2500
# Epoch 113/250
# 4/4 [==============================] - 1s 321ms/step - loss: 0.6219 - accuracy: 0.8438 - val_loss: 4.3957 - val_accuracy: 0.2500
# Epoch 114/250
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0762 - accuracy: 0.9688 - val_loss: 5.0277 - val_accuracy: 0.1250
# Epoch 115/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.4915 - accuracy: 0.8438 - val_loss: 3.2590 - val_accuracy: 0.3750
# Epoch 116/250
# 4/4 [==============================] - 1s 326ms/step - loss: 0.2025 - accuracy: 0.9375 - val_loss: 3.0602 - val_accuracy: 0.3750
# Epoch 117/250
# 4/4 [==============================] - 2s 428ms/step - loss: 0.1958 - accuracy: 0.9375 - val_loss: 4.2976 - val_accuracy: 0.3750
# Epoch 118/250
# 4/4 [==============================] - 2s 440ms/step - loss: 0.8335 - accuracy: 0.7188 - val_loss: 3.7967 - val_accuracy: 0.2500
# Epoch 119/250
# 4/4 [==============================] - 1s 340ms/step - loss: 1.8046 - accuracy: 0.8438 - val_loss: 7.4359 - val_accuracy: 0.3750
# Epoch 120/250
# 4/4 [==============================] - 1s 312ms/step - loss: 1.3785 - accuracy: 0.8125 - val_loss: 2.9934 - val_accuracy: 0.2500
# Epoch 121/250
# 4/4 [==============================] - 1s 309ms/step - loss: 0.6020 - accuracy: 0.8125 - val_loss: 4.4669 - val_accuracy: 0.3750
# Epoch 122/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.6578 - accuracy: 0.9062 - val_loss: 4.7949 - val_accuracy: 0.3750
# Epoch 123/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.2047 - accuracy: 0.9375 - val_loss: 5.5201 - val_accuracy: 0.2500
# Epoch 124/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.6634 - accuracy: 0.9062 - val_loss: 6.5717 - val_accuracy: 0.2500
# Epoch 125/250
# 4/4 [==============================] - 2s 406ms/step - loss: 0.2797 - accuracy: 0.9375 - val_loss: 4.7498 - val_accuracy: 0.3750
# Epoch 126/250
# 4/4 [==============================] - 1s 342ms/step - loss: 0.1677 - accuracy: 0.9062 - val_loss: 4.8872 - val_accuracy: 0.2500
# Epoch 127/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.8430 - accuracy: 0.8438 - val_loss: 7.7139 - val_accuracy: 0.1250
# Epoch 128/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.2573 - accuracy: 0.9375 - val_loss: 8.4257 - val_accuracy: 0.2500
# Epoch 129/250
# 4/4 [==============================] - 1s 341ms/step - loss: 0.0369 - accuracy: 0.9688 - val_loss: 8.4921 - val_accuracy: 0.2500
# Epoch 130/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.1059 - accuracy: 0.9688 - val_loss: 7.3830 - val_accuracy: 0.2500
# Epoch 131/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.2443 - accuracy: 0.9375 - val_loss: 2.8470 - val_accuracy: 0.2500
# Epoch 132/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.4947 - accuracy: 0.8750 - val_loss: 1.2741 - val_accuracy: 0.5000
# Epoch 133/250
# 4/4 [==============================] - 2s 428ms/step - loss: 0.1399 - accuracy: 0.9688 - val_loss: 1.7463 - val_accuracy: 0.6250
# Epoch 134/250
# 4/4 [==============================] - 2s 402ms/step - loss: 0.0764 - accuracy: 0.9375 - val_loss: 2.8407 - val_accuracy: 0.3750
# Epoch 135/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0258 - accuracy: 0.9688 - val_loss: 3.3614 - val_accuracy: 0.5000
# Epoch 136/250
# 4/4 [==============================] - 1s 317ms/step - loss: 0.5078 - accuracy: 0.9062 - val_loss: 1.7501 - val_accuracy: 0.5000
# Epoch 137/250
# 4/4 [==============================] - 1s 322ms/step - loss: 0.3554 - accuracy: 0.9375 - val_loss: 2.6192 - val_accuracy: 0.5000
# Epoch 138/250
# 4/4 [==============================] - 2s 587ms/step - loss: 0.0438 - accuracy: 0.9688 - val_loss: 2.2706 - val_accuracy: 0.5000
# Epoch 139/250
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 3.6190 - val_accuracy: 0.2500
# Epoch 140/250
# 4/4 [==============================] - 2s 421ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 4.0975 - val_accuracy: 0.3750
# Epoch 141/250
# 4/4 [==============================] - 2s 367ms/step - loss: 0.4650 - accuracy: 0.9375 - val_loss: 3.7723 - val_accuracy: 0.3750
# Epoch 142/250
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 2.3821 - val_accuracy: 0.6250
# Epoch 143/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.1560 - accuracy: 0.9688 - val_loss: 6.9678 - val_accuracy: 0.2500
# Epoch 144/250
# 4/4 [==============================] - 1s 309ms/step - loss: 0.3010 - accuracy: 0.9688 - val_loss: 18.3803 - val_accuracy: 0.1250
# Epoch 145/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 20.6120 - val_accuracy: 0.1250
# Epoch 146/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.1711 - accuracy: 0.9062 - val_loss: 19.3760 - val_accuracy: 0.1250
# Epoch 147/250
# 4/4 [==============================] - 2s 369ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 17.0590 - val_accuracy: 0.1250
# Epoch 148/250
# 4/4 [==============================] - 2s 431ms/step - loss: 0.2697 - accuracy: 0.9375 - val_loss: 6.1644 - val_accuracy: 0.3750
# Epoch 149/250
# 4/4 [==============================] - 2s 396ms/step - loss: 0.0356 - accuracy: 1.0000 - val_loss: 3.5871 - val_accuracy: 0.5000
# Epoch 150/250
# 4/4 [==============================] - 1s 309ms/step - loss: 0.0982 - accuracy: 0.9688 - val_loss: 2.3779 - val_accuracy: 0.6250
# Epoch 151/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0669 - accuracy: 0.9688 - val_loss: 2.4344 - val_accuracy: 0.6250
# Epoch 152/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.5419 - accuracy: 0.9375 - val_loss: 2.4819 - val_accuracy: 0.6250
# Epoch 153/250
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.9329 - val_accuracy: 0.6250
# Epoch 154/250
# 4/4 [==============================] - 2s 454ms/step - loss: 0.2041 - accuracy: 0.9062 - val_loss: 2.4467 - val_accuracy: 0.6250
# Epoch 155/250
# 4/4 [==============================] - 2s 423ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.8167 - val_accuracy: 0.7500
# Epoch 156/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.1866 - accuracy: 0.9688 - val_loss: 2.0092 - val_accuracy: 0.5000
# Epoch 157/250
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 3.2830 - val_accuracy: 0.5000
# Epoch 158/250
# 4/4 [==============================] - 1s 308ms/step - loss: 0.0393 - accuracy: 0.9688 - val_loss: 3.6270 - val_accuracy: 0.3750
# Epoch 159/250
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0553 - accuracy: 0.9688 - val_loss: 3.0652 - val_accuracy: 0.5000
# Epoch 160/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 2.4729 - val_accuracy: 0.5000
# Epoch 161/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 2.9582 - val_accuracy: 0.5000
# Epoch 162/250
# 4/4 [==============================] - 2s 403ms/step - loss: 0.0967 - accuracy: 0.9375 - val_loss: 2.8778 - val_accuracy: 0.6250
# Epoch 163/250
# 4/4 [==============================] - 2s 424ms/step - loss: 0.0303 - accuracy: 0.9688 - val_loss: 2.0753 - val_accuracy: 0.5000
# Epoch 164/250
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0322 - accuracy: 0.9688 - val_loss: 1.5959 - val_accuracy: 0.7500
# Epoch 165/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.2281 - accuracy: 0.9375 - val_loss: 1.4275 - val_accuracy: 0.6250
# Epoch 166/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.7711 - val_accuracy: 0.6250
# Epoch 167/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7879 - val_accuracy: 0.6250
# Epoch 168/250
# 4/4 [==============================] - 1s 339ms/step - loss: 0.1681 - accuracy: 0.8750 - val_loss: 2.0368 - val_accuracy: 0.6250
# Epoch 169/250
# 4/4 [==============================] - 2s 395ms/step - loss: 2.3257e-04 - accuracy: 1.0000 - val_loss: 1.9168 - val_accuracy: 0.7500
# Epoch 170/250
# 4/4 [==============================] - 2s 422ms/step - loss: 1.0168e-04 - accuracy: 1.0000 - val_loss: 2.8335 - val_accuracy: 0.6250
# Epoch 171/250
# 4/4 [==============================] - 2s 367ms/step - loss: 0.0817 - accuracy: 0.9688 - val_loss: 3.7561 - val_accuracy: 0.6250
# Epoch 172/250
# 4/4 [==============================] - 1s 307ms/step - loss: 0.1611 - accuracy: 0.9375 - val_loss: 3.0651 - val_accuracy: 0.6250
# Epoch 173/250
# 4/4 [==============================] - 1s 318ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 3.3815 - val_accuracy: 0.5000
# Epoch 174/250
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 5.3437 - val_accuracy: 0.5000
# Epoch 175/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.1209 - accuracy: 0.9688 - val_loss: 4.1483 - val_accuracy: 0.5000
# Epoch 176/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0513 - accuracy: 0.9688 - val_loss: 2.4498 - val_accuracy: 0.6250
# Epoch 177/250
# 4/4 [==============================] - 2s 513ms/step - loss: 3.3969e-04 - accuracy: 1.0000 - val_loss: 3.2136 - val_accuracy: 0.6250
# Epoch 178/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.8230 - val_accuracy: 0.7500
# Epoch 179/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.5638 - val_accuracy: 0.7500
# Epoch 180/250
# 4/4 [==============================] - 1s 311ms/step - loss: 7.8781e-04 - accuracy: 1.0000 - val_loss: 1.9146 - val_accuracy: 0.7500
# Epoch 181/250
# 4/4 [==============================] - 1s 318ms/step - loss: 3.6904e-04 - accuracy: 1.0000 - val_loss: 1.8904 - val_accuracy: 0.7500
# Epoch 182/250
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.7493 - val_accuracy: 0.7500
# Epoch 183/250
# 4/4 [==============================] - 1s 310ms/step - loss: 3.5846e-04 - accuracy: 1.0000 - val_loss: 1.8151 - val_accuracy: 0.7500
# Epoch 184/250
# 4/4 [==============================] - 1s 353ms/step - loss: 6.8383e-05 - accuracy: 1.0000 - val_loss: 1.3448 - val_accuracy: 0.7500
# Epoch 185/250
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.4455 - val_accuracy: 0.7500
# Epoch 186/250
# 4/4 [==============================] - 1s 313ms/step - loss: 7.6960e-05 - accuracy: 1.0000 - val_loss: 3.6012 - val_accuracy: 0.6250
# Epoch 187/250
# 4/4 [==============================] - 1s 314ms/step - loss: 2.3077e-04 - accuracy: 1.0000 - val_loss: 1.5642 - val_accuracy: 0.7500
# Epoch 188/250
# 4/4 [==============================] - 1s 310ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.0174 - val_accuracy: 0.6250
# Epoch 189/250
# 4/4 [==============================] - 1s 312ms/step - loss: 7.2601e-05 - accuracy: 1.0000 - val_loss: 1.9243 - val_accuracy: 0.6250
# Epoch 190/250
# 4/4 [==============================] - 2s 439ms/step - loss: 3.4251e-05 - accuracy: 1.0000 - val_loss: 3.1006 - val_accuracy: 0.6250
# Epoch 191/250
# 4/4 [==============================] - 2s 425ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.5231 - val_accuracy: 0.7500
# Epoch 192/250
# 4/4 [==============================] - 1s 315ms/step - loss: 6.5213e-04 - accuracy: 1.0000 - val_loss: 1.3777 - val_accuracy: 0.7500
# Epoch 193/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.8639 - val_accuracy: 0.7500
# Epoch 194/250
# 4/4 [==============================] - 1s 311ms/step - loss: 7.2754e-05 - accuracy: 1.0000 - val_loss: 2.1239 - val_accuracy: 0.6250
# Epoch 195/250
# 4/4 [==============================] - 1s 314ms/step - loss: 5.7516e-04 - accuracy: 1.0000 - val_loss: 1.7906 - val_accuracy: 0.7500
# Epoch 196/250
# 4/4 [==============================] - 2s 535ms/step - loss: 3.9227e-05 - accuracy: 1.0000 - val_loss: 3.1318 - val_accuracy: 0.7500
# Epoch 197/250
# 4/4 [==============================] - 2s 381ms/step - loss: 1.6803e-05 - accuracy: 1.0000 - val_loss: 1.5899 - val_accuracy: 0.6250
# Epoch 198/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.4116 - val_accuracy: 0.6250
# Epoch 199/250
# 4/4 [==============================] - 1s 312ms/step - loss: 7.2726e-04 - accuracy: 1.0000 - val_loss: 3.0664 - val_accuracy: 0.6250
# Epoch 200/250
# 4/4 [==============================] - 1s 315ms/step - loss: 1.7755e-04 - accuracy: 1.0000 - val_loss: 3.6942 - val_accuracy: 0.6250
# Epoch 201/250
# 4/4 [==============================] - 1s 314ms/step - loss: 3.9042e-05 - accuracy: 1.0000 - val_loss: 3.1424 - val_accuracy: 0.6250
# Epoch 202/250
# 4/4 [==============================] - 2s 409ms/step - loss: 1.9608e-05 - accuracy: 1.0000 - val_loss: 3.0595 - val_accuracy: 0.6250
# Epoch 203/250
# 4/4 [==============================] - 2s 429ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.1708 - val_accuracy: 0.6250
# Epoch 204/250
# 4/4 [==============================] - 1s 322ms/step - loss: 3.3601e-06 - accuracy: 1.0000 - val_loss: 2.6437 - val_accuracy: 0.6250
# Epoch 205/250
# 4/4 [==============================] - 1s 316ms/step - loss: 2.1897e-04 - accuracy: 1.0000 - val_loss: 2.0736 - val_accuracy: 0.6250
# Epoch 206/250
# 4/4 [==============================] - 2s 414ms/step - loss: 1.5518e-05 - accuracy: 1.0000 - val_loss: 1.9261 - val_accuracy: 0.6250
# Epoch 207/250
# 4/4 [==============================] - 1s 315ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 3.5973 - val_accuracy: 0.6250
# Epoch 208/250
# 4/4 [==============================] - 2s 416ms/step - loss: 1.0196e-04 - accuracy: 1.0000 - val_loss: 2.8607 - val_accuracy: 0.6250
# Epoch 209/250
# 4/4 [==============================] - 1s 318ms/step - loss: 1.2491e-04 - accuracy: 1.0000 - val_loss: 1.9913 - val_accuracy: 0.6250
# Epoch 210/250
# 4/4 [==============================] - 1s 318ms/step - loss: 1.1712e-05 - accuracy: 1.0000 - val_loss: 2.2226 - val_accuracy: 0.6250
# Epoch 211/250
# 4/4 [==============================] - 1s 313ms/step - loss: 1.3929e-04 - accuracy: 1.0000 - val_loss: 3.1069 - val_accuracy: 0.6250
# Epoch 212/250
# 4/4 [==============================] - 1s 344ms/step - loss: 0.0315 - accuracy: 0.9688 - val_loss: 2.7825 - val_accuracy: 0.7500
# Epoch 213/250
# 4/4 [==============================] - 1s 317ms/step - loss: 1.1253e-05 - accuracy: 1.0000 - val_loss: 3.0117 - val_accuracy: 0.6250
# Epoch 214/250
# 4/4 [==============================] - 1s 314ms/step - loss: 1.8736e-05 - accuracy: 1.0000 - val_loss: 2.2389 - val_accuracy: 0.6250
# Epoch 215/250
# 4/4 [==============================] - 2s 447ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 2.9594 - val_accuracy: 0.7500
# Epoch 216/250
# 4/4 [==============================] - 1s 316ms/step - loss: 4.5151e-05 - accuracy: 1.0000 - val_loss: 2.6900 - val_accuracy: 0.6250
# Epoch 217/250
# 4/4 [==============================] - 1s 345ms/step - loss: 0.2398 - accuracy: 0.9688 - val_loss: 3.8835 - val_accuracy: 0.6250
# Epoch 218/250
# 4/4 [==============================] - 1s 322ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.3797 - val_accuracy: 0.5000
# Epoch 219/250
# 4/4 [==============================] - 1s 318ms/step - loss: 0.0589 - accuracy: 0.9688 - val_loss: 5.9002 - val_accuracy: 0.3750
# Epoch 220/250
# 4/4 [==============================] - 1s 323ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 3.9041 - val_accuracy: 0.6250
# Epoch 221/250
# 4/4 [==============================] - 1s 320ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 3.9675 - val_accuracy: 0.5000
# Epoch 222/250
# 4/4 [==============================] - 2s 399ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.7238 - val_accuracy: 0.5000
# Epoch 223/250
# 4/4 [==============================] - 2s 387ms/step - loss: 3.5682e-04 - accuracy: 1.0000 - val_loss: 3.7170 - val_accuracy: 0.5000
# Epoch 224/250
# 4/4 [==============================] - 1s 321ms/step - loss: 6.3768e-05 - accuracy: 1.0000 - val_loss: 3.4888 - val_accuracy: 0.5000
# Epoch 225/250
# 4/4 [==============================] - 1s 332ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.6180 - val_accuracy: 0.5000
# Epoch 226/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 3.1406 - val_accuracy: 0.6250
# Epoch 227/250
# 4/4 [==============================] - 1s 314ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 3.4577 - val_accuracy: 0.5000
# Epoch 228/250
# 4/4 [==============================] - 1s 317ms/step - loss: 4.1021e-05 - accuracy: 1.0000 - val_loss: 4.1621 - val_accuracy: 0.6250
# Epoch 229/250
# 4/4 [==============================] - 1s 311ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 3.0372 - val_accuracy: 0.6250
# Epoch 230/250
# 4/4 [==============================] - 2s 395ms/step - loss: 1.7206e-05 - accuracy: 1.0000 - val_loss: 3.8887 - val_accuracy: 0.6250
# Epoch 231/250
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 4.1817 - val_accuracy: 0.5000
# Epoch 232/250
# 4/4 [==============================] - 1s 317ms/step - loss: 8.0585e-05 - accuracy: 1.0000 - val_loss: 4.1857 - val_accuracy: 0.5000
# Epoch 233/250
# 4/4 [==============================] - 1s 322ms/step - loss: 0.0580 - accuracy: 0.9688 - val_loss: 1.4444 - val_accuracy: 0.8750
# Epoch 234/250
# 4/4 [==============================] - 1s 309ms/step - loss: 4.0679e-06 - accuracy: 1.0000 - val_loss: 4.4214 - val_accuracy: 0.6250
# Epoch 235/250
# 4/4 [==============================] - 1s 316ms/step - loss: 1.5072e-04 - accuracy: 1.0000 - val_loss: 4.1432 - val_accuracy: 0.7500
# Epoch 236/250
# 4/4 [==============================] - 1s 328ms/step - loss: 0.1856 - accuracy: 0.9688 - val_loss: 2.3351 - val_accuracy: 0.5000
# Epoch 237/250
# 4/4 [==============================] - 2s 462ms/step - loss: 0.2499 - accuracy: 0.9375 - val_loss: 5.3826 - val_accuracy: 0.3750
# Epoch 238/250
# 4/4 [==============================] - 2s 439ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 3.4242 - val_accuracy: 0.7500
# Epoch 239/250
# 4/4 [==============================] - 1s 310ms/step - loss: 8.4898e-05 - accuracy: 1.0000 - val_loss: 2.2477 - val_accuracy: 0.7500
# Epoch 240/250
# 4/4 [==============================] - 1s 313ms/step - loss: 0.2250 - accuracy: 0.9688 - val_loss: 1.6195 - val_accuracy: 0.7500
# Epoch 241/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 2.2206 - val_accuracy: 0.7500
# Epoch 242/250
# 4/4 [==============================] - 1s 323ms/step - loss: 0.3136 - accuracy: 0.9688 - val_loss: 0.8344 - val_accuracy: 0.7500
# Epoch 243/250
# 4/4 [==============================] - 1s 359ms/step - loss: 0.0441 - accuracy: 0.9688 - val_loss: 2.2551 - val_accuracy: 0.6250
# Epoch 244/250
# 4/4 [==============================] - 2s 400ms/step - loss: 0.0802 - accuracy: 0.9688 - val_loss: 3.9434 - val_accuracy: 0.7500
# Epoch 245/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.2311 - accuracy: 0.9375 - val_loss: 2.8114 - val_accuracy: 0.5000
# Epoch 246/250
# 4/4 [==============================] - 1s 316ms/step - loss: 0.1452 - accuracy: 0.9688 - val_loss: 4.8728 - val_accuracy: 0.6250
# Epoch 247/250
# 4/4 [==============================] - 1s 340ms/step - loss: 0.0953 - accuracy: 0.9688 - val_loss: 9.2640 - val_accuracy: 0.2500
# Epoch 248/250
# 4/4 [==============================] - 1s 312ms/step - loss: 0.1006 - accuracy: 0.9688 - val_loss: 11.8929 - val_accuracy: 0.2500
# Epoch 249/250
# 4/4 [==============================] - 1s 317ms/step - loss: 0.0767 - accuracy: 0.9688 - val_loss: 5.5623 - val_accuracy: 0.5000
# Epoch 250/250
# 4/4 [==============================] - 1s 319ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 3.0052 - val_accuracy: 0.6250
# 1/1 [==============================] - 0s 235ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Сверточный классификатор
# Класс: 049                  100% сеть отнесла к классу 049                  - ВЕРНО :-)
# Класс: 050                  100% сеть отнесла к классу 050                  - ВЕРНО :-)
# Класс: 051                  100% сеть отнесла к классу 051                  - ВЕРНО :-)
# Класс: 052                  100% сеть отнесла к классу 052                  - ВЕРНО :-)
# Класс: 053                  100% сеть отнесла к классу 053                  - ВЕРНО :-)
# Класс: 054                  100% сеть отнесла к классу 054                  - ВЕРНО :-)
# Класс: 055                  100% сеть отнесла к классу 055                  - ВЕРНО :-)
# Класс: 056                  100% сеть отнесла к классу 056                  - ВЕРНО :-)
#
# Средняя точность распознавания: 100%
