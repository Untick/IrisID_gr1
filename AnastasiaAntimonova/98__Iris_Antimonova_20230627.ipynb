# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/main/AnastasiaAntimonova/98__Iris_Antimonova_20230627.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ЗАДАЧА: Идентификации пациента по радужной оболочке**
#
# КОЛИЧЕСТВО КЛАССОВ: равно количеству пациентов (для обучения можно использовать, например, 10 человек (классов)). В данном решении = 64
#
# Использован ДАТАСЕТ1: 64 пары глаз, каждый глаз отснят 3 раза.
#
# ВХОДНЫЕ ДАННЫЕ: Изображение, содержащее передний сегмент глаза, подается в сеть для классификации.
#
# ТРЕБОВАНИЯ К ТОЧНОСТИ:
# FRR (ложный недопуск) ошибка не более 3%; FAR (ложный допуск) ошибка не более 2%; идентификация: точность не менее 98% при вероятности предсказания класса ниже 97% - недопуск (пациент отсутствует в базе)
#
# Дата начала проекта 11.04.23 Дата окончания проекта 30.06.23

# %% [markdown]
# # Загрузка библиотек

# %%
# Работа с массивами
import numpy as np

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Основа для создания последовательной модели
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Оптимизатор
from tensorflow.keras.optimizers import Adam

# Функции для работы с сохраненной моделью
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.models import load_model

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Подключение модуля для загрузки данных из облака
import gdown

# Инструменты для работы с файлами
import time, random, gdown, os

# Для работы с архивами
import zipfile

# Отрисовка графиков
import matplotlib.pyplot as plt

# Дополнительные инструменты для работы с изображениями
from PIL import Image

# Рисование графиков в ячейках Colab
# %matplotlib inline

# %% [markdown]
# #Определение гиперпараметров

# %% [markdown]
# Эксперименты показали, что при сохранении радиальных изображений, разрешение 192х144 оптимально. Увеличение и уменьшение приводили либо к увеличению времени обучения, либо к снижению точности.

# %%
# Определяем параметры данных, в т.ч. аугментации

TRAIN_DIR          = '/content/Iris'        # Папка для обучающего набора данных
TEST_DIR           = '/content/iris_test'   # Папка для тестового набора данных

TEST_SPLIT          = 0.2                  # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.2                  # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 192                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# Параметры аугментации
ROTATION_RANGE      = 5                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.05                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.05                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.05                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.9, 1.1)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение запрещено

EPOCHS              = 300                   # Число эпох для первоначального обучения
BATCH_SIZE          = 6                     # Размер батча для обучения модели
OPTIMIZER           = Adam(0.0001)          # Оптимизатор

# %% [markdown]
# # Загрузка и подготовка данных

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка zip-архива с датасетом
gdown.download('https://drive.google.com/uc?id=16wKj93ooL-mYryWHIDEr49FJAfAFwnRO', None, quiet=True)
# Out:
# 'Iris.zip'

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_DIR} {TEST_DIR}

# Разархивация датасета
# !unzip -q "Iris.zip" -d /content/Iris #Указываем путь к базе в Google Drive

# %%
# Создаем папки для каждого класса и перемещаем файлы в соответствующую папку
for i in range(1, 65):
                        class_folder = os.path.join(TRAIN_DIR, f'{i:03}')
                        if not os.path.exists(class_folder):
                            os.makedirs(class_folder)
                        for file_name in ['%03dL_%d.png' % (i, j) for j in range(1, 4)] + ['%03dR_%d.png' % (i, j) for j in range(1, 4)]:
                            file_path = os.path.join(TRAIN_DIR, file_name)
                            if os.path.exists(file_path):
                                os.replace(file_path, os.path.join(class_folder, file_name))

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_DIR))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 64, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    class_path = f'{TRAIN_DIR}/{CLASS_LIST[i]}'
    # Выбор случайного фото из i-го класса
    img_path = class_path +'/'+random.choice(os.listdir(class_path))
    # Отображение фотографии
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
# Создание директории тестовых данных
os.mkdir(TEST_DIR)
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_DIR}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_DIR}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# #Аугментация данных. Выделение обучающей, валидационной и тестовой выборок

# %% [markdown]
# Для обеспечения достаточного для обучения сети набора данных применена аугментация.

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )


# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
                  TRAIN_DIR,
                  target_size=(IMG_HEIGHT, IMG_WIDTH),
                  batch_size=BATCH_SIZE,
                  class_mode='categorical',
                  shuffle=True,
                  subset='training'
                )

# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
                  TRAIN_DIR,
                  target_size=(IMG_HEIGHT, IMG_WIDTH),
                  batch_size=BATCH_SIZE,
                  class_mode='categorical',
                  shuffle=True,
                  subset='validation'
              )

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
                  TEST_DIR,
                  target_size=(IMG_HEIGHT, IMG_WIDTH),
                  batch_size=test_count,
                  class_mode='categorical',
                  shuffle=True,
              )
# Out:
# Found 256 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (6, 144, 192, 3), (6, 64), батчей: 43
# Формы данных   проверочной выборки: (6, 144, 192, 3), (6, 64), батчей: 11
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 6),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(6), columns = 6)

# %% [markdown]
# #Создание нейронной сети

# %% [markdown]
# # `Сервисные функции`

# %%
#Сохранение лучшей модели
#from tensorflow.keras.callbacks import Callback

class SaveModelOnAccuracy(Callback):
    def __init__(self, filepath, monitor='val_loss', mode='min', save_best_only=True, verbose=1, min_accuracy=0.0):
        super(SaveModelOnAccuracy, self).__init__()
        self.filepath = filepath
        self.monitor = monitor
        self.mode = mode
        self.save_best_only = save_best_only
        self.verbose = verbose
        self.min_accuracy = min_accuracy
        self.best_accuracy = 0.0

    def on_epoch_end(self, epoch, logs=None):
        current_accuracy = logs.get('val_accuracy')
        if current_accuracy >= self.min_accuracy and current_accuracy > self.best_accuracy:
            self.model.save(self.filepath)
            self.best_accuracy = current_accuracy
            if self.verbose == 1:
                print(f" Модель сохранена с точностью {self.best_accuracy * 100:.2f} %")

# %%
# Функция компиляции и обучения модели нейронной сети

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5),        # размер полотна для графиков
                        min_accuracy=0.8,       # минимальное значение accuracy для сохранения модели
                        checkpoint_path='/content/Best_model/best_model.h5'):

    # Компиляция модели
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Создание обратного вызова для сохранения модели с заданным значением accuracy
    checkpoint = SaveModelOnAccuracy(filepath=checkpoint_path,
                                     monitor='val_loss',
                                     mode='min',
                                     save_best_only=True,
                                     verbose=1,
                                     min_accuracy=min_accuracy)

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data,
                        callbacks=[checkpoint])  # Передача обратного вызова в качестве списка)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'],
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

    return history

# %%
# Функция вывода результатов оценки модели на заданных данных

def eval_model(model,
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(15, 15)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=12)
    plt.ylabel('Верные классы', fontsize=12)
    plt.show()

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Cообщение о верности или неверности предсказания
        msg = 'ВЕРНО' if cls_pred == cls else 'НЕВЕРНО'
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model,
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1],
               class_labels=class_labels,
               title=title,
               figsize=cm_size)

# %%
# Сохранение лучшей модели
def save_model_to_drive(model, save_path):

    from google.colab import drive
    import shutil

    # Подключение к Google Диску
    drive.mount('/content/gdrive')

    # Сохранение модели в указанную папку на Google Диск
    shutil.copyfile(model, '/content/gdrive/MyDrive/' + save_path)

# %%
# Загрузка лучшей модели
def load_best_model(model_path):
    # Загрузка модели из указанного файла
    best_model = load_model(model_path)

    return best_model

# %% [markdown]
# # Архитектура модели

# %% [markdown]
# В процессе экспериментов данная модель с дообучением дала наибольшую точность на тестовом наборе данных (98%) на приемлемом количестве эпох (300+150) и с приемлемым временем обучения (28 мин + 14 мин).

# %%
# Создание последовательной модели
model = Sequential()

# Первый сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model.add(BatchNormalization())

# Второй сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.1))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Четвертый сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.2))

# Пятый сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

# Слой преобразования многомерных данных в одномерные
model.add(Flatten())

# Промежуточный полносвязный слой
model.add(Dense(64, activation='relu'))

# Промежуточный полносвязный слой
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))

# Выходной полносвязный слой с количеством нейронов по количесту классов
model.add(Dense(CLASS_COUNT, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 144, 192, 32)      896
#
#  batch_normalization (BatchN  (None, 144, 192, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 144, 192, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 48, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 48, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 64, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 48, 64, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 48, 64, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 64, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 21, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 21, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 21, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 16, 21, 64)       256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 16, 21, 64)        0
#
#  flatten (Flatten)           (None, 21504)             0
#
#  dense (Dense)               (None, 64)                1376320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
# =================================================================
# Total params: 1,496,032
# Trainable params: 1,495,712
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# #Обучение нейронной сети

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         )
# Out:
# Epoch 1/300
# 43/43 [==============================] - 20s 151ms/step - loss: 4.3531 - accuracy: 0.0000e+00 - val_loss: 4.1634 - val_accuracy: 0.0156
# Epoch 2/300
# 43/43 [==============================] - 6s 132ms/step - loss: 4.2057 - accuracy: 0.0273 - val_loss: 4.1662 - val_accuracy: 0.0156
# Epoch 3/300
# 43/43 [==============================] - 6s 130ms/step - loss: 4.1785 - accuracy: 0.0273 - val_loss: 4.1631 - val_accuracy: 0.0156
# Epoch 4/300
# 43/43 [==============================] - 6s 130ms/step - loss: 4.1397 - accuracy: 0.0391 - val_loss: 4.1624 - val_accuracy: 0.0312
# Epoch 5/300
# 43/43 [==============================] - 6s 130ms/step - loss: 4.1327 - accuracy: 0.0234 - val_loss: 4.1694 - val_accuracy: 0.0156
# Epoch 6/300
# 43/43 [==============================] - 6s 128ms/step - loss: 4.1319 - accuracy: 0.0234 - val_loss: 4.1523 - val_accuracy: 0.0312
# Epoch 7/300
# 43/43 [==============================] - 6s 134ms/step - loss: 4.0989 - accuracy: 0.0352 - val_loss: 4.1365 - val_accuracy: 0.0312
# Epoch 8/300
# 43/43 [==============================] - 6s 129ms/step - loss: 4.1083 - accuracy: 0.0156 - val_loss: 4.1279 - val_accuracy: 0.0156
# Epoch 9/300
# 43/43 [==============================] - 6s 132ms/step - loss: 4.0360 - accuracy: 0.0312 - val_loss: 4.1074 - val_accuracy: 0.0469
# Epoch 10/300
# 43/43 [==============================] - 6s 130ms/step - loss: 4.0354 - accuracy: 0.0352 - val_loss: 4.0801 - val_accuracy: 0.0469
# Epoch 11/300
# 43/43 [==============================] - 6s 131ms/step - loss: 4.0124 - accuracy: 0.0352 - val_loss: 4.0406 - val_accuracy: 0.0625
# Epoch 12/300
# 43/43 [==============================] - 6s 130ms/step - loss: 4.0163 - accuracy: 0.0352 - val_loss: 4.0421 - val_accuracy: 0.0312
# Epoch 13/300
# 43/43 [==============================] - 6s 131ms/step - loss: 3.8969 - accuracy: 0.0469 - val_loss: 3.9972 - val_accuracy: 0.0312
# Epoch 14/300
# 43/43 [==============================] - 6s 132ms/step - loss: 3.8408 - accuracy: 0.0547 - val_loss: 3.8024 - val_accuracy: 0.1250
# Epoch 15/300
# 43/43 [==============================] - 6s 128ms/step - loss: 3.8013 - accuracy: 0.0391 - val_loss: 3.8559 - val_accuracy: 0.0938
# Epoch 16/300
# 43/43 [==============================] - 6s 129ms/step - loss: 3.7072 - accuracy: 0.0664 - val_loss: 3.8244 - val_accuracy: 0.0469
# Epoch 17/300
# 43/43 [==============================] - 5s 127ms/step - loss: 3.6885 - accuracy: 0.0547 - val_loss: 3.7745 - val_accuracy: 0.0625
# Epoch 18/300
# 43/43 [==============================] - 6s 133ms/step - loss: 3.5391 - accuracy: 0.0898 - val_loss: 3.6677 - val_accuracy: 0.0781
# Epoch 19/300
# 43/43 [==============================] - 5s 128ms/step - loss: 3.5366 - accuracy: 0.0898 - val_loss: 3.6926 - val_accuracy: 0.0938
# Epoch 20/300
# 43/43 [==============================] - 6s 131ms/step - loss: 3.3607 - accuracy: 0.1250 - val_loss: 3.4820 - val_accuracy: 0.1875
# Epoch 21/300
# 43/43 [==============================] - 5s 126ms/step - loss: 3.2922 - accuracy: 0.1211 - val_loss: 3.3936 - val_accuracy: 0.1094
# Epoch 22/300
# 43/43 [==============================] - 6s 129ms/step - loss: 3.2113 - accuracy: 0.1211 - val_loss: 3.2631 - val_accuracy: 0.1406
# Epoch 23/300
# 43/43 [==============================] - 6s 129ms/step - loss: 3.1370 - accuracy: 0.1406 - val_loss: 3.1745 - val_accuracy: 0.1562
# Epoch 24/300
# 43/43 [==============================] - 6s 133ms/step - loss: 3.0151 - accuracy: 0.1797 - val_loss: 2.9131 - val_accuracy: 0.1875
# Epoch 25/300
# 43/43 [==============================] - 6s 129ms/step - loss: 2.9468 - accuracy: 0.1875 - val_loss: 2.8976 - val_accuracy: 0.1562
# Epoch 26/300
# 43/43 [==============================] - 6s 132ms/step - loss: 2.8493 - accuracy: 0.1875 - val_loss: 2.8185 - val_accuracy: 0.2188
# Epoch 27/300
# 43/43 [==============================] - 5s 128ms/step - loss: 2.6516 - accuracy: 0.2344 - val_loss: 2.6190 - val_accuracy: 0.2188
# Epoch 28/300
# 43/43 [==============================] - 6s 136ms/step - loss: 2.6143 - accuracy: 0.2617 - val_loss: 2.4550 - val_accuracy: 0.3281
# Epoch 29/300
# 43/43 [==============================] - 6s 128ms/step - loss: 2.4934 - accuracy: 0.2773 - val_loss: 2.4886 - val_accuracy: 0.2656
# Epoch 30/300
# 43/43 [==============================] - 6s 130ms/step - loss: 2.3157 - accuracy: 0.3047 - val_loss: 2.2928 - val_accuracy: 0.3438
# Epoch 31/300
# 43/43 [==============================] - 6s 129ms/step - loss: 2.3557 - accuracy: 0.2734 - val_loss: 2.3607 - val_accuracy: 0.3906
# Epoch 32/300
# 43/43 [==============================] - 6s 129ms/step - loss: 2.3183 - accuracy: 0.3242 - val_loss: 2.3190 - val_accuracy: 0.3281
# Epoch 33/300
# 43/43 [==============================] - 6s 130ms/step - loss: 2.0406 - accuracy: 0.4102 - val_loss: 1.8578 - val_accuracy: 0.5156
# Epoch 34/300
# 43/43 [==============================] - 6s 131ms/step - loss: 1.9284 - accuracy: 0.4102 - val_loss: 1.9419 - val_accuracy: 0.5000
# Epoch 35/300
# 43/43 [==============================] - 5s 127ms/step - loss: 1.9668 - accuracy: 0.3984 - val_loss: 1.6417 - val_accuracy: 0.5000
# Epoch 36/300
# 43/43 [==============================] - 6s 130ms/step - loss: 1.7988 - accuracy: 0.4688 - val_loss: 2.7272 - val_accuracy: 0.2031
# Epoch 37/300
# 43/43 [==============================] - 6s 128ms/step - loss: 1.7630 - accuracy: 0.4648 - val_loss: 1.6779 - val_accuracy: 0.5156
# Epoch 38/300
# 43/43 [==============================] - 6s 132ms/step - loss: 1.6899 - accuracy: 0.4727 - val_loss: 1.6218 - val_accuracy: 0.4844
# Epoch 39/300
# 43/43 [==============================] - 6s 129ms/step - loss: 1.6113 - accuracy: 0.4766 - val_loss: 1.5401 - val_accuracy: 0.5781
# Epoch 40/300
# 43/43 [==============================] - 6s 128ms/step - loss: 1.4531 - accuracy: 0.5430 - val_loss: 1.6301 - val_accuracy: 0.5156
# Epoch 41/300
# 43/43 [==============================] - 6s 129ms/step - loss: 1.3768 - accuracy: 0.5625 - val_loss: 1.6981 - val_accuracy: 0.5469
# Epoch 42/300
# 43/43 [==============================] - 5s 128ms/step - loss: 1.2692 - accuracy: 0.5547 - val_loss: 1.3891 - val_accuracy: 0.6406
# Epoch 43/300
# 43/43 [==============================] - 6s 129ms/step - loss: 1.4755 - accuracy: 0.5273 - val_loss: 1.2841 - val_accuracy: 0.6875
# Epoch 44/300
# 43/43 [==============================] - 6s 131ms/step - loss: 1.1630 - accuracy: 0.6094 - val_loss: 1.4028 - val_accuracy: 0.5938
# Epoch 45/300
# 43/43 [==============================] - 5s 127ms/step - loss: 1.1562 - accuracy: 0.6523 - val_loss: 1.3146 - val_accuracy: 0.5625
# Epoch 46/300
# 43/43 [==============================] - 6s 131ms/step - loss: 1.0783 - accuracy: 0.6328 - val_loss: 1.1643 - val_accuracy: 0.6406
# Epoch 47/300
# 43/43 [==============================] - 6s 128ms/step - loss: 1.0729 - accuracy: 0.6367 - val_loss: 1.3055 - val_accuracy: 0.6406
# Epoch 48/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.9934 - accuracy: 0.6602 - val_loss: 1.1678 - val_accuracy: 0.6406
# Epoch 49/300
# 43/43 [==============================] - 6s 131ms/step - loss: 1.0285 - accuracy: 0.6680 - val_loss: 1.0149 - val_accuracy: 0.6562
# Epoch 50/300
# 43/43 [==============================] - 5s 126ms/step - loss: 1.0207 - accuracy: 0.6445 - val_loss: 1.0723 - val_accuracy: 0.6406
# Epoch 51/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.9164 - accuracy: 0.6875 - val_loss: 0.8796 - val_accuracy: 0.7500
# Epoch 52/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.8072 - accuracy: 0.7461 - val_loss: 1.3995 - val_accuracy: 0.5000
# Epoch 53/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.8244 - accuracy: 0.7305 - val_loss: 0.9725 - val_accuracy: 0.7031
# Epoch 54/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.7712 - accuracy: 0.7500 - val_loss: 1.0621 - val_accuracy: 0.6875
# Epoch 55/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.7077 - accuracy: 0.8086 - val_loss: 0.7824 - val_accuracy: 0.7656
# Epoch 56/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.6928 - accuracy: 0.7852 - val_loss: 0.8073 - val_accuracy: 0.7969
# Epoch 57/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5747 - accuracy: 0.7891 - val_loss: 0.6984 - val_accuracy: 0.7969
# Epoch 58/300
# 43/43 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.8320 Модель сохранена с точностью 85.94 %
# 43/43 [==============================] - 6s 129ms/step - loss: 0.5098 - accuracy: 0.8320 - val_loss: 0.6221 - val_accuracy: 0.8594
# Epoch 59/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.7369 - accuracy: 0.7383 - val_loss: 0.8247 - val_accuracy: 0.7812
# Epoch 60/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.5931 - accuracy: 0.7812 - val_loss: 0.6256 - val_accuracy: 0.7969
# Epoch 61/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.6560 - accuracy: 0.7852 - val_loss: 0.7657 - val_accuracy: 0.8281
# Epoch 62/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.6351 - accuracy: 0.7891 - val_loss: 0.8263 - val_accuracy: 0.7344
# Epoch 63/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.6661 - accuracy: 0.7773 - val_loss: 1.0195 - val_accuracy: 0.7344
# Epoch 64/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.4800 - accuracy: 0.8750 - val_loss: 0.6437 - val_accuracy: 0.8125
# Epoch 65/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.5322 - accuracy: 0.8516 - val_loss: 0.9970 - val_accuracy: 0.7500
# Epoch 66/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.4527 - accuracy: 0.8828 - val_loss: 0.6942 - val_accuracy: 0.8438
# Epoch 67/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.5085 - accuracy: 0.8398 - val_loss: 0.6935 - val_accuracy: 0.8281
# Epoch 68/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.4396 - accuracy: 0.8672 - val_loss: 0.6536 - val_accuracy: 0.8125
# Epoch 69/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.3917 - accuracy: 0.8555 - val_loss: 0.6750 - val_accuracy: 0.8125
# Epoch 70/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.4154 - accuracy: 0.8594 - val_loss: 0.6276 - val_accuracy: 0.8125
# Epoch 71/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.3928 - accuracy: 0.8672 - val_loss: 0.6830 - val_accuracy: 0.8125
# Epoch 72/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.3467 - accuracy: 0.8984 - val_loss: 0.5011 - val_accuracy: 0.8438
# Epoch 73/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.3530 - accuracy: 0.8984 - val_loss: 0.8233 - val_accuracy: 0.8125
# Epoch 74/300
# 43/43 [==============================] - ETA: 0s - loss: 0.3517 - accuracy: 0.8828 Модель сохранена с точностью 89.06 %
# 43/43 [==============================] - 6s 130ms/step - loss: 0.3517 - accuracy: 0.8828 - val_loss: 0.4506 - val_accuracy: 0.8906
# Epoch 75/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.3814 - accuracy: 0.8594 - val_loss: 0.6704 - val_accuracy: 0.8438
# Epoch 76/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.3456 - accuracy: 0.8828 - val_loss: 0.6900 - val_accuracy: 0.7969
# Epoch 77/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.2951 - accuracy: 0.9180 - val_loss: 0.5647 - val_accuracy: 0.7969
# Epoch 78/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.2607 - accuracy: 0.9219 - val_loss: 0.4675 - val_accuracy: 0.8594
# Epoch 79/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.2282 - accuracy: 0.9258 - val_loss: 0.4626 - val_accuracy: 0.8594
# Epoch 80/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.2795 - accuracy: 0.9219 - val_loss: 0.5183 - val_accuracy: 0.8281
# Epoch 81/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.2482 - accuracy: 0.9102 - val_loss: 0.4468 - val_accuracy: 0.8906
# Epoch 82/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.1964 - accuracy: 0.9570 - val_loss: 0.5219 - val_accuracy: 0.8438
# Epoch 83/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.2128 - accuracy: 0.9297 - val_loss: 0.5942 - val_accuracy: 0.8281
# Epoch 84/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.2988 - accuracy: 0.9102 - val_loss: 0.7667 - val_accuracy: 0.7656
# Epoch 85/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.2403 - accuracy: 0.9258 - val_loss: 0.4556 - val_accuracy: 0.8750
# Epoch 86/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1601 - accuracy: 0.9727 - val_loss: 0.4435 - val_accuracy: 0.8750
# Epoch 87/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.2177 - accuracy: 0.9414 - val_loss: 0.5835 - val_accuracy: 0.8906
# Epoch 88/300
# 43/43 [==============================] - 6s 136ms/step - loss: 0.1807 - accuracy: 0.9297 - val_loss: 0.5573 - val_accuracy: 0.8438
# Epoch 89/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.2312 - accuracy: 0.9297 - val_loss: 0.5339 - val_accuracy: 0.8438
# Epoch 90/300
# 43/43 [==============================] - 6s 136ms/step - loss: 0.1699 - accuracy: 0.9492 - val_loss: 0.4038 - val_accuracy: 0.8594
# Epoch 91/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.1690 - accuracy: 0.9414 - val_loss: 0.6712 - val_accuracy: 0.8125
# Epoch 92/300
# 43/43 [==============================] - 6s 150ms/step - loss: 0.2171 - accuracy: 0.9375 - val_loss: 0.4399 - val_accuracy: 0.8750
# Epoch 93/300
# 43/43 [==============================] - 6s 148ms/step - loss: 0.1901 - accuracy: 0.9492 - val_loss: 0.5003 - val_accuracy: 0.8281
# Epoch 94/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.1714 - accuracy: 0.9531 - val_loss: 0.5099 - val_accuracy: 0.7969
# Epoch 95/300
# 43/43 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9531 Модель сохранена с точностью 92.19 %
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1553 - accuracy: 0.9531 - val_loss: 0.2787 - val_accuracy: 0.9219
# Epoch 96/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1508 - accuracy: 0.9688 - val_loss: 0.4189 - val_accuracy: 0.8906
# Epoch 97/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.1099 - accuracy: 0.9648 - val_loss: 0.2885 - val_accuracy: 0.8594
# Epoch 98/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.1430 - accuracy: 0.9570 - val_loss: 0.2927 - val_accuracy: 0.8750
# Epoch 99/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1165 - accuracy: 0.9648 - val_loss: 0.2802 - val_accuracy: 0.9062
# Epoch 100/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1118 - accuracy: 0.9766 - val_loss: 0.2866 - val_accuracy: 0.9062
# Epoch 101/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.1568 - accuracy: 0.9531 - val_loss: 0.4137 - val_accuracy: 0.8594
# Epoch 102/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1507 - accuracy: 0.9531 - val_loss: 0.4236 - val_accuracy: 0.8594
# Epoch 103/300
# 43/43 [==============================] - 6s 135ms/step - loss: 0.1621 - accuracy: 0.9453 - val_loss: 0.4792 - val_accuracy: 0.8125
# Epoch 104/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1019 - accuracy: 0.9727 - val_loss: 0.2250 - val_accuracy: 0.9219
# Epoch 105/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1160 - accuracy: 0.9609 - val_loss: 0.3323 - val_accuracy: 0.9062
# Epoch 106/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1279 - accuracy: 0.9453 - val_loss: 0.3563 - val_accuracy: 0.9062
# Epoch 107/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1088 - accuracy: 0.9688 - val_loss: 0.4323 - val_accuracy: 0.9219
# Epoch 108/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.1103 - accuracy: 0.9648 - val_loss: 0.6109 - val_accuracy: 0.8438
# Epoch 109/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0962 - accuracy: 0.9766 - val_loss: 0.6866 - val_accuracy: 0.8438
# Epoch 110/300
# 43/43 [==============================] - ETA: 0s - loss: 0.1338 - accuracy: 0.9570 Модель сохранена с точностью 95.31 %
# 43/43 [==============================] - 6s 132ms/step - loss: 0.1338 - accuracy: 0.9570 - val_loss: 0.2430 - val_accuracy: 0.9531
# Epoch 111/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.1152 - accuracy: 0.9688 - val_loss: 0.4020 - val_accuracy: 0.9219
# Epoch 112/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.1447 - accuracy: 0.9531 - val_loss: 0.2785 - val_accuracy: 0.9375
# Epoch 113/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1368 - accuracy: 0.9688 - val_loss: 0.2848 - val_accuracy: 0.9219
# Epoch 114/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.1159 - accuracy: 0.9648 - val_loss: 0.4258 - val_accuracy: 0.8906
# Epoch 115/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0704 - accuracy: 0.9844 - val_loss: 0.3100 - val_accuracy: 0.9219
# Epoch 116/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0959 - accuracy: 0.9609 - val_loss: 0.4910 - val_accuracy: 0.8594
# Epoch 117/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.1132 - accuracy: 0.9648 - val_loss: 0.3542 - val_accuracy: 0.8906
# Epoch 118/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.1112 - accuracy: 0.9688 - val_loss: 0.2585 - val_accuracy: 0.9219
# Epoch 119/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.1222 - accuracy: 0.9570 - val_loss: 0.3992 - val_accuracy: 0.9062
# Epoch 120/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0928 - accuracy: 0.9648 - val_loss: 0.5061 - val_accuracy: 0.8750
# Epoch 121/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0516 - accuracy: 0.9961 - val_loss: 0.6212 - val_accuracy: 0.8750
# Epoch 122/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0827 - accuracy: 0.9805 - val_loss: 0.4759 - val_accuracy: 0.8750
# Epoch 123/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0870 - accuracy: 0.9805 - val_loss: 0.3846 - val_accuracy: 0.8438
# Epoch 124/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0695 - accuracy: 0.9766 - val_loss: 0.3389 - val_accuracy: 0.9062
# Epoch 125/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0730 - accuracy: 0.9766 - val_loss: 0.2192 - val_accuracy: 0.9062
# Epoch 126/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0808 - accuracy: 0.9766 - val_loss: 0.2844 - val_accuracy: 0.9375
# Epoch 127/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0758 - accuracy: 0.9766 - val_loss: 0.4895 - val_accuracy: 0.8906
# Epoch 128/300
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0837 - accuracy: 0.9727 - val_loss: 0.3632 - val_accuracy: 0.8906
# Epoch 129/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0472 - accuracy: 0.9844 - val_loss: 0.2675 - val_accuracy: 0.9375
# Epoch 130/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0893 - accuracy: 0.9648 - val_loss: 0.2661 - val_accuracy: 0.9062
# Epoch 131/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0835 - accuracy: 0.9805 - val_loss: 0.4122 - val_accuracy: 0.8906
# Epoch 132/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0500 - accuracy: 0.9844 - val_loss: 0.3194 - val_accuracy: 0.8750
# Epoch 133/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1065 - accuracy: 0.9766 - val_loss: 0.5489 - val_accuracy: 0.8594
# Epoch 134/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0786 - accuracy: 0.9766 - val_loss: 0.3811 - val_accuracy: 0.8906
# Epoch 135/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1385 - accuracy: 0.9531 - val_loss: 0.5861 - val_accuracy: 0.8438
# Epoch 136/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0850 - accuracy: 0.9727 - val_loss: 0.3606 - val_accuracy: 0.8750
# Epoch 137/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0967 - accuracy: 0.9648 - val_loss: 0.5035 - val_accuracy: 0.8750
# Epoch 138/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0933 - accuracy: 0.9648 - val_loss: 0.6303 - val_accuracy: 0.8438
# Epoch 139/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0867 - accuracy: 0.9766 - val_loss: 0.3960 - val_accuracy: 0.8594
# Epoch 140/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0569 - accuracy: 0.9805 - val_loss: 0.3946 - val_accuracy: 0.8906
# Epoch 141/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0475 - accuracy: 0.9883 - val_loss: 0.4330 - val_accuracy: 0.8594
# Epoch 142/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0895 - accuracy: 0.9727 - val_loss: 0.6035 - val_accuracy: 0.8750
# Epoch 143/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0762 - accuracy: 0.9766 - val_loss: 0.3912 - val_accuracy: 0.8594
# Epoch 144/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0624 - accuracy: 0.9844 - val_loss: 0.2697 - val_accuracy: 0.9219
# Epoch 145/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0592 - accuracy: 0.9922 - val_loss: 0.3420 - val_accuracy: 0.8906
# Epoch 146/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0775 - accuracy: 0.9844 - val_loss: 0.5114 - val_accuracy: 0.8281
# Epoch 147/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0434 - accuracy: 0.9883 - val_loss: 0.4490 - val_accuracy: 0.8750
# Epoch 148/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0496 - accuracy: 0.9883 - val_loss: 0.3111 - val_accuracy: 0.8750
# Epoch 149/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0411 - accuracy: 0.9883 - val_loss: 0.2653 - val_accuracy: 0.9219
# Epoch 150/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0464 - accuracy: 0.9844 - val_loss: 0.2585 - val_accuracy: 0.9375
# Epoch 151/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0332 - accuracy: 0.9961 - val_loss: 0.3165 - val_accuracy: 0.9219
# Epoch 152/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0980 - accuracy: 0.9648 - val_loss: 0.6874 - val_accuracy: 0.8125
# Epoch 153/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0585 - accuracy: 0.9805 - val_loss: 0.2286 - val_accuracy: 0.9219
# Epoch 154/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.1634 - accuracy: 0.9492 - val_loss: 0.6059 - val_accuracy: 0.8438
# Epoch 155/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0854 - accuracy: 0.9805 - val_loss: 0.2963 - val_accuracy: 0.9062
# Epoch 156/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0678 - accuracy: 0.9844 - val_loss: 0.2567 - val_accuracy: 0.8906
# Epoch 157/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0536 - accuracy: 0.9805 - val_loss: 0.2809 - val_accuracy: 0.8750
# Epoch 158/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0457 - accuracy: 0.9805 - val_loss: 0.2539 - val_accuracy: 0.9531
# Epoch 159/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0517 - accuracy: 0.9766 - val_loss: 0.2312 - val_accuracy: 0.9531
# Epoch 160/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0918 - accuracy: 0.9570 - val_loss: 0.4770 - val_accuracy: 0.8594
# Epoch 161/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1175 - accuracy: 0.9648 - val_loss: 0.4256 - val_accuracy: 0.8594
# Epoch 162/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0662 - accuracy: 0.9883 - val_loss: 0.2578 - val_accuracy: 0.9375
# Epoch 163/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0415 - accuracy: 0.9805 - val_loss: 0.2905 - val_accuracy: 0.9062
# Epoch 164/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0940 - accuracy: 0.9531 - val_loss: 0.4275 - val_accuracy: 0.9219
# Epoch 165/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0373 - accuracy: 0.9883 - val_loss: 0.4034 - val_accuracy: 0.8750
# Epoch 166/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0414 - accuracy: 0.9883 - val_loss: 0.3882 - val_accuracy: 0.8906
# Epoch 167/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0797 - accuracy: 0.9727 - val_loss: 0.4533 - val_accuracy: 0.8906
# Epoch 168/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0420 - accuracy: 0.9883 - val_loss: 0.7080 - val_accuracy: 0.8438
# Epoch 169/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0975 - accuracy: 0.9766 - val_loss: 0.2969 - val_accuracy: 0.9219
# Epoch 170/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0418 - accuracy: 0.9844 - val_loss: 0.5727 - val_accuracy: 0.8438
# Epoch 171/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0394 - accuracy: 0.9844 - val_loss: 0.3838 - val_accuracy: 0.9219
# Epoch 172/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0228 - accuracy: 0.9961 - val_loss: 0.1942 - val_accuracy: 0.9375
# Epoch 173/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.1065 - accuracy: 0.9727 - val_loss: 0.4923 - val_accuracy: 0.7969
# Epoch 174/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0470 - accuracy: 0.9883 - val_loss: 0.4439 - val_accuracy: 0.8906
# Epoch 175/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.1536 - accuracy: 0.9609 - val_loss: 0.3103 - val_accuracy: 0.9062
# Epoch 176/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0279 - accuracy: 0.9922 - val_loss: 0.3399 - val_accuracy: 0.9062
# Epoch 177/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0520 - accuracy: 0.9844 - val_loss: 0.3209 - val_accuracy: 0.9219
# Epoch 178/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0421 - accuracy: 0.9922 - val_loss: 0.1471 - val_accuracy: 0.9219
# Epoch 179/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0266 - accuracy: 0.9961 - val_loss: 0.2680 - val_accuracy: 0.9219
# Epoch 180/300
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0600 - accuracy: 0.9766 - val_loss: 0.2368 - val_accuracy: 0.9375
# Epoch 181/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0375 - accuracy: 0.9961 - val_loss: 0.3454 - val_accuracy: 0.8750
# Epoch 182/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0267 - accuracy: 0.9961 - val_loss: 0.5608 - val_accuracy: 0.8594
# Epoch 183/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0604 - accuracy: 0.9844 - val_loss: 0.4668 - val_accuracy: 0.8750
# Epoch 184/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0782 - accuracy: 0.9766 - val_loss: 0.5359 - val_accuracy: 0.8594
# Epoch 185/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0404 - accuracy: 0.9922 - val_loss: 0.4508 - val_accuracy: 0.8750
# Epoch 186/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0371 - accuracy: 0.9883 - val_loss: 0.3503 - val_accuracy: 0.9062
# Epoch 187/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1069 - accuracy: 0.9648 - val_loss: 0.5819 - val_accuracy: 0.8906
# Epoch 188/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0534 - accuracy: 0.9844 - val_loss: 0.3570 - val_accuracy: 0.8906
# Epoch 189/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0750 - accuracy: 0.9844 - val_loss: 0.2257 - val_accuracy: 0.9375
# Epoch 190/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0561 - accuracy: 0.9727 - val_loss: 0.1982 - val_accuracy: 0.9219
# Epoch 191/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0362 - accuracy: 0.9844 - val_loss: 0.3950 - val_accuracy: 0.8750
# Epoch 192/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0485 - accuracy: 0.9883 - val_loss: 0.4025 - val_accuracy: 0.8906
# Epoch 193/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0227 - accuracy: 0.9922 - val_loss: 0.2018 - val_accuracy: 0.9375
# Epoch 194/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0289 - accuracy: 0.9883 - val_loss: 0.3303 - val_accuracy: 0.9062
# Epoch 195/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0399 - accuracy: 0.9922 - val_loss: 0.1497 - val_accuracy: 0.9219
# Epoch 196/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0230 - accuracy: 0.9961 - val_loss: 0.2292 - val_accuracy: 0.9219
# Epoch 197/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0178 - accuracy: 0.9922 - val_loss: 0.5584 - val_accuracy: 0.8438
# Epoch 198/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0630 - accuracy: 0.9805 - val_loss: 1.9446 - val_accuracy: 0.6562
# Epoch 199/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0723 - accuracy: 0.9766 - val_loss: 0.4290 - val_accuracy: 0.8750
# Epoch 200/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0388 - accuracy: 0.9883 - val_loss: 0.2332 - val_accuracy: 0.9062
# Epoch 201/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0310 - accuracy: 0.9844 - val_loss: 0.4205 - val_accuracy: 0.9062
# Epoch 202/300
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0426 - accuracy: 0.9844 - val_loss: 0.4227 - val_accuracy: 0.8906
# Epoch 203/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9219
# Epoch 204/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0340 - accuracy: 0.9922 - val_loss: 0.2670 - val_accuracy: 0.9062
# Epoch 205/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0377 - accuracy: 0.9922 - val_loss: 0.1572 - val_accuracy: 0.9531
# Epoch 206/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0842 - accuracy: 0.9648 - val_loss: 1.2822 - val_accuracy: 0.7188
# Epoch 207/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0446 - accuracy: 0.9805 - val_loss: 0.3550 - val_accuracy: 0.9375
# Epoch 208/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0316 - accuracy: 0.9922 - val_loss: 0.0900 - val_accuracy: 0.9531
# Epoch 209/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0473 - accuracy: 0.9844 - val_loss: 0.1676 - val_accuracy: 0.9531
# Epoch 210/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0361 - accuracy: 0.9883 - val_loss: 0.3866 - val_accuracy: 0.8906
# Epoch 211/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0740 - accuracy: 0.9727 - val_loss: 0.3120 - val_accuracy: 0.8594
# Epoch 212/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0772 - accuracy: 0.9727 - val_loss: 0.1277 - val_accuracy: 0.9375
# Epoch 213/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0709 - accuracy: 0.9805 - val_loss: 0.2291 - val_accuracy: 0.9062
# Epoch 214/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0459 - accuracy: 0.9883 - val_loss: 0.5239 - val_accuracy: 0.8906
# Epoch 215/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0808 - accuracy: 0.9688 - val_loss: 0.0965 - val_accuracy: 0.9531
# Epoch 216/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0253 - accuracy: 0.9922 - val_loss: 0.5450 - val_accuracy: 0.8594
# Epoch 217/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0452 - accuracy: 0.9922 - val_loss: 0.1899 - val_accuracy: 0.9219
# Epoch 218/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0362 - accuracy: 0.9883 - val_loss: 0.2694 - val_accuracy: 0.9219
# Epoch 219/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0243 - accuracy: 0.9961 - val_loss: 0.7289 - val_accuracy: 0.8125
# Epoch 220/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0394 - accuracy: 0.9805 - val_loss: 0.2604 - val_accuracy: 0.9375
# Epoch 221/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0537 - accuracy: 0.9844 - val_loss: 0.7477 - val_accuracy: 0.8281
# Epoch 222/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0778 - accuracy: 0.9883 - val_loss: 0.2417 - val_accuracy: 0.8906
# Epoch 223/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0192 - accuracy: 0.9961 - val_loss: 0.2619 - val_accuracy: 0.9219
# Epoch 224/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9531
# Epoch 225/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0251 - accuracy: 0.9922 - val_loss: 0.3563 - val_accuracy: 0.8906
# Epoch 226/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0718 - accuracy: 0.9766 - val_loss: 0.4467 - val_accuracy: 0.8438
# Epoch 227/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0515 - accuracy: 0.9883 - val_loss: 0.4643 - val_accuracy: 0.9062
# Epoch 228/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0497 - accuracy: 0.9766 - val_loss: 1.1790 - val_accuracy: 0.7500
# Epoch 229/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0345 - accuracy: 0.9844 - val_loss: 0.1870 - val_accuracy: 0.9531
# Epoch 230/300
# 43/43 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9844 Модель сохранена с точностью 96.88 %
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0596 - accuracy: 0.9844 - val_loss: 0.1444 - val_accuracy: 0.9688
# Epoch 231/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9219
# Epoch 232/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0272 - accuracy: 0.9922 - val_loss: 0.3885 - val_accuracy: 0.9062
# Epoch 233/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0193 - accuracy: 0.9922 - val_loss: 0.3946 - val_accuracy: 0.8750
# Epoch 234/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0166 - accuracy: 0.9922 - val_loss: 0.3547 - val_accuracy: 0.9219
# Epoch 235/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0223 - accuracy: 0.9922 - val_loss: 0.2149 - val_accuracy: 0.9531
# Epoch 236/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0255 - accuracy: 0.9883 - val_loss: 0.3813 - val_accuracy: 0.9375
# Epoch 237/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.3903 - val_accuracy: 0.9062
# Epoch 238/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0252 - accuracy: 0.9922 - val_loss: 0.2520 - val_accuracy: 0.9375
# Epoch 239/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0220 - accuracy: 0.9844 - val_loss: 0.4624 - val_accuracy: 0.8750
# Epoch 240/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0907 - accuracy: 0.9727 - val_loss: 0.4846 - val_accuracy: 0.8906
# Epoch 241/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0211 - accuracy: 0.9961 - val_loss: 0.5092 - val_accuracy: 0.8594
# Epoch 242/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0337 - accuracy: 0.9883 - val_loss: 0.6385 - val_accuracy: 0.8594
# Epoch 243/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0240 - accuracy: 0.9883 - val_loss: 0.1647 - val_accuracy: 0.9688
# Epoch 244/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9375
# Epoch 245/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0084 - accuracy: 0.9961 - val_loss: 0.2087 - val_accuracy: 0.9219
# Epoch 246/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.3318 - val_accuracy: 0.9062
# Epoch 247/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.2786 - val_accuracy: 0.9062
# Epoch 248/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0230 - accuracy: 0.9961 - val_loss: 0.5764 - val_accuracy: 0.8438
# Epoch 249/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.4183 - val_accuracy: 0.9062
# Epoch 250/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.3474 - val_accuracy: 0.9062
# Epoch 251/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.3766 - val_accuracy: 0.9062
# Epoch 252/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0193 - accuracy: 0.9922 - val_loss: 0.7410 - val_accuracy: 0.8438
# Epoch 253/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.4502 - val_accuracy: 0.9219
# Epoch 254/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0263 - accuracy: 0.9922 - val_loss: 0.4291 - val_accuracy: 0.8906
# Epoch 255/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.4412 - val_accuracy: 0.8906
# Epoch 256/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0244 - accuracy: 0.9883 - val_loss: 0.1384 - val_accuracy: 0.9688
# Epoch 257/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0282 - accuracy: 0.9883 - val_loss: 0.2373 - val_accuracy: 0.9375
# Epoch 258/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0263 - accuracy: 0.9922 - val_loss: 0.5628 - val_accuracy: 0.8281
# Epoch 259/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0373 - accuracy: 0.9883 - val_loss: 0.4694 - val_accuracy: 0.8906
# Epoch 260/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0191 - accuracy: 0.9961 - val_loss: 0.5713 - val_accuracy: 0.8594
# Epoch 261/300
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0185 - accuracy: 0.9922 - val_loss: 0.8481 - val_accuracy: 0.8594
# Epoch 262/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0178 - accuracy: 0.9922 - val_loss: 0.2508 - val_accuracy: 0.9062
# Epoch 263/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0614 - accuracy: 0.9844 - val_loss: 0.4011 - val_accuracy: 0.8750
# Epoch 264/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0509 - accuracy: 0.9844 - val_loss: 0.3327 - val_accuracy: 0.9062
# Epoch 265/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0589 - accuracy: 0.9883 - val_loss: 0.3900 - val_accuracy: 0.9062
# Epoch 266/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0937 - accuracy: 0.9727 - val_loss: 0.6191 - val_accuracy: 0.8750
# Epoch 267/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0556 - accuracy: 0.9844 - val_loss: 0.4419 - val_accuracy: 0.8906
# Epoch 268/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 0.5727 - val_accuracy: 0.8438
# Epoch 269/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0137 - accuracy: 0.9922 - val_loss: 0.1818 - val_accuracy: 0.9688
# Epoch 270/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0426 - accuracy: 0.9961 - val_loss: 0.2001 - val_accuracy: 0.9219
# Epoch 271/300
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.2863 - val_accuracy: 0.9219
# Epoch 272/300
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0270 - accuracy: 0.9805 - val_loss: 0.9290 - val_accuracy: 0.7969
# Epoch 273/300
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2538 - val_accuracy: 0.9375
# Epoch 274/300
# 43/43 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9961 Модель сохранена с точностью 98.44 %
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0087 - accuracy: 0.9961 - val_loss: 0.1508 - val_accuracy: 0.9844
# Epoch 275/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9375
# Epoch 276/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.4604 - val_accuracy: 0.9219
# Epoch 277/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0461 - accuracy: 0.9805 - val_loss: 0.4548 - val_accuracy: 0.8906
# Epoch 278/300
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0500 - accuracy: 0.9844 - val_loss: 0.3503 - val_accuracy: 0.8906
# Epoch 279/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0264 - accuracy: 0.9883 - val_loss: 0.1070 - val_accuracy: 0.9688
# Epoch 280/300
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0256 - accuracy: 0.9883 - val_loss: 0.3520 - val_accuracy: 0.9219
# Epoch 281/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0349 - accuracy: 0.9922 - val_loss: 0.2934 - val_accuracy: 0.9219
# Epoch 282/300
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9219
# Epoch 283/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0243 - accuracy: 0.9844 - val_loss: 0.2300 - val_accuracy: 0.9375
# Epoch 284/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 0.9688
# Epoch 285/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0779 - accuracy: 0.9844 - val_loss: 0.4557 - val_accuracy: 0.9062
# Epoch 286/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.3125 - val_accuracy: 0.9375
# Epoch 287/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9375
# Epoch 288/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.2520 - val_accuracy: 0.9062
# Epoch 289/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9688
# Epoch 290/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.1170 - val_accuracy: 0.9531
# Epoch 291/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0.7558 - val_accuracy: 0.8125
# Epoch 292/300
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0362 - accuracy: 0.9922 - val_loss: 0.4045 - val_accuracy: 0.9062
# Epoch 293/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0109 - accuracy: 0.9922 - val_loss: 0.4391 - val_accuracy: 0.9062
# Epoch 294/300
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0168 - accuracy: 0.9961 - val_loss: 0.1143 - val_accuracy: 0.9688
# Epoch 295/300
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0164 - accuracy: 0.9922 - val_loss: 0.3127 - val_accuracy: 0.9375
# Epoch 296/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0379 - accuracy: 0.9922 - val_loss: 0.4215 - val_accuracy: 0.9375
# Epoch 297/300
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0623 - accuracy: 0.9844 - val_loss: 0.5595 - val_accuracy: 0.8750
# Epoch 298/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0167 - accuracy: 0.9961 - val_loss: 0.3353 - val_accuracy: 0.9375
# Epoch 299/300
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0327 - accuracy: 0.9844 - val_loss: 0.3782 - val_accuracy: 0.8750
# Epoch 300/300
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0297 - accuracy: 0.9844 - val_loss: 0.2737 - val_accuracy: 0.9219
# 2/2 [==============================] - 1s 8ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть:
# Класс: 001                  100% сеть отнесла к классу 001                  - ВЕРНО
# Класс: 002                  100% сеть отнесла к классу 002                  - ВЕРНО
# Класс: 003                  100% сеть отнесла к классу 003                  - ВЕРНО
# Класс: 004                  100% сеть отнесла к классу 004                  - ВЕРНО
# Класс: 005                  100% сеть отнесла к классу 060                  - НЕВЕРНО
# Класс: 006                  100% сеть отнесла к классу 006                  - ВЕРНО
# Класс: 007                  100% сеть отнесла к классу 007                  - ВЕРНО
# Класс: 008                  100% сеть отнесла к классу 008                  - ВЕРНО
# Класс: 009                  100% сеть отнесла к классу 009                  - ВЕРНО
# Класс: 010                  100% сеть отнесла к классу 010                  - ВЕРНО
# Класс: 011                  100% сеть отнесла к классу 011                  - ВЕРНО
# Класс: 012                  100% сеть отнесла к классу 012                  - ВЕРНО
# Класс: 013                  100% сеть отнесла к классу 013                  - ВЕРНО
# Класс: 014                  100% сеть отнесла к классу 014                  - ВЕРНО
# Класс: 015                  100% сеть отнесла к классу 015                  - ВЕРНО
# Класс: 016                  100% сеть отнесла к классу 016                  - ВЕРНО
# Класс: 017                  100% сеть отнесла к классу 017                  - ВЕРНО
# Класс: 018                  100% сеть отнесла к классу 018                  - ВЕРНО
# Класс: 019                  100% сеть отнесла к классу 019                  - ВЕРНО
# Класс: 020                  100% сеть отнесла к классу 020                  - ВЕРНО
# Класс: 021                  100% сеть отнесла к классу 021                  - ВЕРНО
# Класс: 022                  100% сеть отнесла к классу 022                  - ВЕРНО
# Класс: 023                  100% сеть отнесла к классу 023                  - ВЕРНО
# Класс: 024                  100% сеть отнесла к классу 024                  - ВЕРНО
# Класс: 025                  100% сеть отнесла к классу 025                  - ВЕРНО
# Класс: 026                  100% сеть отнесла к классу 026                  - ВЕРНО
# Класс: 027                  100% сеть отнесла к классу 027                  - ВЕРНО
# Класс: 028                  100% сеть отнесла к классу 028                  - ВЕРНО
# Класс: 029                  100% сеть отнесла к классу 029                  - ВЕРНО
# Класс: 030                  100% сеть отнесла к классу 030                  - ВЕРНО
# Класс: 031                  100% сеть отнесла к классу 031                  - ВЕРНО
# Класс: 032                  100% сеть отнесла к классу 032                  - ВЕРНО
# Класс: 033                  100% сеть отнесла к классу 033                  - ВЕРНО
# Класс: 034                  100% сеть отнесла к классу 034                  - ВЕРНО
# Класс: 035                  100% сеть отнесла к классу 035                  - ВЕРНО
# Класс: 036                  100% сеть отнесла к классу 036                  - ВЕРНО
# Класс: 037                  100% сеть отнесла к классу 037                  - ВЕРНО
# Класс: 038                  100% сеть отнесла к классу 038                  - ВЕРНО
# Класс: 039                  100% сеть отнесла к классу 039                  - ВЕРНО
# Класс: 040                  100% сеть отнесла к классу 040                  - ВЕРНО
# Класс: 041                  100% сеть отнесла к классу 041                  - ВЕРНО
# Класс: 042                  100% сеть отнесла к классу 042                  - ВЕРНО
# Класс: 043                  100% сеть отнесла к классу 043                  - ВЕРНО
# Класс: 044                  100% сеть отнесла к классу 044                  - ВЕРНО
# Класс: 045                  100% сеть отнесла к классу 045                  - ВЕРНО
# Класс: 046                  100% сеть отнесла к классу 046                  - ВЕРНО
# Класс: 047                  100% сеть отнесла к классу 047                  - ВЕРНО
# Класс: 048                  100% сеть отнесла к классу 048                  - ВЕРНО
# Класс: 049                  100% сеть отнесла к классу 049                  - ВЕРНО
# Класс: 050                  100% сеть отнесла к классу 050                  - ВЕРНО
# Класс: 051                  100% сеть отнесла к классу 042                  - НЕВЕРНО
# Класс: 052                  100% сеть отнесла к классу 052                  - ВЕРНО
# Класс: 053                  100% сеть отнесла к классу 053                  - ВЕРНО
# Класс: 054                  100% сеть отнесла к классу 054                  - ВЕРНО
# Класс: 055                  100% сеть отнесла к классу 055                  - ВЕРНО
# Класс: 056                  100% сеть отнесла к классу 056                  - ВЕРНО
# Класс: 057                  100% сеть отнесла к классу 057                  - ВЕРНО
# Класс: 058                  100% сеть отнесла к классу 058                  - ВЕРНО
# Класс: 059                  100% сеть отнесла к классу 053                  - НЕВЕРНО
# Класс: 060                  100% сеть отнесла к классу 060                  - ВЕРНО
# Класс: 061                  100% сеть отнесла к классу 061                  - ВЕРНО
# Класс: 062                  100% сеть отнесла к классу 062                  - ВЕРНО
# Класс: 063                  100% сеть отнесла к классу 063                  - ВЕРНО
# Класс: 064                  100% сеть отнесла к классу 064                  - ВЕРНО
#
# Средняя точность распознавания:  95%

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         epochs=150,
                         )
# Out:
# Epoch 1/150
# 43/43 [==============================] - 7s 136ms/step - loss: 0.0524 - accuracy: 0.9805 - val_loss: 1.1698 - val_accuracy: 0.7969
# Epoch 2/150
# 43/43 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9922 Модель сохранена с точностью 85.94 %
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0370 - accuracy: 0.9922 - val_loss: 0.5404 - val_accuracy: 0.8594
# Epoch 3/150
# 43/43 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9922 Модель сохранена с точностью 87.50 %
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0676 - accuracy: 0.9922 - val_loss: 0.5966 - val_accuracy: 0.8750
# Epoch 4/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0389 - accuracy: 0.9883 - val_loss: 0.7157 - val_accuracy: 0.8281
# Epoch 5/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0461 - accuracy: 0.9844 - val_loss: 0.7815 - val_accuracy: 0.8281
# Epoch 6/150
# 43/43 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9766 Модель сохранена с точностью 92.19 %
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0383 - accuracy: 0.9766 - val_loss: 0.3186 - val_accuracy: 0.9219
# Epoch 7/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0840 - accuracy: 0.9766 - val_loss: 1.2812 - val_accuracy: 0.7812
# Epoch 8/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0431 - accuracy: 0.9844 - val_loss: 0.5030 - val_accuracy: 0.8906
# Epoch 9/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0264 - accuracy: 0.9883 - val_loss: 0.3150 - val_accuracy: 0.9062
# Epoch 10/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0193 - accuracy: 0.9922 - val_loss: 0.4364 - val_accuracy: 0.8750
# Epoch 11/150
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0223 - accuracy: 0.9961 - val_loss: 0.3299 - val_accuracy: 0.9062
# Epoch 12/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0185 - accuracy: 0.9961 - val_loss: 0.6075 - val_accuracy: 0.8750
# Epoch 13/150
# 43/43 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9922 Модель сохранена с точностью 93.75 %
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0147 - accuracy: 0.9922 - val_loss: 0.1817 - val_accuracy: 0.9375
# Epoch 14/150
# 43/43 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9922 Модель сохранена с точностью 95.31 %
# 43/43 [==============================] - 6s 137ms/step - loss: 0.0309 - accuracy: 0.9922 - val_loss: 0.1856 - val_accuracy: 0.9531
# Epoch 15/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0402 - accuracy: 0.9922 - val_loss: 0.5594 - val_accuracy: 0.8750
# Epoch 16/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9062
# Epoch 17/150
# 43/43 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9922 Модель сохранена с точностью 96.88 %
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0132 - accuracy: 0.9922 - val_loss: 0.0985 - val_accuracy: 0.9688
# Epoch 18/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0055 - accuracy: 0.9961 - val_loss: 0.0962 - val_accuracy: 0.9688
# Epoch 19/150
# 43/43 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000 Модель сохранена с точностью 100.00 %
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 20/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0082 - accuracy: 0.9961 - val_loss: 0.1319 - val_accuracy: 0.9375
# Epoch 21/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0104 - accuracy: 0.9961 - val_loss: 0.1796 - val_accuracy: 0.9531
# Epoch 22/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0281 - accuracy: 0.9961 - val_loss: 0.2764 - val_accuracy: 0.9375
# Epoch 23/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0083 - accuracy: 0.9961 - val_loss: 0.0470 - val_accuracy: 0.9688
# Epoch 24/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0194 - accuracy: 0.9961 - val_loss: 0.1223 - val_accuracy: 0.9375
# Epoch 25/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9531
# Epoch 26/150
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9688
# Epoch 27/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0093 - accuracy: 0.9922 - val_loss: 0.3695 - val_accuracy: 0.8750
# Epoch 28/150
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0096 - accuracy: 0.9961 - val_loss: 0.0446 - val_accuracy: 0.9844
# Epoch 29/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0190 - accuracy: 0.9922 - val_loss: 0.2217 - val_accuracy: 0.9531
# Epoch 30/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0108 - accuracy: 0.9961 - val_loss: 0.4705 - val_accuracy: 0.9219
# Epoch 31/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0368 - accuracy: 0.9844 - val_loss: 0.7288 - val_accuracy: 0.8750
# Epoch 32/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0321 - accuracy: 0.9922 - val_loss: 0.6504 - val_accuracy: 0.8750
# Epoch 33/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0391 - accuracy: 0.9883 - val_loss: 0.6401 - val_accuracy: 0.8438
# Epoch 34/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0267 - accuracy: 0.9922 - val_loss: 0.2368 - val_accuracy: 0.9375
# Epoch 35/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0118 - accuracy: 0.9922 - val_loss: 0.1313 - val_accuracy: 0.9531
# Epoch 36/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0304 - accuracy: 0.9922 - val_loss: 0.1931 - val_accuracy: 0.9375
# Epoch 37/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9688
# Epoch 38/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0458 - accuracy: 0.9883 - val_loss: 0.1003 - val_accuracy: 0.9688
# Epoch 39/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0923 - accuracy: 0.9688 - val_loss: 0.6921 - val_accuracy: 0.8125
# Epoch 40/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0975 - accuracy: 0.9727 - val_loss: 0.5255 - val_accuracy: 0.9062
# Epoch 41/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0717 - accuracy: 0.9844 - val_loss: 0.4518 - val_accuracy: 0.8906
# Epoch 42/150
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0271 - accuracy: 0.9922 - val_loss: 1.0630 - val_accuracy: 0.7812
# Epoch 43/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0100 - accuracy: 0.9961 - val_loss: 0.3010 - val_accuracy: 0.9375
# Epoch 44/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0187 - accuracy: 0.9922 - val_loss: 0.5117 - val_accuracy: 0.8438
# Epoch 45/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0218 - accuracy: 0.9922 - val_loss: 0.1225 - val_accuracy: 0.9375
# Epoch 46/150
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0253 - accuracy: 0.9922 - val_loss: 0.2245 - val_accuracy: 0.9062
# Epoch 47/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0167 - accuracy: 0.9961 - val_loss: 0.3386 - val_accuracy: 0.9062
# Epoch 48/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.3954 - val_accuracy: 0.9062
# Epoch 49/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.1066 - val_accuracy: 0.9375
# Epoch 50/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0122 - accuracy: 0.9922 - val_loss: 0.2331 - val_accuracy: 0.9375
# Epoch 51/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0238 - accuracy: 0.9883 - val_loss: 0.7219 - val_accuracy: 0.8906
# Epoch 52/150
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0162 - accuracy: 0.9922 - val_loss: 0.6146 - val_accuracy: 0.8750
# Epoch 53/150
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0277 - accuracy: 0.9922 - val_loss: 0.3092 - val_accuracy: 0.9062
# Epoch 54/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0172 - accuracy: 0.9961 - val_loss: 0.4564 - val_accuracy: 0.9219
# Epoch 55/150
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0256 - accuracy: 0.9883 - val_loss: 0.4387 - val_accuracy: 0.9219
# Epoch 56/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1032 - accuracy: 0.9609 - val_loss: 0.9728 - val_accuracy: 0.8281
# Epoch 57/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0705 - accuracy: 0.9805 - val_loss: 0.4494 - val_accuracy: 0.8906
# Epoch 58/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0316 - accuracy: 0.9883 - val_loss: 0.8387 - val_accuracy: 0.7969
# Epoch 59/150
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0334 - accuracy: 0.9883 - val_loss: 0.1567 - val_accuracy: 0.9375
# Epoch 60/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0353 - accuracy: 0.9922 - val_loss: 0.4277 - val_accuracy: 0.8906
# Epoch 61/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0172 - accuracy: 0.9961 - val_loss: 0.4886 - val_accuracy: 0.9062
# Epoch 62/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0210 - accuracy: 0.9961 - val_loss: 0.8866 - val_accuracy: 0.8125
# Epoch 63/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0319 - accuracy: 0.9844 - val_loss: 0.2423 - val_accuracy: 0.9219
# Epoch 64/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0339 - accuracy: 0.9922 - val_loss: 0.2551 - val_accuracy: 0.9219
# Epoch 65/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0263 - accuracy: 0.9961 - val_loss: 0.1738 - val_accuracy: 0.9531
# Epoch 66/150
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0157 - accuracy: 0.9922 - val_loss: 0.5187 - val_accuracy: 0.8750
# Epoch 67/150
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0158 - accuracy: 0.9922 - val_loss: 0.2235 - val_accuracy: 0.9219
# Epoch 68/150
# 43/43 [==============================] - 6s 137ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9688
# Epoch 69/150
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2985 - val_accuracy: 0.9219
# Epoch 70/150
# 43/43 [==============================] - 6s 143ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 0.2106 - val_accuracy: 0.9531
# Epoch 71/150
# 43/43 [==============================] - 6s 141ms/step - loss: 0.0249 - accuracy: 0.9883 - val_loss: 0.5060 - val_accuracy: 0.8594
# Epoch 72/150
# 43/43 [==============================] - 6s 137ms/step - loss: 0.0086 - accuracy: 0.9961 - val_loss: 0.2657 - val_accuracy: 0.9375
# Epoch 73/150
# 43/43 [==============================] - 6s 141ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9531
# Epoch 74/150
# 43/43 [==============================] - 6s 141ms/step - loss: 0.0257 - accuracy: 0.9883 - val_loss: 0.3309 - val_accuracy: 0.9219
# Epoch 75/150
# 43/43 [==============================] - 6s 144ms/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.2924 - val_accuracy: 0.9531
# Epoch 76/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9531
# Epoch 77/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0048 - accuracy: 0.9961 - val_loss: 0.4497 - val_accuracy: 0.8594
# Epoch 78/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0055 - accuracy: 0.9961 - val_loss: 0.2872 - val_accuracy: 0.9375
# Epoch 79/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0091 - accuracy: 0.9961 - val_loss: 0.1339 - val_accuracy: 0.9844
# Epoch 80/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0083 - accuracy: 0.9961 - val_loss: 0.2956 - val_accuracy: 0.9062
# Epoch 81/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0202 - accuracy: 0.9961 - val_loss: 0.3216 - val_accuracy: 0.9062
# Epoch 82/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0450 - accuracy: 0.9883 - val_loss: 0.3160 - val_accuracy: 0.9531
# Epoch 83/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0221 - accuracy: 0.9961 - val_loss: 0.1148 - val_accuracy: 0.9688
# Epoch 84/150
# 43/43 [==============================] - 6s 137ms/step - loss: 0.0078 - accuracy: 0.9961 - val_loss: 0.4069 - val_accuracy: 0.8906
# Epoch 85/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9375
# Epoch 86/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.6008 - val_accuracy: 0.8906
# Epoch 87/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0356 - accuracy: 0.9883 - val_loss: 2.0975 - val_accuracy: 0.6094
# Epoch 88/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0286 - accuracy: 0.9883 - val_loss: 0.5174 - val_accuracy: 0.8906
# Epoch 89/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0183 - accuracy: 0.9961 - val_loss: 0.2621 - val_accuracy: 0.9062
# Epoch 90/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0435 - accuracy: 0.9844 - val_loss: 0.2179 - val_accuracy: 0.9375
# Epoch 91/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 0.3425 - val_accuracy: 0.9375
# Epoch 92/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0132 - accuracy: 0.9922 - val_loss: 0.1162 - val_accuracy: 0.9688
# Epoch 93/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1825 - val_accuracy: 0.9375
# Epoch 94/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0319 - accuracy: 0.9922 - val_loss: 0.4120 - val_accuracy: 0.9062
# Epoch 95/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0172 - accuracy: 0.9922 - val_loss: 0.3583 - val_accuracy: 0.9062
# Epoch 96/150
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0280 - accuracy: 0.9883 - val_loss: 0.3160 - val_accuracy: 0.9375
# Epoch 97/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0587 - accuracy: 0.9766 - val_loss: 0.3429 - val_accuracy: 0.9219
# Epoch 98/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0392 - accuracy: 0.9883 - val_loss: 0.1412 - val_accuracy: 0.9219
# Epoch 99/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9375
# Epoch 100/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0285 - accuracy: 0.9922 - val_loss: 0.3615 - val_accuracy: 0.9062
# Epoch 101/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.8750
# Epoch 102/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.2597 - val_accuracy: 0.9531
# Epoch 103/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9531
# Epoch 104/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9531
# Epoch 105/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9688
# Epoch 106/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9531
# Epoch 107/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0387 - accuracy: 0.9844 - val_loss: 0.4592 - val_accuracy: 0.9375
# Epoch 108/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0302 - accuracy: 0.9922 - val_loss: 1.9879 - val_accuracy: 0.6250
# Epoch 109/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9531
# Epoch 110/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0144 - accuracy: 0.9961 - val_loss: 0.2842 - val_accuracy: 0.9375
# Epoch 111/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0089 - accuracy: 0.9922 - val_loss: 0.5644 - val_accuracy: 0.8906
# Epoch 112/150
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0234 - accuracy: 0.9961 - val_loss: 0.5564 - val_accuracy: 0.8281
# Epoch 113/150
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0051 - accuracy: 0.9961 - val_loss: 0.9234 - val_accuracy: 0.8438
# Epoch 114/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0561 - accuracy: 0.9805 - val_loss: 2.7504 - val_accuracy: 0.5625
# Epoch 115/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0337 - accuracy: 0.9844 - val_loss: 0.6212 - val_accuracy: 0.8438
# Epoch 116/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0275 - accuracy: 0.9922 - val_loss: 0.4591 - val_accuracy: 0.9062
# Epoch 117/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 0.3575 - val_accuracy: 0.8906
# Epoch 118/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0141 - accuracy: 0.9922 - val_loss: 0.4178 - val_accuracy: 0.9062
# Epoch 119/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.6032 - val_accuracy: 0.8906
# Epoch 120/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0311 - accuracy: 0.9883 - val_loss: 0.3361 - val_accuracy: 0.9219
# Epoch 121/150
# 43/43 [==============================] - 6s 135ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3716 - val_accuracy: 0.8906
# Epoch 122/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0176 - accuracy: 0.9922 - val_loss: 0.3467 - val_accuracy: 0.9219
# Epoch 123/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0134 - accuracy: 0.9922 - val_loss: 0.2307 - val_accuracy: 0.9375
# Epoch 124/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9375
# Epoch 125/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0281 - accuracy: 0.9883 - val_loss: 0.4654 - val_accuracy: 0.9062
# Epoch 126/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0273 - accuracy: 0.9961 - val_loss: 0.3244 - val_accuracy: 0.8906
# Epoch 127/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0209 - accuracy: 0.9961 - val_loss: 0.2454 - val_accuracy: 0.9375
# Epoch 128/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.4306 - val_accuracy: 0.8750
# Epoch 129/150
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0119 - accuracy: 0.9922 - val_loss: 0.5214 - val_accuracy: 0.9062
# Epoch 130/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2236 - val_accuracy: 0.9688
# Epoch 131/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 0.9531
# Epoch 132/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3462 - val_accuracy: 0.8906
# Epoch 133/150
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0221 - accuracy: 0.9922 - val_loss: 0.7451 - val_accuracy: 0.8438
# Epoch 134/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.9219
# Epoch 135/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 136/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0200 - accuracy: 0.9922 - val_loss: 0.2591 - val_accuracy: 0.9062
# Epoch 137/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.6426 - val_accuracy: 0.8750
# Epoch 138/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0620 - accuracy: 0.9766 - val_loss: 0.6871 - val_accuracy: 0.8438
# Epoch 139/150
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1760 - accuracy: 0.9688 - val_loss: 1.9184 - val_accuracy: 0.6562
# Epoch 140/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0354 - accuracy: 0.9766 - val_loss: 0.4599 - val_accuracy: 0.9219
# Epoch 141/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0198 - accuracy: 0.9961 - val_loss: 0.9332 - val_accuracy: 0.8125
# Epoch 142/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0374 - accuracy: 0.9883 - val_loss: 1.1482 - val_accuracy: 0.8281
# Epoch 143/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0444 - accuracy: 0.9805 - val_loss: 0.2672 - val_accuracy: 0.9531
# Epoch 144/150
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9844
# Epoch 145/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0069 - accuracy: 0.9961 - val_loss: 0.2060 - val_accuracy: 0.9219
# Epoch 146/150
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.9062
# Epoch 147/150
# 43/43 [==============================] - 6s 136ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 0.3968 - val_accuracy: 0.8906
# Epoch 148/150
# 43/43 [==============================] - 6s 133ms/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.3594 - val_accuracy: 0.9531
# Epoch 149/150
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0358 - accuracy: 0.9844 - val_loss: 1.2488 - val_accuracy: 0.7344
# Epoch 150/150
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0178 - accuracy: 0.9922 - val_loss: 0.1981 - val_accuracy: 0.9219
# 2/2 [==============================] - 0s 16ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть:
# Класс: 001                  100% сеть отнесла к классу 001                  - ВЕРНО
# Класс: 002                  100% сеть отнесла к классу 002                  - ВЕРНО
# Класс: 003                  100% сеть отнесла к классу 003                  - ВЕРНО
# Класс: 004                  100% сеть отнесла к классу 004                  - ВЕРНО
# Класс: 005                  100% сеть отнесла к классу 005                  - ВЕРНО
# Класс: 006                  100% сеть отнесла к классу 006                  - ВЕРНО
# Класс: 007                  100% сеть отнесла к классу 007                  - ВЕРНО
# Класс: 008                  100% сеть отнесла к классу 008                  - ВЕРНО
# Класс: 009                  100% сеть отнесла к классу 009                  - ВЕРНО
# Класс: 010                  100% сеть отнесла к классу 010                  - ВЕРНО
# Класс: 011                  100% сеть отнесла к классу 011                  - ВЕРНО
# Класс: 012                  100% сеть отнесла к классу 012                  - ВЕРНО
# Класс: 013                  100% сеть отнесла к классу 013                  - ВЕРНО
# Класс: 014                  100% сеть отнесла к классу 014                  - ВЕРНО
# Класс: 015                  100% сеть отнесла к классу 015                  - ВЕРНО
# Класс: 016                  100% сеть отнесла к классу 016                  - ВЕРНО
# Класс: 017                  100% сеть отнесла к классу 017                  - ВЕРНО
# Класс: 018                  100% сеть отнесла к классу 018                  - ВЕРНО
# Класс: 019                  100% сеть отнесла к классу 019                  - ВЕРНО
# Класс: 020                  100% сеть отнесла к классу 020                  - ВЕРНО
# Класс: 021                  100% сеть отнесла к классу 021                  - ВЕРНО
# Класс: 022                  100% сеть отнесла к классу 022                  - ВЕРНО
# Класс: 023                  100% сеть отнесла к классу 023                  - ВЕРНО
# Класс: 024                  100% сеть отнесла к классу 024                  - ВЕРНО
# Класс: 025                  100% сеть отнесла к классу 025                  - ВЕРНО
# Класс: 026                  100% сеть отнесла к классу 026                  - ВЕРНО
# Класс: 027                  100% сеть отнесла к классу 027                  - ВЕРНО
# Класс: 028                  100% сеть отнесла к классу 028                  - ВЕРНО
# Класс: 029                  100% сеть отнесла к классу 029                  - ВЕРНО
# Класс: 030                  100% сеть отнесла к классу 030                  - ВЕРНО
# Класс: 031                  100% сеть отнесла к классу 031                  - ВЕРНО
# Класс: 032                  100% сеть отнесла к классу 032                  - ВЕРНО
# Класс: 033                  100% сеть отнесла к классу 033                  - ВЕРНО
# Класс: 034                  100% сеть отнесла к классу 034                  - ВЕРНО
# Класс: 035                  100% сеть отнесла к классу 035                  - ВЕРНО
# Класс: 036                  100% сеть отнесла к классу 036                  - ВЕРНО
# Класс: 037                  100% сеть отнесла к классу 037                  - ВЕРНО
# Класс: 038                  100% сеть отнесла к классу 038                  - ВЕРНО
# Класс: 039                  100% сеть отнесла к классу 039                  - ВЕРНО
# Класс: 040                  100% сеть отнесла к классу 040                  - ВЕРНО
# Класс: 041                  100% сеть отнесла к классу 041                  - ВЕРНО
# Класс: 042                  100% сеть отнесла к классу 042                  - ВЕРНО
# Класс: 043                  100% сеть отнесла к классу 043                  - ВЕРНО
# Класс: 044                  100% сеть отнесла к классу 044                  - ВЕРНО
# Класс: 045                  100% сеть отнесла к классу 045                  - ВЕРНО
# Класс: 046                  100% сеть отнесла к классу 046                  - ВЕРНО
# Класс: 047                  100% сеть отнесла к классу 047                  - ВЕРНО
# Класс: 048                  100% сеть отнесла к классу 048                  - ВЕРНО
# Класс: 049                  100% сеть отнесла к классу 049                  - ВЕРНО
# Класс: 050                  100% сеть отнесла к классу 050                  - ВЕРНО
# Класс: 051                  100% сеть отнесла к классу 051                  - ВЕРНО
# Класс: 052                  100% сеть отнесла к классу 052                  - ВЕРНО
# Класс: 053                  100% сеть отнесла к классу 053                  - ВЕРНО
# Класс: 054                  100% сеть отнесла к классу 054                  - ВЕРНО
# Класс: 055                  100% сеть отнесла к классу 055                  - ВЕРНО
# Класс: 056                  100% сеть отнесла к классу 056                  - ВЕРНО
# Класс: 057                  100% сеть отнесла к классу 057                  - ВЕРНО
# Класс: 058                  100% сеть отнесла к классу 058                  - ВЕРНО
# Класс: 059                  100% сеть отнесла к классу 024                  - НЕВЕРНО
# Класс: 060                  100% сеть отнесла к классу 060                  - ВЕРНО
# Класс: 061                  100% сеть отнесла к классу 061                  - ВЕРНО
# Класс: 062                  100% сеть отнесла к классу 062                  - ВЕРНО
# Класс: 063                  100% сеть отнесла к классу 063                  - ВЕРНО
# Класс: 064                  100% сеть отнесла к классу 064                  - ВЕРНО
#
# Средняя точность распознавания:  98%

# %% [markdown]
# # Выводы:

# %% [markdown]
# 1. Ожидаемая точность модели 98% достигнута.
# 2. Увеличение разрешений подаваемых изображений и количества нейронов в слоях сети в основном влияли негативно на эффективность модели (точность снижалась, а время обучения и нагрузки на среду росло). Напротив, облегчение модели позволило достичь более высокой точности и низкого времени обучения.
