# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/AnastasiaAntimonova-folder/AnastasiaAntimonova/%D1%81%D1%82%D0%B0%D0%B6%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Инструменты для построения графиков
import matplotlib.pyplot as plt 

# Инструменты для работы с изображениями
from tensorflow.keras.preprocessing import image 

from tensorflow.keras.models import Sequential #Сеть прямого распространения

#Базовые слои для свёрточных сетей
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator # работа с изображениями
from tensorflow.keras.optimizers import Adam, Adadelta # оптимизаторы
from tensorflow.keras import utils #Используем для to_categoricall
from tensorflow.keras.preprocessing import image #Для отрисовки изображений

# Инструменты для работы с массивами
import numpy as np 

# Системные инструменты
import time, random, gdown, os

# Дополнительные инструменты для работы с изображениями
from PIL import Image 

# Дополнительные инструменты визуализации
import seaborn as sns
sns.set_style('darkgrid')


# Отрисовка графиков
import matplotlib.pyplot as plt

# Рисование графиков в ячейках Colab
# %matplotlib inline

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=1OBAS7s-FnQao0jMp9VHBzZdjGk3RGcVV', None, quiet=True)
# Out:
# 'iris_5.zip'

# %%
# Глобальные параметры

TRAIN_DIR          = '/content/iris_5/iris_5'           # Папка для обучающего набора данных
TEST_DIR           = '/content/iris_test'  # Папка для тестового набора данных

TEST_SPLIT          = 0.2                   # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.2                   # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 256                   # Ширина изображения для нейросети
IMG_HEIGHT          = 192                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_DIR} {TEST_DIR}

# Разархивация датасета
# !unzip -qo "iris_5.zip" -d {TRAIN_DIR}

# %%
#просмотр списка папок
os.listdir(TRAIN_DIR)
# Out:
# ['002', '008', '007', '004', '006', '001', '003', '009', '010', '005']

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_DIR))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 10, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    class_path = f'{TRAIN_DIR}/{CLASS_LIST[i]}' 
    # Выбор случайного фото из i-го класса
    img_path = class_path +'/'+random.choice(os.listdir(class_path)) 
    # Отображение фотографии (подробнее будет объяснено далее)
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))  
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
# Создание директории тестовых данных
os.mkdir(TEST_DIR)                                        
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_DIR}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_DIR}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 60, выделено для обучения: 50, для теста: 10

# %% [markdown]
# Аугментация данных

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 6                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.1                   # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.1                   # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.1                   # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.7, 1.3)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение разрешено

BATCH_SIZE          = 8                     # Размер батча
EPOCHS              = 150                   # Эпох обучения
OPTIMIZER           = Adam(0.001)           # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную 

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, 
    subset='training'
)

# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 40 images belonging to 10 classes.
# Found 10 images belonging to 10 classes.
# Found 10 images belonging to 10 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 192, 256, 3), (8, 10), батчей: 5
# Формы данных   проверочной выборки: (8, 192, 256, 3), (8, 10), батчей: 2
# Формы данных      тестовой выборки: (10, 192, 256, 3), (10, 10), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 6),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])  
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(8), columns = 4)

# %%
# Функция компиляции и обучения модели нейронной сети

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    # Вывод сводки
    model.summary()

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model, 
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1], 
               class_labels=class_labels, 
               title=title,
               figsize=cm_size)

# %%
# Создание последовательной модели
model_conv = Sequential()

# Первый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model_conv.add(BatchNormalization())

# Второй сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())
model_conv.add(Dropout(0.2))

# Четвертый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Пятый сверточный слой
model_conv.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())

# Шестой сверточный слой
model_conv.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Слой преобразования многомерных данных в одномерные 
model_conv.add(Flatten())

# Промежуточный полносвязный слой
model_conv.add(Dense(2048, activation='relu'))

# Промежуточный полносвязный слой
model_conv.add(Dense(4096, activation='relu'))

# Выходной полносвязный слой с количеством нейронов по количесту классов
model_conv.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model_conv,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         title='Сверточный классификатор')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 192, 256, 256)     7168
#
#  batch_normalization (BatchN  (None, 192, 256, 256)    1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 192, 256, 256)     590080
#
#  max_pooling2d (MaxPooling2D  (None, 64, 85, 256)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 64, 85, 256)       590080
#
#  batch_normalization_1 (Batc  (None, 64, 85, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 64, 85, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 64, 85, 256)       590080
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 28, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 21, 28, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 21, 28, 512)       1180160
#
#  batch_normalization_2 (Batc  (None, 21, 28, 512)      2048
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 21, 28, 1024)      4719616
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 9, 1024)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 7, 9, 1024)        0
#
#  flatten (Flatten)           (None, 64512)             0
#
#  dense (Dense)               (None, 2048)              132122624
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  dense_2 (Dense)             (None, 10)                40970
#
# =================================================================
# Total params: 148,237,578
# Trainable params: 148,235,530
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/150
# 5/5 [==============================] - 25s 850ms/step - loss: 246.2438 - accuracy: 0.0750 - val_loss: 29.4949 - val_accuracy: 0.1000
# Epoch 2/150
# 5/5 [==============================] - 3s 490ms/step - loss: 89.4122 - accuracy: 0.0250 - val_loss: 6.0799 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 5/5 [==============================] - 3s 571ms/step - loss: 16.7889 - accuracy: 0.0750 - val_loss: 2.6174 - val_accuracy: 0.1000
# Epoch 4/150
# 5/5 [==============================] - 3s 517ms/step - loss: 4.4629 - accuracy: 0.1000 - val_loss: 2.5333 - val_accuracy: 0.1000
# Epoch 5/150
# 5/5 [==============================] - 3s 514ms/step - loss: 3.0935 - accuracy: 0.1000 - val_loss: 2.3465 - val_accuracy: 0.1000
# Epoch 6/150
# 5/5 [==============================] - 3s 495ms/step - loss: 2.3151 - accuracy: 0.1750 - val_loss: 2.2431 - val_accuracy: 0.1000
# Epoch 7/150
# 5/5 [==============================] - 3s 493ms/step - loss: 2.0719 - accuracy: 0.2250 - val_loss: 2.2156 - val_accuracy: 0.1000
# Epoch 8/150
# 5/5 [==============================] - 3s 577ms/step - loss: 1.8233 - accuracy: 0.2750 - val_loss: 2.1592 - val_accuracy: 0.2000
# Epoch 9/150
# 5/5 [==============================] - 3s 519ms/step - loss: 1.8822 - accuracy: 0.1250 - val_loss: 2.1602 - val_accuracy: 0.2000
# Epoch 10/150
# 5/5 [==============================] - 3s 498ms/step - loss: 1.9133 - accuracy: 0.2500 - val_loss: 2.1755 - val_accuracy: 0.2000
# Epoch 11/150
# 5/5 [==============================] - 3s 498ms/step - loss: 1.8011 - accuracy: 0.2750 - val_loss: 2.1617 - val_accuracy: 0.2000
# Epoch 12/150
# 5/5 [==============================] - 3s 500ms/step - loss: 1.7115 - accuracy: 0.2750 - val_loss: 2.1813 - val_accuracy: 0.2000
# Epoch 13/150
# 5/5 [==============================] - 3s 584ms/step - loss: 1.6004 - accuracy: 0.3000 - val_loss: 2.1437 - val_accuracy: 0.3000
# Epoch 14/150
# 5/5 [==============================] - 3s 523ms/step - loss: 1.6313 - accuracy: 0.2250 - val_loss: 2.1482 - val_accuracy: 0.2000
# Epoch 15/150
# 5/5 [==============================] - 3s 507ms/step - loss: 1.6675 - accuracy: 0.3500 - val_loss: 2.1479 - val_accuracy: 0.1000
# Epoch 16/150
# 5/5 [==============================] - 3s 509ms/step - loss: 1.5840 - accuracy: 0.3750 - val_loss: 2.2523 - val_accuracy: 0.1000
# Epoch 17/150
# Epoch 57/150
# 5/5 [==============================] - 3s 538ms/step - loss: 0.6988 - accuracy: 0.8500 - val_loss: 5.4499 - val_accuracy: 0.1000
# Epoch 58/150
# 5/5 [==============================] - 3s 517ms/step - loss: 0.4023 - accuracy: 0.8250 - val_loss: 5.8757 - val_accuracy: 0.2000
# Epoch 59/150
# 5/5 [==============================] - 3s 518ms/step - loss: 1.1769 - accuracy: 0.8750 - val_loss: 5.2012 - val_accuracy: 0.1000
# Epoch 60/150
# 5/5 [==============================] - 3s 515ms/step - loss: 1.0058 - accuracy: 0.7250 - val_loss: 6.2124 - val_accuracy: 0.1000
# Epoch 61/150
# 5/5 [==============================] - 3s 517ms/step - loss: 1.4663 - accuracy: 0.6250 - val_loss: 3.2234 - val_accuracy: 0.2000
# Epoch 62/150
# 5/5 [==============================] - 3s 602ms/step - loss: 0.8783 - accuracy: 0.7000 - val_loss: 2.3059 - val_accuracy: 0.4000
# Epoch 63/150
# 5/5 [==============================] - 3s 521ms/step - loss: 0.9844 - accuracy: 0.6250 - val_loss: 3.6908 - val_accuracy: 0.1000
# Epoch 64/150
# 5/5 [==============================] - 3s 590ms/step - loss: 0.8648 - accuracy: 0.6000 - val_loss: 4.6888 - val_accuracy: 0.1000
# Epoch 65/150
# 5/5 [==============================] - 3s 517ms/step - loss: 0.6218 - accuracy: 0.6500 - val_loss: 5.3442 - val_accuracy: 0.1000
# Epoch 66/150
# 5/5 [==============================] - 3s 512ms/step - loss: 1.2713 - accuracy: 0.6000 - val_loss: 4.3577 - val_accuracy: 0.3000
# Epoch 67/150
# 5/5 [==============================] - 3s 511ms/step - loss: 1.2114 - accuracy: 0.7000 - val_loss: 3.3556 - val_accuracy: 0.1000
# Epoch 68/150
# 5/5 [==============================] - 3s 519ms/step - loss: 1.4938 - accuracy: 0.7250 - val_loss: 1.5737 - val_accuracy: 0.2000
# Epoch 69/150
# 5/5 [==============================] - 3s 531ms/step - loss: 1.3860 - accuracy: 0.5750 - val_loss: 2.0878 - val_accuracy: 0.2000
# Epoch 70/150
# 5/5 [==============================] - 3s 511ms/step - loss: 0.9352 - accuracy: 0.6500 - val_loss: 2.5155 - val_accuracy: 0.3000
# Epoch 71/150
# 5/5 [==============================] - 3s 513ms/step - loss: 0.9751 - accuracy: 0.7000 - val_loss: 1.9318 - val_accuracy: 0.4000
# Epoch 72/150
# 5/5 [==============================] - 3s 543ms/step - loss: 1.0442 - accuracy: 0.7000 - val_loss: 1.7278 - val_accuracy: 0.4000
# Epoch 73/150
# 5/5 [==============================] - 3s 513ms/step - loss: 0.6090 - accuracy: 0.7750 - val_loss: 3.5386 - val_accuracy: 0.4000
# Epoch 74/150
# 5/5 [==============================] - 3s 516ms/step - loss: 1.0406 - accuracy: 0.8250 - val_loss: 5.0965 - val_accuracy: 0.1000
# Epoch 75/150
# 5/5 [==============================] - 3s 514ms/step - loss: 0.9393 - accuracy: 0.7250 - val_loss: 5.8859 - val_accuracy: 0.2000
# Epoch 76/150
# 5/5 [==============================] - 3s 513ms/step - loss: 2.0090 - accuracy: 0.2000 - val_loss: 2.3149 - val_accuracy: 0.1000
# Epoch 116/150
# 5/5 [==============================] - 3s 511ms/step - loss: 2.0330 - accuracy: 0.2000 - val_loss: 2.3156 - val_accuracy: 0.1000
# Epoch 117/150
# 5/5 [==============================] - 3s 508ms/step - loss: 2.0871 - accuracy: 0.1500 - val_loss: 2.3171 - val_accuracy: 0.1000
# Epoch 118/150
# 5/5 [==============================] - 3s 590ms/step - loss: 2.0709 - accuracy: 0.2000 - val_loss: 2.0694 - val_accuracy: 0.2000
# Epoch 119/150
# 5/5 [==============================] - 3s 508ms/step - loss: 2.1409 - accuracy: 0.2000 - val_loss: 2.0831 - val_accuracy: 0.2000
# Epoch 120/150
# 5/5 [==============================] - 3s 586ms/step - loss: 2.1619 - accuracy: 0.1500 - val_loss: 2.3226 - val_accuracy: 0.1000
# Epoch 121/150
# 5/5 [==============================] - 3s 509ms/step - loss: 2.0160 - accuracy: 0.1750 - val_loss: 2.0317 - val_accuracy: 0.2000
# Epoch 122/150
# 5/5 [==============================] - 3s 509ms/step - loss: 2.1916 - accuracy: 0.2000 - val_loss: 2.0277 - val_accuracy: 0.2000
# Epoch 123/150
# 5/5 [==============================] - 3s 515ms/step - loss: 2.0724 - accuracy: 0.2000 - val_loss: 2.2650 - val_accuracy: 0.3000
# Epoch 124/150
# 5/5 [==============================] - 3s 591ms/step - loss: 2.8642 - accuracy: 0.2500 - val_loss: 1.8310 - val_accuracy: 0.3000
# Epoch 125/150
# 5/5 [==============================] - 3s 510ms/step - loss: 1.9885 - accuracy: 0.2500 - val_loss: 2.1681 - val_accuracy: 0.1000
# Epoch 126/150
# 5/5 [==============================] - 3s 513ms/step - loss: 2.2562 - accuracy: 0.3000 - val_loss: 3.3645 - val_accuracy: 0.1000
# Epoch 127/150
# 5/5 [==============================] - 3s 540ms/step - loss: 2.4768 - accuracy: 0.2500 - val_loss: 2.2959 - val_accuracy: 0.2000
# Epoch 128/150
# 5/5 [==============================] - 3s 505ms/step - loss: 2.1851 - accuracy: 0.2000 - val_loss: 2.0185 - val_accuracy: 0.2000
# Epoch 129/150
# 5/5 [==============================] - 3s 506ms/step - loss: 2.1077 - accuracy: 0.1750 - val_loss: 2.0170 - val_accuracy: 0.2000
# Epoch 130/150
# 5/5 [==============================] - 3s 601ms/step - loss: 2.0355 - accuracy: 0.2000 - val_loss: 2.0156 - val_accuracy: 0.2000
# Epoch 131/150
# 5/5 [==============================] - 3s 516ms/step - loss: 2.0178 - accuracy: 0.2000 - val_loss: 2.0139 - val_accuracy: 0.2000
# Epoch 132/150
# 5/5 [==============================] - 3s 507ms/step - loss: 2.0114 - accuracy: 0.2250 - val_loss: 2.0119 - val_accuracy: 0.2000
# Epoch 133/150
# 5/5 [==============================] - 3s 509ms/step - loss: 2.0122 - accuracy: 0.2000 - val_loss: 2.0096 - val_accuracy: 0.2000
# Epoch 134/150
# 5/5 [==============================] - 3s 512ms/step - loss: 2.0180 - accuracy: 0.2000 - val_loss: 2.0140 - val_accuracy: 0.2000
# Epoch 135/150
# 5/5 [==============================] - 3s 510ms/step - loss: 2.0078 - accuracy: 0.2000 - val_loss: 2.0071 - val_accuracy: 0.2000
# Epoch 136/150
# 5/5 [==============================] - 3s 508ms/step - loss: 2.0022 - accuracy: 0.2000 - val_loss: 2.0040 - val_accuracy: 0.2000
# Epoch 137/150
# 5/5 [==============================] - 3s 539ms/step - loss: 2.0008 - accuracy: 0.2250 - val_loss: 2.0020 - val_accuracy: 0.2000
# Epoch 138/150
# 5/5 [==============================] - 3s 517ms/step - loss: 1.9994 - accuracy: 0.2250 - val_loss: 2.0004 - val_accuracy: 0.2000
# Epoch 139/150
# 5/5 [==============================] - 3s 511ms/step - loss: 2.0014 - accuracy: 0.2000 - val_loss: 1.9989 - val_accuracy: 0.2000
# Epoch 140/150
# 5/5 [==============================] - 3s 509ms/step - loss: 2.0002 - accuracy: 0.2000 - val_loss: 1.9976 - val_accuracy: 0.2000
# Epoch 141/150
# 5/5 [==============================] - 3s 509ms/step - loss: 2.0166 - accuracy: 0.2000 - val_loss: 1.9966 - val_accuracy: 0.2000
# Epoch 142/150
# 5/5 [==============================] - 3s 535ms/step - loss: 2.0885 - accuracy: 0.1750 - val_loss: 1.9956 - val_accuracy: 0.2000
# Epoch 143/150
# 5/5 [==============================] - 3s 508ms/step - loss: 2.1022 - accuracy: 0.2000 - val_loss: 1.9950 - val_accuracy: 0.2000
# Epoch 144/150
# 5/5 [==============================] - 3s 511ms/step - loss: 2.3128 - accuracy: 0.2250 - val_loss: 1.9992 - val_accuracy: 0.2000
# Epoch 145/150
# 5/5 [==============================] - 3s 508ms/step - loss: 2.0133 - accuracy: 0.1750 - val_loss: 2.4052 - val_accuracy: 0.1000
# Epoch 146/150
# 5/5 [==============================] - 3s 505ms/step - loss: 2.1176 - accuracy: 0.1000 - val_loss: 2.1748 - val_accuracy: 0.1000
# Epoch 147/150
# 5/5 [==============================] - 3s 509ms/step - loss: 2.1578 - accuracy: 0.1500 - val_loss: 2.4081 - val_accuracy: 0.1000
# Epoch 148/150
# 5/5 [==============================] - 3s 506ms/step - loss: 2.0283 - accuracy: 0.2000 - val_loss: 2.4094 - val_accuracy: 0.1000
# Epoch 149/150
# 5/5 [==============================] - 3s 534ms/step - loss: 2.0029 - accuracy: 0.2000 - val_loss: 2.4115 - val_accuracy: 0.1000
# Epoch 150/150
# 5/5 [==============================] - 3s 519ms/step - loss: 2.0079 - accuracy: 0.2000 - val_loss: 2.4140 - val_accuracy: 0.1000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-125707e6ab88> in <cell line: 2>()
#       1 # Обучение модели и вывод оценки ее работы на тестовых данных
# ----> 2 compile_train_eval_model(model_conv,
#       3                          train_generator,
#       4                          validation_generator,
#       5                          test_generator,
#
# <ipython-input-25-0d9ebec0d9e1> in compile_train_eval_model(model, train_data, val_data, test_data, class_labels, title, optimizer, epochs, batch_size, graph_size, cm_size)
#      25
#      26     # Вывод результатов оценки работы модели на тестовых данных
# ---> 27     eval_model(model, test_data[0][0], test_data[0][1],
#      28                class_labels=class_labels,
#      29                title=title,
#
# NameError: name 'eval_model' is not defined
