# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/main/AnastasiaAntimonova/Iris_Antimonova_20230625_Acc_97_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Улучшение с 92% до 94%:
# 1. Batch size уменьшен с 8 до 6
# 2. В последнем полносвязном промежуточном слое снижено кол-во нейронов с 1024 до 512

# %%
# Работа с массивами
import numpy as np

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Основа для создания последовательной модели
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Оптимизатор
from tensorflow.keras.optimizers import Adam

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Подключение модуля для загрузки данных из облака
import gdown

# Инструменты для работы с файлами
import time, random, gdown, os

# Для работы с архивами
import zipfile

# Отрисовка графиков
import matplotlib.pyplot as plt

# Дополнительные инструменты для работы с изображениями
from PIL import Image

# Рисование графиков в ячейках Colab
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=16wKj93ooL-mYryWHIDEr49FJAfAFwnRO', None, quiet=True)
# Out:
# 'Iris.zip'

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_DIR} {TEST_DIR}

# Разархивация датасета
# !unzip -q "Iris.zip" -d /content/Iris #Указываем путь к базе в Google Drive

# %%
# Глобальные параметры

TRAIN_DIR          = '/content/Iris'        # Папка для обучающего набора данных
TEST_DIR           = '/content/iris_test'   # Папка для тестового набора данных

TEST_SPLIT          = 0.2                  # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.2                  # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 192                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %%
# Создаем папки для каждого класса и перемещаем файлы в соответствующую папку
for i in range(1, 65):
                        class_folder = os.path.join(TRAIN_DIR, f'{i:03}')
                        if not os.path.exists(class_folder):
                            os.makedirs(class_folder)
                        for file_name in ['%03dL_%d.png' % (i, j) for j in range(1, 4)] + ['%03dR_%d.png' % (i, j) for j in range(1, 4)]:
                            file_path = os.path.join(TRAIN_DIR, file_name)
                            if os.path.exists(file_path):
                                os.replace(file_path, os.path.join(class_folder, file_name))

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_DIR))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 64, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    class_path = f'{TRAIN_DIR}/{CLASS_LIST[i]}'
    # Выбор случайного фото из i-го класса
    img_path = class_path +'/'+random.choice(os.listdir(class_path))
    # Отображение фотографии
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
# Создание директории тестовых данных
os.mkdir(TEST_DIR)
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_DIR}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_DIR}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# #Аугментация данных

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 5                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.05                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.05                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.05                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.9, 1.1)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение

BATCH_SIZE          = 6                     # Размер батча
EPOCHS              = 350                   # Эпох обучения
OPTIMIZER           = Adam(0.0001)         # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='training'
)

# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 256 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (6, 144, 192, 3), (6, 64), батчей: 43
# Формы данных   проверочной выборки: (6, 144, 192, 3), (6, 64), батчей: 11
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 6),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(8), columns = 4)

# %% [markdown]
# #Создание нейронной сети

# %%
from tensorflow.keras.callbacks import Callback

class SaveModelOnAccuracy(Callback):
    def __init__(self, filepath, monitor='val_loss', mode='min', save_best_only=True, verbose=1, min_accuracy=0.0):
        super(SaveModelOnAccuracy, self).__init__()
        self.filepath = filepath
        self.monitor = monitor
        self.mode = mode
        self.save_best_only = save_best_only
        self.verbose = verbose
        self.min_accuracy = min_accuracy
        self.best_accuracy = 0.0

    def on_epoch_end(self, epoch, logs=None):
        current_accuracy = logs.get('val_accuracy')
        if current_accuracy >= self.min_accuracy and current_accuracy > self.best_accuracy:
            self.model.save(self.filepath)
            self.best_accuracy = current_accuracy
            if self.verbose == 1:
                print(f" Модель сохранена с точностью {self.best_accuracy * 100:.2f} %")

# %%
# Функция компиляции и обучения модели нейронной сети

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5),        # размер полотна для графиков
                        min_accuracy=0.8,       # минимальное значение accuracy для сохранения модели
                        checkpoint_path='/content/Best_model/best_model.h5'):

    # Компиляция модели
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Вывод сводки
    # model.summary()

    # Создание обратного вызова для сохранения модели с заданным значением accuracy
    checkpoint = SaveModelOnAccuracy(filepath=checkpoint_path,
                                     monitor='val_loss',
                                     mode='min',
                                     save_best_only=True,
                                     verbose=1,
                                     min_accuracy=min_accuracy)

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data,
                        callbacks=[checkpoint])  # Передача обратного вызова в качестве списка)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'],
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

    return history

# %%
# Функция вывода результатов оценки модели на заданных данных

def eval_model(model,
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(10, 10)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=12)
    plt.ylabel('Верные классы', fontsize=12)
    plt.show()

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Cообщение о верности или неверности предсказания
        msg = 'ВЕРНО' if cls_pred == cls else 'НЕВЕРНО'
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model,
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1],
               class_labels=class_labels,
               title=title,
               figsize=cm_size)

# %%
# Сохранение лучшей модели
def save_model_to_drive(model, save_path):

    from google.colab import drive
    import shutil

    # Подключение к Google Диску
    drive.mount('/content/gdrive')

    # Сохранение модели в указанную папку на Google Диск
    shutil.copyfile(model, '/content/gdrive/MyDrive/' + save_path)

# %%
from tensorflow.keras.models import load_model

# Загрузка лучшей модели
def load_best_model(model_path):
    # Загрузка модели из указанного файла
    best_model = load_model(model_path)

    return best_model

# %%
# Создание последовательной модели
model = Sequential()

# Первый сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model.add(BatchNormalization())

# Второй сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Четвертый сверточный слой
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.2))

# Пятый сверточный слой
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

# Слой преобразования многомерных данных в одномерные
model.add(Flatten())

# Промежуточный полносвязный слой
model.add(Dense(512, activation='relu'))


# Промежуточный полносвязный слой
model.add(Dense(512, activation='relu'))


# Выходной полносвязный слой с количеством нейронов по количесту классов
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         )
# Out:
# Epoch 1/350
# 43/43 [==============================] - 19s 150ms/step - loss: 5.1952 - accuracy: 0.0195 - val_loss: 4.1721 - val_accuracy: 0.0156
# Epoch 2/350
# 43/43 [==============================] - 5s 126ms/step - loss: 4.1156 - accuracy: 0.0391 - val_loss: 4.2244 - val_accuracy: 0.0156
# Epoch 3/350
# 43/43 [==============================] - 6s 131ms/step - loss: 3.5849 - accuracy: 0.0977 - val_loss: 4.3970 - val_accuracy: 0.0156
# Epoch 4/350
# 43/43 [==============================] - 5s 126ms/step - loss: 3.0506 - accuracy: 0.1914 - val_loss: 4.7709 - val_accuracy: 0.0156
# Epoch 5/350
# 43/43 [==============================] - 6s 133ms/step - loss: 2.5377 - accuracy: 0.2695 - val_loss: 4.9887 - val_accuracy: 0.0156
# Epoch 6/350
350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0401 - accuracy: 0.9883 - val_loss: 0.8044 - val_accuracy: 0.7500
# Epoch 34/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0572 - accuracy: 0.9805 - val_loss: 0.8114 - val_accuracy: 0.7344
# Epoch 35/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0456 - accuracy: 0.9805 - val_loss: 0.6125 - val_accuracy: 0.8125
# Epoch 36/350
# 43/43 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9883 Модель сохранена с точностью 85.94 %
# 43/43 [==============================] - 7s 154ms/step - loss: 0.0688 - accuracy: 0.9883 - val_loss: 0.4993 - val_accuracy: 0.8594
# Epoch 37/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0614 - accuracy: 0.9883 - val_loss: 1.0892 - val_accuracy: 0.7656
# Epoch 38/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0989 - accuracy: 0.9805 - val_loss: 0.6882 - val_accuracy: 0.8281
# Epoch 39/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.1637 - accuracy: 0.9648 - val_loss: 1.5488 - val_accuracy: 0.5781
# Epoch 40/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0901 - accuracy: 0.9727 - val_loss: 2.0651 - val_accuracy: 0.6719
# Epoch 41/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.1079 - accuracy: 0.9688 - val_loss: 1.0852 - val_accuracy: 0.7812
# Epoch 42/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.1875 - accuracy: 0.9453 - val_loss: 1.5544 - val_accuracy: 0.6562
# Epoch 43/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.1324 - accuracy: 0.9766 - val_loss: 1.1688 - val_accuracy: 0.7656
# Epoch 44/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0431 - accuracy: 0.9883 - val_loss: 0.8440 - val_accuracy: 0.7969
# Epoch 45/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.1226 - accuracy: 0.9727 - val_loss: 1.4213 - val_accuracy: 0.6875
# Epoch 46/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.1543 - accuracy: 0.9570 - val_loss: 0.5458 - val_accuracy: 0.8125
# Epoch 47/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.2145 - accuracy: 0.9453 - val_loss: 1.6449 - val_accuracy: 0.7188
# Epoch 48/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1935 - accuracy: 0.9453 - val_loss: 1.1822 - val_accuracy: 0.7344
# Epoch 49/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1966 - accuracy: 0.9375 - val_loss: 3.7603 - val_accuracy: 0.2969
# Epoch 50/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1405 - accuracy: 0.9570 - val_loss: 1.5928 - val_accuracy: 0.6562
# Epoch 51/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.2139 - accuracy: 0.9492 - val_loss: 1.7697 - val_accuracy: 0.6562
# Epoch 52/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1896 - accuracy: 0.9570 - val_loss: 1.0402 - val_accuracy: 0.7656
# Epoch 53/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0500 - accuracy: 0.9844 - val_loss: 0.7780 - val_accuracy: 0.7812
# Epoch 54/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.4014 - val_accuracy: 0.8594
# Epoch 55/350
# 43/43 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9961 Модель сохранена с точностью 87.50 %
# 43/43 [==============================] - 7s 155ms/step - loss: 0.0196 - accuracy: 0.9961 - val_loss: 0.3895 - val_accuracy: 0.8750
# Epoch 56/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.4821 - val_accuracy: 0.8438
# Epoch 57/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0155 - accuracy: 0.9961 - val_loss: 0.7612 - val_accuracy: 0.7969
# Epoch 58/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0197 - accuracy: 0.9961 - val_loss: 0.4833 - val_accuracy: 0.8438
# Epoch 59/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0191 - accuracy: 0.9922 - val_loss: 0.7256 - val_accuracy: 0.8125
# Epoch 60/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0477 - accuracy: 0.9844 - val_loss: 0.4741 - val_accuracy: 0.8125
# Epoch 61/350
# 43/43 [==============================] - 5s 124ms/step - loss: 0.0356 - accuracy: 0.9805 - val_loss: 1.5358 - val_accuracy: 0.7031
# Epoch 62/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0881 - accuracy: 0.9727 - val_loss: 1.7238 - val_accuracy: 0.6250
# Epoch 63/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0582 - accuracy: 0.9805 - val_loss: 1.9998 - val_accuracy: 0.5938
# Epoch 64/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0498 - accuracy: 0.9766 - val_loss: 1.0510 - val_accuracy: 0.7656
# Epoch 65/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.1345 - accuracy: 0.9648 - val_loss: 1.0367 - val_accuracy: 0.7969
# Epoch 66/350
# 43/43 [==============================] - 5s 124ms/step - loss: 0.1783 - accuracy: 0.9570 - val_loss: 2.7954 - val_accuracy: 0.5312
# Epoch 67/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.1380 - accuracy: 0.9531 - val_loss: 2.2622 - val_accuracy: 0.7344
# Epoch 68/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.1263 - accuracy: 0.9531 - val_loss: 0.8729 - val_accuracy: 0.7969
# Epoch 69/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1171 - accuracy: 0.9727 - val_loss: 0.9211 - val_accuracy: 0.7969
# Epoch 70/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.2097 - accuracy: 0.9492 - val_loss: 0.9144 - val_accuracy: 0.8125
# Epoch 71/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.2097 - accuracy: 0.9492 - val_loss: 2.2879 - val_accuracy: 0.6250
# Epoch 72/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0355 - accuracy: 0.9922 - val_loss: 1.6868 - val_accuracy: 0.7188
# Epoch 73/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.8885 - val_accuracy: 0.8594
# Epoch 74/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0680 - val_accuracy: 0.8281
# Epoch 75/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0495 - accuracy: 0.9766 - val_loss: 0.9419 - val_accuracy: 0.8125
# Epoch 76/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0861 - accuracy: 0.9844 - val_loss: 1.0316 - val_accuracy: 0.7812
# Epoch 77/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0222 - accuracy: 0.9961 - val_loss: 0.7774 - val_accuracy: 0.8594
# Epoch 78/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0080 - accuracy: 0.9961 - val_loss: 0.6791 - val_accuracy: 0.8594
# Epoch 79/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0329 - accuracy: 0.9922 - val_loss: 0.7244 - val_accuracy: 0.8594
# Epoch 80/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0240 - accuracy: 0.9922 - val_loss: 0.6801 - val_accuracy: 0.7969
# Epoch 81/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0443 - accuracy: 0.9922 - val_loss: 3.2040 - val_accuracy: 0.4531
# Epoch 82/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0188 - accuracy: 0.9883 - val_loss: 1.6717 - val_accuracy: 0.6875
# Epoch 83/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1104 - accuracy: 0.9648 - val_loss: 0.6890 - val_accuracy: 0.8438
# Epoch 84/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0353 - accuracy: 0.9844 - val_loss: 0.9519 - val_accuracy: 0.7344
# Epoch 85/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0729 - accuracy: 0.9844 - val_loss: 1.1944 - val_accuracy: 0.7812
# Epoch 86/350
# 43/43 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9922 Модель сохранена с точностью 90.62 %
# 43/43 [==============================] - 7s 155ms/step - loss: 0.0436 - accuracy: 0.9922 - val_loss: 0.5026 - val_accuracy: 0.9062
# Epoch 87/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0393 - accuracy: 0.9844 - val_loss: 0.6933 - val_accuracy: 0.8281
# Epoch 88/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.1362 - accuracy: 0.9648 - val_loss: 1.1598 - val_accuracy: 0.7656
# Epoch 89/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0926 - accuracy: 0.9688 - val_loss: 1.1342 - val_accuracy: 0.7812
# Epoch 90/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.1284 - accuracy: 0.9688 - val_loss: 0.7439 - val_accuracy: 0.7812
# Epoch 91/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0770 - accuracy: 0.9727 - val_loss: 1.9374 - val_accuracy: 0.7344
# Epoch 92/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1473 - accuracy: 0.9805 - val_loss: 1.1338 - val_accuracy: 0.7812
# Epoch 93/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0868 - accuracy: 0.9844 - val_loss: 0.9896 - val_accuracy: 0.8125
# Epoch 94/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.7216 - val_accuracy: 0.7812
# Epoch 95/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.5826 - val_accuracy: 0.8438
# Epoch 96/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5408 - val_accuracy: 0.8438
# Epoch 97/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0303 - accuracy: 0.9883 - val_loss: 0.8808 - val_accuracy: 0.8125
# Epoch 98/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0369 - accuracy: 0.9844 - val_loss: 1.0010 - val_accuracy: 0.7500
# Epoch 99/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0184 - accuracy: 0.9922 - val_loss: 0.7498 - val_accuracy: 0.8438
# Epoch 100/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.1060 - accuracy: 0.9844 - val_loss: 1.1511 - val_accuracy: 0.7969
# Epoch 101/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0569 - accuracy: 0.9805 - val_loss: 1.6194 - val_accuracy: 0.7500
# Epoch 102/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0829 - accuracy: 0.9766 - val_loss: 4.2861 - val_accuracy: 0.4531
# Epoch 103/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0615 - accuracy: 0.9766 - val_loss: 0.9641 - val_accuracy: 0.8125
# Epoch 104/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1014 - accuracy: 0.9727 - val_loss: 2.6890 - val_accuracy: 0.6406
# Epoch 105/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.1308 - accuracy: 0.9648 - val_loss: 3.0469 - val_accuracy: 0.5938
# Epoch 106/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0762 - accuracy: 0.9766 - val_loss: 0.7648 - val_accuracy: 0.8438
# Epoch 107/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0751 - accuracy: 0.9805 - val_loss: 1.4507 - val_accuracy: 0.8125
# Epoch 108/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.1088 - accuracy: 0.9805 - val_loss: 1.7949 - val_accuracy: 0.6719
# Epoch 109/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.2922 - accuracy: 0.9453 - val_loss: 1.1046 - val_accuracy: 0.7656
# Epoch 110/350
# 43/43 [==============================] - 5s 124ms/step - loss: 0.1161 - accuracy: 0.9688 - val_loss: 2.4999 - val_accuracy: 0.6094
# Epoch 111/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0933 - accuracy: 0.9727 - val_loss: 1.1958 - val_accuracy: 0.8438
# Epoch 112/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0381 - accuracy: 0.9922 - val_loss: 0.6976 - val_accuracy: 0.7969
# Epoch 113/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0595 - accuracy: 0.9844 - val_loss: 0.5778 - val_accuracy: 0.8281
# Epoch 114/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0956 - accuracy: 0.9766 - val_loss: 3.3598 - val_accuracy: 0.6562
# Epoch 115/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0641 - accuracy: 0.9844 - val_loss: 1.5457 - val_accuracy: 0.8125
# Epoch 116/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.1162 - accuracy: 0.9844 - val_loss: 0.7268 - val_accuracy: 0.8438
# Epoch 117/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0274 - accuracy: 0.9844 - val_loss: 1.5451 - val_accuracy: 0.7344
# Epoch 118/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.1160 - accuracy: 0.9727 - val_loss: 2.4434 - val_accuracy: 0.7188
# Epoch 119/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0764 - accuracy: 0.9844 - val_loss: 2.8583 - val_accuracy: 0.6875
# Epoch 120/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0448 - accuracy: 0.9844 - val_loss: 4.0130 - val_accuracy: 0.6250
# Epoch 121/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0676 - accuracy: 0.9844 - val_loss: 0.7594 - val_accuracy: 0.8438
# Epoch 122/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0358 - accuracy: 0.9844 - val_loss: 0.6120 - val_accuracy: 0.8594
# Epoch 123/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0533 - accuracy: 0.9922 - val_loss: 0.8996 - val_accuracy: 0.8594
# Epoch 124/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.
# 43/43 [==============================] - 6s 132ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 1.6316 - val_accuracy: 0.7656
# Epoch 217/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 2.0956 - val_accuracy: 0.7656
# Epoch 218/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0350 - accuracy: 0.9922 - val_loss: 4.1098 - val_accuracy: 0.7344
# Epoch 219/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0255 - accuracy: 0.9922 - val_loss: 2.3572 - val_accuracy: 0.7500
# Epoch 220/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.1707 - accuracy: 0.9727 - val_loss: 3.5465 - val_accuracy: 0.6406
# Epoch 221/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0909 - accuracy: 0.9727 - val_loss: 25.2888 - val_accuracy: 0.2500
# Epoch 222/350
# 43/43 [==============================] - 5s 124ms/step - loss: 0.1513 - accuracy: 0.9688 - val_loss: 2.4041 - val_accuracy: 0.7344
# Epoch 223/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.3684 - accuracy: 0.9609 - val_loss: 2.2064 - val_accuracy: 0.8594
# Epoch 224/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.1134 - accuracy: 0.9883 - val_loss: 2.1507 - val_accuracy: 0.7500
# Epoch 225/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0353 - accuracy: 0.9922 - val_loss: 1.1200 - val_accuracy: 0.8125
# Epoch 226/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0301 - accuracy: 0.9844 - val_loss: 1.8832 - val_accuracy: 0.7656
# Epoch 227/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0170 - accuracy: 0.9922 - val_loss: 3.3286 - val_accuracy: 0.6719
# Epoch 228/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 2.5468 - val_accuracy: 0.7031
# Epoch 229/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.0316 - val_accuracy: 0.7344
# Epoch 230/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0052 - accuracy: 0.9961 - val_loss: 1.4296 - val_accuracy: 0.8750
# Epoch 231/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0216 - accuracy: 0.9961 - val_loss: 0.9626 - val_accuracy: 0.8125
# Epoch 232/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4546 - val_accuracy: 0.9062
# Epoch 233/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0577 - accuracy: 0.9922 - val_loss: 0.9178 - val_accuracy: 0.8125
# Epoch 234/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0265 - accuracy: 0.9883 - val_loss: 4.1327 - val_accuracy: 0.6250
# Epoch 235/350
# 43/43 [==============================] - 5s 123ms/step - loss: 0.0429 - accuracy: 0.9883 - val_loss: 2.1679 - val_accuracy: 0.8438
# Epoch 236/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1113 - accuracy: 0.9766 - val_loss: 0.7257 - val_accuracy: 0.9062
# Epoch 237/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0494 - accuracy: 0.9883 - val_loss: 3.2352 - val_accuracy: 0.6875
# Epoch 238/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0990 - accuracy: 0.9688 - val_loss: 1.8447 - val_accuracy: 0.7188
# Epoch 239/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0338 - accuracy: 0.9883 - val_loss: 1.3745 - val_accuracy: 0.8125
# Epoch 240/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.1115 - val_accuracy: 0.8281
# Epoch 241/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0267 - accuracy: 0.9922 - val_loss: 1.4354 - val_accuracy: 0.8125
# Epoch 242/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0089 - accuracy: 0.9961 - val_loss: 0.8659 - val_accuracy: 0.8750
# Epoch 243/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0061 - accuracy: 0.9922 - val_loss: 0.9856 - val_accuracy: 0.8594
# Epoch 244/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0515 - accuracy: 0.9844 - val_loss: 1.4903 - val_accuracy: 0.8125
# Epoch 245/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.1093 - accuracy: 0.9805 - val_loss: 2.7439 - val_accuracy: 0.6875
# Epoch 246/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0791 - accuracy: 0.9766 - val_loss: 2.7388 - val_accuracy: 0.7188
# Epoch 247/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0305 - accuracy: 0.9883 - val_loss: 0.7985 - val_accuracy: 0.8438
# Epoch 248/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0558 - accuracy: 0.9844 - val_loss: 2.7639 - val_accuracy: 0.7344
# Epoch 249/350
# 43/43 [==============================] - 6s 133ms/step - loss: 0.1025 - accuracy: 0.9883 - val_loss: 2.6558 - val_accuracy: 0.7344
# Epoch 250/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0419 - accuracy: 0.9883 - val_loss: 2.9987 - val_accuracy: 0.7500
# Epoch 251/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0477 - accuracy: 0.9883 - val_loss: 1.5775 - val_accuracy: 0.8125
# Epoch 252/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0766 - accuracy: 0.9805 - val_loss: 2.9201 - val_accuracy: 0.6719
# Epoch 253/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0066 - accuracy: 0.9961 - val_loss: 2.2746 - val_accuracy: 0.7031
# Epoch 254/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0721 - accuracy: 0.9883 - val_loss: 1.5990 - val_accuracy: 0.8281
# Epoch 255/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0518 - accuracy: 0.9844 - val_loss: 3.8165 - val_accuracy: 0.6562
# Epoch 256/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0631 - accuracy: 0.9844 - val_loss: 2.0473 - val_accuracy: 0.7656
# Epoch 257/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0063 - accuracy: 0.9961 - val_loss: 2.3220 - val_accuracy: 0.7500
# Epoch 258/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0318 - accuracy: 0.9961 - val_loss: 1.6462 - val_accuracy: 0.7344
# Epoch 259/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.1385 - accuracy: 0.9766 - val_loss: 2.9469 - val_accuracy: 0.7656
# Epoch 260/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0884 - accuracy: 0.9922 - val_loss: 1.7180 - val_accuracy: 0.7812
# Epoch 261/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0175 - accuracy: 0.9961 - val_loss: 1.3941 - val_accuracy: 0.8125
# Epoch 262/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2957 - val_accuracy: 0.8281
# Epoch 263/350
# 43/43 [==============================] - 6s 128ms/step - loss: 2.7817e-04 - accuracy: 1.0000 - val_loss: 1.3176 - val_accuracy: 0.8125
# Epoch 264/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0049 - accuracy: 0.9961 - val_loss: 1.7028 - val_accuracy: 0.7969
# Epoch 265/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.5446 - val_accuracy: 0.8281
# Epoch 266/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0681 - val_accuracy: 0.8594
# Epoch 267/350
# 43/43 [==============================] - 5s 124ms/step - loss: 1.3630e-04 - accuracy: 1.0000 - val_loss: 1.2619 - val_accuracy: 0.8125
# Epoch 268/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0162 - accuracy: 0.9961 - val_loss: 1.5214 - val_accuracy: 0.8281
# Epoch 269/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0285 - accuracy: 0.9922 - val_loss: 1.8568 - val_accuracy: 0.7812
# Epoch 270/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0384 - accuracy: 0.9922 - val_loss: 0.8530 - val_accuracy: 0.8438
# Epoch 271/350
# 43/43 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9961 Модель сохранена с точностью 92.19 %
# 43/43 [==============================] - 7s 160ms/step - loss: 0.0266 - accuracy: 0.9961 - val_loss: 0.4321 - val_accuracy: 0.9219
# Epoch 272/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0080 - accuracy: 0.9922 - val_loss: 1.3141 - val_accuracy: 0.8438
# Epoch 273/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0321 - accuracy: 0.9883 - val_loss: 0.6661 - val_accuracy: 0.8906
# Epoch 274/350
# 43/43 [==============================] - 5s 126ms/step - loss: 6.6566e-04 - accuracy: 1.0000 - val_loss: 0.8948 - val_accuracy: 0.8438
# Epoch 275/350
# 43/43 [==============================] - 5s 125ms/step - loss: 1.4744e-04 - accuracy: 1.0000 - val_loss: 0.4230 - val_accuracy: 0.9062
# Epoch 276/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.1112 - accuracy: 0.9922 - val_loss: 1.0397 - val_accuracy: 0.8750
# Epoch 277/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.
350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.0148 - accuracy: 0.9922 - val_loss: 1.4945 - val_accuracy: 0.8750
# Epoch 329/350
# 43/43 [==============================] - 6s 132ms/step - loss: 2.8653e-04 - accuracy: 1.0000 - val_loss: 1.2806 - val_accuracy: 0.8750
# Epoch 330/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0521 - accuracy: 0.9883 - val_loss: 1.3702 - val_accuracy: 0.8281
# Epoch 331/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0512 - accuracy: 0.9922 - val_loss: 1.6745 - val_accuracy: 0.8594
# Epoch 332/350
# 43/43 [==============================] - 5s 126ms/step - loss: 0.1031 - accuracy: 0.9961 - val_loss: 1.1416 - val_accuracy: 0.8594
# Epoch 333/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.1297 - accuracy: 0.9766 - val_loss: 2.2107 - val_accuracy: 0.7500
# Epoch 334/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.2295 - accuracy: 0.9492 - val_loss: 10.5599 - val_accuracy: 0.4531
# Epoch 335/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.2897 - accuracy: 0.9688 - val_loss: 5.0770 - val_accuracy: 0.5938
# Epoch 336/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0765 - accuracy: 0.9766 - val_loss: 2.4845 - val_accuracy: 0.7188
# Epoch 337/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0627 - accuracy: 0.9805 - val_loss: 0.9268 - val_accuracy: 0.8750
# Epoch 338/350
# 43/43 [==============================] - 6s 129ms/step - loss: 0.0086 - accuracy: 0.9961 - val_loss: 0.7656 - val_accuracy: 0.8750
# Epoch 339/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.8885 - val_accuracy: 0.8594
# Epoch 340/350
# 43/43 [==============================] - 6s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0279 - val_accuracy: 0.8281
# Epoch 341/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0188 - accuracy: 0.9922 - val_loss: 1.1817 - val_accuracy: 0.8594
# Epoch 342/350
# 43/43 [==============================] - 6s 132ms/step - loss: 3.9612e-04 - accuracy: 1.0000 - val_loss: 1.3635 - val_accuracy: 0.7969
# Epoch 343/350
# 43/43 [==============================] - 5s 127ms/step - loss: 0.0431 - accuracy: 0.9961 - val_loss: 0.7135 - val_accuracy: 0.8906
# Epoch 344/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0426 - accuracy: 0.9922 - val_loss: 1.2009 - val_accuracy: 0.8594
# Epoch 345/350
# 43/43 [==============================] - 6s 128ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.4357 - val_accuracy: 0.7812
# Epoch 346/350
# 43/43 [==============================] - 5s 128ms/step - loss: 0.0275 - accuracy: 0.9961 - val_loss: 8.8427 - val_accuracy: 0.4531
# Epoch 347/350
# 43/43 [==============================] - 6s 131ms/step - loss: 0.0369 - accuracy: 0.9922 - val_loss: 6.9240 - val_accuracy: 0.5625
# Epoch 348/350
# 43/43 [==============================] - 5s 125ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.3787 - val_accuracy: 0.7031
# Epoch 349/350
# 43/43 [==============================] - 6s 130ms/step - loss: 0.0155 - accuracy: 0.9961 - val_loss: 1.6379 - val_accuracy: 0.7969
# Epoch 350/350
# 43/43 [==============================] - 5s 126ms/step - loss: 2.5465e-04 - accuracy: 1.0000 - val_loss: 1.4622 - val_accuracy: 0.8438
# 2/2 [==============================] - 1s 8ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть:
# Класс: 001                  100% сеть отнесла к классу 001                  - ВЕРНО
# Класс: 002                  100% сеть отнесла к классу 002                  - ВЕРНО
# Класс: 003                  100% сеть отнесла к классу 022                  - НЕВЕРНО
# Класс: 004                  100% сеть отнесла к классу 004                  - ВЕРНО
# Класс: 005                  100% сеть отнесла к классу 005                  - ВЕРНО
# Класс: 006                  100% сеть отнесла к классу 006                  - ВЕРНО
# Класс: 007                  100% сеть отнесла к классу 007                  - ВЕРНО
# Класс: 008                  100% сеть отнесла к классу 008                  - ВЕРНО
# Класс: 009                  100% сеть отнесла к классу 009                  - ВЕРНО
# Класс: 010                  100% сеть отнесла к классу 010                  - ВЕРНО
# Класс: 011                  100% сеть отнесла к классу 011                  - ВЕРНО
# Класс: 012                  100% сеть отнесла к классу 012                  - ВЕРНО
# Класс: 013                  100% сеть отнесла к классу 013                  - ВЕРНО
# Класс: 014                  100% сеть отнесла к классу 014                  - ВЕРНО
# Класс: 015                  100% сеть отнесла к классу 015                  - ВЕРНО
# Класс: 016                  100% сеть отнесла к классу 016                  - ВЕРНО
# Класс: 017                  100% сеть отнесла к классу 017                  - ВЕРНО
# Класс: 018                  100% сеть отнесла к классу 018                  - ВЕРНО
# Класс: 019                  100% сеть отнесла к классу 019                  - ВЕРНО
# Класс: 020                  100% сеть отнесла к классу 020                  - ВЕРНО
# Класс: 021                  100% сеть отнесла к классу 021                  - ВЕРНО
# Класс: 022                  100% сеть отнесла к классу 022                  - ВЕРНО
# Класс: 023                  100% сеть отнесла к классу 023                  - ВЕРНО
# Класс: 024                  100% сеть отнесла к классу 024                  - ВЕРНО
# Класс: 025                  100% сеть отнесла к классу 025                  - ВЕРНО
# Класс: 026                  100% сеть отнесла к классу 026                  - ВЕРНО
# Класс: 027                  100% сеть отнесла к классу 027                  - ВЕРНО
# Класс: 028                  100% сеть отнесла к классу 028                  - ВЕРНО
# Класс: 029                  100% сеть отнесла к классу 029                  - ВЕРНО
# Класс: 030                  100% сеть отнесла к классу 030                  - ВЕРНО
# Класс: 031                  100% сеть отнесла к классу 031                  - ВЕРНО
# Класс: 032                  100% сеть отнесла к классу 032                  - ВЕРНО
# Класс: 033                  100% сеть отнесла к классу 033                  - ВЕРНО
# Класс: 034                  100% сеть отнесла к классу 034                  - ВЕРНО
# Класс: 035                  100% сеть отнесла к классу 035                  - ВЕРНО
# Класс: 036                  100% сеть отнесла к классу 036                  - ВЕРНО
# Класс: 037                  100% сеть отнесла к классу 037                  - ВЕРНО
# Класс: 038                  100% сеть отнесла к классу 038                  - ВЕРНО
# Класс: 039                  100% сеть отнесла к классу 039                  - ВЕРНО
# Класс: 040                  100% сеть отнесла к классу 040                  - ВЕРНО
# Класс: 041                  100% сеть отнесла к классу 041                  - ВЕРНО
# Класс: 042                  100% сеть отнесла к классу 042                  - ВЕРНО
# Класс: 043                  100% сеть отнесла к классу 043                  - ВЕРНО
# Класс: 044                  100% сеть отнесла к классу 044                  - ВЕРНО
# Класс: 045                  100% сеть отнесла к классу 008                  - НЕВЕРНО
# Класс: 046                  100% сеть отнесла к классу 046                  - ВЕРНО
# Класс: 047                  100% сеть отнесла к классу 047                  - ВЕРНО
# Класс: 048                  100% сеть отнесла к классу 048                  - ВЕРНО
# Класс: 049                  100% сеть отнесла к классу 049                  - ВЕРНО
# Класс: 050                  100% сеть отнесла к классу 050                  - ВЕРНО
# Класс: 051                  100% сеть отнесла к классу 051                  - ВЕРНО
# Класс: 052                  100% сеть отнесла к классу 052                  - ВЕРНО
# Класс: 053                  100% сеть отнесла к классу 053                  - ВЕРНО
# Класс: 054                  100% сеть отнесла к классу 054                  - ВЕРНО
# Класс: 055                  100% сеть отнесла к классу 055                  - ВЕРНО
# Класс: 056                  100% сеть отнесла к классу 056                  - ВЕРНО
# Класс: 057                  100% сеть отнесла к классу 057                  - ВЕРНО
# Класс: 058                  100% сеть отнесла к классу 058                  - ВЕРНО
# Класс: 059                  100% сеть отнесла к классу 059                  - ВЕРНО
# Класс: 060                  100% сеть отнесла к классу 060                  - ВЕРНО
# Класс: 061                  100% сеть отнесла к классу 061                  - ВЕРНО
# Класс: 062                  100% сеть отнесла к классу 062                  - ВЕРНО
# Класс: 063                  100% сеть отнесла к классу 063                  - ВЕРНО
# Класс: 064                  100% сеть отнесла к классу 064                  - ВЕРНО
#
# Средняя точность распознавания:  97%
