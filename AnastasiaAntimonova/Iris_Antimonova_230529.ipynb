# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/main/AnastasiaAntimonova/Iris_Antimonova_230529.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Инструменты для построения графиков
import matplotlib.pyplot as plt 

# Инструменты для работы с изображениями
from tensorflow.keras.preprocessing import image 

from tensorflow.keras.models import Sequential #Сеть прямого распространения

#Базовые слои для свёрточных сетей
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator # работа с изображениями
from tensorflow.keras.optimizers import Adam, Adadelta # оптимизаторы
from tensorflow.keras import utils #Используем для to_categoricall
from tensorflow.keras.preprocessing import image #Для отрисовки изображений

# Инструменты для работы с массивами
import numpy as np 

# Системные инструменты
import time, random, gdown, os

# Дополнительные инструменты для работы с изображениями
from PIL import Image 

# Дополнительные инструменты визуализации
import seaborn as sns
sns.set_style('darkgrid')


# Отрисовка графиков
import matplotlib.pyplot as plt

# Рисование графиков в ячейках Colab
# %matplotlib inline

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=16wKj93ooL-mYryWHIDEr49FJAfAFwnRO', None, quiet=True)
# Out:
# 'Iris.zip'

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_DIR} {TEST_DIR}

# Разархивация датасета
#!unzip -qo "Iris.zip" -d {TRAIN_DIR}
# !unzip -q "Iris.zip" -d /content/Iris #Указываем путь к базе в Google Drive

# %%
# Глобальные параметры

TRAIN_DIR          = '/content/Iris'        # Папка для обучающего набора данных
TEST_DIR           = '/content/iris_test'   # Папка для тестового набора данных

TEST_SPLIT          = 0.25                  # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.25                  # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 192 # 768                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144 #576                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %%
# Создаем папки для каждого класса и перемещаем файлы в соответствующую папку
for i in range(1, 65):
                        class_folder = os.path.join(TRAIN_DIR, f'{i:03}')
                        if not os.path.exists(class_folder):
                            os.makedirs(class_folder)
                        for file_name in ['%03dL_%d.png' % (i, j) for j in range(1, 4)] + ['%03dR_%d.png' % (i, j) for j in range(1, 4)]:
                            file_path = os.path.join(TRAIN_DIR, file_name)
                            if os.path.exists(file_path):
                                os.replace(file_path, os.path.join(class_folder, file_name))

# %%
#просмотр списка папок
os.listdir(TRAIN_DIR)
# Out:
# ['064',
#  '038',
#  '062',
#  '028',
#  '029',
#  '013',
#  '007',
#  '046',
#  '017',
#  '022',
#  '063',
#  '033',
#  '020',
#  '032',
#  '008',
#  '061',
#  '016',
#  '021',
#  '025',
#  '045',
#  '006',
#  '011',
#  '053',
#  '047',
#  '054',
#  '035',
#  '034',
#  '012',
#  '014',
#  '051',
#  '026',
#  '058',
#  '040',
#  '055',
#  '027',
#  '031',
#  '039',
#  '005',
#  '044',
#  '048',
#  '049',
#  '001',
#  '019',
#  '004',
#  '057',
#  '041',
#  '024',
#  '010',
#  '009',
#  '060',
#  '037',
#  '056',
#  '042',
#  '059',
#  '052',
#  '050',
#  '030',
#  '023',
#  '003',
#  '018',
#  '036',
#  '015',
#  '002',
#  '043']

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_DIR))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 64, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    class_path = f'{TRAIN_DIR}/{CLASS_LIST[i]}' 
    # Выбор случайного фото из i-го класса
    img_path = class_path +'/'+random.choice(os.listdir(class_path)) 
    # Отображение фотографии (подробнее будет объяснено далее)
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))  
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
# Создание директории тестовых данных
os.mkdir(TEST_DIR)                                        
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_DIR}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_DIR}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# #Аугментация данных

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 4                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.05                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.05                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.05                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.7, 1.3)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение запрещено

BATCH_SIZE          = 8                     # Размер батча
EPOCHS              = 200                   # Эпох обучения
OPTIMIZER           = Adam(0.001)           # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную 

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, 
    subset='training'
)

# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 256 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 144, 192, 3), (8, 64), батчей: 32
# Формы данных   проверочной выборки: (8, 144, 192, 3), (8, 64), батчей: 8
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 6),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])  
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(8), columns = 4)

# %%
# Функция компиляции и обучения модели нейронной сети

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    # Вывод сводки
    model.summary()

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model, 
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

# %%
# Создание последовательной модели
model = Sequential()

# Первый сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model.add(BatchNormalization())

# Второй сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Четвертый сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.2))

# Пятый сверточный слой
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

# Слой преобразования многомерных данных в одномерные 
model.add(Flatten())

# Промежуточный полносвязный слой
model.add(Dense(256, activation='relu'))


# Выходной полносвязный слой с количеством нейронов по количесту классов
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         )
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 144, 192, 64)      1792
#
#  batch_normalization_9 (Batc  (None, 144, 192, 64)     256
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (None, 144, 192, 64)      36928
#
#  max_pooling2d_6 (MaxPooling  (None, 48, 64, 64)       0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 48, 64, 64)        36928
#
#  batch_normalization_10 (Bat  (None, 48, 64, 64)       256
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 48, 64, 64)        0
#
#  conv2d_18 (Conv2D)          (None, 48, 64, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 21, 64)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 16, 21, 64)        0
#
#  conv2d_19 (Conv2D)          (None, 16, 21, 128)       73856
#
#  batch_normalization_11 (Bat  (None, 16, 21, 128)      512
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 43008)             0
#
#  dense_4 (Dense)             (None, 256)               11010304
#
#  dense_5 (Dense)             (None, 64)                16448
#
# =================================================================
# Total params: 11,214,208
# Trainable params: 11,213,696
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/200
# 32/32 [==============================] - 11s 226ms/step - loss: 7.3993 - accuracy: 0.0195 - val_loss: 4.1903 - val_accuracy: 0.0156
# Epoch 2/200
# 32/32 [==============================] - 6s 181ms/step - loss: 4.2803 - accuracy: 0.0312 - val_loss: 4.2011 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 32/32 [==============================] - 7s 223ms/step - loss: 4.1536 - accuracy: 0.0352 - val_loss: 4.3324 - val_accuracy: 0.0156
# Epoch 4/200
# 32/32 [==============================] - 6s 181ms/step - loss: 4.1857 - accuracy: 0.0195 - val_loss: 4.1850 - val_accuracy: 0.0156
# Epoch 5/200
# 32/32 [==============================] - 7s 228ms/step - loss: 4.1386 - accuracy: 0.0234 - val_loss: 4.6432 - val_accuracy: 0.0312
# Epoch 6/200
# 32/32 [==============================] - 10s 308ms/step - loss: 4.1349 - accuracy: 0.0469 - val_loss: 4.4902 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 32/32 [==============================] - 7s 223ms/step - loss: 4.1601 - accuracy: 0.0508 - val_loss: 4.1879 - val_accuracy: 0.0156
# Epoch 8/200
# 32/32 [==============================] - 9s 279ms/step - loss: 4.0137 - accuracy: 0.0391 - val_loss: 4.2999 - val_accuracy: 0.0156
# Epoch 9/200
# 32/32 [==============================] - 7s 225ms/step - loss: 4.0154 - accuracy: 0.0625 - val_loss: 4.2073 - val_accuracy: 0.0156
# Epoch 10/200
# 32/32 [==============================] - 6s 183ms/step - loss: 3.8230 - accuracy: 0.0391 - val_loss: 4.4287 - val_accuracy: 0.0156
# Epoch 11/200
# 32/32 [==============================] - 7s 218ms/step - loss: 3.6893 - accuracy: 0.0352 - val_loss: 3.9683 - val_accuracy: 0.0625
# Epoch 12/200
# 32/32 [==============================] - 6s 181ms/step - loss: 3.6170 - accuracy: 0.0547 - val_loss: 4.7978 - val_accuracy: 0.0469
# Epoch 13/200
# 32/32 [==============================] - 8s 250ms/step - loss: 3.5037 - accuracy: 0.0586 - val_loss: 3.9812 - val_accuracy: 0.0625
# Epoch 14/200
# 32/32 [==============================] - 6s 181ms/step - loss: 3.4336 - accuracy: 0.0664 - val_loss: 3.4090 - val_accuracy: 0.0781
# Epoch 15/200
# 32/32 [==============================] - 7s 218ms/step - loss: 3.3676 - accuracy: 0.0859 - val_loss: 3.3290 - val_accuracy: 0.0938
# Epoch 16/200
# 32/32 [==============================] - 6s 180ms/step - loss: 3.1440 - accuracy: 0.1484 - val_loss: 3.4530 - val_accuracy: 0.1562
# Epoch 17/200
# 32/32 [==============================] - 7s 223ms/step - loss: 3.1382 - accuracy: 0.1328 - val_loss: 3.2765 - val_accuracy: 0.1562
# Epoch 18/200
# 32/32 [==============================] - 6s 181ms/step - loss: 3.0028 - accuracy: 0.1875 - val_loss: 4.4365 - val_accuracy: 0.1094
# Epoch 19/200
# 32/32 [==============================] - 7s 220ms/step - loss: 2.8466 - accuracy: 0.1719 - val_loss: 10.2943 - val_accuracy: 0.0469
# Epoch 20/200
# 32/32 [==============================] - 6s 182ms/step - loss: 2.6369 - accuracy: 0.2109 - val_loss: 2.4001 - val_accuracy: 0.3281
# Epoch 21/200
# 32/32 [==============================] - 6s 183ms/step - loss: 2.5201 - accuracy: 0.2500 - val_loss: 2.8825 - val_accuracy: 0.2188
# Epoch 22/200
# 32/32 [==============================] - 7s 231ms/step - loss: 2.3143 - accuracy: 0.2969 - val_loss: 3.2623 - val_accuracy: 0.1719
# Epoch 23/200
# 32/32 [==============================] - 7s 204ms/step - loss: 2.0687 - accuracy: 0.3789 - val_loss: 2.6348 - val_accuracy: 0.3281
# Epoch 24/200
# 32/32 [==============================] - 7s 225ms/step - loss: 1.8277 - accuracy: 0.4062 - val_loss: 3.4382 - val_accuracy: 0.2656
# Epoch 25/200
# 32/32 [==============================] - 6s 181ms/step - loss: 1.9146 - accuracy: 0.4062 - val_loss: 3.1255 - val_accuracy: 0.2500
# Epoch 26/200
# 32/32 [==============================] - 7s 218ms/step - loss: 1.7534 - accuracy: 0.4258 - val_loss: 3.9151 - val_accuracy: 0.2812
# Epoch 27/200
# 32/32 [==============================] - 6s 182ms/step - loss: 1.4686 - accuracy: 0.5469 - val_loss: 18.7251 - val_accuracy: 0.1406
# Epoch 28/200
# 32/32 [==============================] - 6s 183ms/step - loss: 1.4296 - accuracy: 0.5508 - val_loss: 5.7067 - val_accuracy: 0.1406
# Epoch 29/200
# 32/32 [==============================] - 7s 208ms/step - loss: 1.1720 - accuracy: 0.6289 - val_loss: 3.3934 - val_accuracy: 0.2969
# Epoch 30/200
# 32/32 [==============================] - 6s 180ms/step - loss: 1.0466 - accuracy: 0.6875 - val_loss: 2.3383 - val_accuracy: 0.3906
# Epoch 31/200
# 32/32 [==============================] - 7s 219ms/step - loss: 0.9496 - accuracy: 0.7031 - val_loss: 2.8208 - val_accuracy: 0.4219
# Epoch 32/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.9074 - accuracy: 0.6641 - val_loss: 2.0465 - val_accuracy: 0.3906
# Epoch 33/200
# 32/32 [==============================] - 7s 222ms/step - loss: 0.7836 - accuracy: 0.7422 - val_loss: 2.2274 - val_accuracy: 0.5156
# Epoch 34/200
# 32/32 [==============================] - 6s 189ms/step - loss: 1.0809 - accuracy: 0.6875 - val_loss: 2.5490 - val_accuracy: 0.5469
# Epoch 35/200
# 32/32 [==============================] - 7s 213ms/step - loss: 0.9804 - accuracy: 0.7031 - val_loss: 4.5150 - val_accuracy: 0.2500
# Epoch 36/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.9245 - accuracy: 0.7344 - val_loss: 11.9867 - val_accuracy: 0.0938
# Epoch 37/200
# 32/32 [==============================] - 7s 224ms/step - loss: 0.9797 - accuracy: 0.7227 - val_loss: 6.2132 - val_accuracy: 0.2188
# Epoch 38/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.7302 - accuracy: 0.7734 - val_loss: 2.2411 - val_accuracy: 0.5000
# Epoch 39/200
# 32/32 [==============================] - 7s 220ms/step - loss: 0.5649 - accuracy: 0.8281 - val_loss: 3.0200 - val_accuracy: 0.4531
# Epoch 40/200
# 32/32 [==============================] - 6s 194ms/step - loss: 0.6999 - accuracy: 0.7578 - val_loss: 2.0824 - val_accuracy: 0.5625
# Epoch 41/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.6030 - accuracy: 0.8164 - val_loss: 1.8863 - val_accuracy: 0.5938
# Epoch 42/200
# 32/32 [==============================] - 7s 222ms/step - loss: 0.4700 - accuracy: 0.8281 - val_loss: 1.3160 - val_accuracy: 0.6719
# Epoch 43/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.5457 - accuracy: 0.7852 - val_loss: 1.5479 - val_accuracy: 0.6250
# Epoch 44/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.3671 - accuracy: 0.8945 - val_loss: 1.9471 - val_accuracy: 0.6094
# Epoch 45/200
# 32/32 [==============================] - 8s 239ms/step - loss: 0.3280 - accuracy: 0.8984 - val_loss: 1.5552 - val_accuracy: 0.5781
# Epoch 46/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.4455 - accuracy: 0.8516 - val_loss: 1.3545 - val_accuracy: 0.7031
# Epoch 47/200
# 32/32 [==============================] - 8s 239ms/step - loss: 0.4459 - accuracy: 0.8867 - val_loss: 1.3081 - val_accuracy: 0.7031
# Epoch 48/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.4324 - accuracy: 0.8633 - val_loss: 2.2966 - val_accuracy: 0.5312
# Epoch 49/200
# 32/32 [==============================] - 8s 242ms/step - loss: 0.2524 - accuracy: 0.9258 - val_loss: 1.3011 - val_accuracy: 0.7188
# Epoch 50/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.2497 - accuracy: 0.9180 - val_loss: 2.5141 - val_accuracy: 0.5625
# Epoch 51/200
# 32/32 [==============================] - 8s 243ms/step - loss: 0.2561 - accuracy: 0.8945 - val_loss: 1.6281 - val_accuracy: 0.6719
# Epoch 52/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.3346 - accuracy: 0.9102 - val_loss: 1.6094 - val_accuracy: 0.5938
# Epoch 53/200
# 32/32 [==============================] - 7s 214ms/step - loss: 0.1685 - accuracy: 0.9414 - val_loss: 1.3309 - val_accuracy: 0.6406
# Epoch 54/200
# 32/32 [==============================] - 6s 186ms/step - loss: 0.2272 - accuracy: 0.9219 - val_loss: 0.9794 - val_accuracy: 0.7656
# Epoch 55/200
# 32/32 [==============================] - 7s 234ms/step - loss: 0.3494 - accuracy: 0.8828 - val_loss: 2.3133 - val_accuracy: 0.5312
# Epoch 56/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.3457 - accuracy: 0.8984 - val_loss: 1.9563 - val_accuracy: 0.5625
# Epoch 57/200
# 32/32 [==============================] - 8s 238ms/step - loss: 0.3359 - accuracy: 0.8867 - val_loss: 0.9951 - val_accuracy: 0.7656
# Epoch 58/200
# 32/32 [==============================] - 6s 184ms/step - loss: 0.2175 - accuracy: 0.9102 - val_loss: 2.0945 - val_accuracy: 0.5938
# Epoch 59/200
# 32/32 [==============================] - 7s 213ms/step - loss: 0.2347 - accuracy: 0.9336 - val_loss: 2.9181 - val_accuracy: 0.4375
# Epoch 60/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1428 - accuracy: 0.9492 - val_loss: 1.4962 - val_accuracy: 0.7031
# Epoch 61/200
# 32/32 [==============================] - 7s 219ms/step - loss: 0.2389 - accuracy: 0.9258 - val_loss: 1.1063 - val_accuracy: 0.7656
# Epoch 62/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1764 - accuracy: 0.9414 - val_loss: 0.9696 - val_accuracy: 0.7188
# Epoch 63/200
# 32/32 [==============================] - 7s 223ms/step - loss: 0.1472 - accuracy: 0.9531 - val_loss: 1.1426 - val_accuracy: 0.6719
# Epoch 64/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1581 - accuracy: 0.9648 - val_loss: 1.6987 - val_accuracy: 0.6250
# Epoch 65/200
# 32/32 [==============================] - 7s 220ms/step - loss: 0.2164 - accuracy: 0.9219 - val_loss: 1.7261 - val_accuracy: 0.6406
# Epoch 66/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.1876 - accuracy: 0.9453 - val_loss: 1.3856 - val_accuracy: 0.7188
# Epoch 67/200
# 32/32 [==============================] - 7s 222ms/step - loss: 0.2499 - accuracy: 0.9102 - val_loss: 1.3130 - val_accuracy: 0.7656
# Epoch 68/200
# 32/32 [==============================] - 6s 183ms/step - loss: 0.1654 - accuracy: 0.9297 - val_loss: 1.8480 - val_accuracy: 0.6719
# Epoch 69/200
# 32/32 [==============================] - 7s 227ms/step - loss: 0.1922 - accuracy: 0.9414 - val_loss: 1.1489 - val_accuracy: 0.7188
# Epoch 70/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.2434 - accuracy: 0.9180 - val_loss: 1.9084 - val_accuracy: 0.6250
# Epoch 71/200
# 32/32 [==============================] - 7s 223ms/step - loss: 0.2249 - accuracy: 0.9297 - val_loss: 2.2615 - val_accuracy: 0.6562
# Epoch 72/200
# 32/32 [==============================] - 6s 188ms/step - loss: 0.2849 - accuracy: 0.9180 - val_loss: 2.6694 - val_accuracy: 0.5938
# Epoch 73/200
# 32/32 [==============================] - 6s 183ms/step - loss: 0.1824 - accuracy: 0.9492 - val_loss: 1.2719 - val_accuracy: 0.7031
# Epoch 74/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1775 - accuracy: 0.9336 - val_loss: 3.4904 - val_accuracy: 0.5625
# Epoch 75/200
# 32/32 [==============================] - 7s 205ms/step - loss: 0.1450 - accuracy: 0.9492 - val_loss: 1.4379 - val_accuracy: 0.6562
# Epoch 76/200
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1193 - accuracy: 0.9688 - val_loss: 1.6466 - val_accuracy: 0.6562
# Epoch 77/200
# 32/32 [==============================] - 6s 187ms/step - loss: 0.1526 - accuracy: 0.9492 - val_loss: 1.0445 - val_accuracy: 0.7500
# Epoch 78/200
# 32/32 [==============================] - 7s 223ms/step - loss: 0.0523 - accuracy: 0.9883 - val_loss: 1.6039 - val_accuracy: 0.6094
# Epoch 79/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.0686 - accuracy: 0.9766 - val_loss: 0.9721 - val_accuracy: 0.8125
# Epoch 80/200
# 32/32 [==============================] - 7s 220ms/step - loss: 0.0977 - accuracy: 0.9688 - val_loss: 1.7217 - val_accuracy: 0.6562
# Epoch 81/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0815 - accuracy: 0.9727 - val_loss: 1.0144 - val_accuracy: 0.8125
# Epoch 82/200
# 32/32 [==============================] - 8s 247ms/step - loss: 0.0762 - accuracy: 0.9805 - val_loss: 1.3227 - val_accuracy: 0.6719
# Epoch 83/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1349 - accuracy: 0.9414 - val_loss: 1.1794 - val_accuracy: 0.7344
# Epoch 84/200
# 32/32 [==============================] - 7s 217ms/step - loss: 0.1400 - accuracy: 0.9570 - val_loss: 1.1496 - val_accuracy: 0.7656
# Epoch 85/200
# 32/32 [==============================] - 6s 178ms/step - loss: 0.0870 - accuracy: 0.9727 - val_loss: 1.5134 - val_accuracy: 0.7188
# Epoch 86/200
# 32/32 [==============================] - 7s 221ms/step - loss: 0.1640 - accuracy: 0.9258 - val_loss: 2.5655 - val_accuracy: 0.6250
# Epoch 87/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.2046 - accuracy: 0.9492 - val_loss: 1.4939 - val_accuracy: 0.7031
# Epoch 88/200
# 32/32 [==============================] - 7s 221ms/step - loss: 0.1641 - accuracy: 0.9414 - val_loss: 1.6268 - val_accuracy: 0.7656
# Epoch 89/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.2150 - accuracy: 0.9258 - val_loss: 3.3482 - val_accuracy: 0.5625
# Epoch 90/200
# 32/32 [==============================] - 7s 221ms/step - loss: 0.3623 - accuracy: 0.9062 - val_loss: 3.0123 - val_accuracy: 0.5781
# Epoch 91/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.3174 - accuracy: 0.9102 - val_loss: 15.5710 - val_accuracy: 0.1875
# Epoch 92/200
# 32/32 [==============================] - 7s 220ms/step - loss: 0.4071 - accuracy: 0.8711 - val_loss: 2.5091 - val_accuracy: 0.5625
# Epoch 93/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.2726 - accuracy: 0.9180 - val_loss: 7.1772 - val_accuracy: 0.2969
# Epoch 94/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.3424 - accuracy: 0.8828 - val_loss: 2.1635 - val_accuracy: 0.7031
# Epoch 95/200
# 32/32 [==============================] - 6s 196ms/step - loss: 0.3348 - accuracy: 0.9062 - val_loss: 5.9882 - val_accuracy: 0.4219
# Epoch 96/200
# 32/32 [==============================] - 7s 229ms/step - loss: 0.1430 - accuracy: 0.9531 - val_loss: 1.8525 - val_accuracy: 0.6875
# Epoch 97/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1072 - accuracy: 0.9727 - val_loss: 1.9628 - val_accuracy: 0.6875
# Epoch 98/200
# 32/32 [==============================] - 7s 222ms/step - loss: 0.1707 - accuracy: 0.9453 - val_loss: 1.5517 - val_accuracy: 0.7188
# Epoch 99/200
# 32/32 [==============================] - 6s 178ms/step - loss: 0.1142 - accuracy: 0.9688 - val_loss: 2.9487 - val_accuracy: 0.6250
# Epoch 100/200
# 32/32 [==============================] - 7s 217ms/step - loss: 0.1374 - accuracy: 0.9570 - val_loss: 2.0474 - val_accuracy: 0.6406
# Epoch 101/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1321 - accuracy: 0.9453 - val_loss: 2.2655 - val_accuracy: 0.7500
# Epoch 102/200
# 32/32 [==============================] - 7s 214ms/step - loss: 0.1487 - accuracy: 0.9453 - val_loss: 1.2219 - val_accuracy: 0.8438
# Epoch 103/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1716 - accuracy: 0.9414 - val_loss: 1.6102 - val_accuracy: 0.7031
# Epoch 104/200
# 32/32 [==============================] - 7s 216ms/step - loss: 0.0739 - accuracy: 0.9727 - val_loss: 1.7196 - val_accuracy: 0.7344
# Epoch 105/200
# 32/32 [==============================] - 6s 177ms/step - loss: 0.0615 - accuracy: 0.9766 - val_loss: 1.9077 - val_accuracy: 0.7344
# Epoch 106/200
# 32/32 [==============================] - 7s 217ms/step - loss: 0.1163 - accuracy: 0.9609 - val_loss: 2.8159 - val_accuracy: 0.5469
# Epoch 107/200
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0497 - accuracy: 0.9922 - val_loss: 1.4688 - val_accuracy: 0.7969
# Epoch 108/200
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1172 - accuracy: 0.9688 - val_loss: 1.5551 - val_accuracy: 0.6875
# Epoch 109/200
# 32/32 [==============================] - 7s 210ms/step - loss: 0.0669 - accuracy: 0.9844 - val_loss: 1.7149 - val_accuracy: 0.7500
# Epoch 110/200
# 32/32 [==============================] - 6s 178ms/step - loss: 0.0414 - accuracy: 0.9844 - val_loss: 1.1891 - val_accuracy: 0.8125
# Epoch 111/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1004 - accuracy: 0.9688 - val_loss: 2.4702 - val_accuracy: 0.6875
# Epoch 112/200
# 32/32 [==============================] - 7s 208ms/step - loss: 0.0632 - accuracy: 0.9766 - val_loss: 4.6007 - val_accuracy: 0.4688
# Epoch 113/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.0795 - accuracy: 0.9727 - val_loss: 1.5679 - val_accuracy: 0.7344
# Epoch 114/200
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0554 - accuracy: 0.9766 - val_loss: 2.3737 - val_accuracy: 0.6875
# Epoch 115/200
# 32/32 [==============================] - 6s 177ms/step - loss: 0.0817 - accuracy: 0.9648 - val_loss: 1.2115 - val_accuracy: 0.7969
# Epoch 116/200
# 32/32 [==============================] - 7s 208ms/step - loss: 0.1127 - accuracy: 0.9570 - val_loss: 1.8494 - val_accuracy: 0.8125
# Epoch 117/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1761 - accuracy: 0.9609 - val_loss: 0.7402 - val_accuracy: 0.8281
# Epoch 118/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.0986 - accuracy: 0.9688 - val_loss: 4.0689 - val_accuracy: 0.4375
# Epoch 119/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0551 - accuracy: 0.9844 - val_loss: 1.8672 - val_accuracy: 0.6250
# Epoch 120/200
# 32/32 [==============================] - 6s 184ms/step - loss: 0.2868 - accuracy: 0.9570 - val_loss: 1.7953 - val_accuracy: 0.7969
# Epoch 121/200
# 32/32 [==============================] - 6s 199ms/step - loss: 0.1909 - accuracy: 0.9414 - val_loss: 1.6907 - val_accuracy: 0.7031
# Epoch 122/200
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1360 - accuracy: 0.9453 - val_loss: 2.9446 - val_accuracy: 0.5938
# Epoch 123/200
# 32/32 [==============================] - 7s 210ms/step - loss: 0.1427 - accuracy: 0.9648 - val_loss: 2.4004 - val_accuracy: 0.6719
# Epoch 124/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1355 - accuracy: 0.9609 - val_loss: 1.5486 - val_accuracy: 0.7344
# Epoch 125/200
# 32/32 [==============================] - 7s 210ms/step - loss: 0.0862 - accuracy: 0.9727 - val_loss: 2.8625 - val_accuracy: 0.7031
# Epoch 126/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1377 - accuracy: 0.9570 - val_loss: 1.1768 - val_accuracy: 0.7656
# Epoch 127/200
# 32/32 [==============================] - 7s 213ms/step - loss: 0.0685 - accuracy: 0.9648 - val_loss: 2.5302 - val_accuracy: 0.6094
# Epoch 128/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1712 - accuracy: 0.9648 - val_loss: 2.6117 - val_accuracy: 0.7031
# Epoch 129/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.3309 - accuracy: 0.9219 - val_loss: 5.2911 - val_accuracy: 0.4688
# Epoch 130/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.4103 - accuracy: 0.9023 - val_loss: 2.0218 - val_accuracy: 0.7188
# Epoch 131/200
# 32/32 [==============================] - 7s 212ms/step - loss: 0.3432 - accuracy: 0.9062 - val_loss: 2.3744 - val_accuracy: 0.6406
# Epoch 132/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1687 - accuracy: 0.9492 - val_loss: 2.8525 - val_accuracy: 0.6250
# Epoch 133/200
# 32/32 [==============================] - 7s 214ms/step - loss: 0.1106 - accuracy: 0.9727 - val_loss: 3.2558 - val_accuracy: 0.5625
# Epoch 134/200
# 32/32 [==============================] - 6s 184ms/step - loss: 0.1269 - accuracy: 0.9570 - val_loss: 2.7915 - val_accuracy: 0.6406
# Epoch 135/200
# 32/32 [==============================] - 7s 210ms/step - loss: 0.2286 - accuracy: 0.9219 - val_loss: 1.7992 - val_accuracy: 0.6562
# Epoch 136/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1712 - accuracy: 0.9453 - val_loss: 2.1145 - val_accuracy: 0.7188
# Epoch 137/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.0869 - accuracy: 0.9648 - val_loss: 1.6611 - val_accuracy: 0.7031
# Epoch 138/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.0932 - accuracy: 0.9648 - val_loss: 2.2113 - val_accuracy: 0.6562
# Epoch 139/200
# 32/32 [==============================] - 6s 191ms/step - loss: 0.1130 - accuracy: 0.9609 - val_loss: 2.1131 - val_accuracy: 0.7500
# Epoch 140/200
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0307 - accuracy: 0.9883 - val_loss: 2.9389 - val_accuracy: 0.6094
# Epoch 141/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1302 - accuracy: 0.9688 - val_loss: 1.6370 - val_accuracy: 0.6875
# Epoch 142/200
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1173 - accuracy: 0.9648 - val_loss: 1.8027 - val_accuracy: 0.7031
# Epoch 143/200
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0988 - accuracy: 0.9492 - val_loss: 1.5666 - val_accuracy: 0.7188
# Epoch 144/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.1690 - accuracy: 0.9531 - val_loss: 3.1649 - val_accuracy: 0.5469
# Epoch 145/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1879 - accuracy: 0.9570 - val_loss: 1.9902 - val_accuracy: 0.6562
# Epoch 146/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1174 - accuracy: 0.9609 - val_loss: 2.1311 - val_accuracy: 0.6875
# Epoch 147/200
# 32/32 [==============================] - 7s 229ms/step - loss: 0.1357 - accuracy: 0.9609 - val_loss: 1.4503 - val_accuracy: 0.6875
# Epoch 148/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.1548 - accuracy: 0.9492 - val_loss: 2.3020 - val_accuracy: 0.6719
# Epoch 149/200
# 32/32 [==============================] - 7s 208ms/step - loss: 0.1330 - accuracy: 0.9492 - val_loss: 2.9221 - val_accuracy: 0.6250
# Epoch 150/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1965 - accuracy: 0.9414 - val_loss: 6.4659 - val_accuracy: 0.4375
# Epoch 151/200
# 32/32 [==============================] - 7s 209ms/step - loss: 0.2660 - accuracy: 0.9219 - val_loss: 2.9474 - val_accuracy: 0.6719
# Epoch 152/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.3084 - accuracy: 0.9141 - val_loss: 3.6637 - val_accuracy: 0.6719
# Epoch 153/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1273 - accuracy: 0.9570 - val_loss: 2.4775 - val_accuracy: 0.7031
# Epoch 154/200
# 32/32 [==============================] - 7s 213ms/step - loss: 0.0506 - accuracy: 0.9883 - val_loss: 2.4669 - val_accuracy: 0.7344
# Epoch 155/200
# 32/32 [==============================] - 6s 183ms/step - loss: 0.1013 - accuracy: 0.9688 - val_loss: 1.4786 - val_accuracy: 0.7656
# Epoch 156/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0613 - accuracy: 0.9805 - val_loss: 1.4367 - val_accuracy: 0.7344
# Epoch 157/200
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0351 - accuracy: 0.9883 - val_loss: 2.1124 - val_accuracy: 0.7344
# Epoch 158/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.0519 - accuracy: 0.9766 - val_loss: 2.5139 - val_accuracy: 0.6562
# Epoch 159/200
# 32/32 [==============================] - 7s 210ms/step - loss: 0.1765 - accuracy: 0.9688 - val_loss: 2.0211 - val_accuracy: 0.6250
# Epoch 160/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1080 - accuracy: 0.9648 - val_loss: 2.4423 - val_accuracy: 0.7344
# Epoch 161/200
# 32/32 [==============================] - 7s 210ms/step - loss: 0.1057 - accuracy: 0.9609 - val_loss: 1.5500 - val_accuracy: 0.7812
# Epoch 162/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.0602 - accuracy: 0.9844 - val_loss: 1.4345 - val_accuracy: 0.6562
# Epoch 163/200
# 32/32 [==============================] - 8s 236ms/step - loss: 0.0691 - accuracy: 0.9805 - val_loss: 3.0793 - val_accuracy: 0.6719
# Epoch 164/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0455 - accuracy: 0.9883 - val_loss: 1.8244 - val_accuracy: 0.7344
# Epoch 165/200
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1041 - accuracy: 0.9805 - val_loss: 2.8031 - val_accuracy: 0.6562
# Epoch 166/200
# 32/32 [==============================] - 7s 214ms/step - loss: 0.0355 - accuracy: 0.9922 - val_loss: 2.0389 - val_accuracy: 0.7188
# Epoch 167/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0566 - accuracy: 0.9766 - val_loss: 4.3645 - val_accuracy: 0.5781
# Epoch 168/200
# 32/32 [==============================] - 7s 208ms/step - loss: 0.0677 - accuracy: 0.9805 - val_loss: 5.1195 - val_accuracy: 0.5312
# Epoch 169/200
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0592 - accuracy: 0.9727 - val_loss: 1.7955 - val_accuracy: 0.7812
# Epoch 170/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1516 - accuracy: 0.9766 - val_loss: 1.1216 - val_accuracy: 0.8438
# Epoch 171/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1213 - accuracy: 0.9727 - val_loss: 2.8442 - val_accuracy: 0.6406
# Epoch 172/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0804 - accuracy: 0.9727 - val_loss: 2.5711 - val_accuracy: 0.7031
# Epoch 173/200
# 32/32 [==============================] - 7s 212ms/step - loss: 0.0798 - accuracy: 0.9766 - val_loss: 2.5008 - val_accuracy: 0.7500
# Epoch 174/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.2065 - accuracy: 0.9492 - val_loss: 5.4010 - val_accuracy: 0.5156
# Epoch 175/200
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1627 - accuracy: 0.9492 - val_loss: 2.9163 - val_accuracy: 0.6562
# Epoch 176/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.1452 - accuracy: 0.9531 - val_loss: 2.6583 - val_accuracy: 0.6875
# Epoch 177/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1608 - accuracy: 0.9492 - val_loss: 3.8088 - val_accuracy: 0.6719
# Epoch 178/200
# 32/32 [==============================] - 6s 183ms/step - loss: 0.1508 - accuracy: 0.9648 - val_loss: 3.8070 - val_accuracy: 0.5938
# Epoch 179/200
# 32/32 [==============================] - 8s 240ms/step - loss: 0.1361 - accuracy: 0.9648 - val_loss: 2.5956 - val_accuracy: 0.7188
# Epoch 180/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.2101 - accuracy: 0.9219 - val_loss: 2.0982 - val_accuracy: 0.8125
# Epoch 181/200
# 32/32 [==============================] - 7s 213ms/step - loss: 0.0908 - accuracy: 0.9688 - val_loss: 1.8825 - val_accuracy: 0.6875
# Epoch 182/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.2446 - accuracy: 0.9375 - val_loss: 3.5498 - val_accuracy: 0.5625
# Epoch 183/200
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1798 - accuracy: 0.9531 - val_loss: 4.0063 - val_accuracy: 0.5625
# Epoch 184/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1102 - accuracy: 0.9609 - val_loss: 3.0047 - val_accuracy: 0.5781
# Epoch 185/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1671 - accuracy: 0.9648 - val_loss: 1.3300 - val_accuracy: 0.7812
# Epoch 186/200
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1464 - accuracy: 0.9727 - val_loss: 1.8523 - val_accuracy: 0.7656
# Epoch 187/200
# 32/32 [==============================] - 7s 217ms/step - loss: 0.1043 - accuracy: 0.9727 - val_loss: 2.3737 - val_accuracy: 0.7188
# Epoch 188/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.1927 - accuracy: 0.9414 - val_loss: 1.7510 - val_accuracy: 0.7188
# Epoch 189/200
# 32/32 [==============================] - 6s 184ms/step - loss: 0.1924 - accuracy: 0.9531 - val_loss: 3.8917 - val_accuracy: 0.5469
# Epoch 190/200
# 32/32 [==============================] - 6s 190ms/step - loss: 0.1266 - accuracy: 0.9570 - val_loss: 2.3794 - val_accuracy: 0.7031
# Epoch 191/200
# 32/32 [==============================] - 7s 205ms/step - loss: 0.0618 - accuracy: 0.9844 - val_loss: 2.4313 - val_accuracy: 0.6562
# Epoch 192/200
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0463 - accuracy: 0.9844 - val_loss: 3.8610 - val_accuracy: 0.6250
# Epoch 193/200
# 32/32 [==============================] - 7s 232ms/step - loss: 0.1300 - accuracy: 0.9609 - val_loss: 2.9117 - val_accuracy: 0.6719
# Epoch 194/200
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0695 - accuracy: 0.9766 - val_loss: 1.8790 - val_accuracy: 0.7812
# Epoch 195/200
# 32/32 [==============================] - 7s 211ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 1.7511 - val_accuracy: 0.7188
# Epoch 196/200
# 32/32 [==============================] - 6s 180ms/step - loss: 0.2153 - accuracy: 0.9648 - val_loss: 6.4469 - val_accuracy: 0.3750
# Epoch 197/200
# 32/32 [==============================] - 7s 205ms/step - loss: 0.1048 - accuracy: 0.9727 - val_loss: 2.1780 - val_accuracy: 0.6719
# Epoch 198/200
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0330 - accuracy: 0.9883 - val_loss: 2.0311 - val_accuracy: 0.7812
# Epoch 199/200
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0341 - accuracy: 0.9883 - val_loss: 1.4946 - val_accuracy: 0.7812
# Epoch 200/200
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0329 - accuracy: 0.9883 - val_loss: 1.5155 - val_accuracy: 0.7031

# %% [markdown]
# #Эксперимент 1.
# - изменены размеры картинки для сети
# - уменьшен предел поворота при аугментации
# - увеличено количество нейронов в 4 и 5 сверточных слоях с 256 до 512.
# - количество эпох увеличено со 150 до 250
#
# Точность на обучающей выборке увеличилась с 80% до 92%, на проверочной - не стабильно около 60%.

# %% [markdown]
# #Эксперимент 2.
# * размеры картинки возвращены к исходным 768Х576
# * val & test split изменены с 0,2 до 0,25
# * уменьшены параметры аугментации
#
#
# * уменьшено количество нейронов в 4 и 5 и выходном слоях
# * количество эпох уменьшено с 250 до 200
#
#
# Обучение остановила на 90 эпохе - точность 0,0039 и стоит на месте

# %% [markdown]
# #Эксперимент 3
# * размеры картинки изменены с 768Х576 на 192Х144
# * остальные параметры сохранены
#
#
# Выводы:
# 1. Уменьшение размера картинки повзолило существенно увеличить точность и снизить скорость обучения
# 2. Уменьшение эпох не повлияло отрицательно, но оба пункта позволили снизить нагрузку и повысить эффективность
#
# Точность на обучющей выборке 97%, на проверочной - пока не стабильно около 70%
#
# Переобучение? Пила?
