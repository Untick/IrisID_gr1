# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/main/AnastasiaAntimonova/Iris_Antimonova_20230611_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Инструменты для построения графиков
import matplotlib.pyplot as plt 

# Инструменты для работы с изображениями
from tensorflow.keras.preprocessing import image 

from tensorflow.keras.models import Sequential #Сеть прямого распространения

#Базовые слои для свёрточных сетей
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator # работа с изображениями
from tensorflow.keras.optimizers import Adam, Adadelta # оптимизаторы
from tensorflow.keras import utils #Используем для to_categoricall
from tensorflow.keras.preprocessing import image #Для отрисовки изображений

# Инструменты для работы с массивами
import numpy as np 

# Системные инструменты
import time, random, gdown, os

# Дополнительные инструменты для работы с изображениями
from PIL import Image 

# Дополнительные инструменты визуализации
import seaborn as sns
sns.set_style('darkgrid')


# Отрисовка графиков
import matplotlib.pyplot as plt

# Рисование графиков в ячейках Colab
# %matplotlib inline

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=16wKj93ooL-mYryWHIDEr49FJAfAFwnRO', None, quiet=True)
# Out:
# 'Iris.zip'

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_DIR} {TEST_DIR}

# Разархивация датасета
#!unzip -qo "Iris.zip" -d {TRAIN_DIR}
# !unzip -q "Iris.zip" -d /content/Iris #Указываем путь к базе в Google Drive

# %%
# Глобальные параметры

TRAIN_DIR          = '/content/Iris'        # Папка для обучающего набора данных
TEST_DIR           = '/content/iris_test'   # Папка для тестового набора данных

TEST_SPLIT          = 0.25                  # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.25                  # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 192 # 768                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144 #576                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# %%
# Создаем папки для каждого класса и перемещаем файлы в соответствующую папку
for i in range(1, 65):
                        class_folder = os.path.join(TRAIN_DIR, f'{i:03}')
                        if not os.path.exists(class_folder):
                            os.makedirs(class_folder)
                        for file_name in ['%03dL_%d.png' % (i, j) for j in range(1, 4)] + ['%03dR_%d.png' % (i, j) for j in range(1, 4)]:
                            file_path = os.path.join(TRAIN_DIR, file_name)
                            if os.path.exists(file_path):
                                os.replace(file_path, os.path.join(class_folder, file_name))

# %%
#просмотр списка папок
os.listdir(TRAIN_DIR)
# Out:
# ['059',
#  '043',
#  '040',
#  '038',
#  '003',
#  '032',
#  '004',
#  '064',
#  '055',
#  '052',
#  '054',
#  '009',
#  '047',
#  '051',
#  '016',
#  '028',
#  '053',
#  '017',
#  '021',
#  '022',
#  '060',
#  '037',
#  '010',
#  '036',
#  '045',
#  '026',
#  '030',
#  '044',
#  '061',
#  '033',
#  '019',
#  '046',
#  '048',
#  '041',
#  '007',
#  '042',
#  '023',
#  '039',
#  '014',
#  '011',
#  '027',
#  '057',
#  '029',
#  '049',
#  '001',
#  '006',
#  '031',
#  '020',
#  '035',
#  '024',
#  '002',
#  '012',
#  '008',
#  '005',
#  '018',
#  '013',
#  '062',
#  '056',
#  '050',
#  '034',
#  '063',
#  '025',
#  '058',
#  '015']

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_DIR))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 64, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(25, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):
    # Формирование пути к папке содержимого класса
    class_path = f'{TRAIN_DIR}/{CLASS_LIST[i]}' 
    # Выбор случайного фото из i-го класса
    img_path = class_path +'/'+random.choice(os.listdir(class_path)) 
    # Отображение фотографии (подробнее будет объяснено далее)
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))  
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
# Создание директории тестовых данных
os.mkdir(TEST_DIR)                                        
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_DIR}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_DIR}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# #Аугментация данных

# %%
# Параметры аугментации и модели
ROTATION_RANGE      = 5                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.05                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.05                 # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.05                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.9, 1.1)            # Пределы изменения яркости
HORIZONTAL_FLIP     = True                 # Горизонтальное отражение запрещено

BATCH_SIZE          = 8                     # Размер батча
EPOCHS              = 300                   # Эпох обучения
OPTIMIZER           = Adam(0.0001)           # Оптимизатор

# %%
# Нормализация и аугментация обучающих данных. Разделение выборки на обучающую и проверочную 

train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    width_shift_range=WIDTH_SHIFT_RANGE,
                    height_shift_range=HEIGHT_SHIFT_RANGE,
                    zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT
                )

# %%
# Нормализация тестовых изображений
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.
                )

# %%
# Создание обучающей выборки
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True, 
    subset='training'
)

# Создание проверочной выборки
validation_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 256 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 144, 192, 3), (8, 64), батчей: 32
# Формы данных   проверочной выборки: (8, 144, 192, 3), (8, 64), батчей: 8
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 6),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])  
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(8), columns = 4)

# %%
# Функция компиляции и обучения модели нейронной сети

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5),        # размер полотна для графиков
                        min_accuracy=0.8,       # минимальное значение accuracy для сохранения модели
                        checkpoint_path='/content/Best_model/best_model.h5'):       

    # Компиляция модели
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    # Вывод сводки
    # model.summary()

    # Создание обратного вызова для сохранения модели с заданным значением accuracy
    checkpoint = SaveModelOnAccuracy(filepath=checkpoint_path,
                                     monitor='val_loss',
                                     mode='min',
                                     save_best_only=True,
                                     verbose=1,
                                     min_accuracy=min_accuracy)

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data,
                        callbacks=[checkpoint])  # Передача обратного вызова в качестве списка)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

    return history

# %% [markdown]
# #Создание нейронной сети

# %%
from tensorflow.keras.callbacks import Callback

class SaveModelOnAccuracy(Callback):
    def __init__(self, filepath, monitor='val_loss', mode='min', save_best_only=True, verbose=1, min_accuracy=0.0):
        super(SaveModelOnAccuracy, self).__init__()
        self.filepath = filepath
        self.monitor = monitor
        self.mode = mode
        self.save_best_only = save_best_only
        self.verbose = verbose
        self.min_accuracy = min_accuracy
        self.best_accuracy = 0.0

    def on_epoch_end(self, epoch, logs=None):
        current_accuracy = logs.get('val_accuracy')
        if current_accuracy >= self.min_accuracy and current_accuracy > self.best_accuracy:
            self.model.save(self.filepath)
            self.best_accuracy = current_accuracy
            if self.verbose == 1:
                print(f" Модель сохранена с точностью {self.best_accuracy * 100:.2f} %")

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model, 
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

# %%
# Сохранение лучшей модели
def save_model_to_drive(model, save_path):

    from google.colab import drive
    import shutil

    # Подключение к Google Диску
    drive.mount('/content/gdrive')

    # Сохранение модели в указанную папку на Google Диск
    shutil.copyfile(model, '/content/gdrive/MyDrive/' + save_path)

# %%
from tensorflow.keras.models import load_model

# Загрузка лучшей модели
def load_best_model(model_path):
    # Загрузка модели из указанного файла
    best_model = load_model(model_path)
    
    return best_model

# %%
# Создание последовательной модели
model = Sequential()

# Первый сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model.add(BatchNormalization())

# Второй сверточный слой
model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# Четвертый сверточный слой
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.2))

# Пятый сверточный слой
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

# Слой преобразования многомерных данных в одномерные 
model.add(Flatten())

# Промежуточный полносвязный слой
model.add(Dense(512, activation='relu'))


# Промежуточный полносвязный слой
model.add(Dense(1024, activation='relu'))


# Выходной полносвязный слой с количеством нейронов по количесту классов
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         )
# Out:
# Epoch 1/300
# 32/32 [==============================] - 10s 193ms/step - loss: 4.8892 - accuracy: 0.0352 - val_loss: 4.1663 - val_accuracy: 0.0156
# Epoch 2/300
# 32/32 [==============================] - 7s 228ms/step - loss: 3.6538 - accuracy: 0.1094 - val_loss: 4.2493 - val_accuracy: 0.0156
# Epoch 3/300
# 32/32 [==============================] - 6s 184ms/step - loss: 3.1366 - accuracy: 0.1680 - val_loss: 4.3831 - val_accuracy: 0.0156
# Epoch 4/300
# 32/32 [==============================] - 7s 229ms/step - loss: 2.5822 - accuracy: 0.2578 - val_loss: 4.5466 - val_accuracy: 0.0469
# Epoch 5/300
# 32/32 [==============================] - 8s 244ms/step - loss: 1.9977 - accuracy: 0.4102 - val_loss: 4.7437 - val_accuracy: 0.0156
# Epoch 6/300
# 32/32 [==============================] - 6s 185ms/step - loss: 1.5823 - accuracy: 0.5703 - val_loss: 4.9807 - val_accuracy: 0.0469
# Epoch 7/300
# 32/32 [==============================] - 7s 229ms/step - loss: 1.3260 - accuracy: 0.5977 - val_loss: 5.2295 - val_accuracy: 0.0469
# Epoch 8/300
# 32/32 [==============================] - 6s 185ms/step - loss: 1.0868 - accuracy: 0.6484 - val_loss: 5.2677 - val_accuracy: 0.0312
# Epoch 9/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.9246 - accuracy: 0.7070 - val_loss: 4.9672 - val_accuracy: 0.1094
# Epoch 10/300
# 32/32 [==============================] - 6s 183ms/step - loss: 0.6546 - accuracy: 0.7852 - val_loss: 4.5184 - val_accuracy: 0.1250
# Epoch 11/300
# 32/32 [==============================] - 7s 231ms/step - loss: 0.6179 - accuracy: 0.8125 - val_loss: 4.9396 - val_accuracy: 0.0781
# Epoch 12/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.4461 - accuracy: 0.8789 - val_loss: 4.2431 - val_accuracy: 0.1094
# Epoch 13/300
# 32/32 [==============================] - 7s 226ms/step - loss: 0.4215 - accuracy: 0.8594 - val_loss: 4.3062 - val_accuracy: 0.1094
# Epoch 14/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.4765 - accuracy: 0.8477 - val_loss: 4.0700 - val_accuracy: 0.1094
# Epoch 15/300
# 32/32 [==============================] - 7s 209ms/step - loss: 0.4785 - accuracy: 0.8516 - val_loss: 3.2195 - val_accuracy: 0.1562
# Epoch 16/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.3494 - accuracy: 0.8945 - val_loss: 2.4473 - val_accuracy: 0.3438
# Epoch 17/300
# 32/32 [==============================] - 6s 191ms/step - loss: 0.1731 - accuracy: 0.9375 - val_loss: 1.9958 - val_accuracy: 0.4844
# Epoch 18/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.1563 - accuracy: 0.9492 - val_loss: 1.8185 - val_accuracy: 0.4844
# Epoch 19/300
# 32/32 [==============================] - 7s 235ms/step - loss: 0.1201 - accuracy: 0.9688 - val_loss: 0.9841 - val_accuracy: 0.7344
# Epoch 20/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.2444 - accuracy: 0.9414 - val_loss: 1.8434 - val_accuracy: 0.5469
# Epoch 21/300
# 32/32 [==============================] - 7s 216ms/step - loss: 0.1237 - accuracy: 0.9531 - val_loss: 0.9825 - val_accuracy: 0.7656
# Epoch 22/300
# 32/32 [==============================] - 6s 194ms/step - loss: 0.1356 - accuracy: 0.9648 - val_loss: 1.1582 - val_accuracy: 0.7031
# Epoch 23/300
# 32/32 [==============================] - 7s 218ms/step - loss: 0.1411 - accuracy: 0.9688 - val_loss: 1.3666 - val_accuracy: 0.6562
# Epoch 24/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1329 - accuracy: 0.9570 - val_loss: 0.8335 - val_accuracy: 0.7344
# Epoch 25/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.2289 - accuracy: 0.9453 - val_loss: 0.8871 - val_accuracy: 0.7656
# Epoch 26/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1078 - accuracy: 0.9844 - val_loss: 0.7555 - val_accuracy: 0.7812
# Epoch 27/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0682 - accuracy: 0.9844 - val_loss: 0.7138 - val_accuracy: 0.7969
# Epoch 28/300
# 32/32 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9766 Модель сохранена с точностью 84.38 %
# 32/32 [==============================] - 13s 418ms/step - loss: 0.0883 - accuracy: 0.9766 - val_loss: 0.4344 - val_accuracy: 0.8438
# Epoch 29/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1038 - accuracy: 0.9648 - val_loss: 0.4814 - val_accuracy: 0.8438
# Epoch 30/300
# 32/32 [==============================] - 7s 225ms/step - loss: 0.1514 - accuracy: 0.9492 - val_loss: 1.1078 - val_accuracy: 0.7188
# Epoch 31/300
# 32/32 [==============================] - 6s 183ms/step - loss: 0.1918 - accuracy: 0.9531 - val_loss: 0.8681 - val_accuracy: 0.7812
# Epoch 32/300
# 32/32 [==============================] - 8s 254ms/step - loss: 0.1420 - accuracy: 0.9609 - val_loss: 1.8465 - val_accuracy: 0.6094
# Epoch 33/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.1479 - accuracy: 0.9609 - val_loss: 0.7489 - val_accuracy: 0.8281
# Epoch 34/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.1779 - accuracy: 0.9414 - val_loss: 0.3859 - val_accuracy: 0.8438
# Epoch 35/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1933 - accuracy: 0.9570 - val_loss: 1.2471 - val_accuracy: 0.7188
# Epoch 36/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.2050 - accuracy: 0.9414 - val_loss: 0.7644 - val_accuracy: 0.7656
# Epoch 37/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1876 - accuracy: 0.9375 - val_loss: 0.8906 - val_accuracy: 0.7344
# Epoch 38/300
# 32/32 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9492 Модель сохранена с точностью 89.06 %
# 32/32 [==============================] - 9s 290ms/step - loss: 0.1231 - accuracy: 0.9492 - val_loss: 0.4247 - val_accuracy: 0.8906
# Epoch 39/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0627 - accuracy: 0.9688 - val_loss: 0.4781 - val_accuracy: 0.8438
# Epoch 40/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.1613 - accuracy: 0.9648 - val_loss: 0.8841 - val_accuracy: 0.7188
# Epoch 41/300
# 32/32 [==============================] - 7s 231ms/step - loss: 0.1574 - accuracy: 0.9609 - val_loss: 0.8352 - val_accuracy: 0.8594
# Epoch 42/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.1345 - accuracy: 0.9453 - val_loss: 1.6375 - val_accuracy: 0.7188
# Epoch 43/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.1802 - accuracy: 0.9609 - val_loss: 1.0052 - val_accuracy: 0.7188
# Epoch 44/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.1090 - accuracy: 0.9688 - val_loss: 0.9016 - val_accuracy: 0.7969
# Epoch 45/300
# 32/32 [==============================] - 7s 214ms/step - loss: 0.1051 - accuracy: 0.9766 - val_loss: 0.6382 - val_accuracy: 0.8281
# Epoch 46/300
# 32/32 [==============================] - 7s 233ms/step - loss: 0.1517 - accuracy: 0.9609 - val_loss: 0.6510 - val_accuracy: 0.8750
# Epoch 47/300
# 32/32 [==============================] - 6s 193ms/step - loss: 0.1192 - accuracy: 0.9844 - val_loss: 0.7638 - val_accuracy: 0.7656
# Epoch 48/300
# 32/32 [==============================] - 8s 240ms/step - loss: 0.1538 - accuracy: 0.9453 - val_loss: 0.5018 - val_accuracy: 0.8594
# Epoch 49/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1593 - accuracy: 0.9531 - val_loss: 0.4837 - val_accuracy: 0.8594
# Epoch 50/300
# 32/32 [==============================] - 7s 224ms/step - loss: 0.0825 - accuracy: 0.9766 - val_loss: 0.5889 - val_accuracy: 0.7969
# Epoch 51/300
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0714 - accuracy: 0.9844 - val_loss: 0.4663 - val_accuracy: 0.8438
# Epoch 52/300
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0993 - accuracy: 0.9609 - val_loss: 0.4715 - val_accuracy: 0.8594
# Epoch 53/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1566 - accuracy: 0.9727 - val_loss: 1.4500 - val_accuracy: 0.7031
# Epoch 54/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.1826 - accuracy: 0.9531 - val_loss: 1.5388 - val_accuracy: 0.7344
# Epoch 55/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1568 - accuracy: 0.9453 - val_loss: 0.8288 - val_accuracy: 0.8281
# Epoch 56/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.1348 - accuracy: 0.9609 - val_loss: 0.8374 - val_accuracy: 0.7969
# Epoch 57/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0505 - accuracy: 0.9844 - val_loss: 0.6840 - val_accuracy: 0.8594
# Epoch 58/300
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0771 - accuracy: 0.9609 - val_loss: 1.0812 - val_accuracy: 0.7969
# Epoch 59/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.1722 - accuracy: 0.9453 - val_loss: 0.9006 - val_accuracy: 0.8750
# Epoch 60/300
# 32/32 [==============================] - 6s 193ms/step - loss: 0.1841 - accuracy: 0.9531 - val_loss: 0.8599 - val_accuracy: 0.8281
# Epoch 61/300
# 32/32 [==============================] - 8s 238ms/step - loss: 0.1302 - accuracy: 0.9609 - val_loss: 0.3816 - val_accuracy: 0.8438
# Epoch 62/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0610 - accuracy: 0.9805 - val_loss: 0.7200 - val_accuracy: 0.8125
# Epoch 63/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0521 - accuracy: 0.9844 - val_loss: 0.6793 - val_accuracy: 0.8906
# Epoch 64/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0440 - accuracy: 0.9922 - val_loss: 0.5145 - val_accuracy: 0.8906
# Epoch 65/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0499 - accuracy: 0.9922 - val_loss: 0.8395 - val_accuracy: 0.7969
# Epoch 66/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0385 - accuracy: 0.9922 - val_loss: 0.5006 - val_accuracy: 0.8906
# Epoch 67/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0729 - accuracy: 0.9805 - val_loss: 0.5740 - val_accuracy: 0.8594
# Epoch 68/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0988 - accuracy: 0.9727 - val_loss: 1.1087 - val_accuracy: 0.7969
# Epoch 69/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1425 - accuracy: 0.9727 - val_loss: 1.3085 - val_accuracy: 0.8281
# Epoch 70/300
# 32/32 [==============================] - 9s 277ms/step - loss: 0.0301 - accuracy: 0.9922 - val_loss: 0.7295 - val_accuracy: 0.8125
# Epoch 71/300
# 32/32 [==============================] - 6s 190ms/step - loss: 0.0624 - accuracy: 0.9844 - val_loss: 1.6573 - val_accuracy: 0.7188
# Epoch 72/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.1072 - accuracy: 0.9688 - val_loss: 1.5717 - val_accuracy: 0.6562
# Epoch 73/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0930 - accuracy: 0.9688 - val_loss: 1.2078 - val_accuracy: 0.7812
# Epoch 74/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.2270 - accuracy: 0.9375 - val_loss: 2.6821 - val_accuracy: 0.5156
# Epoch 75/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.1234 - accuracy: 0.9648 - val_loss: 2.7419 - val_accuracy: 0.5469
# Epoch 76/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1402 - accuracy: 0.9570 - val_loss: 0.5772 - val_accuracy: 0.8281
# Epoch 77/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0753 - accuracy: 0.9844 - val_loss: 0.5308 - val_accuracy: 0.8750
# Epoch 78/300
# 32/32 [==============================] - 6s 193ms/step - loss: 0.0838 - accuracy: 0.9766 - val_loss: 0.2583 - val_accuracy: 0.8906
# Epoch 79/300
# 32/32 [==============================] - 7s 228ms/step - loss: 0.1401 - accuracy: 0.9688 - val_loss: 0.6148 - val_accuracy: 0.8438
# Epoch 80/300
# 32/32 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9922 Модель сохранена с точностью 92.19 %
# 32/32 [==============================] - 8s 245ms/step - loss: 0.0450 - accuracy: 0.9922 - val_loss: 0.2490 - val_accuracy: 0.9219
# Epoch 81/300
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0217 - accuracy: 0.9922 - val_loss: 0.2275 - val_accuracy: 0.9219
# Epoch 82/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.7476 - val_accuracy: 0.8438
# Epoch 83/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0409 - accuracy: 0.9883 - val_loss: 0.4425 - val_accuracy: 0.8906
# Epoch 84/300
# 32/32 [==============================] - 8s 264ms/step - loss: 0.0919 - accuracy: 0.9844 - val_loss: 0.7299 - val_accuracy: 0.8281
# Epoch 85/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1339 - accuracy: 0.9688 - val_loss: 0.7724 - val_accuracy: 0.7969
# Epoch 86/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0814 - accuracy: 0.9844 - val_loss: 1.0156 - val_accuracy: 0.7812
# Epoch 87/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1351 - accuracy: 0.9688 - val_loss: 0.9969 - val_accuracy: 0.8594
# Epoch 88/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0760 - accuracy: 0.9805 - val_loss: 0.9770 - val_accuracy: 0.7656
# Epoch 89/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0770 - accuracy: 0.9883 - val_loss: 0.3874 - val_accuracy: 0.8906
# Epoch 90/300
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0290 - accuracy: 0.9883 - val_loss: 0.8804 - val_accuracy: 0.8750
# Epoch 91/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0308 - accuracy: 0.9883 - val_loss: 1.0296 - val_accuracy: 0.8281
# Epoch 92/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0398 - accuracy: 0.9805 - val_loss: 0.9348 - val_accuracy: 0.7500
# Epoch 93/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0459 - accuracy: 0.9883 - val_loss: 1.0589 - val_accuracy: 0.7344
# Epoch 94/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0923 - accuracy: 0.9727 - val_loss: 0.8544 - val_accuracy: 0.8594
# Epoch 95/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0779 - accuracy: 0.9727 - val_loss: 0.8097 - val_accuracy: 0.8906
# Epoch 96/300
# 32/32 [==============================] - 7s 205ms/step - loss: 0.1946 - accuracy: 0.9727 - val_loss: 0.9795 - val_accuracy: 0.7344
# Epoch 97/300
# 32/32 [==============================] - 7s 215ms/step - loss: 0.1510 - accuracy: 0.9648 - val_loss: 1.4507 - val_accuracy: 0.6719
# Epoch 98/300
# 32/32 [==============================] - 6s 195ms/step - loss: 0.0657 - accuracy: 0.9805 - val_loss: 0.5599 - val_accuracy: 0.8906
# Epoch 99/300
# 32/32 [==============================] - 7s 221ms/step - loss: 0.0595 - accuracy: 0.9766 - val_loss: 1.2031 - val_accuracy: 0.7812
# Epoch 100/300
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0153 - accuracy: 0.9961 - val_loss: 0.9377 - val_accuracy: 0.8281
# Epoch 101/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0706 - accuracy: 0.9883 - val_loss: 1.0316 - val_accuracy: 0.7812
# Epoch 102/300
# 32/32 [==============================] - 8s 236ms/step - loss: 0.1411 - accuracy: 0.9648 - val_loss: 0.5039 - val_accuracy: 0.8438
# Epoch 103/300
# 32/32 [==============================] - 8s 244ms/step - loss: 0.1210 - accuracy: 0.9688 - val_loss: 1.0291 - val_accuracy: 0.7812
# Epoch 104/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.1219 - accuracy: 0.9727 - val_loss: 2.0033 - val_accuracy: 0.7188
# Epoch 105/300
# 32/32 [==============================] - 7s 228ms/step - loss: 0.1652 - accuracy: 0.9570 - val_loss: 1.1333 - val_accuracy: 0.8281
# Epoch 106/300
# 32/32 [==============================] - 6s 190ms/step - loss: 0.2869 - accuracy: 0.9258 - val_loss: 2.6132 - val_accuracy: 0.6406
# Epoch 107/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0764 - accuracy: 0.9727 - val_loss: 2.3507 - val_accuracy: 0.7188
# Epoch 108/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1616 - accuracy: 0.9453 - val_loss: 1.3911 - val_accuracy: 0.7812
# Epoch 109/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.2402 - accuracy: 0.9453 - val_loss: 1.0358 - val_accuracy: 0.7812
# Epoch 110/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0590 - accuracy: 0.9805 - val_loss: 1.0926 - val_accuracy: 0.8281
# Epoch 111/300
# 32/32 [==============================] - 7s 236ms/step - loss: 0.0529 - accuracy: 0.9805 - val_loss: 1.1216 - val_accuracy: 0.8594
# Epoch 112/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0096 - accuracy: 0.9961 - val_loss: 0.4493 - val_accuracy: 0.9062
# Epoch 113/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.1200 - accuracy: 0.9922 - val_loss: 0.9468 - val_accuracy: 0.8750
# Epoch 114/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0788 - accuracy: 0.9727 - val_loss: 1.4578 - val_accuracy: 0.8125
# Epoch 115/300
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0968 - accuracy: 0.9805 - val_loss: 3.5519 - val_accuracy: 0.6562
# Epoch 116/300
# 32/32 [==============================] - 7s 204ms/step - loss: 0.1416 - accuracy: 0.9648 - val_loss: 1.6113 - val_accuracy: 0.7656
# Epoch 117/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.1215 - accuracy: 0.9766 - val_loss: 3.3442 - val_accuracy: 0.5469
# Epoch 118/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.1325 - accuracy: 0.9727 - val_loss: 3.9168 - val_accuracy: 0.5781
# Epoch 119/300
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0565 - accuracy: 0.9727 - val_loss: 2.6133 - val_accuracy: 0.6562
# Epoch 120/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0834 - accuracy: 0.9883 - val_loss: 0.5232 - val_accuracy: 0.8438
# Epoch 121/300
# 32/32 [==============================] - 8s 253ms/step - loss: 0.0912 - accuracy: 0.9766 - val_loss: 0.6137 - val_accuracy: 0.8125
# Epoch 122/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0413 - accuracy: 0.9883 - val_loss: 0.6874 - val_accuracy: 0.8281
# Epoch 123/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0192 - accuracy: 0.9961 - val_loss: 0.8293 - val_accuracy: 0.8125
# Epoch 124/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0235 - accuracy: 0.9961 - val_loss: 0.2508 - val_accuracy: 0.9219
# Epoch 125/300
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0202 - accuracy: 0.9961 - val_loss: 0.3682 - val_accuracy: 0.8594
# Epoch 126/300
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.8906
# Epoch 127/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0583 - accuracy: 0.9883 - val_loss: 0.1752 - val_accuracy: 0.9219
# Epoch 128/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0543 - accuracy: 0.9766 - val_loss: 0.8993 - val_accuracy: 0.8750
# Epoch 129/300
# 32/32 [==============================] - 7s 215ms/step - loss: 0.0800 - accuracy: 0.9844 - val_loss: 0.6147 - val_accuracy: 0.8438
# Epoch 130/300
# 32/32 [==============================] - 6s 190ms/step - loss: 0.0743 - accuracy: 0.9844 - val_loss: 0.4526 - val_accuracy: 0.8594
# Epoch 131/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0482 - accuracy: 0.9883 - val_loss: 1.2608 - val_accuracy: 0.7969
# Epoch 132/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0730 - accuracy: 0.9883 - val_loss: 0.9691 - val_accuracy: 0.8750
# Epoch 133/300
# 32/32 [==============================] - 7s 233ms/step - loss: 0.0282 - accuracy: 0.9922 - val_loss: 1.0723 - val_accuracy: 0.9062
# Epoch 134/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 0.4882 - val_accuracy: 0.8750
# Epoch 135/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0350 - accuracy: 0.9883 - val_loss: 1.4511 - val_accuracy: 0.8594
# Epoch 136/300
# 32/32 [==============================] - 8s 248ms/step - loss: 0.0326 - accuracy: 0.9961 - val_loss: 0.8720 - val_accuracy: 0.8750
# Epoch 137/300
# 32/32 [==============================] - 6s 190ms/step - loss: 0.0178 - accuracy: 0.9961 - val_loss: 0.9209 - val_accuracy: 0.8750
# Epoch 138/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0341 - accuracy: 0.9883 - val_loss: 2.5767 - val_accuracy: 0.6250
# Epoch 139/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0915 - accuracy: 0.9766 - val_loss: 1.5012 - val_accuracy: 0.8125
# Epoch 140/300
# 32/32 [==============================] - 8s 256ms/step - loss: 0.0489 - accuracy: 0.9727 - val_loss: 1.4476 - val_accuracy: 0.8438
# Epoch 141/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0471 - accuracy: 0.9883 - val_loss: 0.7056 - val_accuracy: 0.8594
# Epoch 142/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0375 - accuracy: 0.9961 - val_loss: 1.4530 - val_accuracy: 0.8281
# Epoch 143/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0198 - accuracy: 0.9883 - val_loss: 1.3949 - val_accuracy: 0.8594
# Epoch 144/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1200 - accuracy: 0.9766 - val_loss: 1.5124 - val_accuracy: 0.7656
# Epoch 145/300
# 32/32 [==============================] - 7s 234ms/step - loss: 0.0451 - accuracy: 0.9844 - val_loss: 0.9252 - val_accuracy: 0.8750
# Epoch 146/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1035 - accuracy: 0.9727 - val_loss: 1.3752 - val_accuracy: 0.8125
# Epoch 147/300
# 32/32 [==============================] - 8s 242ms/step - loss: 0.0614 - accuracy: 0.9766 - val_loss: 0.4977 - val_accuracy: 0.8750
# Epoch 148/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.1105 - accuracy: 0.9727 - val_loss: 9.0261 - val_accuracy: 0.2656
# Epoch 149/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0626 - accuracy: 0.9883 - val_loss: 4.4585 - val_accuracy: 0.5000
# Epoch 150/300
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1376 - accuracy: 0.9844 - val_loss: 1.2889 - val_accuracy: 0.7188
# Epoch 151/300
# 32/32 [==============================] - 6s 195ms/step - loss: 0.1061 - accuracy: 0.9609 - val_loss: 6.8075 - val_accuracy: 0.5625
# Epoch 152/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0447 - accuracy: 0.9805 - val_loss: 1.1417 - val_accuracy: 0.8438
# Epoch 153/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1934 - accuracy: 0.9570 - val_loss: 1.9161 - val_accuracy: 0.6719
# Epoch 154/300
# 32/32 [==============================] - 8s 254ms/step - loss: 0.0497 - accuracy: 0.9922 - val_loss: 0.6026 - val_accuracy: 0.8750
# Epoch 155/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0919 - accuracy: 0.9688 - val_loss: 0.8371 - val_accuracy: 0.8750
# Epoch 156/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.2475 - accuracy: 0.9492 - val_loss: 1.8485 - val_accuracy: 0.6562
# Epoch 157/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.3059 - accuracy: 0.9336 - val_loss: 2.6001 - val_accuracy: 0.8281
# Epoch 158/300
# 32/32 [==============================] - 7s 213ms/step - loss: 0.2475 - accuracy: 0.9570 - val_loss: 10.3164 - val_accuracy: 0.4375
# Epoch 159/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.4026 - accuracy: 0.9336 - val_loss: 2.6040 - val_accuracy: 0.8438
# Epoch 160/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0826 - accuracy: 0.9766 - val_loss: 1.9777 - val_accuracy: 0.8594
# Epoch 161/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.1174 - accuracy: 0.9766 - val_loss: 2.6298 - val_accuracy: 0.6562
# Epoch 162/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0940 - accuracy: 0.9727 - val_loss: 1.7495 - val_accuracy: 0.7500
# Epoch 163/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.1205 - accuracy: 0.9453 - val_loss: 4.3766 - val_accuracy: 0.4062
# Epoch 164/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0504 - accuracy: 0.9844 - val_loss: 2.1328 - val_accuracy: 0.7812
# Epoch 165/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0891 - accuracy: 0.9727 - val_loss: 1.3614 - val_accuracy: 0.8750
# Epoch 166/300
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0823 - accuracy: 0.9844 - val_loss: 1.7872 - val_accuracy: 0.7031
# Epoch 167/300
# 32/32 [==============================] - 7s 222ms/step - loss: 0.0604 - accuracy: 0.9844 - val_loss: 1.6577 - val_accuracy: 0.7969
# Epoch 168/300
# 32/32 [==============================] - 6s 183ms/step - loss: 0.1764 - accuracy: 0.9727 - val_loss: 2.3917 - val_accuracy: 0.7969
# Epoch 169/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0518 - accuracy: 0.9844 - val_loss: 2.5245 - val_accuracy: 0.7031
# Epoch 170/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.1026 - accuracy: 0.9766 - val_loss: 1.4157 - val_accuracy: 0.7969
# Epoch 171/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.2698 - accuracy: 0.9570 - val_loss: 2.0500 - val_accuracy: 0.6719
# Epoch 172/300
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0681 - accuracy: 0.9805 - val_loss: 0.8265 - val_accuracy: 0.8438
# Epoch 173/300
# 32/32 [==============================] - 8s 236ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.9604 - val_accuracy: 0.7500
# Epoch 174/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0396 - accuracy: 0.9883 - val_loss: 1.4129 - val_accuracy: 0.7656
# Epoch 175/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.1208 - accuracy: 0.9609 - val_loss: 1.2314 - val_accuracy: 0.7969
# Epoch 176/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1428 - accuracy: 0.9727 - val_loss: 3.1310 - val_accuracy: 0.7188
# Epoch 177/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0370 - accuracy: 0.9883 - val_loss: 1.9089 - val_accuracy: 0.7344
# Epoch 178/300
# 32/32 [==============================] - 8s 246ms/step - loss: 0.0361 - accuracy: 0.9883 - val_loss: 1.6117 - val_accuracy: 0.7344
# Epoch 179/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0155 - accuracy: 0.9922 - val_loss: 1.1246 - val_accuracy: 0.8594
# Epoch 180/300
# 32/32 [==============================] - 7s 211ms/step - loss: 0.0622 - accuracy: 0.9883 - val_loss: 8.0965 - val_accuracy: 0.3594
# Epoch 181/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.2751 - accuracy: 0.9688 - val_loss: 9.8962 - val_accuracy: 0.3594
# Epoch 182/300
# 32/32 [==============================] - 6s 194ms/step - loss: 0.1029 - accuracy: 0.9727 - val_loss: 2.3694 - val_accuracy: 0.7031
# Epoch 183/300
# 32/32 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9844 Модель сохранена с точностью 93.75 %
# 32/32 [==============================] - 12s 391ms/step - loss: 0.0654 - accuracy: 0.9844 - val_loss: 0.4105 - val_accuracy: 0.9375
# Epoch 184/300
# 32/32 [==============================] - 7s 205ms/step - loss: 0.1161 - accuracy: 0.9688 - val_loss: 1.7338 - val_accuracy: 0.7969
# Epoch 185/300
# 32/32 [==============================] - 7s 226ms/step - loss: 0.1881 - accuracy: 0.9727 - val_loss: 2.5900 - val_accuracy: 0.7344
# Epoch 186/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 1.2425 - val_accuracy: 0.8438
# Epoch 187/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0289 - accuracy: 0.9922 - val_loss: 0.7318 - val_accuracy: 0.8281
# Epoch 188/300
# 32/32 [==============================] - 7s 226ms/step - loss: 0.0338 - accuracy: 0.9922 - val_loss: 3.3785 - val_accuracy: 0.6875
# Epoch 189/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0330 - accuracy: 0.9922 - val_loss: 0.5639 - val_accuracy: 0.8438
# Epoch 190/300
# 32/32 [==============================] - 7s 201ms/step - loss: 0.0178 - accuracy: 0.9922 - val_loss: 1.7740 - val_accuracy: 0.7812
# Epoch 191/300
# 32/32 [==============================] - 7s 235ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5956 - val_accuracy: 0.9375
# Epoch 192/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0064 - accuracy: 0.9961 - val_loss: 0.4642 - val_accuracy: 0.8750
# Epoch 193/300
# 32/32 [==============================] - 7s 228ms/step - loss: 7.9730e-04 - accuracy: 1.0000 - val_loss: 0.4262 - val_accuracy: 0.8906
# Epoch 194/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5602 - val_accuracy: 0.8594
# Epoch 195/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0323 - accuracy: 0.9961 - val_loss: 0.5136 - val_accuracy: 0.8750
# Epoch 196/300
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0154 - accuracy: 0.9922 - val_loss: 0.5426 - val_accuracy: 0.8750
# Epoch 197/300
# 32/32 [==============================] - 9s 274ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3844 - val_accuracy: 0.9062
# Epoch 198/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2714 - val_accuracy: 0.9375
# Epoch 199/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3510 - val_accuracy: 0.9062
# Epoch 200/300
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0074 - accuracy: 0.9961 - val_loss: 0.3348 - val_accuracy: 0.8906
# Epoch 201/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0193 - accuracy: 0.9961 - val_loss: 0.5544 - val_accuracy: 0.9062
# Epoch 202/300
# 32/32 [==============================] - 8s 267ms/step - loss: 4.0415e-04 - accuracy: 1.0000 - val_loss: 0.5756 - val_accuracy: 0.9062
# Epoch 203/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4597 - val_accuracy: 0.9375
# Epoch 204/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0310 - accuracy: 0.9961 - val_loss: 0.7196 - val_accuracy: 0.8750
# Epoch 205/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0299 - accuracy: 0.9961 - val_loss: 0.6704 - val_accuracy: 0.8906
# Epoch 206/300
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.8273 - val_accuracy: 0.8906
# Epoch 207/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0561 - accuracy: 0.9922 - val_loss: 0.3415 - val_accuracy: 0.8906
# Epoch 208/300
# 32/32 [==============================] - 7s 226ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3006 - val_accuracy: 0.9375
# Epoch 209/300
# 32/32 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9961 Модель сохранена с точностью 96.88 %
# 32/32 [==============================] - 13s 408ms/step - loss: 0.0072 - accuracy: 0.9961 - val_loss: 0.0933 - val_accuracy: 0.9688
# Epoch 210/300
# 32/32 [==============================] - 8s 266ms/step - loss: 0.0034 - accuracy: 0.9961 - val_loss: 0.6967 - val_accuracy: 0.8906
# Epoch 211/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0197 - accuracy: 0.9961 - val_loss: 0.6436 - val_accuracy: 0.8438
# Epoch 212/300
# 32/32 [==============================] - 7s 209ms/step - loss: 0.1037 - accuracy: 0.9766 - val_loss: 1.5933 - val_accuracy: 0.7031
# Epoch 213/300
# 32/32 [==============================] - 6s 194ms/step - loss: 0.2622 - accuracy: 0.9570 - val_loss: 4.7262 - val_accuracy: 0.5156
# Epoch 214/300
# 32/32 [==============================] - 7s 219ms/step - loss: 0.1262 - accuracy: 0.9727 - val_loss: 1.2374 - val_accuracy: 0.7656
# Epoch 215/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0462 - accuracy: 0.9766 - val_loss: 1.0590 - val_accuracy: 0.8281
# Epoch 216/300
# 32/32 [==============================] - 7s 224ms/step - loss: 0.1349 - accuracy: 0.9766 - val_loss: 1.4618 - val_accuracy: 0.7969
# Epoch 217/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1147 - accuracy: 0.9727 - val_loss: 1.1458 - val_accuracy: 0.8438
# Epoch 218/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0249 - accuracy: 0.9961 - val_loss: 2.5946 - val_accuracy: 0.8281
# Epoch 219/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0489 - accuracy: 0.9805 - val_loss: 0.7147 - val_accuracy: 0.8594
# Epoch 220/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0982 - accuracy: 0.9688 - val_loss: 0.4756 - val_accuracy: 0.8906
# Epoch 221/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1964 - accuracy: 0.9648 - val_loss: 4.6695 - val_accuracy: 0.5156
# Epoch 222/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.1320 - accuracy: 0.9688 - val_loss: 1.5899 - val_accuracy: 0.8125
# Epoch 223/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.2120 - accuracy: 0.9688 - val_loss: 2.7743 - val_accuracy: 0.6250
# Epoch 224/300
# 32/32 [==============================] - 6s 189ms/step - loss: 0.1456 - accuracy: 0.9766 - val_loss: 1.4212 - val_accuracy: 0.8125
# Epoch 225/300
# 32/32 [==============================] - 8s 238ms/step - loss: 0.0509 - accuracy: 0.9883 - val_loss: 0.8614 - val_accuracy: 0.8438
# Epoch 226/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.8281
# Epoch 227/300
# 32/32 [==============================] - 7s 219ms/step - loss: 0.0822 - accuracy: 0.9961 - val_loss: 0.7036 - val_accuracy: 0.8906
# Epoch 228/300
# 32/32 [==============================] - 7s 227ms/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.6613 - val_accuracy: 0.8281
# Epoch 229/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0459 - accuracy: 0.9844 - val_loss: 0.7474 - val_accuracy: 0.8281
# Epoch 230/300
# 32/32 [==============================] - 8s 255ms/step - loss: 0.0623 - accuracy: 0.9844 - val_loss: 0.6986 - val_accuracy: 0.8594
# Epoch 231/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0505 - accuracy: 0.9805 - val_loss: 2.5288 - val_accuracy: 0.6719
# Epoch 232/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0382 - accuracy: 0.9883 - val_loss: 1.1919 - val_accuracy: 0.8281
# Epoch 233/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1400 - accuracy: 0.9805 - val_loss: 1.4782 - val_accuracy: 0.8438
# Epoch 234/300
# 32/32 [==============================] - 8s 252ms/step - loss: 0.0777 - accuracy: 0.9844 - val_loss: 0.8583 - val_accuracy: 0.8281
# Epoch 235/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 0.6397 - val_accuracy: 0.8906
# Epoch 236/300
# 32/32 [==============================] - 7s 208ms/step - loss: 0.0274 - accuracy: 0.9922 - val_loss: 5.2082 - val_accuracy: 0.5469
# Epoch 237/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0418 - accuracy: 0.9805 - val_loss: 1.3108 - val_accuracy: 0.7656
# Epoch 238/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0394 - accuracy: 0.9922 - val_loss: 0.8731 - val_accuracy: 0.8750
# Epoch 239/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0141 - accuracy: 0.9961 - val_loss: 0.6349 - val_accuracy: 0.8594
# Epoch 240/300
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0487 - accuracy: 0.9883 - val_loss: 0.4111 - val_accuracy: 0.8906
# Epoch 241/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0071 - accuracy: 0.9961 - val_loss: 0.3309 - val_accuracy: 0.9531
# Epoch 242/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0203 - accuracy: 0.9922 - val_loss: 1.2678 - val_accuracy: 0.8594
# Epoch 243/300
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0543 - accuracy: 0.9883 - val_loss: 1.7880 - val_accuracy: 0.9062
# Epoch 244/300
# 32/32 [==============================] - 7s 213ms/step - loss: 0.0743 - accuracy: 0.9922 - val_loss: 2.1780 - val_accuracy: 0.7812
# Epoch 245/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0592 - accuracy: 0.9844 - val_loss: 2.5909 - val_accuracy: 0.7500
# Epoch 246/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1100 - accuracy: 0.9766 - val_loss: 0.8595 - val_accuracy: 0.8281
# Epoch 247/300
# 32/32 [==============================] - 7s 228ms/step - loss: 0.0292 - accuracy: 0.9844 - val_loss: 1.3591 - val_accuracy: 0.8125
# Epoch 248/300
# 32/32 [==============================] - 7s 226ms/step - loss: 0.1268 - accuracy: 0.9883 - val_loss: 0.7987 - val_accuracy: 0.8594
# Epoch 249/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0340 - accuracy: 0.9883 - val_loss: 1.4215 - val_accuracy: 0.8594
# Epoch 250/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0497 - accuracy: 0.9844 - val_loss: 0.6326 - val_accuracy: 0.8906
# Epoch 251/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0383 - accuracy: 0.9844 - val_loss: 2.2146 - val_accuracy: 0.7344
# Epoch 252/300
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0611 - accuracy: 0.9805 - val_loss: 0.8873 - val_accuracy: 0.8906
# Epoch 253/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0544 - accuracy: 0.9883 - val_loss: 2.0416 - val_accuracy: 0.8125
# Epoch 254/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0926 - accuracy: 0.9766 - val_loss: 3.5262 - val_accuracy: 0.7500
# Epoch 255/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 1.6871 - val_accuracy: 0.8594
# Epoch 256/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 1.1569 - val_accuracy: 0.8906
# Epoch 257/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0174 - accuracy: 0.9961 - val_loss: 0.9467 - val_accuracy: 0.8906
# Epoch 258/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.2143 - accuracy: 0.9844 - val_loss: 1.2521 - val_accuracy: 0.8594
# Epoch 259/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.1304 - accuracy: 0.9727 - val_loss: 3.3645 - val_accuracy: 0.5781
# Epoch 260/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1107 - accuracy: 0.9766 - val_loss: 0.9569 - val_accuracy: 0.8750
# Epoch 261/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.2285 - accuracy: 0.9766 - val_loss: 5.1769 - val_accuracy: 0.5625
# Epoch 262/300
# 32/32 [==============================] - 8s 242ms/step - loss: 0.0871 - accuracy: 0.9805 - val_loss: 1.4629 - val_accuracy: 0.8125
# Epoch 263/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0596 - accuracy: 0.9883 - val_loss: 2.8629 - val_accuracy: 0.7188
# Epoch 264/300
# 32/32 [==============================] - 8s 251ms/step - loss: 0.0211 - accuracy: 0.9961 - val_loss: 1.0518 - val_accuracy: 0.9062
# Epoch 265/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0040 - accuracy: 0.9961 - val_loss: 0.7582 - val_accuracy: 0.8906
# Epoch 266/300
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0066 - accuracy: 0.9922 - val_loss: 0.7782 - val_accuracy: 0.8906
# Epoch 267/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0398 - accuracy: 0.9922 - val_loss: 1.3536 - val_accuracy: 0.8750
# Epoch 268/300
# 32/32 [==============================] - 8s 252ms/step - loss: 0.0220 - accuracy: 0.9961 - val_loss: 1.3237 - val_accuracy: 0.8438
# Epoch 269/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.1276 - val_accuracy: 0.8750
# Epoch 270/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0078 - accuracy: 0.9961 - val_loss: 0.5016 - val_accuracy: 0.9062
# Epoch 271/300
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0065 - accuracy: 0.9961 - val_loss: 1.2446 - val_accuracy: 0.8281
# Epoch 272/300
# 32/32 [==============================] - 7s 232ms/step - loss: 0.0054 - accuracy: 0.9961 - val_loss: 1.3249 - val_accuracy: 0.8594
# Epoch 273/300
# 32/32 [==============================] - 6s 186ms/step - loss: 7.9869e-04 - accuracy: 1.0000 - val_loss: 1.3080 - val_accuracy: 0.8750
# Epoch 274/300
# 32/32 [==============================] - 8s 248ms/step - loss: 4.6144e-05 - accuracy: 1.0000 - val_loss: 1.0333 - val_accuracy: 0.8281
# Epoch 275/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0041 - accuracy: 0.9961 - val_loss: 0.9786 - val_accuracy: 0.8906
# Epoch 276/300
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9241 - val_accuracy: 0.8906
# Epoch 277/300
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0285 - accuracy: 0.9922 - val_loss: 0.9014 - val_accuracy: 0.8594
# Epoch 278/300
# 32/32 [==============================] - 7s 220ms/step - loss: 0.0615 - accuracy: 0.9883 - val_loss: 2.9395 - val_accuracy: 0.6875
# Epoch 279/300
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0254 - accuracy: 0.9883 - val_loss: 2.2864 - val_accuracy: 0.7344
# Epoch 280/300
# 32/32 [==============================] - 7s 225ms/step - loss: 0.0899 - accuracy: 0.9883 - val_loss: 1.0729 - val_accuracy: 0.8438
# Epoch 281/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0381 - accuracy: 0.9922 - val_loss: 1.0382 - val_accuracy: 0.8906
# Epoch 282/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0283 - accuracy: 0.9922 - val_loss: 1.4805 - val_accuracy: 0.8594
# Epoch 283/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0088 - accuracy: 0.9961 - val_loss: 1.8178 - val_accuracy: 0.8594
# Epoch 284/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6703 - val_accuracy: 0.8594
# Epoch 285/300
# 32/32 [==============================] - 8s 243ms/step - loss: 0.0486 - accuracy: 0.9805 - val_loss: 0.8545 - val_accuracy: 0.8750
# Epoch 286/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.1108 - accuracy: 0.9805 - val_loss: 1.0163 - val_accuracy: 0.8906
# Epoch 287/300
# 32/32 [==============================] - 7s 228ms/step - loss: 0.1084 - accuracy: 0.9844 - val_loss: 2.4985 - val_accuracy: 0.6719
# Epoch 288/300
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0649 - accuracy: 0.9844 - val_loss: 1.0546 - val_accuracy: 0.8750
# Epoch 289/300
# 32/32 [==============================] - 7s 230ms/step - loss: 0.0165 - accuracy: 0.9922 - val_loss: 0.8804 - val_accuracy: 0.8750
# Epoch 290/300
# 32/32 [==============================] - 6s 197ms/step - loss: 0.1820 - accuracy: 0.9883 - val_loss: 1.1897 - val_accuracy: 0.7969
# Epoch 291/300
# 32/32 [==============================] - 7s 216ms/step - loss: 0.0791 - accuracy: 0.9844 - val_loss: 1.3438 - val_accuracy: 0.8281
# Epoch 292/300
# 32/32 [==============================] - 7s 231ms/step - loss: 0.0276 - accuracy: 0.9922 - val_loss: 0.9972 - val_accuracy: 0.8750
# Epoch 293/300
# 32/32 [==============================] - 6s 192ms/step - loss: 0.0260 - accuracy: 0.9922 - val_loss: 1.0097 - val_accuracy: 0.8594
# Epoch 294/300
# 32/32 [==============================] - 7s 226ms/step - loss: 0.0454 - accuracy: 0.9883 - val_loss: 2.5461 - val_accuracy: 0.8125
# Epoch 295/300
# 32/32 [==============================] - 7s 229ms/step - loss: 0.0348 - accuracy: 0.9844 - val_loss: 1.2536 - val_accuracy: 0.8594
# Epoch 296/300
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0558 - accuracy: 0.9883 - val_loss: 1.2285 - val_accuracy: 0.9062
# Epoch 297/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0252 - accuracy: 0.9922 - val_loss: 1.0461 - val_accuracy: 0.8750
# Epoch 298/300
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.7069 - val_accuracy: 0.7031
# Epoch 299/300
# 32/32 [==============================] - 8s 236ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0173 - val_accuracy: 0.8281
# Epoch 300/300
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.9346 - val_accuracy: 0.9062
