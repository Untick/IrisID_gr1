# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/Sergey-Kim-folder/Sergey%20Kim/%D0%A0%D0%B0%D0%B4%D1%83%D0%B6%D0%BA%D0%B0_%D0%9A%D0%B8%D0%BC_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Идентификация пациента по радужке. Опыт 3

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Материалы и методы
# https://docs.google.com/spreadsheets/d/1vLLVmp67P1sBHKC1HEHnqmWkoZ_9zf_eg27RZj0Xolk/edit#gid=0

# %% [markdown]
# Импорт библиотек и данных

# %%
# Работа с массивами
import numpy as np

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Основа для создания последовательной модели
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Оптимизатор
from tensorflow.keras.optimizers import Adam

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Подключение модуля для загрузки данных из облака
import gdown

# Инструменты для работы с файлами
import os

# Отрисовка графиков
import matplotlib.pyplot as plt

# Библиотека для Computer vision
import cv2

import math
from google.colab.patches import cv2_imshow

# Рисование графиков в ячейках Colab
# %matplotlib inline

# %%
# Задание гиперпараметров
TRAIN_PATH = '/content/iris'      # Папка для обучающего набора данных
TEST_PATH = '/content/iris_test'  # Папка для тестового набора данных

TEST_SPLIT          = 0.2                   # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.2                   # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 192                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# Параметры аугментации
ROTATION_RANGE      = 8                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.10                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.10                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.10                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.8, 1.2)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение разрешено

EPOCHS              = 350                   # Число эпох обучения
BATCH_SIZE          = 8                     # Размер батча для обучения модели
OPTIMIZER           = Adam(0.0001)          # Оптимизатор

# %% [markdown]
# Загрузка zip-архива и изучение структуры материала

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=19ZzpBgbCDVdSgy9joK54wXt9-yURQGtM', None, quiet=True)
# Out:
# 'iris.zip'

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_PATH} {TEST_PATH}

# Разархивация датасета в директорию данных
# !unzip -qo "iris.zip" -d {TRAIN_PATH}

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_PATH))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 64, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# Перенос файлов для теста в отдельное дерево папок, расчет размеров наборов данных

os.mkdir(TEST_PATH)                                        # Создание папки для тестовых данных
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_PATH}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_PATH}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# ## Сегментация радужки

# %% [markdown]
# Просмотр случайных изображений

# %%
# Просмотр изображения и его параметров
img = cv2.imread('./iris/007/007L_2.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F2E2B1C3550>

# %%
img.shape
# Out:
# (576, 768, 3)

# %%
'''
  Формулы для практического поиска окружностей на рисунке весьма сложны.
  Учитывая, что рисунок почти квадратный, нужно найти центр рисунка делением
  высоты и ширины пополам. затем выбрать минимальное значение из высоты и ширины
  изменить размер рисунка по минимальной высоте и ширине (resize) и вернуть новое
  изображение 
'''

# обрезка изображения до квадрата
def unwrap_circular_image(image):

  # Берем центр изображения
  height, width = image.shape[:2]
  center_x, center_y = width // 2, height // 2

  # Вычисляем максимальный радиус окружности
  max_radius = min(center_x, center_y)

  return image[center_y - max_radius: center_y + max_radius, center_x - max_radius: center_x + max_radius]

# %%
# перевод из полярной системы координат в декартову
def ring_to_rect(image):

  size = image.shape[0]  # исходное изображение должно быть квадратным

  # здесь бы не помешало вычислить настоящие радиусы радужки и зрачка, но и так неплохо отделяет
  outer_radius = size // 2.25   # это радиус радужки
  inner_radius_factor = 0.3     # а это зрачка

  # Разворачиваем кольцо
  warped = cv2.warpPolar(image, (size, int(size * math.pi)), (size // 2, size // 2), outer_radius, 0)
  # Поворачиваем на 90 градусов
  straightened = cv2.rotate(warped, cv2.ROTATE_90_COUNTERCLOCKWISE)
  # Обрезаем
  cropped = straightened[: int(straightened.shape[0] * (1 - inner_radius_factor)), :]

  return cropped


def resize(image):
  return cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT)).astype('float64')

img = cv2.imread('./iris/022/022L_2.png')
unwrapped_image = unwrap_circular_image(img)
rect_image = ring_to_rect(unwrapped_image)
resized_image = resize(rect_image)

cv2_imshow(img)
cv2_imshow(unwrapped_image)
cv2_imshow(rect_image)
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F2D9845FB50>
# <PIL.Image.Image image mode=RGB size=576x576 at 0x7F2D9845FFD0>
# <PIL.Image.Image image mode=RGB size=1809x403 at 0x7F2D9845FB80>
# <PIL.Image.Image image mode=RGB size=192x144 at 0x7F2D9845FB50>

# %% [markdown]
# ## Аугментация и формирование выборок

# %%
# кастомная функция предобработки для генератора - после всех аугментаций 
# разворачивает изображение в прямоугольное

def get_iris(image):
  return resize(ring_to_rect(unwrap_circular_image(image)))

# %%
# Генераторы изображений

# Изображения для обучающего набора нормализуются и аугментируются согласно заданным гиперпараметрам
# Далее набор будет разделен на обучающую и проверочную выборку в соотношении VAL_SPLIT
train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    #width_shift_range=WIDTH_SHIFT_RANGE,
                    #height_shift_range=HEIGHT_SHIFT_RANGE,
                    #zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    #horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT,
                    preprocessing_function = get_iris
                )

# Изображения для тестового набора только нормализуются
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.,
                   preprocessing_function = get_iris
                )

# %%
# Обучающая выборка генерируется из папки обучающего набора
train_generator = train_datagen.flow_from_directory(
    # Путь к обучающим изображениям
    TRAIN_PATH,
    # Параметры требуемого размера изображения
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    # Размер батча
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    # Указание сгенерировать обучающую выборку
    subset='training'
)

# Проверочная выборка также генерируется из папки обучающего набора
validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    # Указание сгенерировать проверочную выборку
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 256 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 144, 192, 3), (8, 64), батчей: 32
# Формы данных   проверочной выборки: (8, 144, 192, 3), (8, 64), батчей: 8
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 8),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])  
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(8), columns = 4)

# %% [markdown]
# ## Создание и обучение модели

# %%
# Функция компиляции и обучения модели нейронной сети
# По окончанию выводит графики обучения

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    # Вывод сводки
    model.summary()

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция вывода результатов оценки модели на заданных данных

def eval_model(model, 
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(10, 10)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    plt.show()    

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Формируется сообщение о верности или неверности предсказания
        msg = 'ВЕРНО :-)' if cls_pred == cls else 'НЕВЕРНО :-('
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model, 
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1], 
               class_labels=class_labels, 
               title=title,
               figsize=cm_size)

# %%
# Создание последовательной модели
model_conv = Sequential()

# Первый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model_conv.add(BatchNormalization())

# Второй сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())
model_conv.add(Dropout(0.2))

# Четвертый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Пятый сверточный слой
model_conv.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())

# Шестой сверточный слой
model_conv.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Слой преобразования многомерных данных в одномерные 
model_conv.add(Flatten())

# Промежуточный полносвязный слой
model_conv.add(Dense(2048, activation='relu'))

# Промежуточный полносвязный слой
model_conv.add(Dense(4096, activation='relu'))

# Выходной полносвязный слой с количеством нейронов по количесту классов
model_conv.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model_conv,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         title='Сверточный классификатор')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 144, 192, 256)     7168
#
#  batch_normalization (BatchN  (None, 144, 192, 256)    1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 144, 192, 256)     590080
#
#  max_pooling2d (MaxPooling2D  (None, 48, 64, 256)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 48, 64, 256)       590080
#
#  batch_normalization_1 (Batc  (None, 48, 64, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 48, 64, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 48, 64, 256)       590080
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 21, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 21, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 16, 21, 512)       1180160
#
#  batch_normalization_2 (Batc  (None, 16, 21, 512)      2048
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 16, 21, 1024)      4719616
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 7, 1024)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 5, 7, 1024)        0
#
#  flatten (Flatten)           (None, 35840)             0
#
#  dense (Dense)               (None, 2048)              73402368
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  dense_2 (Dense)             (None, 64)                262208
#
# =================================================================
# Total params: 89,738,560
# Trainable params: 89,736,512
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/350
# 32/32 [==============================] - 28s 301ms/step - loss: 7.1607 - accuracy: 0.0273 - val_loss: 4.1849 - val_accuracy: 0.0156
# Epoch 2/350
# 32/32 [==============================] - 10s 311ms/step - loss: 4.1593 - accuracy: 0.0312 - val_loss: 4.2116 - val_accuracy: 0.0156
# Epoch 3/350
# 32/32 [==============================] - 9s 282ms/step - loss: 3.4974 - accuracy: 0.1055 - val_loss: 4.3524 - val_accuracy: 0.0156
# Epoch 4/350
# 32/32 [==============================] - 9s 281ms/step - loss: 2.9204 - accuracy: 0.1836 - val_loss: 4.5699 - val_accuracy: 0.0156
# Epoch 5/350
# 32/32 [==============================] - 10s 296ms/step - loss: 2.6013 - accuracy: 0.2969 - val_loss: 4.7207 - val_accuracy: 0.0156
# Epoch 6/350
# 32/32 [==============================] - 9s 292ms/step - loss: 2.4814 - accuracy: 0.2930 - val_loss: 4.6881 - val_accuracy: 0.0156
# Epoch 7/350
# 32/32 [==============================] - 9s 292ms/step - loss: 2.1912 - accuracy: 0.3672 - val_loss: 4.9267 - val_accuracy: 0.0156
# Epoch 8/350
# 32/32 [==============================] - 9s 276ms/step - loss: 1.8162 - accuracy: 0.5195 - val_loss: 5.1995 - val_accuracy: 0.0156
# Epoch 9/350
# 32/32 [==============================] - 9s 291ms/step - loss: 1.6340 - accuracy: 0.4844 - val_loss: 4.9849 - val_accuracy: 0.0312
# Epoch 10/350
# 32/32 [==============================] - 9s 294ms/step - loss: 1.2368 - accuracy: 0.6328 - val_loss: 4.8604 - val_accuracy: 0.0312
# Epoch 11/350
# 32/32 [==============================] - 10s 296ms/step - loss: 1.0764 - accuracy: 0.6562 - val_loss: 5.0442 - val_accuracy: 0.0156
# Epoch 12/350
# 32/32 [==============================] - 9s 277ms/step - loss: 1.0056 - accuracy: 0.7070 - val_loss: 4.5307 - val_accuracy: 0.0312
# Epoch 13/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.8557 - accuracy: 0.7578 - val_loss: 4.4760 - val_accuracy: 0.0312
# Epoch 14/350
# 32/32 [==============================] - 9s 290ms/step - loss: 0.8194 - accuracy: 0.7500 - val_loss: 4.8204 - val_accuracy: 0.0469
# Epoch 15/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.6639 - accuracy: 0.7852 - val_loss: 5.3902 - val_accuracy: 0.0625
# Epoch 16/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.6327 - accuracy: 0.8359 - val_loss: 4.2752 - val_accuracy: 0.0938
# Epoch 17/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.4864 - accuracy: 0.8594 - val_loss: 4.4028 - val_accuracy: 0.0938
# Epoch 18/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.5158 - accuracy: 0.8281 - val_loss: 3.1546 - val_accuracy: 0.1875
# Epoch 19/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.6450 - accuracy: 0.7969 - val_loss: 2.0649 - val_accuracy: 0.3750
# Epoch 20/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.2448 - accuracy: 0.9219 - val_loss: 1.9413 - val_accuracy: 0.3906
# Epoch 21/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.2959 - accuracy: 0.9023 - val_loss: 1.2007 - val_accuracy: 0.6094
# Epoch 22/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.2863 - accuracy: 0.9062 - val_loss: 2.2870 - val_accuracy: 0.4844
# Epoch 23/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.6634 - accuracy: 0.8359 - val_loss: 1.0802 - val_accuracy: 0.6875
# Epoch 24/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.4427 - accuracy: 0.8789 - val_loss: 1.1473 - val_accuracy: 0.6094
# Epoch 25/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.3794 - accuracy: 0.8984 - val_loss: 1.6116 - val_accuracy: 0.6250
# Epoch 26/350
# 32/32 [==============================] - 9s 290ms/step - loss: 0.3193 - accuracy: 0.9023 - val_loss: 1.2368 - val_accuracy: 0.6719
# Epoch 27/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.3860 - accuracy: 0.9062 - val_loss: 1.7166 - val_accuracy: 0.5781
# Epoch 28/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2205 - accuracy: 0.9297 - val_loss: 1.1514 - val_accuracy: 0.6406
# Epoch 29/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.2608 - accuracy: 0.9258 - val_loss: 1.3113 - val_accuracy: 0.7656
# Epoch 30/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.2491 - accuracy: 0.9336 - val_loss: 0.7316 - val_accuracy: 0.8281
# Epoch 31/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0755 - accuracy: 0.9766 - val_loss: 1.1942 - val_accuracy: 0.7812
# Epoch 32/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2260 - accuracy: 0.9492 - val_loss: 1.7119 - val_accuracy: 0.6562
# Epoch 33/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.2655 - accuracy: 0.9258 - val_loss: 2.2224 - val_accuracy: 0.6406
# Epoch 34/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.1981 - accuracy: 0.9297 - val_loss: 1.5065 - val_accuracy: 0.7031
# Epoch 35/350
# 32/32 [==============================] - 9s 290ms/step - loss: 0.2670 - accuracy: 0.9336 - val_loss: 2.3757 - val_accuracy: 0.6406
# Epoch 36/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0946 - accuracy: 0.9727 - val_loss: 1.1732 - val_accuracy: 0.7344
# Epoch 37/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.1185 - accuracy: 0.9609 - val_loss: 1.9513 - val_accuracy: 0.7344
# Epoch 38/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1472 - accuracy: 0.9570 - val_loss: 1.8983 - val_accuracy: 0.7500
# Epoch 39/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1059 - accuracy: 0.9688 - val_loss: 1.7093 - val_accuracy: 0.7188
# Epoch 40/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.1792 - accuracy: 0.9688 - val_loss: 1.3398 - val_accuracy: 0.7344
# Epoch 41/350
# 32/32 [==============================] - 9s 278ms/step - loss: 0.2268 - accuracy: 0.9297 - val_loss: 1.1555 - val_accuracy: 0.7812
# Epoch 42/350
# 32/32 [==============================] - 10s 293ms/step - loss: 0.1300 - accuracy: 0.9570 - val_loss: 1.0862 - val_accuracy: 0.8125
# Epoch 43/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1792 - accuracy: 0.9609 - val_loss: 1.4596 - val_accuracy: 0.7031
# Epoch 44/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.2735 - accuracy: 0.9336 - val_loss: 2.5383 - val_accuracy: 0.6719
# Epoch 45/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.3738 - accuracy: 0.9180 - val_loss: 1.0221 - val_accuracy: 0.7656
# Epoch 46/350
# 32/32 [==============================] - 9s 289ms/step - loss: 0.2865 - accuracy: 0.9258 - val_loss: 1.4842 - val_accuracy: 0.7344
# Epoch 47/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.3954 - accuracy: 0.8984 - val_loss: 2.3704 - val_accuracy: 0.6406
# Epoch 48/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.3670 - accuracy: 0.9023 - val_loss: 1.0342 - val_accuracy: 0.6875
# Epoch 49/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2245 - accuracy: 0.9453 - val_loss: 1.7310 - val_accuracy: 0.7188
# Epoch 50/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1594 - accuracy: 0.9688 - val_loss: 0.7629 - val_accuracy: 0.8125
# Epoch 51/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0972 - accuracy: 0.9805 - val_loss: 1.7686 - val_accuracy: 0.6719
# Epoch 52/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.1837 - accuracy: 0.9570 - val_loss: 1.6550 - val_accuracy: 0.6875
# Epoch 53/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2637 - accuracy: 0.9219 - val_loss: 2.0596 - val_accuracy: 0.6875
# Epoch 54/350
# 32/32 [==============================] - 9s 288ms/step - loss: 0.2419 - accuracy: 0.9648 - val_loss: 1.8130 - val_accuracy: 0.7188
# Epoch 55/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0564 - accuracy: 0.9805 - val_loss: 0.9433 - val_accuracy: 0.7969
# Epoch 56/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0448 - accuracy: 0.9922 - val_loss: 0.7229 - val_accuracy: 0.8281
# Epoch 57/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0521 - accuracy: 0.9805 - val_loss: 1.4358 - val_accuracy: 0.8438
# Epoch 58/350
# 32/32 [==============================] - 9s 289ms/step - loss: 0.1668 - accuracy: 0.9531 - val_loss: 1.0266 - val_accuracy: 0.8281
# Epoch 59/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0589 - accuracy: 0.9805 - val_loss: 0.8221 - val_accuracy: 0.8750
# Epoch 60/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0591 - accuracy: 0.9805 - val_loss: 1.4515 - val_accuracy: 0.8281
# Epoch 61/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0857 - accuracy: 0.9688 - val_loss: 1.5187 - val_accuracy: 0.7812
# Epoch 62/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.1100 - accuracy: 0.9688 - val_loss: 1.8091 - val_accuracy: 0.7344
# Epoch 63/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.1486 - accuracy: 0.9609 - val_loss: 1.9759 - val_accuracy: 0.7031
# Epoch 64/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1935 - accuracy: 0.9609 - val_loss: 1.1824 - val_accuracy: 0.7344
# Epoch 65/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.1980 - accuracy: 0.9570 - val_loss: 1.6317 - val_accuracy: 0.7656
# Epoch 66/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.1131 - accuracy: 0.9727 - val_loss: 2.0703 - val_accuracy: 0.6562
# Epoch 67/350
# 32/32 [==============================] - 9s 288ms/step - loss: 0.2745 - accuracy: 0.9414 - val_loss: 1.7867 - val_accuracy: 0.7344
# Epoch 68/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1709 - accuracy: 0.9336 - val_loss: 1.2786 - val_accuracy: 0.8281
# Epoch 69/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0472 - accuracy: 0.9805 - val_loss: 1.4806 - val_accuracy: 0.8125
# Epoch 70/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.2818 - accuracy: 0.9609 - val_loss: 1.0184 - val_accuracy: 0.8594
# Epoch 71/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.1399 - accuracy: 0.9727 - val_loss: 1.8024 - val_accuracy: 0.7188
# Epoch 72/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.2710 - accuracy: 0.9609 - val_loss: 1.2150 - val_accuracy: 0.7969
# Epoch 73/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1177 - accuracy: 0.9648 - val_loss: 1.1118 - val_accuracy: 0.7656
# Epoch 74/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0913 - accuracy: 0.9727 - val_loss: 1.7675 - val_accuracy: 0.7188
# Epoch 75/350
# 32/32 [==============================] - 9s 287ms/step - loss: 0.0671 - accuracy: 0.9766 - val_loss: 1.3230 - val_accuracy: 0.8125
# Epoch 76/350
# 32/32 [==============================] - 9s 284ms/step - loss: 0.0525 - accuracy: 0.9844 - val_loss: 1.4420 - val_accuracy: 0.7344
# Epoch 77/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0816 - accuracy: 0.9727 - val_loss: 2.3213 - val_accuracy: 0.6406
# Epoch 78/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0933 - accuracy: 0.9766 - val_loss: 1.7360 - val_accuracy: 0.7031
# Epoch 79/350
# 32/32 [==============================] - 10s 319ms/step - loss: 0.1522 - accuracy: 0.9648 - val_loss: 2.0665 - val_accuracy: 0.7188
# Epoch 80/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.2060 - accuracy: 0.9766 - val_loss: 1.9117 - val_accuracy: 0.7500
# Epoch 81/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0885 - accuracy: 0.9688 - val_loss: 1.5405 - val_accuracy: 0.7656
# Epoch 82/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1474 - accuracy: 0.9727 - val_loss: 1.7467 - val_accuracy: 0.7500
# Epoch 83/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 1.0207 - val_accuracy: 0.7812
# Epoch 84/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0214 - accuracy: 0.9922 - val_loss: 1.7708 - val_accuracy: 0.7344
# Epoch 85/350
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0170 - accuracy: 0.9961 - val_loss: 1.3720 - val_accuracy: 0.7969
# Epoch 86/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.0256 - val_accuracy: 0.8281
# Epoch 87/350
# 32/32 [==============================] - 10s 319ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.1701 - val_accuracy: 0.7656
# Epoch 88/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3588 - val_accuracy: 0.7969
# Epoch 89/350
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.4791 - val_accuracy: 0.8281
# Epoch 90/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4131 - val_accuracy: 0.8125
# Epoch 91/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.1985 - val_accuracy: 0.7969
# Epoch 92/350
# 32/32 [==============================] - 9s 278ms/step - loss: 0.0170 - accuracy: 0.9961 - val_loss: 1.4077 - val_accuracy: 0.7344
# Epoch 93/350
# 32/32 [==============================] - 9s 284ms/step - loss: 0.3447 - accuracy: 0.9688 - val_loss: 2.4037 - val_accuracy: 0.7188
# Epoch 94/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0891 - accuracy: 0.9688 - val_loss: 1.4482 - val_accuracy: 0.7969
# Epoch 95/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.1012 - accuracy: 0.9805 - val_loss: 2.1192 - val_accuracy: 0.7031
# Epoch 96/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.2127 - accuracy: 0.9570 - val_loss: 1.5639 - val_accuracy: 0.7344
# Epoch 97/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2288 - accuracy: 0.9492 - val_loss: 1.7008 - val_accuracy: 0.7500
# Epoch 98/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.2174 - accuracy: 0.9531 - val_loss: 1.4792 - val_accuracy: 0.7188
# Epoch 99/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.3631 - accuracy: 0.9180 - val_loss: 3.2512 - val_accuracy: 0.6094
# Epoch 100/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.3061 - accuracy: 0.9219 - val_loss: 2.1031 - val_accuracy: 0.6562
# Epoch 101/350
# 32/32 [==============================] - 9s 289ms/step - loss: 0.4018 - accuracy: 0.9531 - val_loss: 2.1402 - val_accuracy: 0.6250
# Epoch 102/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.1688 - accuracy: 0.9727 - val_loss: 2.9666 - val_accuracy: 0.5938
# Epoch 103/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1871 - accuracy: 0.9609 - val_loss: 1.5119 - val_accuracy: 0.6719
# Epoch 104/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0729 - accuracy: 0.9727 - val_loss: 1.5659 - val_accuracy: 0.7344
# Epoch 105/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.1804 - accuracy: 0.9609 - val_loss: 2.3595 - val_accuracy: 0.6094
# Epoch 106/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.5152 - accuracy: 0.8906 - val_loss: 1.7662 - val_accuracy: 0.7812
# Epoch 107/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1838 - accuracy: 0.9570 - val_loss: 2.0968 - val_accuracy: 0.6719
# Epoch 108/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0663 - accuracy: 0.9766 - val_loss: 1.5295 - val_accuracy: 0.7969
# Epoch 109/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0496 - accuracy: 0.9844 - val_loss: 2.0202 - val_accuracy: 0.7500
# Epoch 110/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0395 - accuracy: 0.9844 - val_loss: 4.1717 - val_accuracy: 0.6094
# Epoch 111/350
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0412 - accuracy: 0.9883 - val_loss: 1.6687 - val_accuracy: 0.7969
# Epoch 112/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0163 - accuracy: 0.9922 - val_loss: 1.3122 - val_accuracy: 0.8438
# Epoch 113/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0524 - accuracy: 0.9805 - val_loss: 1.5639 - val_accuracy: 0.7656
# Epoch 114/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0182 - accuracy: 0.9922 - val_loss: 1.6169 - val_accuracy: 0.7969
# Epoch 115/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.0343 - accuracy: 0.9844 - val_loss: 1.3057 - val_accuracy: 0.7812
# Epoch 116/350
# 32/32 [==============================] - 9s 286ms/step - loss: 0.0460 - accuracy: 0.9922 - val_loss: 1.5159 - val_accuracy: 0.7500
# Epoch 117/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.1302 - val_accuracy: 0.8438
# Epoch 118/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.1325 - accuracy: 0.9805 - val_loss: 1.1660 - val_accuracy: 0.8281
# Epoch 119/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0391 - accuracy: 0.9961 - val_loss: 1.2979 - val_accuracy: 0.7969
# Epoch 120/350
# 32/32 [==============================] - 9s 285ms/step - loss: 0.0309 - accuracy: 0.9961 - val_loss: 1.4807 - val_accuracy: 0.7969
# Epoch 121/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0369 - accuracy: 0.9883 - val_loss: 1.3199 - val_accuracy: 0.8438
# Epoch 122/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.1813 - accuracy: 0.9688 - val_loss: 2.6897 - val_accuracy: 0.7031
# Epoch 123/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1964 - accuracy: 0.9727 - val_loss: 3.5289 - val_accuracy: 0.6094
# Epoch 124/350
# 32/32 [==============================] - 10s 317ms/step - loss: 0.4475 - accuracy: 0.9609 - val_loss: 1.2873 - val_accuracy: 0.7500
# Epoch 125/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.1581 - accuracy: 0.9648 - val_loss: 1.6647 - val_accuracy: 0.7344
# Epoch 126/350
# 32/32 [==============================] - 9s 285ms/step - loss: 0.0302 - accuracy: 0.9922 - val_loss: 2.3897 - val_accuracy: 0.7344
# Epoch 127/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1247 - accuracy: 0.9766 - val_loss: 1.9727 - val_accuracy: 0.7969
# Epoch 128/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.4057 - accuracy: 0.9258 - val_loss: 1.4839 - val_accuracy: 0.7188
# Epoch 129/350
# 32/32 [==============================] - 10s 320ms/step - loss: 0.2205 - accuracy: 0.9414 - val_loss: 2.4843 - val_accuracy: 0.6250
# Epoch 130/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.2126 - accuracy: 0.9570 - val_loss: 2.5933 - val_accuracy: 0.6719
# Epoch 131/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.1354 - accuracy: 0.9648 - val_loss: 3.0476 - val_accuracy: 0.6094
# Epoch 132/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0287 - accuracy: 0.9883 - val_loss: 1.2253 - val_accuracy: 0.8125
# Epoch 133/350
# 32/32 [==============================] - 11s 332ms/step - loss: 0.0906 - accuracy: 0.9844 - val_loss: 1.6751 - val_accuracy: 0.7969
# Epoch 134/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0422 - accuracy: 0.9844 - val_loss: 2.4586 - val_accuracy: 0.7969
# Epoch 135/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0151 - accuracy: 0.9961 - val_loss: 2.2641 - val_accuracy: 0.7656
# Epoch 136/350
# 32/32 [==============================] - 9s 280ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 1.8330 - val_accuracy: 0.7812
# Epoch 137/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0974 - accuracy: 0.9844 - val_loss: 2.8724 - val_accuracy: 0.7031
# Epoch 138/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1101 - accuracy: 0.9766 - val_loss: 3.4952 - val_accuracy: 0.7031
# Epoch 139/350
# 32/32 [==============================] - 10s 319ms/step - loss: 0.0377 - accuracy: 0.9805 - val_loss: 1.4345 - val_accuracy: 0.7812
# Epoch 140/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0964 - accuracy: 0.9844 - val_loss: 1.7228 - val_accuracy: 0.7188
# Epoch 141/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0305 - accuracy: 0.9883 - val_loss: 1.0482 - val_accuracy: 0.7969
# Epoch 142/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.6742 - val_accuracy: 0.7969
# Epoch 143/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0205 - accuracy: 0.9961 - val_loss: 1.8274 - val_accuracy: 0.7812
# Epoch 144/350
# 32/32 [==============================] - 10s 320ms/step - loss: 0.0426 - accuracy: 0.9883 - val_loss: 2.7475 - val_accuracy: 0.7969
# Epoch 145/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.1096 - accuracy: 0.9766 - val_loss: 1.9291 - val_accuracy: 0.7188
# Epoch 146/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0404 - accuracy: 0.9961 - val_loss: 2.1176 - val_accuracy: 0.6875
# Epoch 147/350
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0080 - accuracy: 0.9961 - val_loss: 1.6828 - val_accuracy: 0.7656
# Epoch 148/350
# 32/32 [==============================] - 10s 319ms/step - loss: 4.2224e-04 - accuracy: 1.0000 - val_loss: 1.6727 - val_accuracy: 0.7969
# Epoch 149/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.5153 - val_accuracy: 0.7812
# Epoch 150/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0054 - accuracy: 0.9961 - val_loss: 1.4188 - val_accuracy: 0.7812
# Epoch 151/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0053 - accuracy: 0.9961 - val_loss: 1.9658 - val_accuracy: 0.7656
# Epoch 152/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1553 - val_accuracy: 0.7812
# Epoch 153/350
# 32/32 [==============================] - 9s 276ms/step - loss: 2.5412e-04 - accuracy: 1.0000 - val_loss: 1.2622 - val_accuracy: 0.7969
# Epoch 154/350
# 32/32 [==============================] - 9s 291ms/step - loss: 5.2489e-04 - accuracy: 1.0000 - val_loss: 1.4307 - val_accuracy: 0.8125
# Epoch 155/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0059 - accuracy: 0.9961 - val_loss: 1.4432 - val_accuracy: 0.8438
# Epoch 156/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.1459 - val_accuracy: 0.8125
# Epoch 157/350
# 32/32 [==============================] - 9s 277ms/step - loss: 1.9420e-04 - accuracy: 1.0000 - val_loss: 1.0392 - val_accuracy: 0.8125
# Epoch 158/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0060 - accuracy: 0.9961 - val_loss: 1.5486 - val_accuracy: 0.8125
# Epoch 159/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0256 - accuracy: 0.9961 - val_loss: 1.4343 - val_accuracy: 0.8125
# Epoch 160/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0298 - accuracy: 0.9883 - val_loss: 1.9848 - val_accuracy: 0.6562
# Epoch 161/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.1796 - accuracy: 0.9688 - val_loss: 1.2007 - val_accuracy: 0.7812
# Epoch 162/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0583 - accuracy: 0.9844 - val_loss: 1.8141 - val_accuracy: 0.6719
# Epoch 163/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0171 - accuracy: 0.9922 - val_loss: 1.3386 - val_accuracy: 0.7656
# Epoch 164/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0706 - accuracy: 0.9883 - val_loss: 2.4770 - val_accuracy: 0.7344
# Epoch 165/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0083 - accuracy: 0.9961 - val_loss: 1.9911 - val_accuracy: 0.7188
# Epoch 166/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0396 - accuracy: 0.9883 - val_loss: 2.4238 - val_accuracy: 0.7344
# Epoch 167/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0122 - accuracy: 0.9922 - val_loss: 1.5559 - val_accuracy: 0.7500
# Epoch 168/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0549 - accuracy: 0.9883 - val_loss: 2.5314 - val_accuracy: 0.7188
# Epoch 169/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0401 - accuracy: 0.9883 - val_loss: 2.9830 - val_accuracy: 0.7812
# Epoch 170/350
# 32/32 [==============================] - 9s 282ms/step - loss: 0.0276 - accuracy: 0.9922 - val_loss: 2.6343 - val_accuracy: 0.7656
# Epoch 171/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0519 - accuracy: 0.9805 - val_loss: 4.6701 - val_accuracy: 0.6406
# Epoch 172/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.1067 - accuracy: 0.9688 - val_loss: 2.3938 - val_accuracy: 0.7656
# Epoch 173/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0715 - accuracy: 0.9844 - val_loss: 1.8651 - val_accuracy: 0.7812
# Epoch 174/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.0426 - accuracy: 0.9844 - val_loss: 2.4418 - val_accuracy: 0.7812
# Epoch 175/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0583 - accuracy: 0.9805 - val_loss: 3.0546 - val_accuracy: 0.7344
# Epoch 176/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.3024 - accuracy: 0.9570 - val_loss: 5.4808 - val_accuracy: 0.5156
# Epoch 177/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.3210 - accuracy: 0.9414 - val_loss: 3.7742 - val_accuracy: 0.6406
# Epoch 178/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.2110 - accuracy: 0.9453 - val_loss: 2.7258 - val_accuracy: 0.6562
# Epoch 179/350
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0475 - accuracy: 0.9883 - val_loss: 1.4031 - val_accuracy: 0.7500
# Epoch 180/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.1232 - accuracy: 0.9883 - val_loss: 2.0580 - val_accuracy: 0.7344
# Epoch 181/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0512 - accuracy: 0.9844 - val_loss: 1.8106 - val_accuracy: 0.7344
# Epoch 182/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0774 - accuracy: 0.9883 - val_loss: 2.1434 - val_accuracy: 0.7344
# Epoch 183/350
# 32/32 [==============================] - 9s 283ms/step - loss: 0.0422 - accuracy: 0.9844 - val_loss: 1.8309 - val_accuracy: 0.7656
# Epoch 184/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0283 - accuracy: 0.9844 - val_loss: 2.6773 - val_accuracy: 0.7344
# Epoch 185/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0091 - accuracy: 0.9961 - val_loss: 1.8008 - val_accuracy: 0.8750
# Epoch 186/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.1146 - accuracy: 0.9805 - val_loss: 2.0900 - val_accuracy: 0.7969
# Epoch 187/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.0379 - accuracy: 0.9883 - val_loss: 1.6774 - val_accuracy: 0.7656
# Epoch 188/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0374 - accuracy: 0.9961 - val_loss: 2.0500 - val_accuracy: 0.8125
# Epoch 189/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0161 - accuracy: 0.9922 - val_loss: 1.6344 - val_accuracy: 0.8594
# Epoch 190/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0752 - accuracy: 0.9961 - val_loss: 1.5807 - val_accuracy: 0.8750
# Epoch 191/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.0291 - accuracy: 0.9961 - val_loss: 2.0247 - val_accuracy: 0.8281
# Epoch 192/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.1397 - accuracy: 0.9531 - val_loss: 3.3757 - val_accuracy: 0.7031
# Epoch 193/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1777 - accuracy: 0.9766 - val_loss: 2.3773 - val_accuracy: 0.7031
# Epoch 194/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.1623 - accuracy: 0.9570 - val_loss: 2.4630 - val_accuracy: 0.7344
# Epoch 195/350
# 32/32 [==============================] - 9s 281ms/step - loss: 0.0300 - accuracy: 0.9922 - val_loss: 1.9187 - val_accuracy: 0.7656
# Epoch 196/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.1152 - accuracy: 0.9766 - val_loss: 3.2596 - val_accuracy: 0.6562
# Epoch 197/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.1736 - accuracy: 0.9766 - val_loss: 2.7531 - val_accuracy: 0.7188
# Epoch 198/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0681 - accuracy: 0.9922 - val_loss: 2.9128 - val_accuracy: 0.7188
# Epoch 199/350
# 32/32 [==============================] - 9s 282ms/step - loss: 0.1983 - accuracy: 0.9609 - val_loss: 2.4031 - val_accuracy: 0.7969
# Epoch 200/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.0868 - accuracy: 0.9844 - val_loss: 2.1626 - val_accuracy: 0.7188
# Epoch 201/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0189 - accuracy: 0.9961 - val_loss: 1.6049 - val_accuracy: 0.8281
# Epoch 202/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0658 - accuracy: 0.9766 - val_loss: 2.2659 - val_accuracy: 0.7344
# Epoch 203/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.2243 - accuracy: 0.9727 - val_loss: 1.9585 - val_accuracy: 0.7656
# Epoch 204/350
# 32/32 [==============================] - 9s 277ms/step - loss: 0.0401 - accuracy: 0.9922 - val_loss: 1.3992 - val_accuracy: 0.7969
# Epoch 205/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0236 - accuracy: 0.9922 - val_loss: 1.4598 - val_accuracy: 0.8125
# Epoch 206/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0070 - accuracy: 0.9961 - val_loss: 1.0428 - val_accuracy: 0.8594
# Epoch 207/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1186 - val_accuracy: 0.8750
# Epoch 208/350
# 32/32 [==============================] - 9s 281ms/step - loss: 7.3135e-04 - accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.8750
# Epoch 209/350
# 32/32 [==============================] - 9s 278ms/step - loss: 0.0172 - accuracy: 0.9922 - val_loss: 0.7647 - val_accuracy: 0.8438
# Epoch 210/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7591 - val_accuracy: 0.8438
# Epoch 211/350
# 32/32 [==============================] - 10s 299ms/step - loss: 4.7972e-04 - accuracy: 1.0000 - val_loss: 0.7765 - val_accuracy: 0.8594
# Epoch 212/350
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5849 - val_accuracy: 0.8594
# Epoch 213/350
# 32/32 [==============================] - 9s 279ms/step - loss: 8.0940e-05 - accuracy: 1.0000 - val_loss: 0.5772 - val_accuracy: 0.8438
# Epoch 214/350
# 32/32 [==============================] - 9s 283ms/step - loss: 1.0059e-04 - accuracy: 1.0000 - val_loss: 0.9345 - val_accuracy: 0.8438
# Epoch 215/350
# 32/32 [==============================] - 10s 299ms/step - loss: 5.3738e-05 - accuracy: 1.0000 - val_loss: 0.8648 - val_accuracy: 0.8438
# Epoch 216/350
# 32/32 [==============================] - 10s 295ms/step - loss: 6.9435e-05 - accuracy: 1.0000 - val_loss: 0.6241 - val_accuracy: 0.8438
# Epoch 217/350
# 32/32 [==============================] - 10s 295ms/step - loss: 9.5709e-05 - accuracy: 1.0000 - val_loss: 1.0395 - val_accuracy: 0.8438
# Epoch 218/350
# 32/32 [==============================] - 9s 276ms/step - loss: 1.5866e-04 - accuracy: 1.0000 - val_loss: 0.6900 - val_accuracy: 0.8750
# Epoch 219/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0047 - accuracy: 0.9961 - val_loss: 0.9646 - val_accuracy: 0.8750
# Epoch 220/350
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 1.4116 - val_accuracy: 0.7969
# Epoch 221/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.1425 - accuracy: 0.9961 - val_loss: 1.4573 - val_accuracy: 0.7812
# Epoch 222/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.0587 - accuracy: 0.9805 - val_loss: 1.2871 - val_accuracy: 0.8125
# Epoch 223/350
# 32/32 [==============================] - 10s 292ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.6154 - val_accuracy: 0.8594
# Epoch 224/350
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.6914 - val_accuracy: 0.8906
# Epoch 225/350
# 32/32 [==============================] - 10s 300ms/step - loss: 9.3224e-04 - accuracy: 1.0000 - val_loss: 0.9680 - val_accuracy: 0.9062
# Epoch 226/350
# 32/32 [==============================] - 10s 322ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1811 - val_accuracy: 0.8906
# Epoch 227/350
# 32/32 [==============================] - 9s 277ms/step - loss: 2.8142e-04 - accuracy: 1.0000 - val_loss: 1.2038 - val_accuracy: 0.8750
# Epoch 228/350
# 32/32 [==============================] - 11s 334ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.4391 - val_accuracy: 0.8438
# Epoch 229/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1801 - val_accuracy: 0.8594
# Epoch 230/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.9325 - val_accuracy: 0.8594
# Epoch 231/350
# 32/32 [==============================] - 9s 282ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6748 - val_accuracy: 0.8750
# Epoch 232/350
# 32/32 [==============================] - 10s 303ms/step - loss: 4.1706e-05 - accuracy: 1.0000 - val_loss: 1.2763 - val_accuracy: 0.7969
# Epoch 233/350
# 32/32 [==============================] - 10s 301ms/step - loss: 9.6440e-04 - accuracy: 1.0000 - val_loss: 0.7386 - val_accuracy: 0.8438
# Epoch 234/350
# 32/32 [==============================] - 10s 297ms/step - loss: 2.7556e-05 - accuracy: 1.0000 - val_loss: 0.6886 - val_accuracy: 0.8906
# Epoch 235/350
# 32/32 [==============================] - 10s 318ms/step - loss: 2.1366e-04 - accuracy: 1.0000 - val_loss: 0.8159 - val_accuracy: 0.8594
# Epoch 236/350
# 32/32 [==============================] - 9s 276ms/step - loss: 1.0632e-04 - accuracy: 1.0000 - val_loss: 0.8384 - val_accuracy: 0.8906
# Epoch 237/350
# 32/32 [==============================] - 10s 290ms/step - loss: 1.5164e-04 - accuracy: 1.0000 - val_loss: 0.9737 - val_accuracy: 0.8594
# Epoch 238/350
# 32/32 [==============================] - 10s 295ms/step - loss: 9.8180e-05 - accuracy: 1.0000 - val_loss: 0.7109 - val_accuracy: 0.9062
# Epoch 239/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.9627 - val_accuracy: 0.8594
# Epoch 240/350
# 32/32 [==============================] - 10s 297ms/step - loss: 9.4669e-04 - accuracy: 1.0000 - val_loss: 0.9391 - val_accuracy: 0.8750
# Epoch 241/350
# 32/32 [==============================] - 9s 280ms/step - loss: 5.9369e-05 - accuracy: 1.0000 - val_loss: 0.8821 - val_accuracy: 0.8594
# Epoch 242/350
# 32/32 [==============================] - 10s 301ms/step - loss: 1.0365e-05 - accuracy: 1.0000 - val_loss: 0.7917 - val_accuracy: 0.8906
# Epoch 243/350
# 32/32 [==============================] - 10s 295ms/step - loss: 3.0445e-05 - accuracy: 1.0000 - val_loss: 0.9606 - val_accuracy: 0.8750
# Epoch 244/350
# 32/32 [==============================] - 10s 297ms/step - loss: 3.1207e-04 - accuracy: 1.0000 - val_loss: 0.9928 - val_accuracy: 0.8594
# Epoch 245/350
# 32/32 [==============================] - 9s 280ms/step - loss: 6.1702e-05 - accuracy: 1.0000 - val_loss: 1.1254 - val_accuracy: 0.8906
# Epoch 246/350
# 32/32 [==============================] - 9s 291ms/step - loss: 3.3884e-04 - accuracy: 1.0000 - val_loss: 0.7702 - val_accuracy: 0.8750
# Epoch 247/350
# 32/32 [==============================] - 10s 297ms/step - loss: 6.1231e-06 - accuracy: 1.0000 - val_loss: 0.7423 - val_accuracy: 0.9219
# Epoch 248/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0040 - accuracy: 0.9961 - val_loss: 0.7503 - val_accuracy: 0.8906
# Epoch 249/350
# 32/32 [==============================] - 10s 319ms/step - loss: 0.0992 - accuracy: 0.9883 - val_loss: 1.1249 - val_accuracy: 0.8594
# Epoch 250/350
# 32/32 [==============================] - 9s 284ms/step - loss: 0.0375 - accuracy: 0.9922 - val_loss: 2.2572 - val_accuracy: 0.6719
# Epoch 251/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0794 - accuracy: 0.9844 - val_loss: 1.7874 - val_accuracy: 0.8125
# Epoch 252/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0228 - accuracy: 0.9961 - val_loss: 1.1622 - val_accuracy: 0.7969
# Epoch 253/350
# 32/32 [==============================] - 10s 322ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0891 - val_accuracy: 0.8438
# Epoch 254/350
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.8821 - val_accuracy: 0.8125
# Epoch 255/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0546 - accuracy: 0.9922 - val_loss: 0.4768 - val_accuracy: 0.9062
# Epoch 256/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0093 - accuracy: 0.9961 - val_loss: 1.2341 - val_accuracy: 0.8438
# Epoch 257/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.2435 - accuracy: 0.9609 - val_loss: 4.4416 - val_accuracy: 0.7031
# Epoch 258/350
# 32/32 [==============================] - 9s 282ms/step - loss: 0.0906 - accuracy: 0.9805 - val_loss: 2.8699 - val_accuracy: 0.6250
# Epoch 259/350
# 32/32 [==============================] - 9s 289ms/step - loss: 0.2502 - accuracy: 0.9258 - val_loss: 5.0286 - val_accuracy: 0.6406
# Epoch 260/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.6448 - accuracy: 0.8789 - val_loss: 4.4389 - val_accuracy: 0.6406
# Epoch 261/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.5933 - accuracy: 0.9180 - val_loss: 7.5159 - val_accuracy: 0.3125
# Epoch 262/350
# 32/32 [==============================] - 9s 283ms/step - loss: 0.1854 - accuracy: 0.9648 - val_loss: 2.0927 - val_accuracy: 0.6406
# Epoch 263/350
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0630 - accuracy: 0.9688 - val_loss: 1.9544 - val_accuracy: 0.7344
# Epoch 264/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0779 - accuracy: 0.9844 - val_loss: 1.6635 - val_accuracy: 0.8125
# Epoch 265/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0099 - accuracy: 0.9961 - val_loss: 1.1434 - val_accuracy: 0.8750
# Epoch 266/350
# 32/32 [==============================] - 9s 288ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0444 - val_accuracy: 0.8594
# Epoch 267/350
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0513 - accuracy: 0.9922 - val_loss: 2.1095 - val_accuracy: 0.7812
# Epoch 268/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0349 - accuracy: 0.9883 - val_loss: 0.8387 - val_accuracy: 0.8438
# Epoch 269/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.3709 - val_accuracy: 0.8125
# Epoch 270/350
# 32/32 [==============================] - 10s 318ms/step - loss: 7.8521e-04 - accuracy: 1.0000 - val_loss: 1.3995 - val_accuracy: 0.8438
# Epoch 271/350
# 32/32 [==============================] - 9s 285ms/step - loss: 6.1292e-04 - accuracy: 1.0000 - val_loss: 1.0628 - val_accuracy: 0.8906
# Epoch 272/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0053 - accuracy: 0.9961 - val_loss: 0.9226 - val_accuracy: 0.8750
# Epoch 273/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0385 - accuracy: 0.9922 - val_loss: 1.2292 - val_accuracy: 0.8906
# Epoch 274/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.9303 - val_accuracy: 0.7500
# Epoch 275/350
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0261 - accuracy: 0.9961 - val_loss: 1.6382 - val_accuracy: 0.8125
# Epoch 276/350
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0377 - accuracy: 0.9961 - val_loss: 0.5902 - val_accuracy: 0.9062
# Epoch 277/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0301 - accuracy: 0.9883 - val_loss: 6.2974 - val_accuracy: 0.6250
# Epoch 278/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0509 - accuracy: 0.9844 - val_loss: 2.5556 - val_accuracy: 0.6719
# Epoch 279/350
# 32/32 [==============================] - 9s 275ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.1915 - val_accuracy: 0.7500
# Epoch 280/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0923 - accuracy: 0.9727 - val_loss: 2.0322 - val_accuracy: 0.7812
# Epoch 281/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1169 - accuracy: 0.9844 - val_loss: 1.2718 - val_accuracy: 0.8281
# Epoch 282/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.4099 - val_accuracy: 0.8281
# Epoch 283/350
# 32/32 [==============================] - 9s 281ms/step - loss: 0.1273 - accuracy: 0.9844 - val_loss: 2.0880 - val_accuracy: 0.7500
# Epoch 284/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0227 - accuracy: 0.9961 - val_loss: 1.7022 - val_accuracy: 0.8438
# Epoch 285/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0540 - accuracy: 0.9844 - val_loss: 2.1547 - val_accuracy: 0.7812
# Epoch 286/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0592 - accuracy: 0.9805 - val_loss: 2.5431 - val_accuracy: 0.7812
# Epoch 287/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.0773 - accuracy: 0.9844 - val_loss: 2.7305 - val_accuracy: 0.7969
# Epoch 288/350
# 32/32 [==============================] - 9s 283ms/step - loss: 0.0707 - accuracy: 0.9844 - val_loss: 2.7190 - val_accuracy: 0.7656
# Epoch 289/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.1363 - accuracy: 0.9844 - val_loss: 3.0649 - val_accuracy: 0.6562
# Epoch 290/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.1169 - accuracy: 0.9844 - val_loss: 5.6730 - val_accuracy: 0.6250
# Epoch 291/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.1992 - accuracy: 0.9688 - val_loss: 4.6810 - val_accuracy: 0.5469
# Epoch 292/350
# 32/32 [==============================] - 9s 279ms/step - loss: 0.1221 - accuracy: 0.9766 - val_loss: 1.9286 - val_accuracy: 0.7344
# Epoch 293/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.1158 - accuracy: 0.9727 - val_loss: 2.0632 - val_accuracy: 0.7031
# Epoch 294/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0772 - accuracy: 0.9766 - val_loss: 2.3534 - val_accuracy: 0.7969
# Epoch 295/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0708 - accuracy: 0.9844 - val_loss: 5.5161 - val_accuracy: 0.6875
# Epoch 296/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.2117 - accuracy: 0.9688 - val_loss: 4.2552 - val_accuracy: 0.5781
# Epoch 297/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.2677 - accuracy: 0.9727 - val_loss: 2.1930 - val_accuracy: 0.7344
# Epoch 298/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0624 - accuracy: 0.9844 - val_loss: 2.9097 - val_accuracy: 0.6719
# Epoch 299/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0350 - accuracy: 0.9883 - val_loss: 1.8319 - val_accuracy: 0.8125
# Epoch 300/350
# 32/32 [==============================] - 9s 279ms/step - loss: 0.0077 - accuracy: 0.9961 - val_loss: 1.7151 - val_accuracy: 0.8281
# Epoch 301/350
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 1.4520 - val_accuracy: 0.8125
# Epoch 302/350
# 32/32 [==============================] - 9s 293ms/step - loss: 9.3851e-04 - accuracy: 1.0000 - val_loss: 1.3270 - val_accuracy: 0.7656
# Epoch 303/350
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.7997 - val_accuracy: 0.8125
# Epoch 304/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.0073 - accuracy: 0.9922 - val_loss: 1.4235 - val_accuracy: 0.7812
# Epoch 305/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0058 - accuracy: 0.9961 - val_loss: 1.3359 - val_accuracy: 0.8750
# Epoch 306/350
# 32/32 [==============================] - 9s 288ms/step - loss: 0.0069 - accuracy: 0.9961 - val_loss: 0.9240 - val_accuracy: 0.8750
# Epoch 307/350
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0187 - accuracy: 0.9961 - val_loss: 1.8379 - val_accuracy: 0.8125
# Epoch 308/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0537 - accuracy: 0.9922 - val_loss: 1.4917 - val_accuracy: 0.8281
# Epoch 309/350
# 32/32 [==============================] - 9s 280ms/step - loss: 7.3401e-04 - accuracy: 1.0000 - val_loss: 1.3882 - val_accuracy: 0.8438
# Epoch 310/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.0488 - accuracy: 0.9961 - val_loss: 1.7346 - val_accuracy: 0.8438
# Epoch 311/350
# 32/32 [==============================] - 9s 289ms/step - loss: 0.1822 - accuracy: 0.9844 - val_loss: 1.4449 - val_accuracy: 0.8594
# Epoch 312/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0811 - accuracy: 0.9883 - val_loss: 5.8818 - val_accuracy: 0.5156
# Epoch 313/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1722 - accuracy: 0.9844 - val_loss: 2.2038 - val_accuracy: 0.7500
# Epoch 314/350
# 32/32 [==============================] - 10s 318ms/step - loss: 0.0056 - accuracy: 0.9961 - val_loss: 1.1624 - val_accuracy: 0.7969
# Epoch 315/350
# 32/32 [==============================] - 9s 281ms/step - loss: 0.0178 - accuracy: 0.9961 - val_loss: 1.9086 - val_accuracy: 0.7031
# Epoch 316/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0536 - accuracy: 0.9883 - val_loss: 2.2788 - val_accuracy: 0.6875
# Epoch 317/350
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0336 - accuracy: 0.9961 - val_loss: 2.2229 - val_accuracy: 0.7969
# Epoch 318/350
# 32/32 [==============================] - 10s 324ms/step - loss: 4.1786e-04 - accuracy: 1.0000 - val_loss: 2.2067 - val_accuracy: 0.7969
# Epoch 319/350
# 32/32 [==============================] - 9s 277ms/step - loss: 3.5307e-04 - accuracy: 1.0000 - val_loss: 1.3794 - val_accuracy: 0.8281
# Epoch 320/350
# 32/32 [==============================] - 9s 280ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.4502 - val_accuracy: 0.7812
# Epoch 321/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0590 - accuracy: 0.9922 - val_loss: 2.9262 - val_accuracy: 0.6875
# Epoch 322/350
# 32/32 [==============================] - 9s 294ms/step - loss: 0.0084 - accuracy: 0.9961 - val_loss: 1.4748 - val_accuracy: 0.8281
# Epoch 323/350
# 32/32 [==============================] - 9s 284ms/step - loss: 2.7649e-04 - accuracy: 1.0000 - val_loss: 1.1998 - val_accuracy: 0.8281
# Epoch 324/350
# 32/32 [==============================] - 9s 287ms/step - loss: 0.0035 - accuracy: 0.9961 - val_loss: 1.7735 - val_accuracy: 0.8594
# Epoch 325/350
# 32/32 [==============================] - 9s 294ms/step - loss: 2.7635e-04 - accuracy: 1.0000 - val_loss: 1.8619 - val_accuracy: 0.8281
# Epoch 326/350
# 32/32 [==============================] - 9s 294ms/step - loss: 7.8843e-06 - accuracy: 1.0000 - val_loss: 1.3205 - val_accuracy: 0.8438
# Epoch 327/350
# 32/32 [==============================] - 9s 292ms/step - loss: 8.2193e-05 - accuracy: 1.0000 - val_loss: 1.4436 - val_accuracy: 0.8438
# Epoch 328/350
# 32/32 [==============================] - 9s 276ms/step - loss: 1.9616e-04 - accuracy: 1.0000 - val_loss: 1.2073 - val_accuracy: 0.8125
# Epoch 329/350
# 32/32 [==============================] - 9s 292ms/step - loss: 1.3407e-04 - accuracy: 1.0000 - val_loss: 1.0639 - val_accuracy: 0.8906
# Epoch 330/350
# 32/32 [==============================] - 10s 297ms/step - loss: 5.7104e-06 - accuracy: 1.0000 - val_loss: 0.9170 - val_accuracy: 0.8438
# Epoch 331/350
# 32/32 [==============================] - 9s 291ms/step - loss: 3.1757e-05 - accuracy: 1.0000 - val_loss: 1.5924 - val_accuracy: 0.8281
# Epoch 332/350
# 32/32 [==============================] - 9s 277ms/step - loss: 7.0009e-05 - accuracy: 1.0000 - val_loss: 1.5676 - val_accuracy: 0.8594
# Epoch 333/350
# 32/32 [==============================] - 10s 293ms/step - loss: 4.4039e-06 - accuracy: 1.0000 - val_loss: 1.1725 - val_accuracy: 0.8594
# Epoch 334/350
# 32/32 [==============================] - 10s 296ms/step - loss: 9.3679e-04 - accuracy: 1.0000 - val_loss: 1.4912 - val_accuracy: 0.8594
# Epoch 335/350
# 32/32 [==============================] - 9s 294ms/step - loss: 1.9052e-05 - accuracy: 1.0000 - val_loss: 1.2498 - val_accuracy: 0.8438
# Epoch 336/350
# 32/32 [==============================] - 9s 287ms/step - loss: 4.9725e-06 - accuracy: 1.0000 - val_loss: 1.8434 - val_accuracy: 0.8125
# Epoch 337/350
# 32/32 [==============================] - 9s 288ms/step - loss: 4.5436e-06 - accuracy: 1.0000 - val_loss: 1.3198 - val_accuracy: 0.8750
# Epoch 338/350
# 32/32 [==============================] - 9s 291ms/step - loss: 4.6969e-04 - accuracy: 1.0000 - val_loss: 1.3019 - val_accuracy: 0.8438
# Epoch 339/350
# 32/32 [==============================] - 9s 293ms/step - loss: 4.3017e-05 - accuracy: 1.0000 - val_loss: 1.2372 - val_accuracy: 0.8906
# Epoch 340/350
# 32/32 [==============================] - 10s 295ms/step - loss: 4.5218e-04 - accuracy: 1.0000 - val_loss: 1.9663 - val_accuracy: 0.8281
# Epoch 341/350
# 32/32 [==============================] - 9s 276ms/step - loss: 8.8433e-04 - accuracy: 1.0000 - val_loss: 1.0096 - val_accuracy: 0.8438
# Epoch 342/350
# 32/32 [==============================] - 9s 289ms/step - loss: 5.2159e-06 - accuracy: 1.0000 - val_loss: 1.1921 - val_accuracy: 0.7969
# Epoch 343/350
# 32/32 [==============================] - 10s 296ms/step - loss: 1.2884e-04 - accuracy: 1.0000 - val_loss: 1.0049 - val_accuracy: 0.8750
# Epoch 344/350
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0181 - accuracy: 0.9961 - val_loss: 1.4613 - val_accuracy: 0.7969
# Epoch 345/350
# 32/32 [==============================] - 9s 293ms/step - loss: 0.0178 - accuracy: 0.9961 - val_loss: 1.4432 - val_accuracy: 0.8125
# Epoch 346/350
# 32/32 [==============================] - 9s 276ms/step - loss: 0.1207 - accuracy: 0.9883 - val_loss: 1.6422 - val_accuracy: 0.7500
# Epoch 347/350
# 32/32 [==============================] - 9s 281ms/step - loss: 0.2007 - accuracy: 0.9727 - val_loss: 2.3449 - val_accuracy: 0.7188
# Epoch 348/350
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0961 - accuracy: 0.9805 - val_loss: 3.2623 - val_accuracy: 0.7031
# Epoch 349/350
# 32/32 [==============================] - 10s 295ms/step - loss: 0.1631 - accuracy: 0.9688 - val_loss: 2.8309 - val_accuracy: 0.7500
# Epoch 350/350
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0098 - accuracy: 0.9922 - val_loss: 2.4196 - val_accuracy: 0.8281
# 2/2 [==============================] - 6s 17ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Сверточный классификатор
# Класс: 001                  100% сеть отнесла к классу 001                  - ВЕРНО :-)
# Класс: 002                  100% сеть отнесла к классу 047                  - НЕВЕРНО :-(
# Класс: 003                  100% сеть отнесла к классу 003                  - ВЕРНО :-)
# Класс: 004                  100% сеть отнесла к классу 004                  - ВЕРНО :-)
# Класс: 005                  100% сеть отнесла к классу 005                  - ВЕРНО :-)
# Класс: 006                  100% сеть отнесла к классу 006                  - ВЕРНО :-)
# Класс: 007                  100% сеть отнесла к классу 007                  - ВЕРНО :-)
# Класс: 008                  100% сеть отнесла к классу 021                  - НЕВЕРНО :-(
# Класс: 009                  100% сеть отнесла к классу 029                  - НЕВЕРНО :-(
# Класс: 010                  100% сеть отнесла к классу 010                  - ВЕРНО :-)
# Класс: 011                  100% сеть отнесла к классу 011                  - ВЕРНО :-)
# Класс: 012                  100% сеть отнесла к классу 012                  - ВЕРНО :-)
# Класс: 013                  100% сеть отнесла к классу 013                  - ВЕРНО :-)
# Класс: 014                  100% сеть отнесла к классу 014                  - ВЕРНО :-)
# Класс: 015                  100% сеть отнесла к классу 015                  - ВЕРНО :-)
# Класс: 016                  100% сеть отнесла к классу 016                  - ВЕРНО :-)
# Класс: 017                  100% сеть отнесла к классу 021                  - НЕВЕРНО :-(
# Класс: 018                  100% сеть отнесла к классу 018                  - ВЕРНО :-)
# Класс: 019                  100% сеть отнесла к классу 019                  - ВЕРНО :-)
# Класс: 020                  100% сеть отнесла к классу 020                  - ВЕРНО :-)
# Класс: 021                  100% сеть отнесла к классу 021                  - ВЕРНО :-)
# Класс: 022                  100% сеть отнесла к классу 022                  - ВЕРНО :-)
# Класс: 023                  100% сеть отнесла к классу 023                  - ВЕРНО :-)
# Класс: 024                  100% сеть отнесла к классу 024                  - ВЕРНО :-)
# Класс: 025                  100% сеть отнесла к классу 025                  - ВЕРНО :-)
# Класс: 026                  100% сеть отнесла к классу 026                  - ВЕРНО :-)
# Класс: 027                  100% сеть отнесла к классу 027                  - ВЕРНО :-)
# Класс: 028                  100% сеть отнесла к классу 028                  - ВЕРНО :-)
# Класс: 029                  100% сеть отнесла к классу 029                  - ВЕРНО :-)
# Класс: 030                  100% сеть отнесла к классу 030                  - ВЕРНО :-)
# Класс: 031                  100% сеть отнесла к классу 031                  - ВЕРНО :-)
# Класс: 032                  100% сеть отнесла к классу 032                  - ВЕРНО :-)
# Класс: 033                  100% сеть отнесла к классу 033                  - ВЕРНО :-)
# Класс: 034                  100% сеть отнесла к классу 034                  - ВЕРНО :-)
# Класс: 035                  100% сеть отнесла к классу 035                  - ВЕРНО :-)
# Класс: 036                  100% сеть отнесла к классу 036                  - ВЕРНО :-)
# Класс: 037                  100% сеть отнесла к классу 037                  - ВЕРНО :-)
# Класс: 038                  100% сеть отнесла к классу 038                  - ВЕРНО :-)
# Класс: 039                  100% сеть отнесла к классу 039                  - ВЕРНО :-)
# Класс: 040                  100% сеть отнесла к классу 040                  - ВЕРНО :-)
# Класс: 041                  100% сеть отнесла к классу 041                  - ВЕРНО :-)
# Класс: 042                  100% сеть отнесла к классу 042                  - ВЕРНО :-)
# Класс: 043                  100% сеть отнесла к классу 043                  - ВЕРНО :-)
# Класс: 044                  100% сеть отнесла к классу 042                  - НЕВЕРНО :-(
# Класс: 045                  100% сеть отнесла к классу 057                  - НЕВЕРНО :-(
# Класс: 046                  100% сеть отнесла к классу 046                  - ВЕРНО :-)
# Класс: 047                  100% сеть отнесла к классу 047                  - ВЕРНО :-)
# Класс: 048                  100% сеть отнесла к классу 053                  - НЕВЕРНО :-(
# Класс: 049                  100% сеть отнесла к классу 049                  - ВЕРНО :-)
# Класс: 050                  100% сеть отнесла к классу 050                  - ВЕРНО :-)
# Класс: 051                  100% сеть отнесла к классу 051                  - ВЕРНО :-)
# Класс: 052                  100% сеть отнесла к классу 052                  - ВЕРНО :-)
# Класс: 053                  100% сеть отнесла к классу 064                  - НЕВЕРНО :-(
# Класс: 054                  100% сеть отнесла к классу 054                  - ВЕРНО :-)
# Класс: 055                  100% сеть отнесла к классу 064                  - НЕВЕРНО :-(
# Класс: 056                  100% сеть отнесла к классу 056                  - ВЕРНО :-)
# Класс: 057                  100% сеть отнесла к классу 057                  - ВЕРНО :-)
# Класс: 058                  100% сеть отнесла к классу 058                  - ВЕРНО :-)
# Класс: 059                  100% сеть отнесла к классу 059                  - ВЕРНО :-)
# Класс: 060                  100% сеть отнесла к классу 060                  - ВЕРНО :-)
# Класс: 061                  100% сеть отнесла к классу 061                  - ВЕРНО :-)
# Класс: 062                  100% сеть отнесла к классу 062                  - ВЕРНО :-)
# Класс: 063                  100% сеть отнесла к классу 036                  - НЕВЕРНО :-(
# Класс: 064                  100% сеть отнесла к классу 064                  - ВЕРНО :-)
#
# Средняя точность распознавания:  84%
