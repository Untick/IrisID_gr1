# %% [markdown]
# <a href="https://colab.research.google.com/github/Untick/IrisID_gr1/blob/Sergey-Kim-folder/Sergey%20Kim/%D0%A0%D0%B0%D0%B4%D1%83%D0%B6%D0%BA%D0%B0_%D0%9A%D0%B8%D0%BC_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Идентификация пациента по радужке. Опыт 3

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Материалы и методы
# https://docs.google.com/spreadsheets/d/1vLLVmp67P1sBHKC1HEHnqmWkoZ_9zf_eg27RZj0Xolk/edit#gid=0

# %% [markdown]
# Импорт библиотек и данных

# %%
# Работа с массивами
import numpy as np

# Генератор аугментированных изображений
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Основа для создания последовательной модели
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# Оптимизатор
from tensorflow.keras.optimizers import Adam

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Подключение модуля для загрузки данных из облака
import gdown

# Инструменты для работы с файлами
import os

# Отрисовка графиков
import matplotlib.pyplot as plt

# Библиотека для Computer vision
import cv2

import math
from google.colab.patches import cv2_imshow

# Рисование графиков в ячейках Colab
# %matplotlib inline

# %%
# Задание гиперпараметров
TRAIN_PATH = '/content/iris'      # Папка для обучающего набора данных
TEST_PATH = '/content/iris_test'  # Папка для тестового набора данных

TEST_SPLIT          = 0.2                   # Доля тестовых данных в общем наборе
VAL_SPLIT           = 0.2                   # Доля проверочной выборки в обучающем наборе

IMG_WIDTH           = 192                   # Ширина изображения для нейросети
IMG_HEIGHT          = 144                   # Высота изображения для нейросети
IMG_CHANNELS        = 3                     # Количество каналов (для RGB равно 3, для Grey равно 1)

# Параметры аугментации
ROTATION_RANGE      = 8                     # Пределы поворота
WIDTH_SHIFT_RANGE   = 0.10                  # Пределы сдвига по горизонтали
HEIGHT_SHIFT_RANGE  = 0.10                  # Пределы сдвига по вертикали
ZOOM_RANGE          = 0.10                  # Пределы увеличения/уменьшения
BRIGHTNESS_RANGE    = (0.9, 1.1)            # Пределы изменения яркости
HORIZONTAL_FLIP     = False                 # Горизонтальное отражение разрешено

EPOCHS              = 330                   # Число эпох обучения
BATCH_SIZE          = 8                     # Размер батча для обучения модели
OPTIMIZER           = Adam(0.0001)          # Оптимизатор

# %% [markdown]
# Загрузка zip-архива и изучение структуры материала

# %%
# Загрузка zip-архива с датасетом из облака на диск виртуальной машины colab
gdown.download('https://drive.google.com/uc?id=19ZzpBgbCDVdSgy9joK54wXt9-yURQGtM', None, quiet=True)
# Out:
# 'iris.zip'

# %%
# Очистка данных от прошлого запуска (если есть)
# !rm -rf {TRAIN_PATH} {TEST_PATH}

# Разархивация датасета в директорию данных
# !unzip -qo "iris.zip" -d {TRAIN_PATH}

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(TRAIN_PATH))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 64, метки классов: ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015', '016', '017', '018', '019', '020', '021', '022', '023', '024', '025', '026', '027', '028', '029', '030', '031', '032', '033', '034', '035', '036', '037', '038', '039', '040', '041', '042', '043', '044', '045', '046', '047', '048', '049', '050', '051', '052', '053', '054', '055', '056', '057', '058', '059', '060', '061', '062', '063', '064']

# %%
# Перенос файлов для теста в отдельное дерево папок, расчет размеров наборов данных

os.mkdir(TEST_PATH)                                        # Создание папки для тестовых данных
train_count = 0
test_count = 0

for class_name in CLASS_LIST:                              # Для всех классов по порядку номеров (их меток)
    class_path = f'{TRAIN_PATH}/{class_name}'              # Формирование полного пути к папке с изображениями класса
    test_path = f'{TEST_PATH}/{class_name}'                # Полный путь для тестовых данных класса
    class_files = os.listdir(class_path)                   # Получение списка имен файлов с изображениями текущего класса
    class_file_count = len(class_files)                    # Получение общего числа файлов класса
    os.mkdir(test_path)                                    # Создание подпапки класса для тестовых данных
    test_file_count = int(class_file_count * TEST_SPLIT)   # Определение числа тестовых файлов для класса
    test_files = class_files[-test_file_count:]            # Выделение файлов для теста от конца списка
    for f in test_files:                                   # Перемещение тестовых файлов в папку для теста
        os.rename(f'{class_path}/{f}', f'{test_path}/{f}')
    train_count += class_file_count                        # Увеличение общего счетчика файлов обучающего набора
    test_count += test_file_count                          # Увеличение общего счетчика файлов тестового набора

    print(f'Размер класса {class_name}: {class_file_count} фото, для теста выделено файлов: {test_file_count}')

print(f'Общий размер базы: {train_count}, выделено для обучения: {train_count - test_count}, для теста: {test_count}')
# Out:
# Размер класса 001: 6 фото, для теста выделено файлов: 1
# Размер класса 002: 6 фото, для теста выделено файлов: 1
# Размер класса 003: 6 фото, для теста выделено файлов: 1
# Размер класса 004: 6 фото, для теста выделено файлов: 1
# Размер класса 005: 6 фото, для теста выделено файлов: 1
# Размер класса 006: 6 фото, для теста выделено файлов: 1
# Размер класса 007: 6 фото, для теста выделено файлов: 1
# Размер класса 008: 6 фото, для теста выделено файлов: 1
# Размер класса 009: 6 фото, для теста выделено файлов: 1
# Размер класса 010: 6 фото, для теста выделено файлов: 1
# Размер класса 011: 6 фото, для теста выделено файлов: 1
# Размер класса 012: 6 фото, для теста выделено файлов: 1
# Размер класса 013: 6 фото, для теста выделено файлов: 1
# Размер класса 014: 6 фото, для теста выделено файлов: 1
# Размер класса 015: 6 фото, для теста выделено файлов: 1
# Размер класса 016: 6 фото, для теста выделено файлов: 1
# Размер класса 017: 6 фото, для теста выделено файлов: 1
# Размер класса 018: 6 фото, для теста выделено файлов: 1
# Размер класса 019: 6 фото, для теста выделено файлов: 1
# Размер класса 020: 6 фото, для теста выделено файлов: 1
# Размер класса 021: 6 фото, для теста выделено файлов: 1
# Размер класса 022: 6 фото, для теста выделено файлов: 1
# Размер класса 023: 6 фото, для теста выделено файлов: 1
# Размер класса 024: 6 фото, для теста выделено файлов: 1
# Размер класса 025: 6 фото, для теста выделено файлов: 1
# Размер класса 026: 6 фото, для теста выделено файлов: 1
# Размер класса 027: 6 фото, для теста выделено файлов: 1
# Размер класса 028: 6 фото, для теста выделено файлов: 1
# Размер класса 029: 6 фото, для теста выделено файлов: 1
# Размер класса 030: 6 фото, для теста выделено файлов: 1
# Размер класса 031: 6 фото, для теста выделено файлов: 1
# Размер класса 032: 6 фото, для теста выделено файлов: 1
# Размер класса 033: 6 фото, для теста выделено файлов: 1
# Размер класса 034: 6 фото, для теста выделено файлов: 1
# Размер класса 035: 6 фото, для теста выделено файлов: 1
# Размер класса 036: 6 фото, для теста выделено файлов: 1
# Размер класса 037: 6 фото, для теста выделено файлов: 1
# Размер класса 038: 6 фото, для теста выделено файлов: 1
# Размер класса 039: 6 фото, для теста выделено файлов: 1
# Размер класса 040: 6 фото, для теста выделено файлов: 1
# Размер класса 041: 6 фото, для теста выделено файлов: 1
# Размер класса 042: 6 фото, для теста выделено файлов: 1
# Размер класса 043: 6 фото, для теста выделено файлов: 1
# Размер класса 044: 6 фото, для теста выделено файлов: 1
# Размер класса 045: 6 фото, для теста выделено файлов: 1
# Размер класса 046: 6 фото, для теста выделено файлов: 1
# Размер класса 047: 6 фото, для теста выделено файлов: 1
# Размер класса 048: 6 фото, для теста выделено файлов: 1
# Размер класса 049: 6 фото, для теста выделено файлов: 1
# Размер класса 050: 6 фото, для теста выделено файлов: 1
# Размер класса 051: 6 фото, для теста выделено файлов: 1
# Размер класса 052: 6 фото, для теста выделено файлов: 1
# Размер класса 053: 6 фото, для теста выделено файлов: 1
# Размер класса 054: 6 фото, для теста выделено файлов: 1
# Размер класса 055: 6 фото, для теста выделено файлов: 1
# Размер класса 056: 6 фото, для теста выделено файлов: 1
# Размер класса 057: 6 фото, для теста выделено файлов: 1
# Размер класса 058: 6 фото, для теста выделено файлов: 1
# Размер класса 059: 6 фото, для теста выделено файлов: 1
# Размер класса 060: 6 фото, для теста выделено файлов: 1
# Размер класса 061: 6 фото, для теста выделено файлов: 1
# Размер класса 062: 6 фото, для теста выделено файлов: 1
# Размер класса 063: 6 фото, для теста выделено файлов: 1
# Размер класса 064: 6 фото, для теста выделено файлов: 1
# Общий размер базы: 384, выделено для обучения: 320, для теста: 64

# %% [markdown]
# ## Сегментация радужки

# %% [markdown]
# Просмотр случайных изображений

# %%
# Просмотр изображения и его параметров
img = cv2.imread('./iris/007/007L_2.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7FA7E970F5E0>

# %%
img.shape
# Out:
# (576, 768, 3)

# %%
'''
  Формулы для практического поиска окружностей на рисунке весьма сложны.
  Учитывая, что рисунок почти квадратный, нужно найти центр рисунка делением
  высоты и ширины пополам. затем выбрать минимальное значение из высоты и ширины
  изменить размер рисунка по минимальной высоте и ширине (resize) и вернуть новое
  изображение 
'''

# обрезка изображения до квадрата
def unwrap_circular_image(image):

  # Берем центр изображения
  height, width = image.shape[:2]
  center_x, center_y = width // 2, height // 2

  # Вычисляем максимальный радиус окружности
  max_radius = min(center_x, center_y)

  return image[center_y - max_radius: center_y + max_radius, center_x - max_radius: center_x + max_radius]

# %%
# перевод из полярной системы координат в декартову
def ring_to_rect(image):

  size = image.shape[0]  # исходное изображение должно быть квадратным

  # здесь бы не помешало вычислить настоящие радиусы радужки и зрачка, но и так неплохо отделяет
  outer_radius = size // 2.25   # это радиус радужки
  inner_radius_factor = 0.3     # а это зрачка

  # Разворачиваем кольцо
  warped = cv2.warpPolar(image, (size, int(size * math.pi)), (size // 2, size // 2), outer_radius, 0)
  # Поворачиваем на 90 градусов
  straightened = cv2.rotate(warped, cv2.ROTATE_90_COUNTERCLOCKWISE)
  # Обрезаем
  cropped = straightened[: int(straightened.shape[0] * (1 - inner_radius_factor)), :]

  return cropped


def resize(image):
  return cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT)).astype('float64')

img = cv2.imread('./iris/022/022L_2.png')
unwrapped_image = unwrap_circular_image(img)
rect_image = ring_to_rect(unwrapped_image)
resized_image = resize(rect_image)

cv2_imshow(img)
cv2_imshow(unwrapped_image)
cv2_imshow(rect_image)
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7FA7E97D7AF0>
# <PIL.Image.Image image mode=RGB size=576x576 at 0x7FA7E97D6C20>
# <PIL.Image.Image image mode=RGB size=1809x403 at 0x7FA7E97D6620>
# <PIL.Image.Image image mode=RGB size=192x144 at 0x7FA7E97D6A40>

# %% [markdown]
# ## Аугментация и формирование выборок

# %%
# кастомная функция предобработки для генератора - после всех аугментаций 
# разворачивает изображение в прямоугольное

def get_iris(image):
  return resize(ring_to_rect(unwrap_circular_image(image)))

# %%
# Генераторы изображений

# Изображения для обучающего набора нормализуются и аугментируются согласно заданным гиперпараметрам
# Далее набор будет разделен на обучающую и проверочную выборку в соотношении VAL_SPLIT
train_datagen = ImageDataGenerator(
                    rescale=1. / 255.,
                    rotation_range=ROTATION_RANGE,
                    #width_shift_range=WIDTH_SHIFT_RANGE,
                    #height_shift_range=HEIGHT_SHIFT_RANGE,
                    #zoom_range=ZOOM_RANGE,
                    brightness_range=BRIGHTNESS_RANGE,
                    #horizontal_flip=HORIZONTAL_FLIP,
                    validation_split=VAL_SPLIT,
                    preprocessing_function = get_iris
                )

# Изображения для тестового набора только нормализуются
test_datagen = ImageDataGenerator(
                   rescale=1. / 255.,
                   preprocessing_function = get_iris
                )

# %%
# Обучающая выборка генерируется из папки обучающего набора
train_generator = train_datagen.flow_from_directory(
    # Путь к обучающим изображениям
    TRAIN_PATH,
    # Параметры требуемого размера изображения
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    # Размер батча
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    # Указание сгенерировать обучающую выборку
    subset='training'
)

# Проверочная выборка также генерируется из папки обучающего набора
validation_generator = train_datagen.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    # Указание сгенерировать проверочную выборку
    subset='validation'
)

# Тестовая выборка генерируется из папки тестового набора
test_generator = test_datagen.flow_from_directory(
    TEST_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=test_count,
    class_mode='categorical',
    shuffle=True,
)
# Out:
# Found 256 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.
# Found 64 images belonging to 64 classes.

# %%
# Проверка формы данных
print(f'Формы данных тренировочной выборки: {train_generator[0][0].shape}, {train_generator[0][1].shape}, батчей: {len(train_generator)}')
print(f'Формы данных   проверочной выборки: {validation_generator[0][0].shape}, {validation_generator[0][1].shape}, батчей: {len(validation_generator)}')
print(f'Формы данных      тестовой выборки: {test_generator[0][0].shape}, {test_generator[0][1].shape}, батчей: {len(test_generator)}')

print()

# Проверка назначения меток классов
print(f'Метки классов тренировочной выборки: {train_generator.class_indices}')
print(f'Метки классов   проверочной выборки: {validation_generator.class_indices}')
print(f'Метки классов      тестовой выборки: {test_generator.class_indices}')
# Out:
# Формы данных тренировочной выборки: (8, 144, 192, 3), (8, 64), батчей: 32
# Формы данных   проверочной выборки: (8, 144, 192, 3), (8, 64), батчей: 8
# Формы данных      тестовой выборки: (64, 144, 192, 3), (64, 64), батчей: 1
#
# Метки классов тренировочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов   проверочной выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}
# Метки классов      тестовой выборки: {'001': 0, '002': 1, '003': 2, '004': 3, '005': 4, '006': 5, '007': 6, '008': 7, '009': 8, '010': 9, '011': 10, '012': 11, '013': 12, '014': 13, '015': 14, '016': 15, '017': 16, '018': 17, '019': 18, '020': 19, '021': 20, '022': 21, '023': 22, '024': 23, '025': 24, '026': 25, '027': 26, '028': 27, '029': 28, '030': 29, '031': 30, '032': 31, '033': 32, '034': 33, '035': 34, '036': 35, '037': 36, '038': 37, '039': 38, '040': 39, '041': 40, '042': 41, '043': 42, '044': 43, '045': 44, '046': 45, '047': 46, '048': 47, '049': 48, '050': 49, '051': 50, '052': 51, '053': 52, '054': 53, '055': 54, '056': 55, '057': 56, '058': 57, '059': 58, '060': 59, '061': 60, '062': 61, '063': 62, '064': 63}

# %%
# Функция рисования образцов изображений из заданной выборки

def show_batch(batch,                # батч с примерами
               img_range=range(20),  # диапазон номеров картинок
               figsize=(25, 8),      # размер полотна для рисования одной строки таблицы
               columns=5             # число колонок в таблице
               ):

    for i in img_range:
        ix = i % columns
        if ix == 0:
            fig, ax = plt.subplots(1, columns, figsize=figsize)
        class_label = np.argmax(batch[1][i])
        ax[ix].set_title(CLASS_LIST[class_label])
        ax[ix].imshow(batch[0][i])  
        ax[ix].axis('off')
        plt.tight_layout()

    plt.show()

# %%
# Вывод примеров из 0-го батча train_generator
show_batch(train_generator[0], range(8), columns = 4)

# %% [markdown]
# ## Создание и обучение модели

# %%
# Функция компиляции и обучения модели нейронной сети
# По окончанию выводит графики обучения

def compile_train_model(model,                  # модель нейронной сети
                        train_data,             # обучающие данные
                        val_data,               # проверочные данные
                        optimizer=OPTIMIZER,    # оптимизатор
                        epochs=EPOCHS,          # количество эпох обучения
                        batch_size=BATCH_SIZE,  # размер батча
                        figsize=(20, 5)):       # размер полотна для графиков

    # Компиляция модели
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

    # Вывод сводки
    model.summary()

    # Обучение модели с заданными параметрами
    history = model.fit(train_data,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=val_data)

    # Вывод графиков точности и ошибки
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'], 
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'], 
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'], 
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'], 
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %%
# Функция вывода результатов оценки модели на заданных данных

def eval_model(model, 
               x,                # данные для предсказания модели (вход)
               y_true,           # верные метки классов в формате OHE (выход)
               class_labels=[],  # список меток классов
               cm_round=3,       # число знаков после запятой для матрицы ошибок
               title='',         # название модели
               figsize=(10, 10)  # размер полотна для матрицы ошибок
               ):
    # Вычисление предсказания сети
    y_pred = model.predict(x)
    # Построение матрицы ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, cm_round)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(f'Нейросеть {title}: матрица ошибок нормализованная', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    ax.images[-1].colorbar.remove()       # Стирание ненужной цветовой шкалы
    fig.autofmt_xdate(rotation=45)        # Наклон меток горизонтальной оси
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    plt.show()    

    print('-'*100)
    print(f'Нейросеть: {title}')

    # Для каждого класса:
    for cls in range(len(class_labels)):
        # Определяется индекс класса с максимальным значением предсказания (уверенности)
        cls_pred = np.argmax(cm[cls])
        # Формируется сообщение о верности или неверности предсказания
        msg = 'ВЕРНО :-)' if cls_pred == cls else 'НЕВЕРНО :-('
        # Выводится текстовая информация о предсказанном классе и значении уверенности
        print('Класс: {:<20} {:3.0f}% сеть отнесла к классу {:<20} - {}'.format(class_labels[cls],
                                                                               100. * cm[cls, cls_pred],
                                                                               class_labels[cls_pred],
                                                                               msg))

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
# Совместная функция обучения и оценки модели нейронной сети

def compile_train_eval_model(model,                    # модель нейронной сети
                             train_data,               # обучающие данные
                             val_data,                 # проверочные данные
                             test_data,                # тестовые данные
                             class_labels=CLASS_LIST,  # список меток классов
                             title='',                 # название модели
                             optimizer=OPTIMIZER,      # оптимизатор
                             epochs=EPOCHS,            # количество эпох обучения
                             batch_size=BATCH_SIZE,    # размер батча
                             graph_size=(20, 5),       # размер полотна для графиков обучения
                             cm_size=(10, 10)          # размер полотна для матрицы ошибок
                             ):

    # Компиляция и обучение модели на заданных параметрах
    # В качестве проверочных используются тестовые данные
    compile_train_model(model, 
                        train_data,
                        val_data,
                        optimizer=optimizer,
                        epochs=epochs,
                        batch_size=batch_size,
                        figsize=graph_size)

    # Вывод результатов оценки работы модели на тестовых данных
    eval_model(model, test_data[0][0], test_data[0][1], 
               class_labels=class_labels, 
               title=title,
               figsize=cm_size)

# %%
# Создание последовательной модели
model_conv = Sequential()

# Первый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)))
model_conv.add(BatchNormalization())

# Второй сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))

# Третий сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())
model_conv.add(Dropout(0.2))

# Четвертый сверточный слой
model_conv.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Пятый сверточный слой
model_conv.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model_conv.add(BatchNormalization())

# Шестой сверточный слой
model_conv.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model_conv.add(MaxPooling2D(pool_size=(3, 3)))
model_conv.add(Dropout(0.2))

# Слой преобразования многомерных данных в одномерные 
model_conv.add(Flatten())

# Промежуточный полносвязный слой
model_conv.add(Dense(2048, activation='relu'))

# Промежуточный полносвязный слой
model_conv.add(Dense(4096, activation='relu'))

# Выходной полносвязный слой с количеством нейронов по количесту классов
model_conv.add(Dense(CLASS_COUNT, activation='softmax'))

# %%
# Обучение модели и вывод оценки ее работы на тестовых данных
compile_train_eval_model(model_conv,
                         train_generator,
                         validation_generator,
                         test_generator,
                         class_labels=CLASS_LIST,
                         title='Сверточный классификатор')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 144, 192, 256)     7168
#
#  batch_normalization (BatchN  (None, 144, 192, 256)    1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 144, 192, 256)     590080
#
#  max_pooling2d (MaxPooling2D  (None, 48, 64, 256)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 48, 64, 256)       590080
#
#  batch_normalization_1 (Batc  (None, 48, 64, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 48, 64, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 48, 64, 256)       590080
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 21, 256)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 21, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 16, 21, 512)       1180160
#
#  batch_normalization_2 (Batc  (None, 16, 21, 512)      2048
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 16, 21, 1024)      4719616
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 7, 1024)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 5, 7, 1024)        0
#
#  flatten (Flatten)           (None, 35840)             0
#
#  dense (Dense)               (None, 2048)              73402368
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  dense_2 (Dense)             (None, 64)                262208
#
# =================================================================
# Total params: 89,738,560
# Trainable params: 89,736,512
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/330
# 32/32 [==============================] - 29s 307ms/step - loss: 7.3184 - accuracy: 0.0391 - val_loss: 4.1878 - val_accuracy: 0.0156
# Epoch 2/330
# 32/32 [==============================] - 10s 301ms/step - loss: 4.0867 - accuracy: 0.0898 - val_loss: 4.2112 - val_accuracy: 0.0156
# Epoch 3/330
# 32/32 [==============================] - 9s 281ms/step - loss: 2.9989 - accuracy: 0.2109 - val_loss: 4.4450 - val_accuracy: 0.0156
# Epoch 4/330
# 32/32 [==============================] - 10s 322ms/step - loss: 2.5498 - accuracy: 0.3047 - val_loss: 4.8449 - val_accuracy: 0.0156
# Epoch 5/330
# 32/32 [==============================] - 10s 300ms/step - loss: 2.3147 - accuracy: 0.3906 - val_loss: 5.1151 - val_accuracy: 0.0156
# Epoch 6/330
# 32/32 [==============================] - 10s 298ms/step - loss: 1.9107 - accuracy: 0.4297 - val_loss: 6.0041 - val_accuracy: 0.0156
# Epoch 7/330
# 32/32 [==============================] - 9s 290ms/step - loss: 1.7311 - accuracy: 0.5156 - val_loss: 5.5686 - val_accuracy: 0.0156
# Epoch 8/330
# 32/32 [==============================] - 10s 293ms/step - loss: 1.4617 - accuracy: 0.5547 - val_loss: 5.5671 - val_accuracy: 0.0156
# Epoch 9/330
# 32/32 [==============================] - 10s 300ms/step - loss: 1.2799 - accuracy: 0.6211 - val_loss: 6.6654 - val_accuracy: 0.0156
# Epoch 10/330
# 32/32 [==============================] - 10s 301ms/step - loss: 1.1233 - accuracy: 0.7109 - val_loss: 5.6997 - val_accuracy: 0.0156
# Epoch 11/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.7631 - accuracy: 0.7812 - val_loss: 5.6249 - val_accuracy: 0.0312
# Epoch 12/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.9972 - accuracy: 0.7188 - val_loss: 7.1427 - val_accuracy: 0.0156
# Epoch 13/330
# 32/32 [==============================] - 10s 313ms/step - loss: 0.6562 - accuracy: 0.7969 - val_loss: 6.6861 - val_accuracy: 0.0156
# Epoch 14/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.5925 - accuracy: 0.8164 - val_loss: 6.8771 - val_accuracy: 0.0469
# Epoch 15/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.5833 - accuracy: 0.8281 - val_loss: 5.9722 - val_accuracy: 0.0469
# Epoch 16/330
# 32/32 [==============================] - 9s 287ms/step - loss: 0.7463 - accuracy: 0.8125 - val_loss: 5.5903 - val_accuracy: 0.0469
# Epoch 17/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.5397 - accuracy: 0.8594 - val_loss: 3.5627 - val_accuracy: 0.1406
# Epoch 18/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.4522 - accuracy: 0.8633 - val_loss: 3.2334 - val_accuracy: 0.2656
# Epoch 19/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.3197 - accuracy: 0.9062 - val_loss: 5.0977 - val_accuracy: 0.1250
# Epoch 20/330
# 32/32 [==============================] - 11s 328ms/step - loss: 0.5019 - accuracy: 0.8594 - val_loss: 2.1183 - val_accuracy: 0.4375
# Epoch 21/330
# 32/32 [==============================] - 9s 288ms/step - loss: 0.3691 - accuracy: 0.8984 - val_loss: 1.9465 - val_accuracy: 0.4531
# Epoch 22/330
# 32/32 [==============================] - 10s 298ms/step - loss: 0.2084 - accuracy: 0.9180 - val_loss: 1.3068 - val_accuracy: 0.6406
# Epoch 23/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.1691 - accuracy: 0.9570 - val_loss: 1.4708 - val_accuracy: 0.6875
# Epoch 24/330
# 32/32 [==============================] - 10s 305ms/step - loss: 0.2589 - accuracy: 0.9180 - val_loss: 1.6509 - val_accuracy: 0.5781
# Epoch 25/330
# 32/32 [==============================] - 10s 295ms/step - loss: 0.3644 - accuracy: 0.8984 - val_loss: 1.3668 - val_accuracy: 0.6875
# Epoch 26/330
# 32/32 [==============================] - 10s 296ms/step - loss: 0.2172 - accuracy: 0.9414 - val_loss: 1.1872 - val_accuracy: 0.7031
# Epoch 27/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.1545 - accuracy: 0.9688 - val_loss: 0.9384 - val_accuracy: 0.7500
# Epoch 28/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.2139 - accuracy: 0.9570 - val_loss: 1.1015 - val_accuracy: 0.7500
# Epoch 29/330
# 32/32 [==============================] - 10s 309ms/step - loss: 0.1576 - accuracy: 0.9570 - val_loss: 1.1147 - val_accuracy: 0.7031
# Epoch 30/330
# 32/32 [==============================] - 9s 291ms/step - loss: 0.2285 - accuracy: 0.9414 - val_loss: 1.6375 - val_accuracy: 0.7031
# Epoch 31/330
# 32/32 [==============================] - 10s 313ms/step - loss: 0.2110 - accuracy: 0.9336 - val_loss: 1.6002 - val_accuracy: 0.6719
# Epoch 32/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.2769 - accuracy: 0.9062 - val_loss: 1.3129 - val_accuracy: 0.6719
# Epoch 33/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.3487 - accuracy: 0.9180 - val_loss: 1.6590 - val_accuracy: 0.7031
# Epoch 34/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.2136 - accuracy: 0.9375 - val_loss: 2.0788 - val_accuracy: 0.7188
# Epoch 35/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.2168 - accuracy: 0.9297 - val_loss: 1.5366 - val_accuracy: 0.7500
# Epoch 36/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1501 - accuracy: 0.9531 - val_loss: 1.1240 - val_accuracy: 0.7500
# Epoch 37/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1848 - accuracy: 0.9648 - val_loss: 1.7993 - val_accuracy: 0.6875
# Epoch 38/330
# 32/32 [==============================] - 10s 305ms/step - loss: 0.2292 - accuracy: 0.9531 - val_loss: 1.7900 - val_accuracy: 0.7500
# Epoch 39/330
# 32/32 [==============================] - 11s 330ms/step - loss: 0.2112 - accuracy: 0.9531 - val_loss: 1.6261 - val_accuracy: 0.7500
# Epoch 40/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.1718 - accuracy: 0.9453 - val_loss: 1.2200 - val_accuracy: 0.7344
# Epoch 41/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.2359 - accuracy: 0.9414 - val_loss: 1.8000 - val_accuracy: 0.7031
# Epoch 42/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.1901 - accuracy: 0.9414 - val_loss: 1.2193 - val_accuracy: 0.7031
# Epoch 43/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.1983 - accuracy: 0.9492 - val_loss: 1.3841 - val_accuracy: 0.7656
# Epoch 44/330
# 32/32 [==============================] - 10s 307ms/step - loss: 0.0867 - accuracy: 0.9727 - val_loss: 0.7642 - val_accuracy: 0.8281
# Epoch 45/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.1902 - accuracy: 0.9375 - val_loss: 2.7715 - val_accuracy: 0.5625
# Epoch 46/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.3735 - accuracy: 0.9375 - val_loss: 1.6281 - val_accuracy: 0.6562
# Epoch 47/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.3060 - accuracy: 0.9219 - val_loss: 1.8173 - val_accuracy: 0.7188
# Epoch 48/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1585 - accuracy: 0.9570 - val_loss: 1.7204 - val_accuracy: 0.6406
# Epoch 49/330
# 32/32 [==============================] - 10s 313ms/step - loss: 0.2191 - accuracy: 0.9375 - val_loss: 1.2769 - val_accuracy: 0.6875
# Epoch 50/330
# 32/32 [==============================] - 10s 295ms/step - loss: 0.1154 - accuracy: 0.9648 - val_loss: 1.3479 - val_accuracy: 0.7344
# Epoch 51/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1401 - accuracy: 0.9570 - val_loss: 1.3957 - val_accuracy: 0.7344
# Epoch 52/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0255 - accuracy: 0.9961 - val_loss: 1.2147 - val_accuracy: 0.7188
# Epoch 53/330
# 32/32 [==============================] - 10s 308ms/step - loss: 0.0488 - accuracy: 0.9922 - val_loss: 0.9706 - val_accuracy: 0.8125
# Epoch 54/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0584 - accuracy: 0.9805 - val_loss: 1.6169 - val_accuracy: 0.7344
# Epoch 55/330
# 32/32 [==============================] - 10s 297ms/step - loss: 0.2288 - accuracy: 0.9492 - val_loss: 1.9417 - val_accuracy: 0.6875
# Epoch 56/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.2280 - accuracy: 0.9375 - val_loss: 3.0689 - val_accuracy: 0.5469
# Epoch 57/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.2150 - accuracy: 0.9609 - val_loss: 2.1691 - val_accuracy: 0.7188
# Epoch 58/330
# 32/32 [==============================] - 10s 308ms/step - loss: 0.2344 - accuracy: 0.9375 - val_loss: 2.1365 - val_accuracy: 0.6406
# Epoch 59/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.1869 - accuracy: 0.9453 - val_loss: 1.3362 - val_accuracy: 0.7188
# Epoch 60/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1508 - accuracy: 0.9766 - val_loss: 1.2838 - val_accuracy: 0.7344
# Epoch 61/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1827 - accuracy: 0.9492 - val_loss: 3.1845 - val_accuracy: 0.5938
# Epoch 62/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1415 - accuracy: 0.9688 - val_loss: 1.8565 - val_accuracy: 0.7344
# Epoch 63/330
# 32/32 [==============================] - 10s 295ms/step - loss: 0.1284 - accuracy: 0.9609 - val_loss: 1.6370 - val_accuracy: 0.7031
# Epoch 64/330
# 32/32 [==============================] - 10s 291ms/step - loss: 0.1372 - accuracy: 0.9688 - val_loss: 1.9439 - val_accuracy: 0.6719
# Epoch 65/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0654 - accuracy: 0.9805 - val_loss: 2.5255 - val_accuracy: 0.7500
# Epoch 66/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0882 - accuracy: 0.9883 - val_loss: 2.2442 - val_accuracy: 0.7344
# Epoch 67/330
# 32/32 [==============================] - 11s 338ms/step - loss: 0.0353 - accuracy: 0.9883 - val_loss: 1.8695 - val_accuracy: 0.7500
# Epoch 68/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0731 - accuracy: 0.9883 - val_loss: 2.0172 - val_accuracy: 0.7344
# Epoch 69/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.4385 - val_accuracy: 0.7656
# Epoch 70/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0268 - accuracy: 0.9883 - val_loss: 1.1567 - val_accuracy: 0.8125
# Epoch 71/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0468 - accuracy: 0.9844 - val_loss: 1.5483 - val_accuracy: 0.7812
# Epoch 72/330
# 32/32 [==============================] - 11s 329ms/step - loss: 0.0290 - accuracy: 0.9883 - val_loss: 1.6191 - val_accuracy: 0.7656
# Epoch 73/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0248 - accuracy: 0.9883 - val_loss: 1.7562 - val_accuracy: 0.8125
# Epoch 74/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.5887 - val_accuracy: 0.7812
# Epoch 75/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0142 - accuracy: 0.9961 - val_loss: 1.3199 - val_accuracy: 0.7812
# Epoch 76/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0183 - accuracy: 0.9922 - val_loss: 1.7932 - val_accuracy: 0.6875
# Epoch 77/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.2858 - accuracy: 0.9297 - val_loss: 2.4908 - val_accuracy: 0.6875
# Epoch 78/330
# 32/32 [==============================] - 10s 306ms/step - loss: 0.3961 - accuracy: 0.9219 - val_loss: 2.9957 - val_accuracy: 0.6250
# Epoch 79/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.2428 - accuracy: 0.9492 - val_loss: 1.5249 - val_accuracy: 0.7656
# Epoch 80/330
# 32/32 [==============================] - 10s 306ms/step - loss: 0.2136 - accuracy: 0.9492 - val_loss: 1.9904 - val_accuracy: 0.7188
# Epoch 81/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.1092 - accuracy: 0.9766 - val_loss: 0.8076 - val_accuracy: 0.7969
# Epoch 82/330
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0250 - accuracy: 0.9922 - val_loss: 1.1973 - val_accuracy: 0.8125
# Epoch 83/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0376 - accuracy: 0.9844 - val_loss: 1.2616 - val_accuracy: 0.7812
# Epoch 84/330
# 32/32 [==============================] - 10s 321ms/step - loss: 0.1829 - accuracy: 0.9609 - val_loss: 1.6877 - val_accuracy: 0.7344
# Epoch 85/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1324 - accuracy: 0.9648 - val_loss: 2.0427 - val_accuracy: 0.7031
# Epoch 86/330
# 32/32 [==============================] - 11s 328ms/step - loss: 0.0832 - accuracy: 0.9805 - val_loss: 1.3418 - val_accuracy: 0.7969
# Epoch 87/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.1898 - accuracy: 0.9766 - val_loss: 2.1268 - val_accuracy: 0.6094
# Epoch 88/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0860 - accuracy: 0.9727 - val_loss: 1.0681 - val_accuracy: 0.7656
# Epoch 89/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.2035 - accuracy: 0.9688 - val_loss: 1.4829 - val_accuracy: 0.8438
# Epoch 90/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0710 - accuracy: 0.9766 - val_loss: 1.2780 - val_accuracy: 0.7969
# Epoch 91/330
# 32/32 [==============================] - 10s 306ms/step - loss: 0.0635 - accuracy: 0.9883 - val_loss: 1.3404 - val_accuracy: 0.8125
# Epoch 92/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0236 - accuracy: 0.9844 - val_loss: 1.3530 - val_accuracy: 0.7812
# Epoch 93/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.1101 - accuracy: 0.9688 - val_loss: 1.7875 - val_accuracy: 0.7031
# Epoch 94/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1080 - accuracy: 0.9805 - val_loss: 1.5530 - val_accuracy: 0.8438
# Epoch 95/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.1174 - accuracy: 0.9883 - val_loss: 2.0362 - val_accuracy: 0.7188
# Epoch 96/330
# 32/32 [==============================] - 11s 329ms/step - loss: 0.0634 - accuracy: 0.9805 - val_loss: 1.7291 - val_accuracy: 0.7969
# Epoch 97/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0233 - accuracy: 0.9922 - val_loss: 1.8492 - val_accuracy: 0.7656
# Epoch 98/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0634 - accuracy: 0.9805 - val_loss: 1.7234 - val_accuracy: 0.7344
# Epoch 99/330
# 32/32 [==============================] - 10s 305ms/step - loss: 0.1013 - accuracy: 0.9844 - val_loss: 1.5255 - val_accuracy: 0.7812
# Epoch 100/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0222 - accuracy: 0.9961 - val_loss: 1.7965 - val_accuracy: 0.7344
# Epoch 101/330
# 32/32 [==============================] - 11s 330ms/step - loss: 0.0679 - accuracy: 0.9844 - val_loss: 1.3504 - val_accuracy: 0.8125
# Epoch 102/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0561 - accuracy: 0.9805 - val_loss: 1.2567 - val_accuracy: 0.7344
# Epoch 103/330
# 32/32 [==============================] - 10s 298ms/step - loss: 0.1003 - accuracy: 0.9766 - val_loss: 1.6145 - val_accuracy: 0.8281
# Epoch 104/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0753 - accuracy: 0.9766 - val_loss: 0.9737 - val_accuracy: 0.8594
# Epoch 105/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1077 - accuracy: 0.9609 - val_loss: 1.3039 - val_accuracy: 0.7812
# Epoch 106/330
# 32/32 [==============================] - 10s 305ms/step - loss: 0.0800 - accuracy: 0.9805 - val_loss: 2.5633 - val_accuracy: 0.6719
# Epoch 107/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.2732 - accuracy: 0.9609 - val_loss: 1.9244 - val_accuracy: 0.7188
# Epoch 108/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.3253 - accuracy: 0.9375 - val_loss: 1.9771 - val_accuracy: 0.5781
# Epoch 109/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.1093 - accuracy: 0.9648 - val_loss: 2.0383 - val_accuracy: 0.7188
# Epoch 110/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0582 - accuracy: 0.9805 - val_loss: 1.9313 - val_accuracy: 0.7344
# Epoch 111/330
# 32/32 [==============================] - 11s 330ms/step - loss: 0.0288 - accuracy: 0.9961 - val_loss: 2.2824 - val_accuracy: 0.6719
# Epoch 112/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0802 - accuracy: 0.9805 - val_loss: 3.6067 - val_accuracy: 0.7188
# Epoch 113/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.2934 - accuracy: 0.9492 - val_loss: 2.9002 - val_accuracy: 0.6094
# Epoch 114/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.1595 - accuracy: 0.9805 - val_loss: 2.1764 - val_accuracy: 0.7188
# Epoch 115/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0915 - accuracy: 0.9883 - val_loss: 1.9131 - val_accuracy: 0.7812
# Epoch 116/330
# 32/32 [==============================] - 11s 330ms/step - loss: 0.0400 - accuracy: 0.9844 - val_loss: 2.0205 - val_accuracy: 0.7031
# Epoch 117/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0171 - accuracy: 0.9961 - val_loss: 1.2649 - val_accuracy: 0.7812
# Epoch 118/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0175 - accuracy: 0.9922 - val_loss: 1.7326 - val_accuracy: 0.7656
# Epoch 119/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0170 - accuracy: 0.9922 - val_loss: 1.1930 - val_accuracy: 0.7969
# Epoch 120/330
# 32/32 [==============================] - 10s 319ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8903 - val_accuracy: 0.8594
# Epoch 121/330
# 32/32 [==============================] - 10s 305ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1811 - val_accuracy: 0.8281
# Epoch 122/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0095 - accuracy: 0.9922 - val_loss: 1.0195 - val_accuracy: 0.8438
# Epoch 123/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2531 - val_accuracy: 0.7812
# Epoch 124/330
# 32/32 [==============================] - 10s 306ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.2135 - val_accuracy: 0.8125
# Epoch 125/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0051 - accuracy: 0.9961 - val_loss: 1.1170 - val_accuracy: 0.8281
# Epoch 126/330
# 32/32 [==============================] - 10s 297ms/step - loss: 2.4639e-04 - accuracy: 1.0000 - val_loss: 0.9874 - val_accuracy: 0.8594
# Epoch 127/330
# 32/32 [==============================] - 10s 292ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7844 - val_accuracy: 0.8750
# Epoch 128/330
# 32/32 [==============================] - 10s 305ms/step - loss: 8.1305e-05 - accuracy: 1.0000 - val_loss: 0.9501 - val_accuracy: 0.8750
# Epoch 129/330
# 32/32 [==============================] - 10s 303ms/step - loss: 1.0838e-04 - accuracy: 1.0000 - val_loss: 0.7594 - val_accuracy: 0.8906
# Epoch 130/330
# 32/32 [==============================] - 10s 303ms/step - loss: 1.3529e-04 - accuracy: 1.0000 - val_loss: 0.7192 - val_accuracy: 0.8594
# Epoch 131/330
# 32/32 [==============================] - 10s 295ms/step - loss: 2.2375e-04 - accuracy: 1.0000 - val_loss: 1.1298 - val_accuracy: 0.8594
# Epoch 132/330
# 32/32 [==============================] - 10s 292ms/step - loss: 1.0530e-04 - accuracy: 1.0000 - val_loss: 0.7448 - val_accuracy: 0.9062
# Epoch 133/330
# 32/32 [==============================] - 10s 303ms/step - loss: 8.6610e-05 - accuracy: 1.0000 - val_loss: 0.7484 - val_accuracy: 0.8281
# Epoch 134/330
# 32/32 [==============================] - 10s 304ms/step - loss: 3.7596e-05 - accuracy: 1.0000 - val_loss: 0.6338 - val_accuracy: 0.8906
# Epoch 135/330
# 32/32 [==============================] - 10s 307ms/step - loss: 1.4559e-04 - accuracy: 1.0000 - val_loss: 0.8583 - val_accuracy: 0.8750
# Epoch 136/330
# 32/32 [==============================] - 10s 301ms/step - loss: 9.9764e-05 - accuracy: 1.0000 - val_loss: 0.8484 - val_accuracy: 0.8906
# Epoch 137/330
# 32/32 [==============================] - 10s 298ms/step - loss: 3.9816e-04 - accuracy: 1.0000 - val_loss: 0.6606 - val_accuracy: 0.9062
# Epoch 138/330
# 32/32 [==============================] - 10s 304ms/step - loss: 6.3843e-06 - accuracy: 1.0000 - val_loss: 1.0114 - val_accuracy: 0.8594
# Epoch 139/330
# 32/32 [==============================] - 10s 321ms/step - loss: 2.2590e-05 - accuracy: 1.0000 - val_loss: 0.7222 - val_accuracy: 0.8750
# Epoch 140/330
# 32/32 [==============================] - 10s 310ms/step - loss: 3.6222e-05 - accuracy: 1.0000 - val_loss: 1.0187 - val_accuracy: 0.8906
# Epoch 141/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.4526 - val_accuracy: 0.8281
# Epoch 142/330
# 32/32 [==============================] - 10s 305ms/step - loss: 3.0571e-04 - accuracy: 1.0000 - val_loss: 1.2145 - val_accuracy: 0.8750
# Epoch 143/330
# 32/32 [==============================] - 10s 303ms/step - loss: 1.6398e-04 - accuracy: 1.0000 - val_loss: 1.0534 - val_accuracy: 0.8906
# Epoch 144/330
# 32/32 [==============================] - 10s 302ms/step - loss: 3.2924e-04 - accuracy: 1.0000 - val_loss: 1.0465 - val_accuracy: 0.9219
# Epoch 145/330
# 32/32 [==============================] - 10s 297ms/step - loss: 2.2398e-04 - accuracy: 1.0000 - val_loss: 1.0195 - val_accuracy: 0.8125
# Epoch 146/330
# 32/32 [==============================] - 10s 294ms/step - loss: 5.6208e-05 - accuracy: 1.0000 - val_loss: 1.0753 - val_accuracy: 0.8750
# Epoch 147/330
# 32/32 [==============================] - 10s 300ms/step - loss: 2.6542e-04 - accuracy: 1.0000 - val_loss: 1.0534 - val_accuracy: 0.8594
# Epoch 148/330
# 32/32 [==============================] - 10s 307ms/step - loss: 1.5352e-04 - accuracy: 1.0000 - val_loss: 0.9507 - val_accuracy: 0.8438
# Epoch 149/330
# 32/32 [==============================] - 10s 307ms/step - loss: 1.6360e-04 - accuracy: 1.0000 - val_loss: 0.9685 - val_accuracy: 0.8594
# Epoch 150/330
# 32/32 [==============================] - 9s 291ms/step - loss: 3.5906e-04 - accuracy: 1.0000 - val_loss: 0.9769 - val_accuracy: 0.8438
# Epoch 151/330
# 32/32 [==============================] - 10s 303ms/step - loss: 5.2748e-05 - accuracy: 1.0000 - val_loss: 0.9866 - val_accuracy: 0.8594
# Epoch 152/330
# 32/32 [==============================] - 10s 305ms/step - loss: 1.1293e-04 - accuracy: 1.0000 - val_loss: 1.0932 - val_accuracy: 0.8750
# Epoch 153/330
# 32/32 [==============================] - 10s 308ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2935 - val_accuracy: 0.8281
# Epoch 154/330
# 32/32 [==============================] - 10s 308ms/step - loss: 4.4069e-05 - accuracy: 1.0000 - val_loss: 0.8530 - val_accuracy: 0.8594
# Epoch 155/330
# 32/32 [==============================] - 9s 291ms/step - loss: 3.8249e-04 - accuracy: 1.0000 - val_loss: 1.0627 - val_accuracy: 0.8281
# Epoch 156/330
# 32/32 [==============================] - 10s 304ms/step - loss: 3.0573e-04 - accuracy: 1.0000 - val_loss: 1.1238 - val_accuracy: 0.8438
# Epoch 157/330
# 32/32 [==============================] - 10s 304ms/step - loss: 5.0310e-05 - accuracy: 1.0000 - val_loss: 1.1470 - val_accuracy: 0.8594
# Epoch 158/330
# 32/32 [==============================] - 11s 327ms/step - loss: 8.7658e-04 - accuracy: 1.0000 - val_loss: 0.9167 - val_accuracy: 0.8438
# Epoch 159/330
# 32/32 [==============================] - 9s 291ms/step - loss: 2.2893e-05 - accuracy: 1.0000 - val_loss: 1.1373 - val_accuracy: 0.8594
# Epoch 160/330
# 32/32 [==============================] - 10s 306ms/step - loss: 7.6270e-05 - accuracy: 1.0000 - val_loss: 1.1161 - val_accuracy: 0.8438
# Epoch 161/330
# 32/32 [==============================] - 10s 308ms/step - loss: 2.1934e-05 - accuracy: 1.0000 - val_loss: 1.2914 - val_accuracy: 0.8750
# Epoch 162/330
# 32/32 [==============================] - 10s 307ms/step - loss: 7.2837e-05 - accuracy: 1.0000 - val_loss: 1.2014 - val_accuracy: 0.8281
# Epoch 163/330
# 32/32 [==============================] - 10s 309ms/step - loss: 3.6223e-05 - accuracy: 1.0000 - val_loss: 0.9901 - val_accuracy: 0.8438
# Epoch 164/330
# 32/32 [==============================] - 9s 293ms/step - loss: 2.2493e-05 - accuracy: 1.0000 - val_loss: 0.9960 - val_accuracy: 0.8906
# Epoch 165/330
# 32/32 [==============================] - 10s 305ms/step - loss: 1.0702e-04 - accuracy: 1.0000 - val_loss: 0.9725 - val_accuracy: 0.8438
# Epoch 166/330
# 32/32 [==============================] - 10s 310ms/step - loss: 1.1929e-04 - accuracy: 1.0000 - val_loss: 1.1198 - val_accuracy: 0.8750
# Epoch 167/330
# 32/32 [==============================] - 10s 306ms/step - loss: 3.6844e-05 - accuracy: 1.0000 - val_loss: 0.9219 - val_accuracy: 0.8594
# Epoch 168/330
# 32/32 [==============================] - 11s 331ms/step - loss: 2.9170e-05 - accuracy: 1.0000 - val_loss: 0.9291 - val_accuracy: 0.8438
# Epoch 169/330
# 32/32 [==============================] - 9s 292ms/step - loss: 7.7866e-05 - accuracy: 1.0000 - val_loss: 1.0039 - val_accuracy: 0.8750
# Epoch 170/330
# 32/32 [==============================] - 10s 308ms/step - loss: 1.9549e-04 - accuracy: 1.0000 - val_loss: 1.1680 - val_accuracy: 0.8125
# Epoch 171/330
# 32/32 [==============================] - 10s 306ms/step - loss: 8.9596e-05 - accuracy: 1.0000 - val_loss: 1.1702 - val_accuracy: 0.8125
# Epoch 172/330
# 32/32 [==============================] - 10s 305ms/step - loss: 3.3108e-04 - accuracy: 1.0000 - val_loss: 1.1633 - val_accuracy: 0.8594
# Epoch 173/330
# 32/32 [==============================] - 10s 302ms/step - loss: 8.6051e-06 - accuracy: 1.0000 - val_loss: 0.9195 - val_accuracy: 0.8750
# Epoch 174/330
# 32/32 [==============================] - 10s 291ms/step - loss: 1.2397e-05 - accuracy: 1.0000 - val_loss: 1.0834 - val_accuracy: 0.8594
# Epoch 175/330
# 32/32 [==============================] - 10s 305ms/step - loss: 3.5244e-05 - accuracy: 1.0000 - val_loss: 1.3700 - val_accuracy: 0.8125
# Epoch 176/330
# 32/32 [==============================] - 10s 305ms/step - loss: 2.2122e-05 - accuracy: 1.0000 - val_loss: 1.0638 - val_accuracy: 0.8594
# Epoch 177/330
# 32/32 [==============================] - 10s 316ms/step - loss: 1.5681e-05 - accuracy: 1.0000 - val_loss: 0.9258 - val_accuracy: 0.8906
# Epoch 178/330
# 32/32 [==============================] - 10s 301ms/step - loss: 1.7638e-04 - accuracy: 1.0000 - val_loss: 0.9974 - val_accuracy: 0.8594
# Epoch 179/330
# 32/32 [==============================] - 10s 298ms/step - loss: 9.4218e-06 - accuracy: 1.0000 - val_loss: 0.8768 - val_accuracy: 0.8750
# Epoch 180/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0159 - val_accuracy: 0.8750
# Epoch 181/330
# 32/32 [==============================] - 10s 305ms/step - loss: 0.0029 - accuracy: 0.9961 - val_loss: 1.0079 - val_accuracy: 0.8438
# Epoch 182/330
# 32/32 [==============================] - 10s 307ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3509 - val_accuracy: 0.8594
# Epoch 183/330
# 32/32 [==============================] - 11s 330ms/step - loss: 1.3440e-04 - accuracy: 1.0000 - val_loss: 1.3511 - val_accuracy: 0.8125
# Epoch 184/330
# 32/32 [==============================] - 10s 303ms/step - loss: 1.6844e-05 - accuracy: 1.0000 - val_loss: 0.8291 - val_accuracy: 0.8906
# Epoch 185/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.5930 - val_accuracy: 0.7969
# Epoch 186/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.2363 - accuracy: 0.9609 - val_loss: 2.8277 - val_accuracy: 0.7344
# Epoch 187/330
# 32/32 [==============================] - 11s 329ms/step - loss: 1.3184 - accuracy: 0.7969 - val_loss: 10.1710 - val_accuracy: 0.2031
# Epoch 188/330
# 32/32 [==============================] - 10s 299ms/step - loss: 1.0049 - accuracy: 0.7773 - val_loss: 10.2505 - val_accuracy: 0.3906
# Epoch 189/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.3669 - accuracy: 0.9219 - val_loss: 3.3727 - val_accuracy: 0.6562
# Epoch 190/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.1861 - accuracy: 0.9414 - val_loss: 2.5674 - val_accuracy: 0.7031
# Epoch 191/330
# 32/32 [==============================] - 10s 305ms/step - loss: 0.1720 - accuracy: 0.9766 - val_loss: 2.8665 - val_accuracy: 0.6562
# Epoch 192/330
# 32/32 [==============================] - 9s 287ms/step - loss: 0.0324 - accuracy: 0.9961 - val_loss: 1.9133 - val_accuracy: 0.8281
# Epoch 193/330
# 32/32 [==============================] - 10s 307ms/step - loss: 0.0583 - accuracy: 0.9844 - val_loss: 1.6166 - val_accuracy: 0.7812
# Epoch 194/330
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0352 - accuracy: 0.9844 - val_loss: 1.8463 - val_accuracy: 0.8125
# Epoch 195/330
# 32/32 [==============================] - 11s 335ms/step - loss: 0.2424 - accuracy: 0.9609 - val_loss: 1.9643 - val_accuracy: 0.7656
# Epoch 196/330
# 32/32 [==============================] - 10s 295ms/step - loss: 0.1402 - accuracy: 0.9727 - val_loss: 1.7284 - val_accuracy: 0.7188
# Epoch 197/330
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0377 - accuracy: 0.9883 - val_loss: 2.0075 - val_accuracy: 0.7344
# Epoch 198/330
# 32/32 [==============================] - 11s 328ms/step - loss: 0.0528 - accuracy: 0.9922 - val_loss: 1.7640 - val_accuracy: 0.8125
# Epoch 199/330
# 32/32 [==============================] - 11s 328ms/step - loss: 0.0183 - accuracy: 0.9961 - val_loss: 1.5598 - val_accuracy: 0.8125
# Epoch 200/330
# 32/32 [==============================] - 9s 288ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.5794 - val_accuracy: 0.8125
# Epoch 201/330
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0305 - accuracy: 0.9961 - val_loss: 1.7091 - val_accuracy: 0.7344
# Epoch 202/330
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0193 - accuracy: 0.9922 - val_loss: 1.7924 - val_accuracy: 0.7812
# Epoch 203/330
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0090 - accuracy: 0.9922 - val_loss: 1.7763 - val_accuracy: 0.8281
# Epoch 204/330
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2485 - val_accuracy: 0.8281
# Epoch 205/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0059 - accuracy: 0.9961 - val_loss: 1.9856 - val_accuracy: 0.7812
# Epoch 206/330
# 32/32 [==============================] - 9s 292ms/step - loss: 0.1470 - accuracy: 0.9922 - val_loss: 2.3482 - val_accuracy: 0.7812
# Epoch 207/330
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1297 - accuracy: 0.9570 - val_loss: 1.6056 - val_accuracy: 0.8125
# Epoch 208/330
# 32/32 [==============================] - 10s 293ms/step - loss: 0.0161 - accuracy: 0.9961 - val_loss: 1.1529 - val_accuracy: 0.8281
# Epoch 209/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0681 - accuracy: 0.9961 - val_loss: 1.6429 - val_accuracy: 0.8281
# Epoch 210/330
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0252 - accuracy: 0.9922 - val_loss: 1.0788 - val_accuracy: 0.8125
# Epoch 211/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0190 - accuracy: 0.9961 - val_loss: 1.9903 - val_accuracy: 0.8125
# Epoch 212/330
# 32/32 [==============================] - 10s 320ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 1.0666 - val_accuracy: 0.8594
# Epoch 213/330
# 32/32 [==============================] - 9s 289ms/step - loss: 0.0492 - accuracy: 0.9961 - val_loss: 1.1922 - val_accuracy: 0.8281
# Epoch 214/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.3871 - val_accuracy: 0.8125
# Epoch 215/330
# 32/32 [==============================] - 10s 300ms/step - loss: 7.8955e-04 - accuracy: 1.0000 - val_loss: 1.0418 - val_accuracy: 0.8594
# Epoch 216/330
# 32/32 [==============================] - 10s 300ms/step - loss: 7.5270e-04 - accuracy: 1.0000 - val_loss: 1.1536 - val_accuracy: 0.8750
# Epoch 217/330
# 32/32 [==============================] - 10s 301ms/step - loss: 6.9293e-04 - accuracy: 1.0000 - val_loss: 1.1827 - val_accuracy: 0.8594
# Epoch 218/330
# 32/32 [==============================] - 10s 306ms/step - loss: 2.7269e-04 - accuracy: 1.0000 - val_loss: 1.0466 - val_accuracy: 0.8438
# Epoch 219/330
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1506 - accuracy: 0.9805 - val_loss: 1.6317 - val_accuracy: 0.7500
# Epoch 220/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.1968 - accuracy: 0.9688 - val_loss: 2.0696 - val_accuracy: 0.7969
# Epoch 221/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.2514 - val_accuracy: 0.7500
# Epoch 222/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0271 - val_accuracy: 0.8125
# Epoch 223/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0951 - accuracy: 0.9805 - val_loss: 1.1050 - val_accuracy: 0.8281
# Epoch 224/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0188 - accuracy: 0.9961 - val_loss: 1.4821 - val_accuracy: 0.7656
# Epoch 225/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0220 - accuracy: 0.9922 - val_loss: 1.6665 - val_accuracy: 0.7969
# Epoch 226/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0065 - accuracy: 0.9961 - val_loss: 1.2982 - val_accuracy: 0.8281
# Epoch 227/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0343 - accuracy: 0.9922 - val_loss: 1.3187 - val_accuracy: 0.8125
# Epoch 228/330
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 1.9302 - val_accuracy: 0.7500
# Epoch 229/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0102 - accuracy: 0.9961 - val_loss: 1.6675 - val_accuracy: 0.7500
# Epoch 230/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.4655 - val_accuracy: 0.8281
# Epoch 231/330
# 32/32 [==============================] - 10s 316ms/step - loss: 7.5644e-04 - accuracy: 1.0000 - val_loss: 1.7658 - val_accuracy: 0.8281
# Epoch 232/330
# 32/32 [==============================] - 9s 290ms/step - loss: 5.5424e-04 - accuracy: 1.0000 - val_loss: 1.3139 - val_accuracy: 0.8281
# Epoch 233/330
# 32/32 [==============================] - 10s 297ms/step - loss: 4.2229e-05 - accuracy: 1.0000 - val_loss: 1.3756 - val_accuracy: 0.8438
# Epoch 234/330
# 32/32 [==============================] - 10s 300ms/step - loss: 4.1517e-04 - accuracy: 1.0000 - val_loss: 1.2060 - val_accuracy: 0.8750
# Epoch 235/330
# 32/32 [==============================] - 10s 301ms/step - loss: 9.6552e-04 - accuracy: 1.0000 - val_loss: 1.2718 - val_accuracy: 0.8125
# Epoch 236/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0448 - accuracy: 0.9883 - val_loss: 1.7803 - val_accuracy: 0.7344
# Epoch 237/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0668 - accuracy: 0.9883 - val_loss: 0.8925 - val_accuracy: 0.8281
# Epoch 238/330
# 32/32 [==============================] - 9s 291ms/step - loss: 0.1054 - accuracy: 0.9844 - val_loss: 1.6956 - val_accuracy: 0.7500
# Epoch 239/330
# 32/32 [==============================] - 10s 296ms/step - loss: 0.2228 - accuracy: 0.9727 - val_loss: 1.6685 - val_accuracy: 0.7969
# Epoch 240/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.1863 - accuracy: 0.9688 - val_loss: 3.0500 - val_accuracy: 0.5781
# Epoch 241/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.1686 - accuracy: 0.9414 - val_loss: 1.4150 - val_accuracy: 0.8594
# Epoch 242/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0417 - accuracy: 0.9922 - val_loss: 1.9908 - val_accuracy: 0.8125
# Epoch 243/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1270 - accuracy: 0.9727 - val_loss: 1.8815 - val_accuracy: 0.7969
# Epoch 244/330
# 32/32 [==============================] - 11s 331ms/step - loss: 0.0821 - accuracy: 0.9844 - val_loss: 1.3480 - val_accuracy: 0.7656
# Epoch 245/330
# 32/32 [==============================] - 10s 289ms/step - loss: 0.0373 - accuracy: 0.9961 - val_loss: 1.2221 - val_accuracy: 0.8438
# Epoch 246/330
# 32/32 [==============================] - 10s 297ms/step - loss: 0.0316 - accuracy: 0.9922 - val_loss: 1.4099 - val_accuracy: 0.7969
# Epoch 247/330
# 32/32 [==============================] - 10s 298ms/step - loss: 0.0185 - accuracy: 0.9961 - val_loss: 1.2263 - val_accuracy: 0.8281
# Epoch 248/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0087 - accuracy: 0.9961 - val_loss: 1.6491 - val_accuracy: 0.7344
# Epoch 249/330
# 32/32 [==============================] - 10s 312ms/step - loss: 0.0515 - accuracy: 0.9922 - val_loss: 1.5462 - val_accuracy: 0.7812
# Epoch 250/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0855 - accuracy: 0.9922 - val_loss: 1.2401 - val_accuracy: 0.7812
# Epoch 251/330
# 32/32 [==============================] - 9s 290ms/step - loss: 0.0076 - accuracy: 0.9961 - val_loss: 1.3490 - val_accuracy: 0.7656
# Epoch 252/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.5366 - val_accuracy: 0.7812
# Epoch 253/330
# 32/32 [==============================] - 10s 300ms/step - loss: 8.8732e-04 - accuracy: 1.0000 - val_loss: 1.4628 - val_accuracy: 0.7969
# Epoch 254/330
# 32/32 [==============================] - 10s 300ms/step - loss: 1.4954e-04 - accuracy: 1.0000 - val_loss: 1.3365 - val_accuracy: 0.8281
# Epoch 255/330
# 32/32 [==============================] - 10s 304ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.4232 - val_accuracy: 0.8281
# Epoch 256/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.0138 - accuracy: 0.9922 - val_loss: 1.6313 - val_accuracy: 0.7656
# Epoch 257/330
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0216 - accuracy: 0.9961 - val_loss: 1.3330 - val_accuracy: 0.8125
# Epoch 258/330
# 32/32 [==============================] - 9s 291ms/step - loss: 0.0065 - accuracy: 0.9961 - val_loss: 1.0470 - val_accuracy: 0.8125
# Epoch 259/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1314 - val_accuracy: 0.7969
# Epoch 260/330
# 32/32 [==============================] - 10s 301ms/step - loss: 6.0263e-04 - accuracy: 1.0000 - val_loss: 1.5242 - val_accuracy: 0.8281
# Epoch 261/330
# 32/32 [==============================] - 10s 301ms/step - loss: 5.4505e-04 - accuracy: 1.0000 - val_loss: 1.4077 - val_accuracy: 0.7656
# Epoch 262/330
# 32/32 [==============================] - 10s 299ms/step - loss: 2.7214e-04 - accuracy: 1.0000 - val_loss: 1.2592 - val_accuracy: 0.7969
# Epoch 263/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9940 - val_accuracy: 0.8125
# Epoch 264/330
# 32/32 [==============================] - 9s 290ms/step - loss: 4.3916e-05 - accuracy: 1.0000 - val_loss: 1.1130 - val_accuracy: 0.8125
# Epoch 265/330
# 32/32 [==============================] - 10s 293ms/step - loss: 9.7044e-06 - accuracy: 1.0000 - val_loss: 1.2254 - val_accuracy: 0.7969
# Epoch 266/330
# 32/32 [==============================] - 10s 300ms/step - loss: 1.0479e-04 - accuracy: 1.0000 - val_loss: 1.4234 - val_accuracy: 0.7812
# Epoch 267/330
# 32/32 [==============================] - 10s 302ms/step - loss: 3.3954e-05 - accuracy: 1.0000 - val_loss: 1.2279 - val_accuracy: 0.8125
# Epoch 268/330
# 32/32 [==============================] - 10s 308ms/step - loss: 1.5381e-05 - accuracy: 1.0000 - val_loss: 1.1655 - val_accuracy: 0.8438
# Epoch 269/330
# 32/32 [==============================] - 10s 300ms/step - loss: 3.0172e-04 - accuracy: 1.0000 - val_loss: 1.2473 - val_accuracy: 0.8438
# Epoch 270/330
# 32/32 [==============================] - 10s 302ms/step - loss: 9.4721e-05 - accuracy: 1.0000 - val_loss: 1.3183 - val_accuracy: 0.8438
# Epoch 271/330
# 32/32 [==============================] - 9s 291ms/step - loss: 5.3252e-04 - accuracy: 1.0000 - val_loss: 1.0236 - val_accuracy: 0.8438
# Epoch 272/330
# 32/32 [==============================] - 9s 291ms/step - loss: 2.7349e-04 - accuracy: 1.0000 - val_loss: 1.3354 - val_accuracy: 0.7969
# Epoch 273/330
# 32/32 [==============================] - 10s 299ms/step - loss: 1.7358e-04 - accuracy: 1.0000 - val_loss: 1.1517 - val_accuracy: 0.8750
# Epoch 274/330
# 32/32 [==============================] - 10s 298ms/step - loss: 7.6598e-06 - accuracy: 1.0000 - val_loss: 1.6552 - val_accuracy: 0.7500
# Epoch 275/330
# 32/32 [==============================] - 10s 299ms/step - loss: 3.7454e-05 - accuracy: 1.0000 - val_loss: 1.3712 - val_accuracy: 0.7969
# Epoch 276/330
# 32/32 [==============================] - 10s 301ms/step - loss: 1.8025e-04 - accuracy: 1.0000 - val_loss: 1.0644 - val_accuracy: 0.8281
# Epoch 277/330
# 32/32 [==============================] - 10s 304ms/step - loss: 7.2142e-05 - accuracy: 1.0000 - val_loss: 0.7610 - val_accuracy: 0.8594
# Epoch 278/330
# 32/32 [==============================] - 9s 291ms/step - loss: 1.2092e-05 - accuracy: 1.0000 - val_loss: 1.1700 - val_accuracy: 0.7969
# Epoch 279/330
# 32/32 [==============================] - 10s 299ms/step - loss: 1.0106e-05 - accuracy: 1.0000 - val_loss: 1.5060 - val_accuracy: 0.8281
# Epoch 280/330
# 32/32 [==============================] - 10s 303ms/step - loss: 7.1846e-06 - accuracy: 1.0000 - val_loss: 1.2987 - val_accuracy: 0.7969
# Epoch 281/330
# 32/32 [==============================] - 10s 299ms/step - loss: 2.3643e-05 - accuracy: 1.0000 - val_loss: 1.0112 - val_accuracy: 0.8750
# Epoch 282/330
# 32/32 [==============================] - 10s 298ms/step - loss: 1.3765e-04 - accuracy: 1.0000 - val_loss: 1.0978 - val_accuracy: 0.8906
# Epoch 283/330
# 32/32 [==============================] - 10s 305ms/step - loss: 7.0692e-06 - accuracy: 1.0000 - val_loss: 0.8806 - val_accuracy: 0.8594
# Epoch 284/330
# 32/32 [==============================] - 9s 292ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1227 - val_accuracy: 0.7812
# Epoch 285/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0250 - accuracy: 0.9961 - val_loss: 2.0451 - val_accuracy: 0.7656
# Epoch 286/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.1329 - accuracy: 0.9805 - val_loss: 2.1249 - val_accuracy: 0.6719
# Epoch 287/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.1245 - accuracy: 0.9727 - val_loss: 3.0872 - val_accuracy: 0.7031
# Epoch 288/330
# 32/32 [==============================] - 10s 310ms/step - loss: 0.2586 - accuracy: 0.9531 - val_loss: 2.8198 - val_accuracy: 0.7188
# Epoch 289/330
# 32/32 [==============================] - 10s 302ms/step - loss: 0.2699 - accuracy: 0.9531 - val_loss: 2.5087 - val_accuracy: 0.7031
# Epoch 290/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.3006 - accuracy: 0.9570 - val_loss: 4.6969 - val_accuracy: 0.5625
# Epoch 291/330
# 32/32 [==============================] - 10s 294ms/step - loss: 0.1050 - accuracy: 0.9766 - val_loss: 3.4684 - val_accuracy: 0.6719
# Epoch 292/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 1.2091 - val_accuracy: 0.8281
# Epoch 293/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1190 - accuracy: 0.9648 - val_loss: 1.1447 - val_accuracy: 0.7969
# Epoch 294/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0745 - accuracy: 0.9727 - val_loss: 2.0026 - val_accuracy: 0.6875
# Epoch 295/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1309 - accuracy: 0.9766 - val_loss: 1.3187 - val_accuracy: 0.8125
# Epoch 296/330
# 32/32 [==============================] - 10s 296ms/step - loss: 0.0242 - accuracy: 0.9883 - val_loss: 0.9458 - val_accuracy: 0.8438
# Epoch 297/330
# 32/32 [==============================] - 10s 295ms/step - loss: 0.0734 - accuracy: 0.9805 - val_loss: 1.8712 - val_accuracy: 0.7500
# Epoch 298/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0828 - accuracy: 0.9805 - val_loss: 1.3959 - val_accuracy: 0.7812
# Epoch 299/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0923 - accuracy: 0.9883 - val_loss: 1.7993 - val_accuracy: 0.7656
# Epoch 300/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.2180 - accuracy: 0.9766 - val_loss: 1.2486 - val_accuracy: 0.8125
# Epoch 301/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0495 - accuracy: 0.9805 - val_loss: 3.1037 - val_accuracy: 0.7344
# Epoch 302/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.2826 - accuracy: 0.9531 - val_loss: 1.3862 - val_accuracy: 0.7344
# Epoch 303/330
# 32/32 [==============================] - 10s 292ms/step - loss: 0.1222 - accuracy: 0.9727 - val_loss: 2.4842 - val_accuracy: 0.7188
# Epoch 304/330
# 32/32 [==============================] - 10s 298ms/step - loss: 0.1634 - accuracy: 0.9688 - val_loss: 2.0062 - val_accuracy: 0.6875
# Epoch 305/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.1617 - accuracy: 0.9766 - val_loss: 1.7928 - val_accuracy: 0.7656
# Epoch 306/330
# 32/32 [==============================] - 10s 303ms/step - loss: 0.0054 - accuracy: 0.9961 - val_loss: 1.7707 - val_accuracy: 0.7812
# Epoch 307/330
# 32/32 [==============================] - 10s 301ms/step - loss: 0.0202 - accuracy: 0.9883 - val_loss: 1.7188 - val_accuracy: 0.7656
# Epoch 308/330
# 32/32 [==============================] - 10s 310ms/step - loss: 0.1244 - accuracy: 0.9922 - val_loss: 1.3656 - val_accuracy: 0.8281
# Epoch 309/330
# 32/32 [==============================] - 10s 294ms/step - loss: 0.0163 - accuracy: 0.9922 - val_loss: 1.2588 - val_accuracy: 0.9219
# Epoch 310/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0149 - accuracy: 0.9961 - val_loss: 2.8713 - val_accuracy: 0.6875
# Epoch 311/330
# 32/32 [==============================] - 10s 299ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 1.4141 - val_accuracy: 0.8750
# Epoch 312/330
# 32/32 [==============================] - 10s 300ms/step - loss: 7.3537e-04 - accuracy: 1.0000 - val_loss: 1.0680 - val_accuracy: 0.8750
# Epoch 313/330
# 32/32 [==============================] - 10s 300ms/step - loss: 3.3928e-04 - accuracy: 1.0000 - val_loss: 1.4426 - val_accuracy: 0.8281
# Epoch 314/330
# 32/32 [==============================] - 10s 301ms/step - loss: 1.0006e-04 - accuracy: 1.0000 - val_loss: 1.6054 - val_accuracy: 0.8438
# Epoch 315/330
# 32/32 [==============================] - 11s 332ms/step - loss: 7.1840e-04 - accuracy: 1.0000 - val_loss: 1.0327 - val_accuracy: 0.8594
# Epoch 316/330
# 32/32 [==============================] - 11s 331ms/step - loss: 1.5804e-04 - accuracy: 1.0000 - val_loss: 1.3365 - val_accuracy: 0.8594
# Epoch 317/330
# 32/32 [==============================] - 10s 294ms/step - loss: 1.4704e-04 - accuracy: 1.0000 - val_loss: 1.3361 - val_accuracy: 0.9062
# Epoch 318/330
# 32/32 [==============================] - 10s 298ms/step - loss: 9.4357e-05 - accuracy: 1.0000 - val_loss: 1.1797 - val_accuracy: 0.8906
# Epoch 319/330
# 32/32 [==============================] - 10s 300ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1208 - val_accuracy: 0.9062
# Epoch 320/330
# 32/32 [==============================] - 10s 301ms/step - loss: 1.9494e-04 - accuracy: 1.0000 - val_loss: 1.5587 - val_accuracy: 0.8281
# Epoch 321/330
# 32/32 [==============================] - 10s 298ms/step - loss: 2.7823e-05 - accuracy: 1.0000 - val_loss: 1.6686 - val_accuracy: 0.8438
# Epoch 322/330
# 32/32 [==============================] - 10s 304ms/step - loss: 3.1150e-04 - accuracy: 1.0000 - val_loss: 1.1824 - val_accuracy: 0.8906
# Epoch 323/330
# 32/32 [==============================] - 9s 289ms/step - loss: 6.9804e-05 - accuracy: 1.0000 - val_loss: 1.3124 - val_accuracy: 0.8906
# Epoch 324/330
# 32/32 [==============================] - 10s 302ms/step - loss: 3.4261e-05 - accuracy: 1.0000 - val_loss: 1.2469 - val_accuracy: 0.8906
# Epoch 325/330
# 32/32 [==============================] - 10s 298ms/step - loss: 6.1203e-05 - accuracy: 1.0000 - val_loss: 1.0313 - val_accuracy: 0.8906
# Epoch 326/330
# 32/32 [==============================] - 10s 310ms/step - loss: 5.4224e-05 - accuracy: 1.0000 - val_loss: 1.0755 - val_accuracy: 0.9375
# Epoch 327/330
# 32/32 [==============================] - 10s 300ms/step - loss: 2.1955e-04 - accuracy: 1.0000 - val_loss: 0.9245 - val_accuracy: 0.8906
# Epoch 328/330
# 32/32 [==============================] - 10s 306ms/step - loss: 8.4395e-06 - accuracy: 1.0000 - val_loss: 1.2326 - val_accuracy: 0.9219
# Epoch 329/330
# 32/32 [==============================] - 9s 293ms/step - loss: 9.0621e-06 - accuracy: 1.0000 - val_loss: 1.0490 - val_accuracy: 0.8750
# Epoch 330/330
# 32/32 [==============================] - 10s 302ms/step - loss: 2.0211e-06 - accuracy: 1.0000 - val_loss: 1.0081 - val_accuracy: 0.9219
# 2/2 [==============================] - 6s 16ms/step
# ----------------------------------------------------------------------------------------------------
# Нейросеть: Сверточный классификатор
# Класс: 001                  100% сеть отнесла к классу 001                  - ВЕРНО :-)
# Класс: 002                  100% сеть отнесла к классу 002                  - ВЕРНО :-)
# Класс: 003                  100% сеть отнесла к классу 003                  - ВЕРНО :-)
# Класс: 004                  100% сеть отнесла к классу 004                  - ВЕРНО :-)
# Класс: 005                  100% сеть отнесла к классу 005                  - ВЕРНО :-)
# Класс: 006                  100% сеть отнесла к классу 006                  - ВЕРНО :-)
# Класс: 007                  100% сеть отнесла к классу 007                  - ВЕРНО :-)
# Класс: 008                  100% сеть отнесла к классу 008                  - ВЕРНО :-)
# Класс: 009                  100% сеть отнесла к классу 009                  - ВЕРНО :-)
# Класс: 010                  100% сеть отнесла к классу 010                  - ВЕРНО :-)
# Класс: 011                  100% сеть отнесла к классу 011                  - ВЕРНО :-)
# Класс: 012                  100% сеть отнесла к классу 012                  - ВЕРНО :-)
# Класс: 013                  100% сеть отнесла к классу 013                  - ВЕРНО :-)
# Класс: 014                  100% сеть отнесла к классу 014                  - ВЕРНО :-)
# Класс: 015                  100% сеть отнесла к классу 015                  - ВЕРНО :-)
# Класс: 016                  100% сеть отнесла к классу 016                  - ВЕРНО :-)
# Класс: 017                  100% сеть отнесла к классу 017                  - ВЕРНО :-)
# Класс: 018                  100% сеть отнесла к классу 018                  - ВЕРНО :-)
# Класс: 019                  100% сеть отнесла к классу 043                  - НЕВЕРНО :-(
# Класс: 020                  100% сеть отнесла к классу 020                  - ВЕРНО :-)
# Класс: 021                  100% сеть отнесла к классу 021                  - ВЕРНО :-)
# Класс: 022                  100% сеть отнесла к классу 022                  - ВЕРНО :-)
# Класс: 023                  100% сеть отнесла к классу 023                  - ВЕРНО :-)
# Класс: 024                  100% сеть отнесла к классу 024                  - ВЕРНО :-)
# Класс: 025                  100% сеть отнесла к классу 025                  - ВЕРНО :-)
# Класс: 026                  100% сеть отнесла к классу 026                  - ВЕРНО :-)
# Класс: 027                  100% сеть отнесла к классу 027                  - ВЕРНО :-)
# Класс: 028                  100% сеть отнесла к классу 028                  - ВЕРНО :-)
# Класс: 029                  100% сеть отнесла к классу 029                  - ВЕРНО :-)
# Класс: 030                  100% сеть отнесла к классу 039                  - НЕВЕРНО :-(
# Класс: 031                  100% сеть отнесла к классу 031                  - ВЕРНО :-)
# Класс: 032                  100% сеть отнесла к классу 032                  - ВЕРНО :-)
# Класс: 033                  100% сеть отнесла к классу 033                  - ВЕРНО :-)
# Класс: 034                  100% сеть отнесла к классу 034                  - ВЕРНО :-)
# Класс: 035                  100% сеть отнесла к классу 035                  - ВЕРНО :-)
# Класс: 036                  100% сеть отнесла к классу 036                  - ВЕРНО :-)
# Класс: 037                  100% сеть отнесла к классу 037                  - ВЕРНО :-)
# Класс: 038                  100% сеть отнесла к классу 038                  - ВЕРНО :-)
# Класс: 039                  100% сеть отнесла к классу 039                  - ВЕРНО :-)
# Класс: 040                  100% сеть отнесла к классу 040                  - ВЕРНО :-)
# Класс: 041                  100% сеть отнесла к классу 041                  - ВЕРНО :-)
# Класс: 042                  100% сеть отнесла к классу 042                  - ВЕРНО :-)
# Класс: 043                  100% сеть отнесла к классу 043                  - ВЕРНО :-)
# Класс: 044                  100% сеть отнесла к классу 055                  - НЕВЕРНО :-(
# Класс: 045                  100% сеть отнесла к классу 045                  - ВЕРНО :-)
# Класс: 046                  100% сеть отнесла к классу 046                  - ВЕРНО :-)
# Класс: 047                  100% сеть отнесла к классу 047                  - ВЕРНО :-)
# Класс: 048                  100% сеть отнесла к классу 048                  - ВЕРНО :-)
# Класс: 049                  100% сеть отнесла к классу 049                  - ВЕРНО :-)
# Класс: 050                  100% сеть отнесла к классу 050                  - ВЕРНО :-)
# Класс: 051                  100% сеть отнесла к классу 051                  - ВЕРНО :-)
# Класс: 052                  100% сеть отнесла к классу 052                  - ВЕРНО :-)
# Класс: 053                  100% сеть отнесла к классу 053                  - ВЕРНО :-)
# Класс: 054                  100% сеть отнесла к классу 054                  - ВЕРНО :-)
# Класс: 055                  100% сеть отнесла к классу 055                  - ВЕРНО :-)
# Класс: 056                  100% сеть отнесла к классу 056                  - ВЕРНО :-)
# Класс: 057                  100% сеть отнесла к классу 057                  - ВЕРНО :-)
# Класс: 058                  100% сеть отнесла к классу 058                  - ВЕРНО :-)
# Класс: 059                  100% сеть отнесла к классу 059                  - ВЕРНО :-)
# Класс: 060                  100% сеть отнесла к классу 060                  - ВЕРНО :-)
# Класс: 061                  100% сеть отнесла к классу 061                  - ВЕРНО :-)
# Класс: 062                  100% сеть отнесла к классу 062                  - ВЕРНО :-)
# Класс: 063                  100% сеть отнесла к классу 036                  - НЕВЕРНО :-(
# Класс: 064                  100% сеть отнесла к классу 064                  - ВЕРНО :-)
#
# Средняя точность распознавания:  94%

# %% [markdown]
# Количество объектов 64. Средняя точность распознавания: 84%.
# При втором проходе с немного уменьшенными параметрами аугментации по яркости точность распознавания увеличиласьдо 94%. Время выполнения 34, 5 минуты.
